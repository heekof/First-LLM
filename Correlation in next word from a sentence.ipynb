# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download the stopwords dataset
#nltk.download('stopwords')
#nltk.download('punkt')  # For tokenization

# Example text
text = "This is an example sentence to demonstrate removing stopwords."

# Tokenize the text
words = word_tokenize(text)

# Get the list of English stopwords
stop_words = set(stopwords.words('english'))

# Remove stopwords from the tokenized words list
filtered_words = [word for word in words if word.lower() not in stop_words]

# Reconstruct the text without stopwords
filtered_text = ' '.join(filtered_words)

print(filtered_text)
# Out:
# example sentence demonstrate removing stopwords .

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
import torch
from collections import Counter
import random
import re
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import spacy

# Load the SpaCy model
nlp = spacy.load("en_core_web_sm")


def remove_words_in_parentheses(text):
    """
    
    """
    pattern = (r"\s?\(.*?\)\s?")
    return re.sub(pattern," ",text)

def remove_citations(text):
    pattern = r"\[\d+]"
    cleaned_text = re.sub(pattern, "", text)    
    return cleaned_text

def remove_spaces(text):
    pattern = r"\s+"
    cleaned_text = re.sub(pattern, " ", text)    
    return cleaned_text

file_path = '/Users/jaafarbendriss/First-LLM/dataset/black_hole_wiki.txt'

# Open the file and read its content
with open(file_path, 'r') as file:
    file_content = file.read()

raw_text = file_content

raw_text = remove_words_in_parentheses(remove_spaces(remove_citations(raw_text)))

# Process a sentence
doc = nlp(raw_text)

# Lemmatize each word
for token in doc:
    print(token.text, "->", token.lemma_)

    
raw_text = " ".join([token.lemma_ for token in doc if token.lemma_ not in stop_words])

def add_start_end_sentence(text):
    return "start-of-sentence " + text.replace("."," end-of-sentence start-of-sentence ")




def preprocess(text: str):
    return remove_spaces(remove_citations((text.lower().replace(":"," ").replace(" s "," ").replace("-"," ").replace(";",".").replace("-","")).replace("}","").replace("{","").replace("[ edit ]","").replace(" s ","").replace("\\","").replace("'"," ").replace('"',' ').replace(","," ").replace("\ s"," ").replace("\n"," "))).replace(":"," ").replace(" s "," ").replace("-"," ") #.replace("black hole","black_hole")

preprocessed_text = preprocess(raw_text)

most_common_tokens = Counter(preprocessed_text.split(" ")).most_common(120)

least_common_tokens = Counter(preprocessed_text.split(" "))

preprocessed_text_array = preprocessed_text.split(" ")

#preprocessed_text = preprocessed_text.replace("end-of-sentence start-of-sentence", "end-of-sentence69696969start-of-sentence")
splited_data = preprocessed_text.split(" . ")

train_data =  [(i,sentence) for i, sentence in zip( range(0,len(splited_data)), splited_data  )]
train_iter = iter(train_data)
splited_data
# Out:
# ' -> '
# Object -> object
# that -> that
# has -> have
# a -> a
# no -> no
# - -> -
# return -> return
# boundary -> boundary
# For -> for
# other -> other
# uses -> use
# , -> ,
# see -> see
# Black -> black
# hole -> hole
# . -> .
# Direct -> direct
# radio -> radio
# image -> image
# of -> of
# a -> a
# supermassive -> supermassive
# black -> black
# hole -> hole
# at -> at
# the -> the
# core -> core
# of -> of
# Messier -> Messier
# 87 -> 87
# Animated -> animated
# simulation -> simulation
# of -> of
# a -> a
# Schwarzschild -> Schwarzschild
# black -> black
# hole -> hole
# with -> with
# a -> a
# galaxy -> galaxy
# passing -> pass
# behind -> behind
# . -> .
# Around -> around
# the -> the
# time -> time
# of -> of
# alignment -> alignment
# , -> ,
# extreme -> extreme
# gravitational -> gravitational
# lensing -> lensing
# of -> of
# the -> the
# galaxy -> galaxy
# is -> be
# observed -> observe
# . -> .
# A -> a
# black -> black
# hole -> hole
# is -> be
# a -> a
# region -> region
# of -> of
# spacetime -> spacetime
# where -> where
# gravity -> gravity
# is -> be
# so -> so
# strong -> strong
# that -> that
# nothing -> nothing
# , -> ,
# including -> include
# light -> light
# and -> and
# other -> other
# electromagnetic -> electromagnetic
# waves -> wave
# , -> ,
# has -> have
# enough -> enough
# energy -> energy
# to -> to
# escape -> escape
# it -> it
# . -> .
# Einstein -> Einstein
# \ -> \
# 's -> 's
# theory -> theory
# of -> of
# general -> general
# relativity -> relativity
# predicts -> predict
# that -> that
# a -> a
# sufficiently -> sufficiently
# compact -> compact
# mass -> mass
# can -> can
# deform -> deform
# spacetime -> spacetime
# to -> to
# form -> form
# a -> a
# black -> black
# hole -> hole
# . -> .
# The -> the
# boundary -> boundary
# of -> of
# no -> no
# escape -> escape
# is -> be
# called -> call
# the -> the
# event -> event
# horizon -> horizon
# . -> .
# A -> a
# black -> black
# hole -> hole
# has -> have
# a -> a
# great -> great
# effect -> effect
# on -> on
# the -> the
# fate -> fate
# and -> and
# circumstances -> circumstance
# of -> of
# an -> an
# object -> object
# crossing -> cross
# it -> it
# , -> ,
# but -> but
# it -> it
# has -> have
# no -> no
# locally -> locally
# detectable -> detectable
# features -> feature
# according -> accord
# to -> to
# general -> general
# relativity -> relativity
# . -> .
# In -> in
# many -> many
# ways -> way
# , -> ,
# a -> a
# black -> black
# hole -> hole
# acts -> act
# like -> like
# an -> an
# ideal -> ideal
# black -> black
# body -> body
# , -> ,
# as -> as
# it -> it
# reflects -> reflect
# no -> no
# light -> light
# . -> .
# Moreover -> moreover
# , -> ,
# quantum -> quantum
# field -> field
# theory -> theory
# in -> in
# curved -> curved
# spacetime -> spacetime
# predicts -> predict
# that -> that
# event -> event
# horizons -> horizon
# emit -> emit
# Hawking -> hawking
# radiation -> radiation
# , -> ,
# with -> with
# the -> the
# same -> same
# spectrum -> spectrum
# as -> as
# a -> a
# black -> black
# body -> body
# of -> of
# a -> a
# temperature -> temperature
# inversely -> inversely
# proportional -> proportional
# to -> to
# its -> its
# mass -> mass
# . -> .
# This -> this
# temperature -> temperature
# is -> be
# of -> of
# the -> the
# order -> order
# of -> of
# billionths -> billionth
# of -> of
# a -> a
# kelvin -> kelvin
# for -> for
# stellar -> stellar
# black -> black
# holes -> hole
# , -> ,
# making -> make
# it -> it
# essentially -> essentially
# impossible -> impossible
# to -> to
# observe -> observe
# directly -> directly
# . -> .
# Objects -> object
# whose -> whose
# gravitational -> gravitational
# fields -> field
# are -> be
# too -> too
# strong -> strong
# for -> for
# light -> light
# to -> to
# escape -> escape
# were -> be
# first -> first
# considered -> consider
# in -> in
# the -> the
# 18th -> 18th
# century -> century
# by -> by
# John -> John
# Michell -> Michell
# and -> and
# Pierre -> Pierre
# - -> -
# Simon -> Simon
# Laplace -> Laplace
# . -> .
# In -> in
# 1916 -> 1916
# , -> ,
# Karl -> Karl
# Schwarzschild -> Schwarzschild
# found -> find
# the -> the
# first -> first
# modern -> modern
# solution -> solution
# of -> of
# general -> general
# relativity -> relativity
# that -> that
# would -> would
# characterize -> characterize
# a -> a
# black -> black
# hole -> hole
# . -> .
# David -> David
# Finkelstein -> Finkelstein
# , -> ,
# in -> in
# 1958 -> 1958
# , -> ,
# first -> first
# published -> publish
# the -> the
# interpretation -> interpretation
# of -> of
# " -> "
# black -> black
# hole -> hole
# " -> "
# as -> as
# a -> a
# region -> region
# of -> of
# space -> space
# from -> from
# which -> which
# nothing -> nothing
# can -> can
# escape -> escape
# . -> .
# Black -> black
# holes -> hole
# were -> be
# long -> long
# considered -> consider
# a -> a
# mathematical -> mathematical
# curiosity -> curiosity
# ; -> ;
# it -> it
# was -> be
# not -> not
# until -> until
# the -> the
# 1960s -> 1960
# that -> that
# theoretical -> theoretical
# work -> work
# showed -> show
# they -> they
# were -> be
# a -> a
# generic -> generic
# prediction -> prediction
# of -> of
# general -> general
# relativity -> relativity
# . -> .
# The -> the
# discovery -> discovery
# of -> of
# neutron -> neutron
# stars -> star
# by -> by
# Jocelyn -> Jocelyn
# Bell -> Bell
# Burnell -> Burnell
# in -> in
# 1967 -> 1967
# sparked -> spark
# interest -> interest
# in -> in
# gravitationally -> gravitationally
# collapsed -> collapse
# compact -> compact
# objects -> object
# as -> as
# a -> a
# possible -> possible
# astrophysical -> astrophysical
# reality -> reality
# . -> .
# The -> the
# first -> first
# black -> black
# hole -> hole
# known -> know
# was -> be
# Cygnus -> Cygnus
# X-1 -> x-1
# , -> ,
# identified -> identify
# by -> by
# several -> several
# researchers -> researcher
# independently -> independently
# in -> in
# 1971 -> 1971
# . -> .
# Black -> black
# holes -> hole
# of -> of
# stellar -> stellar
# mass -> mass
# form -> form
# when -> when
# massive -> massive
# stars -> star
# collapse -> collapse
# at -> at
# the -> the
# end -> end
# of -> of
# their -> their
# life -> life
# cycle -> cycle
# . -> .
# After -> after
# a -> a
# black -> black
# hole -> hole
# has -> have
# formed -> form
# , -> ,
# it -> it
# can -> can
# grow -> grow
# by -> by
# absorbing -> absorb
# mass -> mass
# from -> from
# its -> its
# surroundings -> surrounding
# . -> .
# Supermassive -> supermassive
# black -> black
# holes -> hole
# of -> of
# millions -> million
# of -> of
# solar -> solar
# masses -> masse
# may -> may
# form -> form
# by -> by
# absorbing -> absorb
# other -> other
# stars -> star
# and -> and
# merging -> merge
# with -> with
# other -> other
# black -> black
# holes -> hole
# , -> ,
# or -> or
# via -> via
# direct -> direct
# collapse -> collapse
# of -> of
# gas -> gas
# clouds -> cloud
# . -> .
# There -> there
# is -> be
# consensus -> consensus
# that -> that
# supermassive -> supermassive
# black -> black
# holes -> hole
# exist -> exist
# in -> in
# the -> the
# centres -> centre
# of -> of
# most -> most
# galaxies -> galaxy
# . -> .
# The -> the
# presence -> presence
# of -> of
# a -> a
# black -> black
# hole -> hole
# can -> can
# be -> be
# inferred -> infer
# through -> through
# its -> its
# interaction -> interaction
# with -> with
# other -> other
# matter -> matter
# and -> and
# with -> with
# electromagnetic -> electromagnetic
# radiation -> radiation
# such -> such
# as -> as
# visible -> visible
# light -> light
# . -> .
# Any -> any
# matter -> matter
# that -> that
# falls -> fall
# toward -> toward
# a -> a
# black -> black
# hole -> hole
# can -> can
# form -> form
# an -> an
# external -> external
# accretion -> accretion
# disk -> disk
# heated -> heat
# by -> by
# friction -> friction
# , -> ,
# forming -> form
# quasars -> quasar
# , -> ,
# some -> some
# of -> of
# the -> the
# brightest -> bright
# objects -> object
# in -> in
# the -> the
# universe -> universe
# . -> .
# Stars -> star
# passing -> pass
# too -> too
# close -> close
# to -> to
# a -> a
# supermassive -> supermassive
# black -> black
# hole -> hole
# can -> can
# be -> be
# shredded -> shred
# into -> into
# streamers -> streamer
# that -> that
# shine -> shine
# very -> very
# brightly -> brightly
# before -> before
# being -> be
# " -> "
# swallowed -> swallow
# . -> .
# " -> "
# If -> if
# other -> other
# stars -> star
# are -> be
# orbiting -> orbit
# a -> a
# black -> black
# hole -> hole
# , -> ,
# their -> their
# orbits -> orbit
# can -> can
# be -> be
# used -> use
# to -> to
# determine -> determine
# the -> the
# black -> black
# hole\ -> hole\
# 's -> 's
# mass -> mass
# and -> and
# location -> location
# . -> .
# Such -> such
# observations -> observation
# can -> can
# be -> be
# used -> use
# to -> to
# exclude -> exclude
# possible -> possible
# alternatives -> alternative
# such -> such
# as -> as
# neutron -> neutron
# stars -> star
# . -> .
# In -> in
# this -> this
# way -> way
# , -> ,
# astronomers -> astronomer
# have -> have
# identified -> identify
# numerous -> numerous
# stellar -> stellar
# black -> black
# hole -> hole
# candidates -> candidate
# in -> in
# binary -> binary
# systems -> system
# and -> and
# established -> establish
# that -> that
# the -> the
# radio -> radio
# source -> source
# known -> know
# as -> as
# Sagittarius -> Sagittarius
# A -> A
# * -> *
# , -> ,
# at -> at
# the -> the
# core -> core
# of -> of
# the -> the
# Milky -> Milky
# Way -> Way
# galaxy -> galaxy
# , -> ,
# contains -> contain
# a -> a
# supermassive -> supermassive
# black -> black
# hole -> hole
# of -> of
# about -> about
# 4.3\xa0million -> 4.3\xa0million
# solar -> solar
# masses -> masse
# . -> .
# History -> history
# [ -> [
# edit -> edit
# ] -> ]
# The -> the
# idea -> idea
# of -> of
# a -> a
# body -> body
# so -> so
# big -> big
# that -> that
# even -> even
# light -> light
# could -> could
# not -> not
# escape -> escape
# was -> be
# briefly -> briefly
# proposed -> propose
# by -> by
# English -> english
# astronomical -> astronomical
# pioneer -> pioneer
# and -> and
# clergyman -> clergyman
# John -> John
# Michell -> Michell
# in -> in
# a -> a
# letter -> letter
# published -> publish
# in -> in
# November -> November
# 1784 -> 1784
# . -> .
# Michell\ -> Michell\
# 's -> 's
# simplistic -> simplistic
# calculations -> calculation
# assumed -> assume
# such -> such
# a -> a
# body -> body
# might -> might
# have -> have
# the -> the
# same -> same
# density -> density
# as -> as
# the -> the
# Sun -> Sun
# , -> ,
# and -> and
# concluded -> conclude
# that -> that
# one -> one
# would -> would
# form -> form
# when -> when
# a -> a
# star\ -> star\
# 's -> 's
# diameter -> diameter
# exceeds -> exceed
# the -> the
# Sun\ -> sun\
# 's -> 's
# by -> by
# a -> a
# factor -> factor
# of -> of
# 500 -> 500
# , -> ,
# and -> and
# its -> its
# surface -> surface
# escape -> escape
# velocity -> velocity
# exceeds -> exceed
# the -> the
# usual -> usual
# speed -> speed
# of -> of
# light -> light
# . -> .
# Michell -> Michell
# referred -> refer
# to -> to
# these -> these
# bodies -> body
# as -> as
# dark -> dark
# stars -> star
# . -> .
# He -> he
# correctly -> correctly
# noted -> note
# that -> that
# such -> such
# supermassive -> supermassive
# but -> but
# non -> non
# - -> -
# radiating -> radiating
# bodies -> body
# might -> might
# be -> be
# detectable -> detectable
# through -> through
# their -> their
# gravitational -> gravitational
# effects -> effect
# on -> on
# nearby -> nearby
# visible -> visible
# bodies -> body
# . -> .
# Scholars -> scholar
# of -> of
# the -> the
# time -> time
# were -> be
# initially -> initially
# excited -> excite
# by -> by
# the -> the
# proposal -> proposal
# that -> that
# giant -> giant
# but -> but
# invisible -> invisible
# \'dark -> \'dark
# stars\ -> stars\
# ' -> '
# might -> might
# be -> be
# hiding -> hide
# in -> in
# plain -> plain
# view -> view
# , -> ,
# but -> but
# enthusiasm -> enthusiasm
# dampened -> dampen
# when -> when
# the -> the
# wavelike -> wavelike
# nature -> nature
# of -> of
# light -> light
# became -> become
# apparent -> apparent
# in -> in
# the -> the
# early -> early
# nineteenth -> nineteenth
# century -> century
# , -> ,
# as -> as
# if -> if
# light -> light
# were -> be
# a -> a
# wave -> wave
# rather -> rather
# than -> than
# a -> a
# particle -> particle
# , -> ,
# it -> it
# was -> be
# unclear -> unclear
# what -> what
# , -> ,
# if -> if
# any -> any
# , -> ,
# influence -> influence
# gravity -> gravity
# would -> would
# have -> have
# on -> on
# escaping -> escape
# light -> light
# waves -> wave
# . -> .
# The -> the
# modern -> modern
# theory -> theory
# of -> of
# gravity -> gravity
# , -> ,
# general -> general
# relativity -> relativity
# , -> ,
# discredits -> discredit
# Michell\ -> Michell\
# 's -> 's
# notion -> notion
# of -> of
# a -> a
# light -> light
# ray -> ray
# shooting -> shoot
# directly -> directly
# from -> from
# the -> the
# surface -> surface
# of -> of
# a -> a
# supermassive -> supermassive
# star -> star
# , -> ,
# being -> be
# slowed -> slow
# down -> down
# by -> by
# the -> the
# star\ -> star\
# 's -> 's
# gravity -> gravity
# , -> ,
# stopping -> stop
# , -> ,
# and -> and
# then -> then
# free -> free
# - -> -
# falling -> fall
# back -> back
# to -> to
# the -> the
# star\ -> star\
# 's -> 's
# surface -> surface
# . -> .
# Instead -> instead
# , -> ,
# spacetime -> spacetime
# itself -> itself
# is -> be
# curved -> curve
# such -> such
# that -> that
# the -> the
# geodesic -> geodesic
# light -> light
# travels -> travel
# on -> on
# never -> never
# leaves -> leave
# the -> the
# surface -> surface
# of -> of
# the -> the
# " -> "
# star -> star
# " -> "
# . -> .
# General -> general
# relativity -> relativity
# [ -> [
# edit -> edit
# ] -> ]
# See -> see
# also -> also
# : -> :
# History -> history
# of -> of
# general -> general
# relativity -> relativity
# General -> General
# relativity -> relativity
# G -> G
# μ -> μ
# ν -> ν
# + -> +
# Λ -> Λ
# g -> g
# μ -> μ
# ν -> ν
# = -> =
# κ -> κ
# T -> t
# μ -> μ
# ν -> ν
# { -> {
# \\displaystyle -> \\displaystyle
# G_{\\mu -> G_{\\mu
# \\nu -> \\nu
# } -> }
# + -> +
# \\Lambda -> \\lambda
# g_{\\mu -> g_{\\mu
# \\nu -> \\nu
# } -> }
# = -> =
# { -> {
# \\kappa -> \\kappa
# } -> }
# T_{\\mu -> T_{\\mu
# \\nu -> \\nu
# } -> }
# } -> }
# Introduction -> Introduction
# History -> History
# Timeline -> Timeline
# Tests -> Tests
# Mathematical -> Mathematical
# formulation -> formulation
# Fundamental -> fundamental
# concepts -> concept
# Equivalence -> Equivalence
# principle -> principle
# Special -> special
# relativity -> relativity
# World -> World
# line -> line
# Pseudo -> Pseudo
# - -> -
# Riemannian -> riemannian
# manifold -> manifold
# Phenomena -> Phenomena
# Kepler -> Kepler
# problem -> problem
# Gravitational -> Gravitational
# lensing -> lense
# Gravitational -> gravitational
# red -> red
# shift -> shift
# Gravitational -> gravitational
# time -> time
# dilation -> dilation
# Gravitational -> Gravitational
# waves -> wave
# Frame -> Frame
# - -> -
# dragging -> drag
# Geodetic -> geodetic
# effect -> effect
# Event -> Event
# horizon -> horizon
# Singularity -> Singularity
# Black -> Black
# hole -> hole
# Spacetime -> Spacetime
# Spacetime -> Spacetime
# diagrams -> diagram
# Minkowski -> Minkowski
# spacetime -> spacetime
# Einstein -> Einstein
# – -> –
# Rosen -> Rosen
# bridge -> bridge
# Equations -> Equations
# Formalisms -> Formalisms
# Equations -> Equations
# Linearized -> linearized
# gravity -> gravity
# Einstein -> Einstein
# field -> field
# equations -> equation
# Friedmann -> Friedmann
# Geodesics -> Geodesics
# Mathisson -> Mathisson
# – -> –
# Papapetrou -> Papapetrou
# – -> –
# Dixon -> Dixon
# Hamilton -> Hamilton
# – -> –
# Jacobi -> Jacobi
# – -> –
# Einstein -> Einstein
# Formalisms -> Formalisms
# ADM -> ADM
# BSSN -> BSSN
# Post -> Post
# - -> -
# Newtonian -> newtonian
# Advanced -> Advanced
# theory -> theory
# Kaluza -> Kaluza
# – -> –
# Klein -> Klein
# theory -> theory
# Quantum -> Quantum
# gravity -> gravity
# Solutions -> Solutions
# Schwarzschild -> Schwarzschild
# Reissner -> Reissner
# – -> –
# Nordström -> Nordström
# Gödel -> Gödel
# Kerr -> Kerr
# Kerr -> Kerr
# – -> –
# Newman -> Newman
# Kerr -> Kerr
# – -> –
# Newman -> Newman
# – -> –
# de -> de
# Sitter -> Sitter
# Kasner -> Kasner
# Lemaître -> Lemaître
# – -> –
# Tolman -> Tolman
# Taub -> Taub
# – -> –
# NUT -> NUT
# Milne -> Milne
# Robertson -> Robertson
# – -> –
# Walker -> Walker
# Oppenheimer -> Oppenheimer
# – -> –
# Snyder -> Snyder
# pp -> pp
# - -> -
# wave -> wave
# van -> van
# Stockum -> Stockum
# dust -> dust
# Weyl−Lewis−Papapetrou -> weyl−lewis−papapetrou
# Scientists -> Scientists
# Einstein -> Einstein
# Lorentz -> Lorentz
# Hilbert -> Hilbert
# Poincaré -> Poincaré
# Schwarzschild -> Schwarzschild
# de -> de
# Sitter -> Sitter
# Reissner -> Reissner
# Nordström -> Nordström
# Weyl -> Weyl
# Eddington -> Eddington
# Friedman -> Friedman
# Milne -> Milne
# Zwicky -> Zwicky
# Lemaître -> Lemaître
# Oppenheimer -> Oppenheimer
# Gödel -> Gödel
# Wheeler -> Wheeler
# Robertson -> Robertson
# Bardeen -> Bardeen
# Walker -> Walker
# Kerr -> Kerr
# Chandrasekhar -> Chandrasekhar
# Ehlers -> Ehlers
# Penrose -> Penrose
# Hawking -> Hawking
# Raychaudhuri -> Raychaudhuri
# Taylor -> Taylor
# Hulse -> Hulse
# van -> van
# Stockum -> Stockum
# Taub -> Taub
# Newman -> Newman
# Yau -> Yau
# Thorne -> Thorne
# others -> other
# Physics -> Physics
# portal -> portal
# Category -> Category
# v -> v
# t -> t
# e -> e
# In -> in
# 1915 -> 1915
# , -> ,
# Albert -> Albert
# Einstein -> Einstein
# developed -> develop
# his -> his
# theory -> theory
# of -> of
# general -> general
# relativity -> relativity
# , -> ,
# having -> having
# earlier -> early
# shown -> show
# that -> that
# gravity -> gravity
# does -> do
# influence -> influence
# light\ -> light\
# 's -> 's
# motion -> motion
# . -> .
# Only -> only
# a -> a
# few -> few
# months -> month
# later -> later
# , -> ,
# Karl -> Karl
# Schwarzschild -> Schwarzschild
# found -> find
# a -> a
# solution -> solution
# to -> to
# the -> the
# Einstein -> Einstein
# field -> field
# equations -> equation
# that -> that
# describes -> describe
# the -> the
# gravitational -> gravitational
# field -> field
# of -> of
# a -> a
# point -> point
# mass -> mass
# and -> and
# a -> a
# spherical -> spherical
# mass -> mass
# . -> .
# A -> a
# few -> few
# months -> month
# after -> after
# Schwarzschild -> Schwarzschild
# , -> ,
# Johannes -> Johannes
# Droste -> Droste
# , -> ,
# a -> a
# student -> student
# of -> of
# Hendrik -> Hendrik
# Lorentz -> Lorentz
# , -> ,
# independently -> independently
# gave -> give
# the -> the
# same -> same
# solution -> solution
# for -> for
# the -> the
# point -> point
# mass -> mass
# and -> and
# wrote -> write
# more -> more
# extensively -> extensively
# about -> about
# its -> its
# properties -> property
# . -> .
# This -> this
# solution -> solution
# had -> have
# a -> a
# peculiar -> peculiar
# behaviour -> behaviour
# at -> at
# what -> what
# is -> be
# now -> now
# called -> call
# the -> the
# Schwarzschild -> Schwarzschild
# radius -> radius
# , -> ,
# where -> where
# it -> it
# became -> become
# singular -> singular
# , -> ,
# meaning -> mean
# that -> that
# some -> some
# of -> of
# the -> the
# terms -> term
# in -> in
# the -> the
# Einstein -> Einstein
# equations -> equation
# became -> become
# infinite -> infinite
# . -> .
# The -> the
# nature -> nature
# of -> of
# this -> this
# surface -> surface
# was -> be
# not -> not
# quite -> quite
# understood -> understand
# at -> at
# the -> the
# time -> time
# . -> .
# In -> in
# 1924 -> 1924
# , -> ,
# Arthur -> Arthur
# Eddington -> Eddington
# showed -> show
# that -> that
# the -> the
# singularity -> singularity
# disappeared -> disappear
# after -> after
# a -> a
# change -> change
# of -> of
# coordinates -> coordinate
# , -> ,
# although -> although
# it -> it
# took -> take
# until -> until
# 1933 -> 1933
# for -> for
# Georges -> Georges
# Lemaître -> Lemaître
# to -> to
# realize -> realize
# that -> that
# this -> this
# meant -> mean
# the -> the
# singularity -> singularity
# at -> at
# the -> the
# Schwarzschild -> Schwarzschild
# radius -> radius
# was -> be
# a -> a
# non -> non
# - -> -
# physical -> physical
# coordinate -> coordinate
# singularity -> singularity
# . -> .
# Arthur -> Arthur
# Eddington -> Eddington
# did -> do
# however -> however
# comment -> comment
# on -> on
# the -> the
# possibility -> possibility
# of -> of
# a -> a
# star -> star
# with -> with
# mass -> mass
# compressed -> compress
# to -> to
# the -> the
# Schwarzschild -> Schwarzschild
# radius -> radius
# in -> in
# a -> a
# 1926 -> 1926
# book -> book
# , -> ,
# noting -> note
# that -> that
# Einstein\ -> Einstein\
# 's -> 's
# theory -> theory
# allows -> allow
# us -> we
# to -> to
# rule -> rule
# out -> out
# overly -> overly
# large -> large
# densities -> density
# for -> for
# visible -> visible
# stars -> star
# like -> like
# Betelgeuse -> Betelgeuse
# because -> because
# " -> "
# a -> a
# star -> star
# of -> of
# 250 -> 250
# million -> million
# km -> km
# radius -> radius
# could -> could
# not -> not
# possibly -> possibly
# have -> have
# so -> so
# high -> high
# a -> a
# density -> density
# as -> as
# the -> the
# Sun -> Sun
# . -> .
# Firstly -> firstly
# , -> ,
# the -> the
# force -> force
# of -> of
# gravitation -> gravitation
# would -> would
# be -> be
# so -> so
# great -> great
# that -> that
# light -> light
# would -> would
# be -> be
# unable -> unable
# to -> to
# escape -> escape
# from -> from
# it -> it
# , -> ,
# the -> the
# rays -> ray
# falling -> fall
# back -> back
# to -> to
# the -> the
# star -> star
# like -> like
# a -> a
# stone -> stone
# to -> to
# the -> the
# earth -> earth
# . -> .
# Secondly -> secondly
# , -> ,
# the -> the
# red -> red
# shift -> shift
# of -> of
# the -> the
# spectral -> spectral
# lines -> line
# would -> would
# be -> be
# so -> so
# great -> great
# that -> that
# the -> the
# spectrum -> spectrum
# would -> would
# be -> be
# shifted -> shift
# out -> out
# of -> of
# existence -> existence
# . -> .
# Thirdly -> thirdly
# , -> ,
# the -> the
# mass -> mass
# would -> would
# produce -> produce
# so -> so
# much -> much
# curvature -> curvature
# of -> of
# the -> the
# spacetime -> spacetime
# metric -> metric
# that -> that
# space -> space
# would -> would
# close -> close
# up -> up
# around -> around
# the -> the
# star -> star
# , -> ,
# leaving -> leave
# us -> we
# outside -> outside
# . -> .
# " -> "
# In -> in
# 1931 -> 1931
# , -> ,
# Subrahmanyan -> Subrahmanyan
# Chandrasekhar -> Chandrasekhar
# calculated -> calculate
# , -> ,
# using -> use
# special -> special
# relativity -> relativity
# , -> ,
# that -> that
# a -> a
# non -> non
# - -> -
# rotating -> rotating
# body -> body
# of -> of
# electron -> electron
# - -> -
# degenerate -> degenerate
# matter -> matter
# above -> above
# a -> a
# certain -> certain
# limiting -> limiting
# mass -> mass
# has -> have
# no -> no
# stable -> stable
# solutions -> solution
# . -> .
# His -> his
# arguments -> argument
# were -> be
# opposed -> oppose
# by -> by
# many -> many
# of -> of
# his -> his
# contemporaries -> contemporary
# like -> like
# Eddington -> Eddington
# and -> and
# Lev -> Lev
# Landau -> Landau
# , -> ,
# who -> who
# argued -> argue
# that -> that
# some -> some
# yet -> yet
# unknown -> unknown
# mechanism -> mechanism
# would -> would
# stop -> stop
# the -> the
# collapse -> collapse
# . -> .
# They -> they
# were -> be
# partly -> partly
# correct -> correct
# : -> :
# a -> a
# white -> white
# dwarf -> dwarf
# slightly -> slightly
# more -> more
# massive -> massive
# than -> than
# the -> the
# Chandrasekhar -> Chandrasekhar
# limit -> limit
# will -> will
# collapse -> collapse
# into -> into
# a -> a
# neutron -> neutron
# star -> star
# , -> ,
# which -> which
# is -> be
# itself -> itself
# stable -> stable
# . -> .
# But -> but
# in -> in
# 1939 -> 1939
# , -> ,
# Robert -> Robert
# Oppenheimer -> Oppenheimer
# and -> and
# others -> other
# predicted -> predict
# that -> that
# neutron -> neutron
# stars -> star
# above -> above
# another -> another
# limit -> limit
# would -> would
# collapse -> collapse
# further -> far
# for -> for
# the -> the
# reasons -> reason
# presented -> present
# by -> by
# Chandrasekhar -> Chandrasekhar
# , -> ,
# and -> and
# concluded -> conclude
# that -> that
# no -> no
# law -> law
# of -> of
# physics -> physics
# was -> be
# likely -> likely
# to -> to
# intervene -> intervene
# and -> and
# stop -> stop
# at -> at
# least -> least
# some -> some
# stars -> star
# from -> from
# collapsing -> collapse
# to -> to
# black -> black
# holes -> hole
# . -> .
# Their -> their
# original -> original
# calculations -> calculation
# , -> ,
# based -> base
# on -> on
# the -> the
# Pauli -> Pauli
# exclusion -> exclusion
# principle -> principle
# , -> ,
# gave -> give
# it -> it
# as -> as
# 0.7 -> 0.7
# M -> M
# ☉ -> ☉
# ; -> ;
# subsequent -> subsequent
# consideration -> consideration
# of -> of
# neutron -> neutron
# - -> -
# neutron -> neutron
# repulsion -> repulsion
# mediated -> mediate
# by -> by
# the -> the
# strong -> strong
# force -> force
# raised -> raise
# the -> the
# estimate -> estimate
# to -> to
# approximately -> approximately
# 1.5 -> 1.5
# M -> M
# ☉ -> ☉
# to -> to
# 3.0 -> 3.0
# M -> M
# ☉ -> ☉
# . -> .
# Observations -> observation
# of -> of
# the -> the
# neutron -> neutron
# star -> star
# merger -> merger
# GW170817 -> GW170817
# , -> ,
# which -> which
# is -> be
# thought -> think
# to -> to
# have -> have
# generated -> generate
# a -> a
# black -> black
# hole -> hole
# shortly -> shortly
# afterward -> afterward
# , -> ,
# have -> have
# refined -> refine
# the -> the
# TOV -> TOV
# limit -> limit
# estimate -> estimate
# to -> to
# ~2.17 -> ~2.17
# M -> M
# ☉ -> ☉
# . -> .
# Oppenheimer -> Oppenheimer
# and -> and
# his -> his
# co -> co
# - -> -
# authors -> author
# interpreted -> interpret
# the -> the
# singularity -> singularity
# at -> at
# the -> the
# boundary -> boundary
# of -> of
# the -> the
# Schwarzschild -> Schwarzschild
# radius -> radius
# as -> as
# indicating -> indicate
# that -> that
# this -> this
# was -> be
# the -> the
# boundary -> boundary
# of -> of
# a -> a
# bubble -> bubble
# in -> in
# which -> which
# time -> time
# stopped -> stop
# . -> .
# This -> this
# is -> be
# a -> a
# valid -> valid
# point -> point
# of -> of
# view -> view
# for -> for
# external -> external
# observers -> observer
# , -> ,
# but -> but
# not -> not
# for -> for
# infalling -> infalle
# observers -> observer
# . -> .
# Because -> because
# of -> of
# this -> this
# property -> property
# , -> ,
# the -> the
# collapsed -> collapse
# stars -> star
# were -> be
# called -> call
# " -> "
# frozen -> frozen
# stars -> star
# " -> "
# , -> ,
# because -> because
# an -> an
# outside -> outside
# observer -> observer
# would -> would
# see -> see
# the -> the
# surface -> surface
# of -> of
# the -> the
# star -> star
# frozen -> freeze
# in -> in
# time -> time
# at -> at
# the -> the
# instant -> instant
# where -> where
# its -> its
# collapse -> collapse
# takes -> take
# it -> it
# to -> to
# the -> the
# Schwarzschild -> Schwarzschild
# radius -> radius
# . -> .
# Also -> also
# in -> in
# 1939 -> 1939
# , -> ,
# Einstein -> Einstein
# would -> would
# attempt -> attempt
# to -> to
# prove -> prove
# that -> that
# black -> black
# holes -> hole
# were -> be
# impossible -> impossible
# in -> in
# his -> his
# publication -> publication
# " -> "
# On -> on
# a -> a
# Stationary -> Stationary
# System -> System
# with -> with
# Spherical -> Spherical
# Symmetry -> Symmetry
# Consisting -> consist
# of -> of
# Many -> many
# Gravitating -> Gravitating
# Masses -> Masses
# " -> "
# , -> ,
# using -> use
# his -> his
# theory -> theory
# of -> of
# general -> general
# relativity -> relativity
# to -> to
# defend -> defend
# his -> his
# argument -> argument
# . -> .
# Months -> month
# later -> later
# , -> ,
# Oppenheimer -> Oppenheimer
# and -> and
# his -> his
# student -> student
# Hartland -> Hartland
# Snyder -> Snyder
# would -> would
# provide -> provide
# the -> the
# Oppenheimer -> Oppenheimer
# – -> –
# Snyder -> Snyder
# model -> model
# in -> in
# their -> their
# paper -> paper
# " -> "
# On -> on
# Continued -> Continued
# Gravitational -> Gravitational
# Contraction -> Contraction
# " -> "
# , -> ,
# which -> which
# predicted -> predict
# the -> the
# existence -> existence
# of -> of
# black -> black
# holes -> hole
# . -> .
# In -> in
# the -> the
# paper -> paper
# , -> ,
# which -> which
# made -> make
# no -> no
# reference -> reference
# to -> to
# Einstein\ -> Einstein\
# 's -> 's
# recent -> recent
# publication -> publication
# , -> ,
# Oppenheimer -> Oppenheimer
# and -> and
# Snyder -> Snyder
# used -> use
# Einstein\ -> Einstein\
# 's -> 's
# own -> own
# theory -> theory
# of -> of
# general -> general
# relativity -> relativity
# to -> to
# show -> show
# the -> the
# conditions -> condition
# on -> on
# how -> how
# a -> a
# black -> black
# hole -> hole
# could -> could
# develop -> develop
# for -> for
# the -> the
# first -> first
# time -> time
# in -> in
# contemporary -> contemporary
# physics -> physics
# . -> .
# Golden -> golden
# age -> age
# [ -> [
# edit -> edit
# ] -> ]
# In -> in
# 1958 -> 1958
# , -> ,
# David -> David
# Finkelstein -> Finkelstein
# identified -> identify
# the -> the
# Schwarzschild -> Schwarzschild
# surface -> surface
# as -> as
# an -> an
# event -> event
# horizon -> horizon
# , -> ,
# " -> "
# a -> a
# perfect -> perfect
# unidirectional -> unidirectional
# membrane -> membrane
# : -> :
# causal -> causal
# influences -> influence
# can -> can
# cross -> cross
# it -> it
# in -> in
# only -> only
# one -> one
# direction -> direction
# " -> "
# . -> .
# This -> this
# did -> do
# not -> not
# strictly -> strictly
# contradict -> contradict
# Oppenheimer\ -> Oppenheimer\
# 's -> 's
# results -> result
# , -> ,
# but -> but
# extended -> extend
# them -> they
# to -> to
# include -> include
# the -> the
# point -> point
# of -> of
# view -> view
# of -> of
# infalling -> infalle
# observers -> observer
# . -> .
# Finkelstein\ -> Finkelstein\
# 's -> 's
# solution -> solution
# extended -> extend
# the -> the
# Schwarzschild -> Schwarzschild
# solution -> solution
# for -> for
# the -> the
# future -> future
# of -> of
# observers -> observer
# falling -> fall
# into -> into
# a -> a
# black -> black
# hole -> hole
# . -> .
# A -> a
# complete -> complete
# extension -> extension
# had -> have
# already -> already
# been -> be
# found -> find
# by -> by
# Martin -> Martin
# Kruskal -> Kruskal
# , -> ,
# who -> who
# was -> be
# urged -> urge
# to -> to
# publish -> publish
# it -> it
# . -> .
# These -> these
# results -> result
# came -> come
# at -> at
# the -> the
# beginning -> beginning
# of -> of
# the -> the
# golden -> golden
# age -> age
# of -> of
# general -> general
# relativity -> relativity
# , -> ,
# which -> which
# was -> be
# marked -> mark
# by -> by
# general -> general
# relativity -> relativity
# and -> and
# black -> black
# holes -> hole
# becoming -> become
# mainstream -> mainstream
# subjects -> subject
# of -> of
# research -> research
# . -> .
# This -> this
# process -> process
# was -> be
# helped -> help
# by -> by
# the -> the
# discovery -> discovery
# of -> of
# pulsars -> pulsar
# by -> by
# Jocelyn -> Jocelyn
# Bell -> Bell
# Burnell -> Burnell
# in -> in
# 1967 -> 1967
# , -> ,
# which -> which
# , -> ,
# by -> by
# 1969 -> 1969
# , -> ,
# were -> be
# shown -> show
# to -> to
# be -> be
# rapidly -> rapidly
# rotating -> rotate
# neutron -> neutron
# stars -> star
# . -> .
# Until -> until
# that -> that
# time -> time
# , -> ,
# neutron -> neutron
# stars -> star
# , -> ,
# like -> like
# black -> black
# holes -> hole
# , -> ,
# were -> be
# regarded -> regard
# as -> as
# just -> just
# theoretical -> theoretical
# curiosities -> curiosity
# ; -> ;
# but -> but
# the -> the
# discovery -> discovery
# of -> of
# pulsars -> pulsar
# showed -> show
# their -> their
# physical -> physical
# relevance -> relevance
# and -> and
# spurred -> spur
# a -> a
# further -> further
# interest -> interest
# in -> in
# all -> all
# types -> type
# of -> of
# compact -> compact
# objects -> object
# that -> that
# might -> might
# be -> be
# formed -> form
# by -> by
# gravitational -> gravitational
# collapse -> collapse
# . -> .
# In -> in
# this -> this
# period -> period
# more -> more
# general -> general
# black -> black
# hole -> hole
# solutions -> solution
# were -> be
# found -> find
# . -> .
# In -> in
# 1963 -> 1963
# , -> ,
# Roy -> Roy
# Kerr -> Kerr
# found -> find
# the -> the
# exact -> exact
# solution -> solution
# for -> for
# a -> a
# rotating -> rotate
# black -> black
# hole -> hole
# . -> .
# Two -> two
# years -> year
# later -> later
# , -> ,
# Ezra -> Ezra
# Newman -> Newman
# found -> find
# the -> the
# axisymmetric -> axisymmetric
# solution -> solution
# for -> for
# a -> a
# black -> black
# hole -> hole
# that -> that
# is -> be
# both -> both
# rotating -> rotate
# and -> and
# electrically -> electrically
# charged -> charge
# . -> .
# Through -> through
# the -> the
# work -> work
# of -> of
# Werner -> Werner
# Israel -> Israel
# , -> ,
# Brandon -> Brandon
# Carter -> Carter
# , -> ,
# and -> and
# David -> David
# Robinson -> Robinson
# the -> the
# no -> no
# - -> -
# hair -> hair
# theorem -> theorem
# emerged -> emerge
# , -> ,
# stating -> state
# that -> that
# a -> a
# stationary -> stationary
# black -> black
# hole -> hole
# solution -> solution
# is -> be
# completely -> completely
# described -> describe
# by -> by
# the -> the
# three -> three
# parameters -> parameter
# of -> of
# the -> the
# Kerr -> Kerr
# – -> –
# Newman -> Newman
# metric -> metric
# : -> :
# mass -> mass
# , -> ,
# angular -> angular
# momentum -> momentum
# , -> ,
# and -> and
# electric -> electric
# charge -> charge
# . -> .
# At -> at
# first -> first
# , -> ,
# it -> it
# was -> be
# suspected -> suspect
# that -> that
# the -> the
# strange -> strange
# features -> feature
# of -> of
# the -> the
# black -> black
# hole -> hole
# solutions -> solution
# were -> be
# pathological -> pathological
# artifacts -> artifact
# from -> from
# the -> the
# symmetry -> symmetry
# conditions -> condition
# imposed -> impose
# , -> ,
# and -> and
# that -> that
# the -> the
# singularities -> singularity
# would -> would
# not -> not
# appear -> appear
# in -> in
# generic -> generic
# situations -> situation
# . -> .
# This -> this
# view -> view
# was -> be
# held -> hold
# in -> in
# particular -> particular
# by -> by
# Vladimir -> Vladimir
# Belinsky -> Belinsky
# , -> ,
# Isaak -> Isaak
# Khalatnikov -> Khalatnikov
# , -> ,
# and -> and
# Evgeny -> Evgeny
# Lifshitz -> Lifshitz
# , -> ,
# who -> who
# tried -> try
# to -> to
# prove -> prove
# that -> that
# no -> no
# singularities -> singularity
# appear -> appear
# in -> in
# generic -> generic
# solutions -> solution
# . -> .
# However -> however
# , -> ,
# in -> in
# the -> the
# late -> late
# 1960s -> 1960
# Roger -> Roger
# Penrose -> Penrose
# and -> and
# Stephen -> Stephen
# Hawking -> Hawking
# used -> use
# global -> global
# techniques -> technique
# to -> to
# prove -> prove
# that -> that
# singularities -> singularity
# appear -> appear
# generically -> generically
# . -> .
# For -> for
# this -> this
# work -> work
# , -> ,
# Penrose -> Penrose
# received -> receive
# half -> half
# of -> of
# the -> the
# 2020 -> 2020
# Nobel -> Nobel
# Prize -> Prize
# in -> in
# Physics -> Physics
# , -> ,
# Hawking -> hawk
# having -> having
# died -> die
# in -> in
# 2018 -> 2018
# . -> .
# Based -> base
# on -> on
# observations -> observation
# in -> in
# Greenwich -> Greenwich
# and -> and
# Toronto -> Toronto
# in -> in
# the -> the
# early -> early
# 1970s -> 1970
# , -> ,
# Cygnus -> Cygnus
# X-1 -> X-1
# , -> ,
# a -> a
# galactic -> galactic
# X -> x
# - -> -
# ray -> ray
# source -> source
# discovered -> discover
# in -> in
# 1964 -> 1964
# , -> ,
# became -> become
# the -> the
# first -> first
# astronomical -> astronomical
# object -> object
# commonly -> commonly
# accepted -> accept
# to -> to
# be -> be
# a -> a
# black -> black
# hole -> hole
# . -> .
# Work -> work
# by -> by
# James -> James
# Bardeen -> Bardeen
# , -> ,
# Jacob -> Jacob
# Bekenstein -> Bekenstein
# , -> ,
# Carter -> Carter
# , -> ,
# and -> and
# Hawking -> hawk
# in -> in
# the -> the
# early -> early
# 1970s -> 1970
# led -> lead
# to -> to
# the -> the
# formulation -> formulation
# of -> of
# black -> black
# hole -> hole
# thermodynamics -> thermodynamic
# . -> .
# These -> these
# laws -> law
# describe -> describe
# the -> the
# behaviour -> behaviour
# of -> of
# a -> a
# black -> black
# hole -> hole
# in -> in
# close -> close
# analogy -> analogy
# to -> to
# the -> the
# laws -> law
# of -> of
# thermodynamics -> thermodynamic
# by -> by
# relating -> relate
# mass -> mass
# to -> to
# energy -> energy
# , -> ,
# area -> area
# to -> to
# entropy -> entropy
# , -> ,
# and -> and
# surface -> surface
# gravity -> gravity
# to -> to
# temperature -> temperature
# . -> .
# The -> the
# analogy -> analogy
# was -> be
# completed -> complete
# when -> when
# Hawking -> Hawking
# , -> ,
# in -> in
# 1974 -> 1974
# , -> ,
# showed -> show
# that -> that
# quantum -> quantum
# field -> field
# theory -> theory
# implies -> imply
# that -> that
# black -> black
# holes -> hole
# should -> should
# radiate -> radiate
# like -> like
# a -> a
# black -> black
# body -> body
# with -> with
# a -> a
# temperature -> temperature
# proportional -> proportional
# to -> to
# the -> the
# surface -> surface
# gravity -> gravity
# of -> of
# the -> the
# black -> black
# hole -> hole
# , -> ,
# predicting -> predict
# the -> the
# effect -> effect
# now -> now
# known -> know
# as -> as
# Hawking -> hawk
# radiation -> radiation
# . -> .
# Observation -> observation
# [ -> [
# edit -> edit
# ] -> ]
# On -> on
# 11 -> 11
# February -> February
# 2016 -> 2016
# , -> ,
# the -> the
# LIGO -> LIGO
# Scientific -> Scientific
# Collaboration -> Collaboration
# and -> and
# the -> the
# Virgo -> Virgo
# collaboration -> collaboration
# announced -> announce
# the -> the
# first -> first
# direct -> direct
# detection -> detection
# of -> of
# gravitational -> gravitational
# waves -> wave
# , -> ,
# representing -> represent
# the -> the
# first -> first
# observation -> observation
# of -> of
# a -> a
# black -> black
# hole -> hole
# merger -> merger
# . -> .
# On -> on
# 10 -> 10
# April -> April
# 2019 -> 2019
# , -> ,
# the -> the
# first -> first
# direct -> direct
# image -> image
# of -> of
# a -> a
# black -> black
# hole -> hole
# and -> and
# its -> its
# vicinity -> vicinity
# was -> be
# published -> publish
# , -> ,
# following -> follow
# observations -> observation
# made -> make
# by -> by
# the -> the
# Event -> Event
# Horizon -> Horizon
# Telescope -> Telescope
# in -> in
# 2017 -> 2017
# of -> of
# the -> the
# supermassive -> supermassive
# black -> black
# hole -> hole
# in -> in
# Messier -> Messier
# 87 -> 87
# \ -> \
# 's -> 's
# galactic -> galactic
# centre -> centre
# . -> .
# As -> as
# of -> of
# 2023 -> 2023
# [ -> [
# update -> update
# ] -> ]
# , -> ,
# the -> the
# nearest -> near
# known -> know
# body -> body
# thought -> think
# to -> to
# be -> be
# a -> a
# black -> black
# hole -> hole
# , -> ,
# Gaia -> Gaia
# BH1 -> BH1
# , -> ,
# is -> be
# around -> around
# 1,560 -> 1,560
# light -> light
# - -> -
# years -> year
# away -> away
# . -> .
# Though -> though
# only -> only
# a -> a
# couple -> couple
# dozen -> dozen
# black -> black
# holes -> hole
# have -> have
# been -> be
# found -> find
# so -> so
# far -> far
# in -> in
# the -> the
# Milky -> Milky
# Way -> Way
# , -> ,
# there -> there
# are -> be
# thought -> think
# to -> to
# be -> be
# hundreds -> hundred
# of -> of
# millions -> million
# , -> ,
# most -> most
# of -> of
# which -> which
# are -> be
# solitary -> solitary
# and -> and
# do -> do
# not -> not
# cause -> cause
# emission -> emission
# of -> of
# radiation -> radiation
# . -> .
# Therefore -> therefore
# , -> ,
# they -> they
# would -> would
# only -> only
# be -> be
# detectable -> detectable
# by -> by
# gravitational -> gravitational
# lensing -> lensing
# . -> .
# Etymology -> etymology
# [ -> [
# edit -> edit
# ] -> ]
# John -> John
# Michell -> Michell
# used -> use
# the -> the
# term -> term
# " -> "
# dark -> dark
# star -> star
# " -> "
# in -> in
# a -> a
# November -> November
# 1783 -> 1783
# letter -> letter
# to -> to
# Henry -> Henry
# Cavendish -> Cavendish
# , -> ,
# and -> and
# in -> in
# the -> the
# early -> early
# 20th -> 20th
# century -> century
# , -> ,
# physicists -> physicist
# used -> use
# the -> the
# term -> term
# " -> "
# gravitationally -> gravitationally
# collapsed -> collapse
# object -> object
# " -> "
# . -> .
# Science -> science
# writer -> writer
# Marcia -> Marcia
# Bartusiak -> Bartusiak
# traces -> trace
# the -> the
# term -> term
# " -> "
# black -> black
# hole -> hole
# " -> "
# to -> to
# physicist -> physicist
# Robert -> Robert
# H. -> H.
# Dicke -> Dicke
# , -> ,
# who -> who
# in -> in
# the -> the
# early -> early
# 1960s -> 1960
# reportedly -> reportedly
# compared -> compare
# the -> the
# phenomenon -> phenomenon
# to -> to
# the -> the
# Black -> Black
# Hole -> Hole
# of -> of
# Calcutta -> Calcutta
# , -> ,
# notorious -> notorious
# as -> as
# a -> a
# prison -> prison
# where -> where
# people -> people
# entered -> enter
# but -> but
# never -> never
# left -> leave
# alive -> alive
# . -> .
# The -> the
# term -> term
# " -> "
# black -> black
# hole -> hole
# " -> "
# was -> be
# used -> use
# in -> in
# print -> print
# by -> by
# Life -> Life
# and -> and
# Science -> Science
# News -> News
# magazines -> magazine
# in -> in
# 1963 -> 1963
# , -> ,
# and -> and
# by -> by
# science -> science
# journalist -> journalist
# Ann -> Ann
# Ewing -> Ewing
# in -> in
# her -> her
# article -> article
# " -> "
# \'Black -> \'black
# Holes\ -> Holes\
# ' -> '
# in -> in
# Space -> Space
# " -> "
# , -> ,
# dated -> date
# 18 -> 18
# January -> January
# 1964 -> 1964
# , -> ,
# which -> which
# was -> be
# a -> a
# report -> report
# on -> on
# a -> a
# meeting -> meeting
# of -> of
# the -> the
# American -> American
# Association -> Association
# for -> for
# the -> the
# Advancement -> Advancement
# of -> of
# Science -> Science
# held -> hold
# in -> in
# Cleveland -> Cleveland
# , -> ,
# Ohio -> Ohio
# . -> .
# In -> in
# December -> December
# 1967 -> 1967
# , -> ,
# a -> a
# student -> student
# reportedly -> reportedly
# suggested -> suggest
# the -> the
# phrase -> phrase
# " -> "
# black -> black
# hole -> hole
# " -> "
# at -> at
# a -> a
# lecture -> lecture
# by -> by
# John -> John
# Wheeler -> Wheeler
# ; -> ;
# Wheeler -> wheeler
# adopted -> adopt
# the -> the
# term -> term
# for -> for
# its -> its
# brevity -> brevity
# and -> and
# " -> "
# advertising -> advertising
# value -> value
# " -> "
# , -> ,
# and -> and
# it -> it
# quickly -> quickly
# caught -> catch
# on -> on
# , -> ,
# leading -> lead
# some -> some
# to -> to
# credit -> credit
# Wheeler -> Wheeler
# with -> with
# coining -> coin
# the -> the
# phrase -> phrase
# . -> .
# Properties -> property
# and -> and
# structure -> structure
# [ -> [
# edit -> edit
# ] -> ]
# The -> the
# no -> no
# - -> -
# hair -> hair
# theorem -> theorem
# postulates -> postulate
# that -> that
# , -> ,
# once -> once
# it -> it
# achieves -> achieve
# a -> a
# stable -> stable
# condition -> condition
# after -> after
# formation -> formation
# , -> ,
# a -> a
# black -> black
# hole -> hole
# has -> have
# only -> only
# three -> three
# independent -> independent
# physical -> physical
# properties -> property
# : -> :
# mass -> mass
# , -> ,
# electric -> electric
# charge -> charge
# , -> ,
# and -> and
# angular -> angular
# momentum -> momentum
# ; -> ;
# the -> the
# black -> black
# hole -> hole
# is -> be
# otherwise -> otherwise
# featureless -> featureless
# . -> .
# If -> if
# the -> the
# conjecture -> conjecture
# is -> be
# true -> true
# , -> ,
# any -> any
# two -> two
# black -> black
# holes -> hole
# that -> that
# share -> share
# the -> the
# same -> same
# values -> value
# for -> for
# these -> these
# properties -> property
# , -> ,
# or -> or
# parameters -> parameter
# , -> ,
# are -> be
# indistinguishable -> indistinguishable
# from -> from
# one -> one
# another -> another
# . -> .
# The -> the
# degree -> degree
# to -> to
# which -> which
# the -> the
# conjecture -> conjecture
# is -> be
# true -> true
# for -> for
# real -> real
# black -> black
# holes -> hole
# under -> under
# the -> the
# laws -> law
# of -> of
# modern -> modern
# physics -> physics
# is -> be
# currently -> currently
# an -> an
# unsolved -> unsolved
# problem -> problem
# . -> .
# These -> these
# properties -> property
# are -> be
# special -> special
# because -> because
# they -> they
# are -> be
# visible -> visible
# from -> from
# outside -> outside
# a -> a
# black -> black
# hole -> hole
# . -> .
# For -> for
# example -> example
# , -> ,
# a -> a
# charged -> charge
# black -> black
# hole -> hole
# repels -> repel
# other -> other
# like -> like
# charges -> charge
# just -> just
# like -> like
# any -> any
# other -> other
# charged -> charge
# object -> object
# . -> .
# Similarly -> similarly
# , -> ,
# the -> the
# total -> total
# mass -> mass
# inside -> inside
# a -> a
# sphere -> sphere
# containing -> contain
# a -> a
# black -> black
# hole -> hole
# can -> can
# be -> be
# found -> find
# by -> by
# using -> use
# the -> the
# gravitational -> gravitational
# analog -> analog
# of -> of
# Gauss\ -> Gauss\
# 's -> 's
# law -> law
# , -> ,
# far -> far
# away -> away
# from -> from
# the -> the
# black -> black
# hole -> hole
# . -> .
# Likewise -> likewise
# , -> ,
# the -> the
# angular -> angular
# momentum -> momentum
# can -> can
# be -> be
# measured -> measure
# from -> from
# far -> far
# away -> away
# using -> use
# frame -> frame
# dragging -> drag
# by -> by
# the -> the
# gravitomagnetic -> gravitomagnetic
# field -> field
# , -> ,
# through -> through
# for -> for
# example -> example
# the -> the
# Lense -> Lense
# – -> –
# Thirring -> thirring
# effect -> effect
# . -> .
# Artistic -> artistic
# depiction -> depiction
# of -> of
# a -> a
# black -> black
# hole -> hole
# and -> and
# its -> its
# features -> feature
# When -> when
# an -> an
# object -> object
# falls -> fall
# into -> into
# a -> a
# black -> black
# hole -> hole
# , -> ,
# any -> any
# information -> information
# about -> about
# the -> the
# shape -> shape
# of -> of
# the -> the
# object -> object
# or -> or
# distribution -> distribution
# of -> of
# charge -> charge
# on -> on
# it -> it
# is -> be
# evenly -> evenly
# distributed -> distribute
# along -> along
# the -> the
# horizon -> horizon
# of -> of
# the -> the
# black -> black
# hole -> hole
# , -> ,
# and -> and
# is -> be
# lost -> lose
# to -> to
# outside -> outside
# observers -> observer
# . -> .
# The -> the
# behavior -> behavior
# of -> of
# the -> the
# horizon -> horizon
# in -> in
# this -> this
# situation -> situation
# is -> be
# a -> a
# dissipative -> dissipative
# system -> system
# that -> that
# is -> be
# closely -> closely
# analogous -> analogous
# to -> to
# that -> that
# of -> of
# a -> a
# conductive -> conductive
# stretchy -> stretchy
# membrane -> membrane
# with -> with
# friction -> friction
# and -> and
# electrical -> electrical
# resistance -> resistance
# — -> —
# the -> the
# membrane -> membrane
# paradigm -> paradigm
# . -> .
# This -> this
# is -> be
# different -> different
# from -> from
# other -> other
# field -> field
# theories -> theory
# such -> such
# as -> as
# electromagnetism -> electromagnetism
# , -> ,
# which -> which
# do -> do
# not -> not
# have -> have
# any -> any
# friction -> friction
# or -> or
# resistivity -> resistivity
# at -> at
# the -> the
# microscopic -> microscopic
# level -> level
# , -> ,
# because -> because
# they -> they
# are -> be
# time -> time
# - -> -
# reversible -> reversible
# . -> .
# Because -> because
# a -> a
# black -> black
# hole -> hole
# eventually -> eventually
# achieves -> achieve
# a -> a
# stable -> stable
# state -> state
# with -> with
# only -> only
# three -> three
# parameters -> parameter
# , -> ,
# there -> there
# is -> be
# no -> no
# way -> way
# to -> to
# avoid -> avoid
# losing -> lose
# information -> information
# about -> about
# the -> the
# initial -> initial
# conditions -> condition
# : -> :
# the -> the
# gravitational -> gravitational
# and -> and
# electric -> electric
# fields -> field
# of -> of
# a -> a
# black -> black
# hole -> hole
# give -> give
# very -> very
# little -> little
# information -> information
# about -> about
# what -> what
# went -> go
# in -> in
# . -> .
# The -> the
# information -> information
# that -> that
# is -> be
# lost -> lose
# includes -> include
# every -> every
# quantity -> quantity
# that -> that
# can -> can
# not -> not
# be -> be
# measured -> measure
# far -> far
# away -> away
# from -> from
# the -> the
# black -> black
# hole -> hole
# horizon -> horizon
# , -> ,
# including -> include
# approximately -> approximately
# conserved -> conserve
# quantum -> quantum
# numbers -> number
# such -> such
# as -> as
# the -> the
# total -> total
# baryon -> baryon
# number -> number
# and -> and
# lepton -> lepton
# number -> number
# . -> .
# This -> this
# behavior -> behavior
# is -> be
# so -> so
# puzzling -> puzzle
# that -> that
# it -> it
# has -> have
# been -> be
# called -> call
# the -> the
# black -> black
# hole -> hole
# information -> information
# loss -> loss
# paradox -> paradox
# . -> .
# Physical -> physical
# properties -> property
# [ -> [
# edit -> edit
# ] -> ]
# An -> an
# animation -> animation
# of -> of
# how -> how
# light -> light
# rays -> ray
# can -> can
# be -> be
# gravitationally -> gravitationally
# bent -> bent
# The -> the
# simplest -> simple
# static -> static
# black -> black
# holes -> hole
# have -> have
# mass -> mass
# but -> but
# neither -> neither
# electric -> electric
# charge -> charge
# nor -> nor
# angular -> angular
# momentum -> momentum
# . -> .
# These -> these
# black -> black
# holes -> hole
# are -> be
# often -> often
# referred -> refer
# to -> to
# as -> as
# Schwarzschild -> Schwarzschild
# black -> black
# holes -> hole
# after -> after
# Karl -> Karl
# Schwarzschild -> Schwarzschild
# who -> who
# discovered -> discover
# this -> this
# solution -> solution
# in -> in
# 1916 -> 1916
# . -> .
# According -> accord
# to -> to
# Birkhoff\ -> Birkhoff\
# 's -> 's
# theorem -> theorem
# , -> ,
# it -> it
# is -> be
# the -> the
# only -> only
# vacuum -> vacuum
# solution -> solution
# that -> that
# is -> be
# spherically -> spherically
# symmetric -> symmetric
# . -> .
# This -> this
# means -> mean
# there -> there
# is -> be
# no -> no
# observable -> observable
# difference -> difference
# at -> at
# a -> a
# distance -> distance
# between -> between
# the -> the
# gravitational -> gravitational
# field -> field
# of -> of
# such -> such
# a -> a
# black -> black
# hole -> hole
# and -> and
# that -> that
# of -> of
# any -> any
# other -> other
# spherical -> spherical
# object -> object
# of -> of
# the -> the
# same -> same
# mass -> mass
# . -> .
# The -> the
# popular -> popular
# notion -> notion
# of -> of
# a -> a
# black -> black
# hole -> hole
# " -> "
# sucking -> suck
# in -> in
# everything -> everything
# " -> "
# in -> in
# its -> its
# surroundings -> surrounding
# is -> be
# therefore -> therefore
# correct -> correct
# only -> only
# near -> near
# a -> a
# black -> black
# hole\ -> hole\
# 's -> 's
# horizon -> horizon
# ; -> ;
# far -> far
# away -> away
# , -> ,
# the -> the
# external -> external
# gravitational -> gravitational
# field -> field
# is -> be
# identical -> identical
# to -> to
# that -> that
# of -> of
# any -> any
# other -> other
# body -> body
# of -> of
# the -> the
# same -> same
# mass -> mass
# . -> .
# Solutions -> solution
# describing -> describe
# more -> more
# general -> general
# black -> black
# holes -> hole
# also -> also
# exist -> exist
# . -> .
# Non -> non
# - -> -
# rotating -> rotating
# charged -> charge
# black -> black
# holes -> hole
# are -> be
# described -> describe
# by -> by
# the -> the
# Reissner -> Reissner
# – -> –
# Nordström -> Nordström
# metric -> metric
# , -> ,
# while -> while
# the -> the
# Kerr -> Kerr
# metric -> metric
# describes -> describe
# a -> a
# non -> non
# - -> -
# charged -> charged
# rotating -> rotate
# black -> black
# hole -> hole
# . -> .
# The -> the
# most -> most
# general -> general
# stationary -> stationary
# black -> black
# hole -> hole
# solution -> solution
# known -> know
# is -> be
# the -> the
# Kerr -> Kerr
# – -> –
# Newman -> Newman
# metric -> metric
# , -> ,
# which -> which
# describes -> describe
# a -> a
# black -> black
# hole -> hole
# with -> with
# both -> both
# charge -> charge
# and -> and
# angular -> angular
# momentum -> momentum
# . -> .
# While -> while
# the -> the
# mass -> mass
# of -> of
# a -> a
# black -> black
# hole -> hole
# can -> can
# take -> take
# any -> any
# positive -> positive
# value -> value
# , -> ,
# the -> the
# charge -> charge
# and -> and
# angular -> angular
# momentum -> momentum
# are -> be
# constrained -> constrain
# by -> by
# the -> the
# mass -> mass
# . -> .
# The -> the
# total -> total
# electric -> electric
# charge -> charge
# Q -> Q
# and -> and
# the -> the
# total -> total
# angular -> angular
# momentum -> momentum
# J -> J
# are -> be
# expected -> expect
# to -> to
# satisfy -> satisfy
# the -> the
# inequality -> inequality
# Q -> Q
# 2 -> 2
# 4 -> 4
# π -> π
# ϵ -> ϵ
# 0 -> 0
# + -> +
# ...
#  '2015 eht detect magnetic field outside event horizon sagittarius a * even discern property',
#  'field line pass accretion disc complex mixture order tangle',
#  'theoretical study black hole predict existence magnetic field',
#  'april 2023 image shadow messier 87 black hole related high energy jet view together first time present',
#  'detection gravitational wave merge black hole ligo measurement gravitational wave livingston hanford detector compare theoretical predict value 14 september 2015 ligo gravitational wave observatory make first ever successful direct observation gravitational wave',
#  'signal consistent theoretical prediction gravitational wave produce merger two black hole one 36 solar masse around 29 solar masse',
#  'observation provide concrete evidence existence black hole date',
#  'instance gravitational wave signal suggest separation two object merger 350xa0 km',
#  'object must therefore extremely compact leave black hole plausible interpretation',
#  'importantly signal observe ligo also include start post merger ringdown signal produce newly form compact object settle stationary state',
#  'arguably ringdown direct way observe black hole',
#  'ligo signal possible extract frequency damp time dominant mode ringdown',
#  'possible infer mass angular momentum final object match independent prediction numerical simulation merger',
#  'frequency decay time dominant mode determine geometry photon sphere',
#  'hence observation mode confirm presence photon sphere',
#  'however exclude possible exotic alternative black hole compact enough photon sphere',
#  'observation also provide first observational evidence existence stellar mass black hole binary',
#  'furthermore first observational evidence stellar mass black hole weigh 25 solar masse',
#  'since many gravitational wave event observe',
#  'star orbit sagittarius a * main article sagittarius a * cluster stars move around sagittarius a * see 2021 proper motion star near centre milky way provide strong observational evidence star orbit supermassive black hole',
#  'since 1995 astronomer track motion 90 star orbit invisible object coincident radio source sagittarius a *',
#  'fit motion keplerian orbit astronomer able infer 1998 2.6 × 10 6 m ☉ object must contain volume radius 0.02 light year cause motion star',
#  'since one star — call s2 — complete full orbit',
#  'orbital datum astronomer able refine calculation mass 4.3 × 10 6 m ☉ radius less 0.002 light year object cause orbital motion star',
#  'upper limit object size still large test whether small schwarzschild radius',
#  'nevertheless observation strongly suggest central object supermassive black hole plausible scenario confine much invisible mass small volume',
#  'additionally observational evidence object might possess event horizon feature unique black hole',
#  'accretion matter see also accretion disk blurring x ray near black hole due conservation angular momentum gas fall gravitational well create massive object typically form disk like structure around object',
#  'artists impression accompany representation black hole corona commonly depict black hole flat space body hide part disk behind reality gravitational lense would greatly distort image accretion disk',
#  'within disk friction would cause angular momentum transport outward allow matter fall far inward thus release potential energy increase temperature gas',
#  'accrete object neutron star black hole gas inner accretion disk orbit high speed proximity compact object',
#  'result friction significant heat inner disk temperature emit vast amount electromagnetic radiation',
#  'bright x ray source may detect telescope',
#  'process accretion one efficient energy produce process know',
#  '40 % rest mass accrete material emit radiation',
#  'many case accretion disk accompany relativistic jet emit along pole carry away much energy',
#  'mechanism creation jet currently well understand part due insufficient datum',
#  'many universe energetic phenomenon attribute accretion matter black hole',
#  'particular active galactic nucleus quasar believe accretion disk supermassive black hole',
#  'similarly x ray binary generally accept binary star system one two star compact object accrete matter companion',
#  'also suggest ultraluminous x ray source may accretion disk intermediate mass black hole',
#  'november 2011 first direct observation quasar accretion disk around supermassive black hole report',
#  'x ray binary see also x ray binary a chandra x ray observatory image cygnus x 1 first strong black hole candidate discover x ray binary binary star system emit majority radiation x ray part spectrum',
#  'x ray emission generally think result one star accrete matter another star',
#  'presence ordinary star system provide opportunity study central object determine might black hole',
#  'system emit signal directly trace back compact object black hole',
#  'absence signal however exclude possibility compact object neutron star',
#  'study companion star often possible obtain orbital parameter system obtain estimate mass compact object',
#  'much large tolman – oppenheimer – volkoff limit object neutron star generally expect black hole',
#  'first strong candidate black hole cygnus x 1 discover way charles thomas bolton louise webster paul murdin 1972',
#  'doubt however remain due uncertainty result companion star much heavy candidate black hole',
#  'currently well candidate black hole find class x ray binary call soft x ray transient',
#  'class system companion star relatively low mass allow accurate estimate black hole mass',
#  'moreover system actively emit x ray several month every 10–50 year',
#  'period low x ray emission accretion disk extremely faint allow detailed observation companion star period',
#  'one good candidate v404 cygni',
#  'quasi periodic oscillation main article quasi periodic oscillation x ray emission accretion disk sometimes flicker certain frequency',
#  'signal call quasi periodic oscillation think cause material move along inner edge accretion disk',
#  'frequency link mass compact object',
#  'thus use alternative way determine mass candidate black hole',
#  'galactic nucleus see also active galactic nucleus detection unusually bright x ray flare sagittarius a * black hole centre milky way galaxy 5 january 2015 astronomers use term active galaxy describe galaxy unusual characteristic unusual spectral line emission strong radio emission',
#  'theoretical observational study show activity active galactic nucleus may explain presence supermassive black hole million time massive stellar one',
#  'model agn consist central black hole may million billion time massive sun',
#  'disk interstellar gas dust call accretion disk',
#  'two jet perpendicular accretion disk',
#  'although supermassive black hole expect find agn galaxies nucleus carefully study attempt identify measure actual masse central supermassive black hole candidate',
#  'notable galaxy supermassive black hole candidate include andromeda galaxy m32 m87 ngc 3115 ngc 3377 ngc 4258 ngc 4889 ngc 1277 oj 287 apm 08279 + 5255 sombrero galaxy',
#  'widely accept centre nearly every galaxy active one contain supermassive black hole',
#  'close observational correlation mass hole velocity dispersion host galaxy bulge know m – sigma relation strongly suggest connection formation black hole galaxy',
#  'microlensing another way black hole nature object may test observation effect cause strong gravitational field vicinity',
#  'one effect gravitational lense deformation spacetime around massive object cause light ray deflect light pass optic lens',
#  'observation make weak gravitational lense light ray deflect arcsecond',
#  'microlensing occur source unresolved observer see small brightening',
#  'january 2022 astronomer report first possible detection microlensing event isolated black hole',
#  'another possibility observe gravitational lense black hole would observe star orbit black hole',
#  'several candidate observation orbit around sagittarius a *',
#  'alternative see also exotic star evidence stellar black hole strongly rely existence upper limit mass neutron star',
#  'size limit heavily depend assumption make property dense matter',
#  'new exotic phase matter could push bind',
#  'phase free quark high density might allow existence dense quark star supersymmetric model predict existence q star',
#  'extension standard model posit existence preon fundamental building block quark lepton could hypothetically form preon star',
#  'hypothetical model could potentially explain number observation stellar black hole candidate',
#  'however show argument general relativity object maximum mass',
#  'since average density black hole inside schwarzschild radius inversely proportional square mass supermassive black hole much less dense stellar black hole',
#  'consequently physics matter form supermassive black hole much well understand possible alternative explanation supermassive black hole observation much mundane',
#  'example supermassive black hole could model large cluster dark object',
#  'however alternative typically stable enough explain supermassive black hole candidate',
#  'evidence existence stellar supermassive black hole imply order black hole form general relativity must fail theory gravity perhaps due onset quantum mechanical correction',
#  'much anticipate feature theory quantum gravity feature singularity event horizon thus black hole would real artifact',
#  'example fuzzball model base string theory individual state black hole solution generally event horizon singularity classical / semi classical observer statistical average state appear ordinary black hole deduce general relativity',
#  'theoretical object conjecture match observation astronomical black hole candidate identically near identically function via different mechanism',
#  'include gravastar black star dark energy star',
#  'open question entropy thermodynamic information black hole thermodynamic bekenstein bind = 1 / 4 c 3 k / għ formula bekenstein – hawk entropy black hole depend area black hole',
#  'constant speed light boltzmann constant newton constant reduce planck constant',
#  'planck unit reduce = a / 4',
#  '1971 hawking show general condition [ note 5 ] total area event horizon collection classical black hole never decrease even collide merge',
#  'result know second law black hole mechanic remarkably similar second law thermodynamic state total entropy isolated system never decrease',
#  'classical object absolute zero temperature assume black hole zero entropy',
#  'case second law thermodynamic would violate entropy laden matter enter black hole result decrease total entropy universe',
#  'therefore bekenstein propose black hole entropy proportional horizon area',
#  'link law thermodynamic far strengthen hawking discovery 1974 quantum field theory predict black hole radiate blackbody radiation constant temperature',
#  'seemingly cause violation second law black hole mechanic since radiation carry away energy black hole cause shrink',
#  'radiation however also carry away entropy prove general assumption sum entropy matter surround black hole one quarter area horizon measure planck unit fact always increase',
#  'allow formulation first law black hole mechanic analogue first law thermodynamic mass acting energy surface gravity temperature area entropy',
#  'one puzzle feature entropy black hole scale area rather volume since entropy normally extensive quantity scale linearly volume system',
#  'odd property lead gerard t hooft leonard susskind propose holographic principle suggest anything happen volume spacetime describe datum boundary volume',
#  'although general relativity use perform semi classical calculation black hole entropy situation theoretically unsatisfying',
#  'statistical mechanic entropy understand count number microscopic configuration system macroscopic quality',
#  'without satisfactory theory quantum gravity one perform computation black hole',
#  'progress make various approach quantum gravity',
#  '1995 andrew strominger cumrun vafa show count microstate specific supersymmetric black hole string theory reproduce bekenstein – hawking entropy',
#  'since similar result report different black hole string theory approach quantum gravity like loop quantum gravity',
#  'another promising approach constitute treat gravity effective field theory',
#  'one first compute quantum gravitational correction radius event horizon black hole integrate find quantum gravitational correction entropy give wald formula',
#  'method apply schwarzschild black hole calmet kuipers successfully generalise charge black hole campos delgado',
#  'information loss paradox main article black hole information paradox unsolved problem physics physical information lose black hole ? black hole internal parameter information matter go form black hole lose',
#  'regardless type matter go black hole appear information concern total mass charge angular momentum conserve',
#  'long black hole think persist forever information loss problematic information think exist inside black hole inaccessible outside represent event horizon accordance holographic principle',
#  'however black hole slowly evaporate emit hawk radiation',
#  'radiation appear carry additional information matter form black hole mean information appear go forever',
#  'question whether information truly lose black hole divide theoretical physics community',
#  'quantum mechanic loss information correspond violation property call unitarity argue loss unitarity would also imply violation conservation energy though also dispute',
#  'recent year evidence build indeed information unitarity preserve full quantum gravitational treatment problem',
#  'one attempt resolve black hole information paradox know black hole complementarity',
#  '2012 firewall paradox introduce goal demonstrate black hole complementarity fail solve information paradox',
#  'accord quantum field theory curve spacetime single emission hawk radiation involve two mutually entangle particle',
#  'outgoing particle escape emit quantum hawk radiation',
#  'infalle particle swallow black hole',
#  'assume black hole form finite time past fully evaporate away finite time future',
#  'emit finite amount information encode within hawking radiation',
#  'accord research physicist like don page leonard susskind eventually time outgoing particle must entangle hawking radiation black hole previously emit',
#  'seemingly create paradox principle call monogamy entanglement require like quantum system outgoing particle fully entangle two system time',
#  'yet outgoing particle appear entangle infalle particle independently past hawk radiation',
#  'order resolve contradiction physicist may eventually force give one three time test principle einstein equivalence principle unitarity local quantum field theory',
#  'one possible solution violate equivalence principle firewall destroy incoming particle event horizon',
#  'general — — assumption abandon remain topic debate',
#  'see also binary black hole black brane black string black hole initiative black hole starship black hole fiction blanet btz black hole charge black hole direct collapse black hole hypothetical black hole kugelblitz list black hole list near black hole outline black hole sonic black hole virtual black hole susskind hawk battle timeline black hole physics white hole planck star dark star schwarzschild radius notes ^ value cj / gm 2 exceed 1 object black hole',
#  'large value know neutron star ≤ 0.4 commonly use equation state would limit value < 0.7',
#  '^ event horizon radius scale m + m 2 − 2 − q 2',
#  'displaystyle m+sqrt m^2 ^2 q^2',
#  '^ set possible path accurately future light cone contain possible world line tilt way eddington – finkelstein coordinate coordinate light cone tilt way example schwarzschild coordinate narrow without tilt one approach event horizon kruskal – szekere coordinate light cone change shape orientation',
#  '^ true four dimensional spacetime',
#  'high dimension complicated horizon topology like black ring possible',
#  '^ particular assume matter satisfy weak energy condition .']

# %%
most_common_tokens
# Out:
# [('.', 436),
#  ('black', 335),
#  ('hole', 325),
#  ('mass', 78),
#  ('star', 77),
#  ('object', 65),
#  ('horizon', 55),
#  ('event', 54),
#  ('gravitational', 51),
#  ('would', 47),
#  ('light', 37),
#  ('collapse', 37),
#  ('form', 34),
#  ('time', 32),
#  ('general', 32),
#  ('m', 32),
#  ('supermassive', 31),
#  ('theory', 30),
#  ('quantum', 30),
#  ('radiation', 30),
#  ('–', 30),
#  ('relativity', 28),
#  ('gravity', 27),
#  ('schwarzschild', 26),
#  ('solution', 26),
#  ('matter', 26),
#  ('ray', 26),
#  ('singularity', 25),
#  ('field', 24),
#  ('first', 23),
#  ('way', 22),
#  ('emit', 22),
#  ('possible', 22),
#  ('x', 22),
#  ('observation', 22),
#  ('one', 22),
#  ('radius', 22),
#  ('information', 22),
#  ('energy', 21),
#  ('accretion', 21),
#  ('orbit', 21),
#  ('particle', 21),
#  ('effect', 20),
#  ('also', 20),
#  ('process', 20),
#  ('charge', 20),
#  ('2', 20),
#  ('spacetime', 19),
#  ('☉', 19),
#  ('10', 19),
#  ('galaxy', 18),
#  ('disk', 18),
#  ('could', 18),
#  ('however', 18),
#  ('observer', 18),
#  ('away', 18),
#  ('use', 17),
#  ('see', 17),
#  ('einstein', 17),
#  ('temperature', 17),
#  ('*', 17),
#  ('entropy', 17),
#  ('escape', 16),
#  ('predict', 16),
#  ('hawking', 16),
#  ('system', 16),
#  ('photon', 16),
#  ('like', 15),
#  ('stellar', 15),
#  ('find', 15),
#  ('show', 15),
#  ('neutron', 15),
#  ('candidate', 15),
#  ('density', 15),
#  ('hawk', 15),
#  ('expect', 15),
#  ('image', 14),
#  ('around', 14),
#  ('observe', 14),
#  ('compact', 14),
#  ('know', 14),
#  ('centre', 14),
#  ('a', 14),
#  ('far', 14),
#  ('result', 14),
#  ('rotate', 14),
#  ('angular', 14),
#  ('momentum', 14),
#  ('appear', 14),
#  ('sphere', 14),
#  ('wave', 13),
#  ('call', 13),
#  ('body', 13),
#  ('universe', 13),
#  ('describe', 13),
#  ('high', 13),
#  ('law', 13),
#  ('cause', 13),
#  ('strong', 12),
#  ('1', 12),
#  ('may', 12),
#  ('sagittarius', 12),
#  ('early', 12),
#  ('property', 12),
#  ('allow', 12),
#  ('existence', 12),
#  ('much', 12),
#  ('outside', 12),
#  ('limit', 12),
#  ('small', 12),
#  ('since', 12),
#  ('direct', 11),
#  ('many', 11),
#  ('make', 11),
#  ('fall', 11),
#  ('binary', 11),
#  ('even', 11),
#  ('surface', 11),
#  ('kerr', 11),
#  ('take', 11)]

# %%
concat_data = " ".join(splited_data)

# %%
counterToDict = { key:value for key, value in Counter(concat_data.split(" ")).items() if value < 2 }
wordCounter = { key:value for key, value in Counter(concat_data.split(" ")).items() }

#sorted(counterToDict, key=lambda x: x) 
counterToDict

sorted_dict = {k: v for k, v in sorted(counterToDict.items(), key=lambda item: item[1], reverse=False)}
print(sorted_dict)
print(f"Number of unique words {len(sorted_dict)}" ) # 1234 => 896 => 863
# Out:
# {'': 1, 'return': 1, 'animated': 1, 'alignment': 1, 'sufficiently': 1, 'fate': 1, 'circumstance': 1, 'locally': 1, 'ideal': 1, 'reflect': 1, 'curved': 1, 'billionth': 1, 'kelvin': 1, 'essentially': 1, 'whose': 1, '18th': 1, 'pierre': 1, 'simon': 1, 'laplace': 1, 'characterize': 1, 'spark': 1, 'cycle': 1, 'consensus': 1, 'toward': 1, 'shred': 1, 'streamer': 1, 'shine': 1, 'brightly': 1, 'numerous': 1, 'establish': 1, '4.3xa0million': 1, 'idea': 1, 'english': 1, 'pioneer': 1, 'clergyman': 1, '1784': 1, 'simplistic': 1, 'factor': 1, '500': 1, 'usual': 1, 'correctly': 1, 'radiating': 1, 'nearby': 1, 'scholar': 1, 'initially': 1, 'excite': 1, 'proposal': 1, 'giant': 1, 'plain': 1, 'enthusiasm': 1, 'dampen': 1, 'wavelike': 1, 'apparent': 1, 'nineteenth': 1, 'unclear': 1, 'discredit': 1, 'shoot': 1, 'geodesic': 1, 'λ': 1, 'κ': 1, 'lambda': 1, 'kappa': 1, 't_mu': 1, 'introduction': 1, 'tests': 1, 'concept': 1, 'pseudo': 1, 'riemannian': 1, 'manifold': 1, 'phenomena': 1, 'kepler': 1, 'geodetic': 1, 'diagram': 1, 'minkowski': 1, 'rosen': 1, 'bridge': 1, 'linearized': 1, 'friedmann': 1, 'geodesics': 1, 'mathisson': 1, 'papapetrou': 1, 'dixon': 1, 'hamilton': 1, 'jacobi': 1, 'adm': 1, 'bssn': 1, 'advanced': 1, 'kaluza': 1, 'klein': 1, 'solutions': 1, 'kasner': 1, 'nut': 1, 'pp': 1, 'weyl−lewis−papapetrou': 1, 'scientists': 1, 'hilbert': 1, 'poincaré': 1, 'weyl': 1, 'friedman': 1, 'zwicky': 1, 'ehlers': 1, 'raychaudhuri': 1, 'taylor': 1, 'hulse': 1, 'yau': 1, 'thorne': 1, 'portal': 1, 'category': 1, 'v': 1, 'e': 1, 'albert': 1, 'johannes': 1, 'droste': 1, 'hendrik': 1, 'write': 1, 'extensively': 1, 'quite': 1, '1924': 1, '1933': 1, 'georges': 1, 'realize': 1, 'comment': 1, 'compress': 1, '1926': 1, 'book': 1, 'overly': 1, 'betelgeuse': 1, '250': 1, 'firstly': 1, 'unable': 1, 'stone': 1, 'secondly': 1, 'thirdly': 1, '1931': 1, 'subrahmanyan': 1, 'calculate': 1, 'electron': 1, 'degenerate': 1, 'limiting': 1, 'oppose': 1, 'lev': 1, 'landau': 1, 'unknown': 1, 'partly': 1, 'dwarf': 1, 'reason': 1, 'intervene': 1, 'least': 1, 'pauli': 1, 'exclusion': 1, 'subsequent': 1, 'consideration': 1, 'repulsion': 1, 'mediate': 1, '3.0': 1, 'gw170817': 1, 'generate': 1, 'afterward': 1, 'tov': 1, '~2.17': 1, 'co': 1, 'author': 1, 'interpret': 1, 'bubble': 1, 'valid': 1, 'frozen': 1, 'freeze': 1, 'instant': 1, 'gravitating': 1, 'masses': 1, 'defend': 1, 'hartland': 1, 'continued': 1, 'contraction': 1, 'unidirectional': 1, 'causal': 1, 'strictly': 1, 'contradict': 1, 'martin': 1, 'urge': 1, 'come': 1, 'mark': 1, 'mainstream': 1, 'help': 1, '1969': 1, 'regard': 1, 'relevance': 1, 'spur': 1, 'roy': 1, 'exact': 1, 'ezra': 1, 'axisymmetric': 1, 'electrically': 1, 'werner': 1, 'israel': 1, 'brandon': 1, 'robinson': 1, 'suspect': 1, 'strange': 1, 'impose': 1, 'vladimir': 1, 'belinsky': 1, 'isaak': 1, 'khalatnikov': 1, 'evgeny': 1, 'lifshitz': 1, 'try': 1, 'late': 1, 'roger': 1, 'stephen': 1, 'global': 1, 'generically': 1, '2020': 1, 'nobel': 1, 'prize': 1, 'die': 1, '2018': 1, 'greenwich': 1, 'toronto': 1, 'james': 1, 'jacob': 1, 'relate': 1, 'february': 1, '2016': 1, 'scientific': 1, 'announce': 1, 'update': 1, 'gaia': 1, 'bh1': 1, '560': 1, 'couple': 1, 'dozen': 1, 'solitary': 1, 'etymology': 1, '1783': 1, 'henry': 1, 'cavendish': 1, '20th': 1, 'writer': 1, 'marcia': 1, 'bartusiak': 1, 'h.': 1, 'dicke': 1, 'calcutta': 1, 'notorious': 1, 'prison': 1, 'people': 1, 'alive': 1, 'print': 1, 'news': 1, 'magazine': 1, 'journalist': 1, 'ann': 1, 'ewing': 1, '18': 1, 'meeting': 1, 'american': 1, 'association': 1, 'advancement': 1, 'cleveland': 1, 'ohio': 1, 'december': 1, 'lecture': 1, 'adopt': 1, 'brevity': 1, 'advertising': 1, 'credit': 1, 'coin': 1, 'postulate': 1, 'otherwise': 1, 'featureless': 1, 'share': 1, 'indistinguishable': 1, 'degree': 1, 'repel': 1, 'analog': 1, 'gauss': 1, 'likewise': 1, 'gravitomagnetic': 1, 'thirring': 1, 'artistic': 1, 'depiction': 1, 'evenly': 1, 'distribute': 1, 'dissipative': 1, 'closely': 1, 'analogous': 1, 'conductive': 1, 'stretchy':  ...
# Number of unique words 854

# %%
for k, train_sentence in train_data[0:20]:
    print(train_sentence)
# Out:
#  object return boundary use see black hole
# direct radio image supermassive black hole core messier 87 animated simulation schwarzschild black hole galaxy pass behind
# around time alignment extreme gravitational lensing galaxy observe
# black hole region spacetime gravity strong nothing include light electromagnetic wave enough energy escape
# einstein theory general relativity predict sufficiently compact mass deform spacetime form black hole
# boundary escape call event horizon
# black hole great effect fate circumstance object cross locally detectable feature accord general relativity
# many way black hole act like ideal black body reflect light
# moreover quantum field theory curved spacetime predict event horizon emit hawking radiation spectrum black body temperature inversely proportional mass
# temperature order billionth kelvin stellar black hole make essentially impossible observe directly
# object whose gravitational field strong light escape first consider 18th century john michell pierre simon laplace
# 1916 karl schwarzschild find first modern solution general relativity would characterize black hole
# david finkelstein 1958 first publish interpretation black hole region space nothing escape
# black hole long consider mathematical curiosity
# 1960 theoretical work show generic prediction general relativity
# discovery neutron star jocelyn bell burnell 1967 spark interest gravitationally collapse compact object possible astrophysical reality
# first black hole know cygnus x 1 identify several researcher independently 1971
# black hole stellar mass form massive star collapse end life cycle
# black hole form grow absorb mass surrounding
# supermassive black hole million solar masse may form absorb star merge black hole via direct collapse gas cloud

# %% [markdown]
# Per sentence, what is the lowest repeating word :

# %%
def lowest_repeating_word(sentence):
    repeating_words = []
    for word in sentence.split(" "):
        repeating_words.append((word, wordCounter[word]))
    return min(repeating_words, key=lambda x:x[1])
        
sentence_with_common_words = []
for k, train_sentence in train_data:
    lowest_repeated = lowest_repeating_word(train_sentence)[1]
    if lowest_repeated > 1 and "displaystyle" not in train_sentence and len(train_sentence.split(" "))>1:
       print(train_sentence, lowest_repeating_word(train_sentence), lowest_repeated)
       sentence_with_common_words.append(train_sentence)
    #sentence_with_common_words.append(train_sentence.strip())
# Out:
# black hole region spacetime gravity strong nothing include light electromagnetic wave enough energy escape ('nothing', 3) 3
# boundary escape call event horizon ('boundary', 10) 10
# david finkelstein 1958 first publish interpretation black hole region space nothing escape ('1958', 2) 2
# black hole long consider mathematical curiosity ('mathematical', 2) 2
# 1960 theoretical work show generic prediction general relativity ('generic', 3) 3
# first black hole know cygnus x 1 identify several researcher independently 1971 ('researcher', 2) 2
# black hole form grow absorb mass surrounding ('absorb', 4) 4
# supermassive black hole million solar masse may form absorb star merge black hole via direct collapse gas cloud ('via', 3) 3
# presence black hole infer interaction matter electromagnetic radiation visible light ('interaction', 2) 2
# star orbit black hole orbit use determine black hole mass location ('location', 3) 3
# observation use exclude possible alternative neutron star ('exclude', 3) 3
# michell refer body dark star ('refer', 4) 4
# month later karl schwarzschild find solution einstein field equation describe gravitational field point mass spherical mass ('later', 3) 3
# solution peculiar behaviour call schwarzschild radius become singular mean term einstein equation become infinite ('peculiar', 2) 2
# paper make reference einstein recent publication oppenheimer snyder use einstein theory general relativity show condition black hole could develop first time contemporary physics ('paper', 2) 2
# finkelstein solution extend schwarzschild solution future observer fall black hole ('extend', 3) 3
# period general black hole solution find ('period', 4) 4
# analogy complete hawking 1974 show quantum field theory imply black hole radiate like black body temperature proportional surface gravity black hole predict effect know hawk radiation ('analogy', 2) 2
# 10 april 2019 first direct image black hole vicinity publish follow observation make event horizon telescope 2017 supermassive black hole messier 87 galactic centre ('2019', 2) 2
# therefore would detectable gravitational lensing ('lensing', 2) 2
# property special visible outside black hole ('special', 3) 3
# black hole eventually achieve stable state three parameter way avoid lose information initial condition gravitational electric field black hole give little information go ('initial', 2) 2
# behavior puzzle call black hole information loss paradox ('behavior', 2) 2
# black hole often refer schwarzschild black hole karl schwarzschild discover solution 1916 ('often', 2) 2
# solution describe general black hole also exist ('exist', 7) 7
# general stationary black hole solution know kerr – newman metric describe black hole charge angular momentum ('stationary', 4) 4
# black hole minimum possible mass satisfy inequality call extremal ('minimum', 2) 2
# solution einstein equation violate inequality exist possess event horizon ('possess', 2) 2
# mass approx ('approx', 2) 2
# close black hole spacetime start deform ('start', 3) 3
# path go towards black hole path move away ('towards', 3) 3
# long possible particle escape ('long', 9) 9
# define feature black hole appearance event horizon — boundary spacetime matter light pass inward towards mass black hole ('define', 2) 2
# nothing even light escape inside event horizon ('nothing', 3) 3
# event horizon refer event occur within boundary information event reach outside observer make impossible determine whether event occur ('refer', 4) 4
# predict general relativity presence mass deform spacetime way path take particle bend towards mass ('bend', 2) 2
# event horizon black hole deformation become strong path lead away black hole ('deformation', 2) 2
# distant observer clock near black hole would appear tick slowly far away black hole ('distant', 2) 2
# due effect know gravitational time dilation object fall black hole appear slow approach event horizon take infinite time reach ('dilation', 3) 3
# eventually fall object fade away long see ('fade', 2) 2
# typically process happen rapidly object disappear view within less second ('disappear', 2) 2
# accord clock appear tick normally cross event horizon finite time without note singular behaviour ('clock', 2) 2
# classical general relativity impossible determine location event horizon local observation due einstein equivalence principle ('local', 2) 2
# singularity main article gravitational singularity centre black hole describe general relativity may lie gravitational singularity region spacetime curvature become infinite ('curvature', 2) 2
# non rotating black hole region take shape single point ('shape', 3) 3
# case singular region zero volume ('zero', 4) 4
# also show singular region contain mass black hole solution ('singular', 5) 5
# singular region thus think infinite density ('singular', 5) 5
# observer fall schwarzschild black hole avoid carry singularity cross event horizon ('avoid', 3) 3
# case charge rotate black hole possible avoid singularity ('avoid', 3) 3
# possibility travel another universe however theoretical since perturbation would destroy possibility ('travel', 2) 2
# appearance singularity general relativity commonly perceive signal breakdown theory ('appearance', 2) 2
# breakdown however expect ('breakdown', 2) 2
# generally expect theory feature singularity ('generally', 6) 6
# non rotating black hole photon sphere radius 1.5 time schwarzschild radius ('1.5', 2) 2
# hence light reach outside observer photon sphere must emit object photon sphere event horizon ('hence', 5) 5
# rotate black hole surround region spacetime impossible stand still call ergosphere ('stand', 2) 2
# object near rotate mass tend start move direction rotation ('tend', 2) 2
# object radiation escape normally ergosphere ('normally', 3) 3
# penrose process object emerge ergosphere energy enter ('emerge', 2) 2
# thereby rotation black hole slow ('thereby', 2) 2
# penrose demonstrate event horizon form general relativity without quantum mechanic require singularity form within ('demonstrate', 2) 2
# result one various type compact star ('various', 4) 4
# black hole could seed supermassive black hole find centre galaxy ('seed', 2) 2
# candidate object find observation young universe ('young', 2) 2
# energy release gravitational collapse emit quickly outside observer actually see end process ('quickly', 2) 2
# thus external observer never see formation event horizon ('external', 4) 4
# primordial black hole big bang gravitational collapse require great density ('require', 3) 3
# high energy collision gravitational collapse process could create black hole ('collision', 3) 3
# suggest must low limit mass black hole ('low', 7) 7
# growth black hole form continue grow absorb additional matter ('growth', 3) 3
# growth process one possible way supermassive black hole may form although formation supermassive black hole still open field research ('open', 2) 2
# black hole also merge object star even black hole ('merge', 4) 4
# effect become know hawk radiation ('become', 10) 10
# apply quantum field theory static black hole background determine black hole emit particle display perfect black body spectrum ('static', 2) 2
# hawking theory black hole radiation correct black hole expect shrink evaporate time lose mass emission photon particle ('correct', 3) 3
# temperature thermal spectrum proportional surface gravity black hole schwarzschild black hole inversely proportional mass ('thermal', 2) 2
# hence large black hole emit less radiation small black hole ('hence', 5) 5
# far less 2.7xa0 k temperature cosmic microwave background radiation ('2.7xa0', 2) 2
# stellar mass large black hole receive mass cosmic microwave background emit hawk radiation thus grow instead shrink ('microwave', 2) 2
# hawk temperature large 2.7xa0 k black hole would need mass less moon ('2.7xa0', 2) 2
# black hole small radiation effect expect become strong ('become', 10) 10
# low mass black hole expect evaporate even fast ('fast', 2) 2
# example black hole existence sometimes infer observe gravitational influence surrounding ('sometimes', 3) 3
# visible black hole — show black loss light within dark region ('visible', 6) 6
# instead gas edge event horizon define black hole ('define', 2) 2
# publish image display ring like structure circular shadow see m87 * black hole image create use technique m87 black hole ('display', 2) 2
# theoretical study black hole predict existence magnetic field ('magnetic', 3) 3
# object must therefore extremely compact leave black hole plausible interpretation ('plausible', 2) 2
# however exclude possible exotic alternative black hole compact enough photon sphere ('exclude', 3) 3
# observation also provide first observational evidence existence stellar mass black hole binary ('provide', 7) 7
# since many gravitational wave event observe ('many', 11) 11
# upper limit object size still large test whether small schwarzschild radius ('upper', 2) 2
# bright x ray source may detect telescope ('detect', 4) 4
# many case accretion disk accompany relativistic jet emit along pole carry away much energy ('accompany', 2) 2
# mechanism creation jet currently well understand part due insufficient datum ('currently', 3) 3
# similarly x ray binary generally accept binary star system one two star compact object accrete matter companion ('similarly', 2) 2
# x ray emission generally think result one star accrete matter another star ('accrete', 4) 4
# system emit signal directly trace back compact object black hole ('trace', 2) 2
# study companion star often possible obtain orbital parameter system obtain estimate mass compact object ('often', 2) 2
# signal call quasi periodic oscillation think cause material move along inner edge accretion disk ('quasi', 3) 3
# frequency link mass compact object ('link', 2) 2
# thus use alternative way determine mass candidate black hole ('alternative', 6) 6
# disk interstellar gas dust call accretion disk ('interstellar', 2) 2
# widely accept centre nearly every galaxy active one contain supermassive black hole ('widely', 2) 2
# microlensing another way black hole nature object may test observation effect cause strong gravitational field vicinity ('vicinity', 2) 2
# january 2022 astronomer report first possible detection microlensing event isolated black hole ('2022', 2) 2
# another possibility observe gravitational lense black hole would observe star orbit black hole ('another', 7) 7
# several candidate observation orbit around sagittarius a * ('several', 3) 3
# alternative see also exotic star evidence stellar black hole strongly rely existence upper limit mass neutron star ('rely', 2) 2
# phase free quark high density might allow existence dense quark star supersymmetric model predict existence q star ('phase', 2) 2
# however show argument general relativity object maximum mass ('maximum', 2) 2
# example supermassive black hole could model large cluster dark object ('cluster', 3) 3
# however alternative typically stable enough explain supermassive black hole candidate ('typically', 3) 3
# planck unit reduce = a / 4 ('unit', 2) 2
# therefore bekenstein propose black hole entropy proportional horizon area ('therefore', 5) 5
# seemingly cause violation second law black hole mechanic since radiation carry away energy black hole cause shrink ('seemingly', 2) 2
# however black hole slowly evaporate emit hawk radiation ('slowly', 2) 2
# radiation appear carry additional information matter form black hole mean information appear go forever ('forever', 2) 2
# one attempt resolve black hole information paradox know black hole complementarity ('resolve', 2) 2
# outgoing particle escape emit quantum hawk radiation ('outgoing', 4) 4
# infalle particle swallow black hole ('swallow', 2) 2
# assume black hole form finite time past fully evaporate away finite time future ('past', 2) 2
# yet outgoing particle appear entangle infalle particle independently past hawk radiation ('yet', 2) 2
# ^ event horizon radius scale m + m 2 − 2 − q 2 ('−', 2) 2

# %%
train_data
# Out:
# [(0, ' object return boundary use see black hole'),
#  (1,
#   'direct radio image supermassive black hole core messier 87 animated simulation schwarzschild black hole galaxy pass behind'),
#  (2, 'around time alignment extreme gravitational lensing galaxy observe'),
#  (3,
#   'black hole region spacetime gravity strong nothing include light electromagnetic wave enough energy escape'),
#  (4,
#   'einstein theory general relativity predict sufficiently compact mass deform spacetime form black hole'),
#  (5, 'boundary escape call event horizon'),
#  (6,
#   'black hole great effect fate circumstance object cross locally detectable feature accord general relativity'),
#  (7, 'many way black hole act like ideal black body reflect light'),
#  (8,
#   'moreover quantum field theory curved spacetime predict event horizon emit hawking radiation spectrum black body temperature inversely proportional mass'),
#  (9,
#   'temperature order billionth kelvin stellar black hole make essentially impossible observe directly'),
#  (10,
#   'object whose gravitational field strong light escape first consider 18th century john michell pierre simon laplace'),
#  (11,
#   '1916 karl schwarzschild find first modern solution general relativity would characterize black hole'),
#  (12,
#   'david finkelstein 1958 first publish interpretation black hole region space nothing escape'),
#  (13, 'black hole long consider mathematical curiosity'),
#  (14, '1960 theoretical work show generic prediction general relativity'),
#  (15,
#   'discovery neutron star jocelyn bell burnell 1967 spark interest gravitationally collapse compact object possible astrophysical reality'),
#  (16,
#   'first black hole know cygnus x 1 identify several researcher independently 1971'),
#  (17, 'black hole stellar mass form massive star collapse end life cycle'),
#  (18, 'black hole form grow absorb mass surrounding'),
#  (19,
#   'supermassive black hole million solar masse may form absorb star merge black hole via direct collapse gas cloud'),
#  (20, 'consensus supermassive black hole exist centre galaxy'),
#  (21,
#   'presence black hole infer interaction matter electromagnetic radiation visible light'),
#  (22,
#   'matter fall toward black hole form external accretion disk heat friction form quasar bright object universe'),
#  (23,
#   'star pass close supermassive black hole shred streamer shine brightly swallow'),
#  (24, 'star orbit black hole orbit use determine black hole mass location'),
#  (25, 'observation use exclude possible alternative neutron star'),
#  (26,
#   'way astronomer identify numerous stellar black hole candidate binary system establish radio source know sagittarius a * core milky way galaxy contain supermassive black hole 4.3xa0million solar masse'),
#  (27,
#   'history idea body big even light could escape briefly propose english astronomical pioneer clergyman john michell letter publish november 1784'),
#  (28,
#   'michell simplistic calculation assume body might density sun conclude one would form star diameter exceed sun factor 500 surface escape velocity exceed usual speed light'),
#  (29, 'michell refer body dark star'),
#  (30,
#   'correctly note supermassive non radiating body might detectable gravitational effect nearby visible body'),
#  (31,
#   'scholar time initially excite proposal giant invisible dark stars might hide plain view enthusiasm dampen wavelike nature light become apparent early nineteenth century light wave rather particle unclear influence gravity would escape light wave'),
#  (32,
#   'modern theory gravity general relativity discredit michell notion light ray shoot directly surface supermassive star slow star gravity stop free fall back star surface'),
#  (33,
#   'instead spacetime curve geodesic light travel never leave surface star'),
#  (34,
#   'general relativity see also history general relativity general relativity g μ ν + λ g μ ν = κ μ ν displaystyle g_mu nu + lambda g_mu nu = kappa t_mu nu introduction history timeline tests mathematical formulation fundamental concept equivalence principle special relativity world line pseudo riemannian manifold phenomena kepler problem gravitational lense gravitational red shift gravitational time dilation gravitational wave frame drag geodetic effect event horizon singularity black hole spacetime spacetime diagram minkowski spacetime einstein – rosen bridge equations formalisms equations linearized gravity einstein field equation friedmann geodesics mathisson – papapetrou – dixon hamilton – jacobi – einstein formalisms adm bssn post newtonian advanced theory kaluza – klein theory quantum gravity solutions schwarzschild reissner – nordström gödel kerr kerr – newman kerr – newman – de sitter kasner lemaître – tolman taub – nut milne robertson – walker oppenheimer – snyder pp wave van stockum dust weyl−lewis−papapetrou scientists einstein lorentz hilbert poincaré schwarzschild de sitter reissner nordström weyl eddington friedman milne zwicky lemaître oppenheimer gödel wheeler robertson bardeen walker kerr chandrasekhar ehlers penrose hawking raychaudhuri taylor hulse van stockum taub newman yau thorne physics portal category v e 1915 albert einstein develop theory general relativity early show gravity influence light motion'),
#  (35,
#   'month later karl schwarzschild find solution einstein field equation describe gravitational field point mass spherical mass'),
#  (36,
#   'month schwarzschild johannes droste student hendrik lorentz independently give solution point mass write extensively property'),
#  (37,
#   'solution peculiar behaviour call schwarzschild radius become singular mean term einstein equation become infinite'),
#  (38, 'nature surface quite understand time'),
#  (39,
#   '1924 arthur eddington show singularity disappear change coordinate although take 1933 georges lemaître realize mean singularity schwarzschild radius non physical coordinate singularity'),
#  (40,
#   'arthur eddington however comment possibility star mass compress schwarzschild radius 1926 book note einstein theory allow rule overly large density visible star like betelgeuse star 250 million km radius could possibly high density sun'),
#  (41,
#   'firstly force gravitation would great light would unable escape ray fall back star like stone earth'),
#  (42,
#   'secondly red shift spectral line would great spectrum would shift existence'),
#  (43,
#   'thirdly mass would produce much curvature spacetime metric space would close around star leave outside'),
#  (44,
#   '1931 subrahmanyan chandrasekhar calculate use special relativity non rotating body electron degenerate matter certain limiting mass stable solution'),
#  (45,
#   'argument oppose many contemporary like eddington lev landau argue yet unknown mechanism would stop collapse'),
#  (46,
#   'partly correct white dwarf slightly massive chandrasekhar limit collapse neutron star stable'),
#  (47,
#   '1939 robert oppenheimer predict neutron star another limit would collapse far reason present chandrasekhar conclude law physics likely intervene stop least star collapse black hole'),
#  (48, 'original calculation base pauli exclusion principle give 0.7 m ☉'),
#  (49,
#   'subsequent consideration neutron neutron repulsion mediate strong force raise estimate approximately 1.5 m ☉ 3.0 m ☉'),
#  (50,
#   'observation neutron star merger gw170817 think generate black hole shortly afterward refine tov limit estimate ~2.17 m ☉'),
#  (51,
#   'oppenheimer co author interpret singularity boundary schwarzschild radius indicate boundary bubble time stop'),
#  (52, 'valid point view external observer infalle observer'),
#  (53,
#   'property collapse star call frozen star outside observer would see surface star freeze time instant collapse take schwarzschild radius'),
#  (54,
#   'also 1939 einstein would attempt prove black hole impossible publication stationary system spherical symmetry consist many gravitating masses use theory general relativity defend argument'),
#  (55,
#   'month later oppenheimer student hartland snyder would provide oppenheimer – snyder model paper continued gravitational contraction predict existence black hole'),
#  (56,
#   'paper make reference einstein recent publication oppenheimer snyder use einstein theory general relativity show condition black hole could develop first time contemporary physics'),
#  (57,
#   'golden age 1958 david finkelstein identify schwarzschild surface event horizon perfect unidirectional membrane causal influence cross one direction'),
#  (58,
#   'strictly contradict oppenheimer result extend include point view infalle observer'),
#  (59,
#   'finkelstein solution extend schwarzschild solution future observer fall black hole'),
#  (60, 'complete extension already find martin kruskal urge publish'),
#  (61,
#   'result come beginning golden age general relativity mark general relativity black hole become mainstream subject research'),
#  (62,
#   'process help discovery pulsar jocelyn bell burnell 1967 1969 show rapidly rotate neutron star'),
#  (63, 'time neutron star like black hole regard theoretical curiosity'),
#  (64,
#   'discovery pulsar show physical relevance spur interest type compact object might form gravitational collapse'),
#  (65, 'period general black hole solution find'),
#  (66, '1963 roy kerr find exact solution rotate black hole'),
#  (67,
#   'two year later ezra newman find axisymmetric solution black hole rotate electrically charge'),
#  (68,
#   'work werner israel brandon carter david robinson hair theorem emerge state stationary black hole solution completely describe three parameter kerr – newman metric mass angular momentum electric charge'),
#  (69,
#   'first suspect strange feature black hole solution pathological artifact symmetry condition impose singularity would appear generic situation'),
#  (70,
#   'view hold particular vladimir belinsky isaak khalatnikov evgeny lifshitz try prove singularity appear generic solution'),
#  (71,
#   'however late 1960 roger penrose stephen hawking use global technique prove singularity appear generically'),
#  (72, 'work penrose receive half 2020 nobel prize physics hawk die 2018'),
#  (73,
#   'base observation greenwich toronto early 1970 cygnus x 1 galactic x ray source discover 1964 become first astronomical object commonly accept black hole'),
#  (74,
#   'work james bardeen jacob bekenstein carter hawk early 1970 lead formulation black hole thermodynamic'),
#  (75,
#   'law describe behaviour black hole close analogy law thermodynamic relate mass energy area entropy surface gravity temperature'),
#  (76,
#   'analogy complete hawking 1974 show quantum field theory imply black hole radiate like black body temperature proportional surface gravity black hole predict effect know hawk radiation'),
#  (77,
#   'observation 11 february 2016 ligo scientific collaboration virgo collaboration announce first direct detection gravitational wave represent first observation black hole merger'),
#  (78,
#   '10 april 2019 first direct image black hole vicinity publish follow observation make event horizon telescope 2017 supermassive black hole messier 87 galactic centre'),
#  (79,
#   '2023 [ update ] near know body think black hole gaia bh1 around 1 560 light year away'),
#  (80,
#   'though couple dozen black hole find far milky way think hundred million solitary cause emission radiation'),
#  (81, 'therefore would detectable gravitational lensing'),
#  (82,
#   'etymology john michell use term dark star november 1783 letter henry cavendish early 20th century physicist use term gravitationally collapse object'),
#  (83,
#   'science writer marcia bartusiak trace term black hole physicist robert h. dicke early 1960 reportedly compare phenomenon black hole calcutta notorious prison people enter never leave alive'),
#  (84,
#   'term black hole use print life science news magazine 1963 science journalist ann ewing article black holes space date 18 january 1964 report meeting american association advancement science hold cleveland ohio'),
#  (85,
#   'december 1967 student reportedly suggest phrase black hole lecture john wheeler'),
#  (86,
#   'wheeler adopt term brevity advertising value quickly catch lead credit wheeler coin phrase'),
#  (87,
#   'property structure hair theorem postulate achieve stable condition formation black hole three independent physical property mass electric charge angular momentum'),
#  (88, 'black hole otherwise featureless'),
#  (89,
#   'conjecture true two black hole share value property parameter indistinguishable one another'),
#  (90,
#   'degree conjecture true real black hole law modern physics currently unsolved problem'),
#  (91, 'property special visible outside black hole'),
#  (92, 'example charge black hole repel like charge like charge object'),
#  (93,
#   'similarly total mass inside sphere contain black hole find use gravitational analog gauss law far away black hole'),
#  (94,
#   'likewise angular momentum measure far away use frame drag gravitomagnetic field example lense – thirring effect'),
#  (95,
#   'artistic depiction black hole feature object fall black hole information shape object distribution charge evenly distribute along horizon black hole lose outside observer'),
#  (96,
#   'behavior horizon situation dissipative system closely analogous conductive stretchy membrane friction electrical resistance — membrane paradigm'),
#  (97,
#   'different field theory electromagnetism friction resistivity microscopic level time reversible'),
#  (98,
#   'black hole eventually achieve stable state three parameter way avoid lose information initial condition gravitational electric field black hole give little information go'),
#  (99,
#   'information lose include every quantity measure far away black hole horizon include approximately conserve quantum number total baryon number lepton number'),
#  (100, 'behavior puzzle call black hole information loss paradox'),
#  (101,
#   'physical property animation light ray gravitationally bent simple static black hole mass neither electric charge angular momentum'),
#  (102,
#   'black hole often refer schwarzschild black hole karl schwarzschild discover solution 1916'),
#  (103, 'accord birkhoff theorem vacuum solution spherically symmetric'),
#  (104,
#   'mean observable difference distance gravitational field black hole spherical object mass'),
#  (105,
#   'popular notion black hole suck everything surrounding therefore correct near black hole horizon'),
#  (106, 'far away external gravitational field identical body mass'),
#  (107, 'solution describe general black hole also exist'),
#  (108,
#   'non rotating charge black hole describe reissner – nordström metric kerr metric describe non charged rotate black hole'),
#  (109,
#   'general stationary black hole solution know kerr – newman metric describe black hole charge angular momentum'),
#  (110,
#   'mass black hole take positive value charge angular momentum constrain mass'),
#  (111,
#   'total electric charge q total angular momentum j expect satisfy inequality q 2 4 π ϵ 0 + c 2 j 2 g 2 ≤ g m 2 displaystyle frac q^24pi epsilon _ 0+frac c^2j^2gm^2leq gm^2 black hole mass m'),
#  (112, 'black hole minimum possible mass satisfy inequality call extremal'),
#  (113,
#   'solution einstein equation violate inequality exist possess event horizon'),
#  (114,
#   'solution call naked singularity observe outside hence deem unphysical'),
#  (115,
#   'cosmic censorship hypothesis rule formation singularity create gravitational collapse realistic matter'),
#  (116, 'support numerical simulation'),
#  (117,
#   'due relatively large strength electromagnetic force black hole form collapse star expect retain nearly neutral charge star'),
#  (118,
#   'rotation however expect universal feature compact astrophysical object'),
#  (119,
#   'black hole candidate binary x ray source grs 1915 + 105 appear angular momentum near maximum allow value'),
#  (120,
#   'uncharged limit j ≤ g m 2 c displaystyle jleq frac gm^2c allow definition dimensionless spin parameter 0 ≤ c j g m 2 ≤ 1'),
#  (121, 'displaystyle 0leq frac cjgm^2leq 1'),
#  (122, '[ note 1 ] black hole classification class approx'),
#  (123, 'mass approx'),
#  (124,
#   'radius ultramassive black hole 10 9 – 10 11 m ☉ > 1 000 au supermassive black hole 10 6 – 10 9 m ☉ 0.001–400 au intermediate mass black hole 10 2 – 10 5 m ☉ 10 3 km ≈ r earth stellar black hole 2 150 m ☉ 30xa0 km micro black hole m moon 0.1xa0 mm black hole commonly classify accord mass independent angular momentum j'),
#  (125,
#   'size black hole determine radius event horizon schwarzschild radius proportional mass m r = 2 g m c 2 ≈ 2.95 m m ⊙ k displaystyle r_mathrm = frac 2gmc^2approx 2.95 frac mm_odot ~mathrm km r schwarzschild radius m ☉ mass sun'),
#  (126,
#   'black hole nonzero spin and/or electric charge radius small [ note 2 ] extremal black hole could event horizon close r + = g m c 2'),
#  (127, 'displaystyle r_mathrm + = frac gmc^2'),
#  (128,
#   'event horizon main article event horizon far away black hole particle move direction illustrate set arrow'),
#  (129, 'restrict speed light'),
#  (130, 'close black hole spacetime start deform'),
#  (131, 'path go towards black hole path move away'),
#  (132,
#   '[ note 3 ] inside event horizon path bring particle close centre black hole'),
#  (133, 'long possible particle escape'),
#  (134,
#   'define feature black hole appearance event horizon — boundary spacetime matter light pass inward towards mass black hole'),
#  (135, 'nothing even light escape inside event horizon'),
#  (136,
#   'event horizon refer event occur within boundary information event reach outside observer make impossible determine whether event occur'),
#  (137,
#   'predict general relativity presence mass deform spacetime way path take particle bend towards mass'),
#  (138,
#   'event horizon black hole deformation become strong path lead away black hole'),
#  (139,
#   'distant observer clock near black hole would appear tick slowly far away black hole'),
#  (140,
#   'due effect know gravitational time dilation object fall black hole appear slow approach event horizon take infinite time reach'),
#  (141,
#   'time process object slow viewpoint fix outside observer cause light emit object appear red dimmer effect know gravitational redshift'),
#  (142, 'eventually fall object fade away long see'),
#  (143,
#   'typically process happen rapidly object disappear view within less second'),
#  (144,
#   'hand indestructible observer fall black hole notice effect cross event horizon'),
#  (145,
#   'accord clock appear tick normally cross event horizon finite time without note singular behaviour'),
#  (146,
#   'classical general relativity impossible determine location event horizon local observation due einstein equivalence principle'),
#  (147, 'topology event horizon black hole equilibrium always spherical'),
#  (148,
#   '[ note 4 ] non rotating black hole geometry event horizon precisely spherical rotate black hole event horizon oblate'),
#  (149,
#   'singularity main article gravitational singularity centre black hole describe general relativity may lie gravitational singularity region spacetime curvature become infinite'),
#  (150, 'non rotating black hole region take shape single point'),
#  (151, 'rotate black hole smear form ring singularity lie plane rotation'),
#  (152, 'case singular region zero volume'),
#  (153, 'also show singular region contain mass black hole solution'),
#  (154, 'singular region thus think infinite density'),
#  (155,
#   'observer fall schwarzschild black hole avoid carry singularity cross event horizon'),
#  (156, 'prolong experience accelerate away slow descent limit'),
#  (157, 'reach singularity crush infinite density mass add total black hole'),
#  (158,
#   'happen tear apart grow tidal force process sometimes refer spaghettification noodle effect'),
#  (159, 'case charge rotate black hole possible avoid singularity'),
#  (160,
#   'extend solution far possible reveal hypothetical possibility exit black hole different spacetime black hole act wormhole'),
#  (161,
#   'possibility travel another universe however theoretical since perturbation would destroy possibility'),
#  (162,
#   'also appear possible follow closed timelike curve around kerr singularity lead problem causality like grandfather paradox'),
#  (163,
#   'expect none peculiar effect would survive proper quantum treatment rotate charge black hole'),
#  (164,
#   'appearance singularity general relativity commonly perceive signal breakdown theory'),
#  (165, 'breakdown however expect'),
#  (166,
#   'occur situation quantum effect describe action due extremely high density therefore particle interaction'),
#  (167,
#   'date possible combine quantum gravitational effect single theory although exist attempt formulate theory quantum gravity'),
#  (168, 'generally expect theory feature singularity'),
#  (169,
#   'photon sphere main article photon sphere photon sphere spherical boundary zero thickness photon move tangent sphere would trap circular orbit black hole'),
#  (170,
#   'non rotating black hole photon sphere radius 1.5 time schwarzschild radius'),
#  (171,
#   'orbit would dynamically unstable hence small perturbation particle infalle matter would cause instability would grow time either set photon outward trajectory cause escape black hole inward spiral would eventually cross event horizon'),
#  (172,
#   'light still escape photon sphere light cross photon sphere inbound trajectory capture black hole'),
#  (173,
#   'hence light reach outside observer photon sphere must emit object photon sphere event horizon'),
#  (174,
#   'kerr black hole radius photon sphere depend spin parameter detail photon orbit prograde retrograde'),
#  (175,
#   'ergosphere main article ergosphere ergosphere region outside event horizon object remain place'),
#  (176,
#   'rotate black hole surround region spacetime impossible stand still call ergosphere'),
#  (177, 'result process know frame dragging'),
#  (178,
#   'general relativity predict rotate mass tend slightly drag along spacetime immediately surround'),
#  (179, 'object near rotate mass tend start move direction rotation'),
#  (180,
#   'rotate black hole effect strong near event horizon object would move fast speed light opposite direction stand still'),
#  (181,
#   'ergosphere black hole volume bound black hole event horizon ergosurface coincide event horizon pole much great distance around equator'),
#  (182, 'object radiation escape normally ergosphere'),
#  (183, 'penrose process object emerge ergosphere energy enter'),
#  (184, 'extra energy take rotational energy black hole'),
#  (185, 'thereby rotation black hole slow'),
#  (186,
#   'variation penrose process presence strong magnetic field blandford – znajek process consider likely mechanism enormous luminosity relativistic jet quasar active galactic nucleus'),
#  (187,
#   'innermost stable circular orbit main article innermost stable circular orbit newtonian gravity test particle stably orbit arbitrary distance central object'),
#  (188,
#   'general relativity however exist innermost stable circular orbit infinitesimal inward perturbation circular orbit lead spiral black hole outward perturbation depend energy result spiral stably orbit apastron periastron escape infinity'),
#  (189,
#   'location isco depend spin black hole case schwarzschild black hole r i c = 3 r = 6 g m c 2 displaystyle r_rm isco=3 r_s=frac 6 gmc^2 decrease increase black hole spin particle orbit direction spin'),
#  (190,
#   'formation evolution give bizarre character black hole long question whether object could actually exist nature whether merely pathological solution einstein equation'),
#  (191,
#   'einstein wrongly think black hole would form hold angular momentum collapse particle would stabilize motion radius'),
#  (192, 'lead general relativity community dismiss result contrary many year'),
#  (193,
#   'however minority relativist continue contend black hole physical object end 1960 persuade majority researcher field obstacle formation event horizon'),
#  (194,
#   'penrose demonstrate event horizon form general relativity without quantum mechanic require singularity form within'),
#  (195,
#   'shortly afterwards hawking show many cosmological solution describe big bang singularity without scalar field exotic matter'),
#  (196,
#   '[ clarification need ] kerr solution hair theorem law black hole thermodynamic show physical property black hole simple comprehensible make respectable subject research'),
#  (197,
#   'conventional black hole form gravitational collapse heavy object star also theory form process'),
#  (198,
#   'gravitational collapse main article gravitational collapse gas cloud rip apart black hole centre milky way'),
#  (199,
#   'gravitational collapse occur object internal pressure insufficient resist object gravity'),
#  (200,
#   'star usually occur either star little fuel leave maintain temperature stellar nucleosynthesis star would stable receive extra matter way raise core temperature'),
#  (201,
#   'either case star temperature long high enough prevent collapse weight'),
#  (202,
#   'collapse may stop degeneracy pressure star constituent allow condensation matter exotic denser state'),
#  (203, 'result one various type compact star'),
#  (204,
#   'type form depend mass remnant original star leave outer layer blow away'),
#  (205,
#   'mass remnant collapse object survive explosion substantially less original star'),
#  (206, 'remnant exceed 5 m ☉ produce star 20 m ☉ collapse'),
#  (207,
#   'mass remnant exceed 3–4 m ☉ either original star heavy remnant collect additional mass accretion matter even degeneracy pressure neutron insufficient stop collapse'),
#  (208,
#   'known mechanism powerful enough stop implosion object inevitably collapse form black hole'),
#  (209,
#   'gravitational collapse heavy star assume responsible formation stellar mass black hole'),
#  (210,
#   'star formation early universe may result massive star upon collapse would produce black hole 10 3 ☉'),
#  (211, 'black hole could seed supermassive black hole find centre galaxy'),
#  (212,
#   'far suggest massive black hole typical masse ~10 5 m ☉ could form direct collapse gas cloud young universe'),
#  (213,
#   'massive object propose seed eventually form early quasar observe already redshift z ∼ 7 displaystyle zsim 7'),
#  (214, 'candidate object find observation young universe'),
#  (215,
#   'energy release gravitational collapse emit quickly outside observer actually see end process'),
#  (216,
#   'even though collapse take finite amount time reference frame infalle matter distant observer would see infalle material slow halt event horizon due gravitational time dilation'),
#  (217,
#   'light collapse material take long long reach observer light emit event horizon form delay infinite amount time'),
#  (218, 'thus external observer never see formation event horizon'),
#  (219,
#   'instead collapse material seem become dimmer increasingly red shift eventually fade away'),
#  (220,
#   'primordial black hole big bang gravitational collapse require great density'),
#  (221,
#   'current epoch universe high density find star early universe shortly big bang density much great possibly allow creation black hole'),
#  (222,
#   'high density alone enough allow black hole formation since uniform mass distribution allow mass bunch'),
#  (223,
#   'order primordial black hole form dense medium must initial density perturbation could grow gravity'),
#  (224,
#   'different model early universe vary widely prediction scale fluctuation'),
#  (225,
#   'various model predict creation primordial black hole range size planck mass hundred thousand solar masse'),
#  (226,
#   'despite early universe extremely dense collapse black hole big bang since expansion rate great attraction'),
#  (227,
#   'follow inflation theory net repulsive gravitation beginning end inflation'),
#  (228, 'since hubble flow slow energy density universe'),
#  (229,
#   'model gravitational collapse object relatively constant size star necessarily apply way rapidly expand space big bang'),
#  (230,
#   'high energy collision gravitational collapse process could create black hole'),
#  (231,
#   'principle black hole could form high energy collision achieve sufficient density'),
#  (232,
#   '2002 event detect either directly indirectly deficiency mass balance particle accelerator experiment'),
#  (233, 'suggest must low limit mass black hole'),
#  (234,
#   'theoretically boundary expect lie around planck mass quantum effect expect invalidate prediction general relativity'),
#  (235,
#   'would put creation black hole firmly reach high energy process occur near earth'),
#  (236,
#   'however certain development quantum gravity suggest minimum black hole mass could much low braneworld scenario example put boundary low 1xa0tev/ c 2'),
#  (237,
#   'would make conceivable micro black hole create high energy collision occur cosmic ray hit earth atmosphere possibly large hadron collider cern'),
#  (238,
#   'theory speculative creation black hole process deem unlikely many specialist'),
#  (239,
#   'even micro black hole could form expect would evaporate 10 −25 second pose threat earth'),
#  (240, 'growth black hole form continue grow absorb additional matter'),
#  (241, 'black hole continually absorb gas interstellar dust surrounding'),
#  (242,
#   'growth process one possible way supermassive black hole may form although formation supermassive black hole still open field research'),
#  (243,
#   'similar process suggest formation intermediate mass black hole find globular cluster'),
#  (244, 'black hole also merge object star even black hole'),
#  (245,
#   'think important especially early growth supermassive black hole could form aggregation many small object'),
#  (246, 'process also propose origin intermediate mass black hole'),
#  (247,
#   'evaporation main article hawk radiation 1974 hawking predict black hole entirely black emit small amount thermal radiation temperature ℏ c 3 /'),
#  (248, 'effect become know hawk radiation'),
#  (249,
#   'apply quantum field theory static black hole background determine black hole emit particle display perfect black body spectrum'),
#  (250, 'since hawking publication many verify result various approach'),
#  (251,
#   'hawking theory black hole radiation correct black hole expect shrink evaporate time lose mass emission photon particle'),
#  (252,
#   'temperature thermal spectrum proportional surface gravity black hole schwarzschild black hole inversely proportional mass'),
#  (253, 'hence large black hole emit less radiation small black hole'),
#  (254, 'stellar black hole 1 m ☉ hawk temperature 62 nanokelvin'),
#  (255, 'far less 2.7xa0 k temperature cosmic microwave background radiation'),
#  (256,
#   'stellar mass large black hole receive mass cosmic microwave background emit hawk radiation thus grow instead shrink'),
#  (257, 'hawk temperature large 2.7xa0 k black hole would need mass less moon'),
#  (258, 'black hole would diameter less tenth millimeter'),
#  (259, 'black hole small radiation effect expect become strong'),
#  (260,
#   'black hole mass car would diameter 10 −24 take nanosecond evaporate time would briefly luminosity 200 time sun'),
#  (261, 'low mass black hole expect evaporate even fast'),
#  (262,
#   'example black hole mass 1xa0tev/ c 2 would take less 10 −88 second evaporate completely'),
#  (263,
#   'small black hole quantum gravity effect expect play important role could hypothetically make small black hole stable although current development quantum gravity indicate case'),
#  (264,
#   'hawking radiation astrophysical black hole predict weak would thus exceedingly difficult detect earth'),
#  (265,
#   'possible exception however burst gamma ray emit last stage evaporation primordial black hole'),
#  (266,
#   'search flash prove unsuccessful provide stringent limit possibility existence low mass primordial black hole'),
#  (267,
#   'nasa fermi gamma ray space telescope launch 2008 continue search flash'),
#  (268,
#   'black hole evaporate via hawk radiation solar mass black hole evaporate period 10 64 year'),
#  (269,
#   'supermassive black hole mass 10 11 m ☉ evaporate around 2×10 100 year'),
#  (270,
#   'monster black hole universe predict continue grow perhaps 10 14 m ☉ collapse supercluster galaxy'),
#  (271, 'even would evaporate timescale 10 106 year'),
#  (272,
#   'model quantum gravity predict modification hawking description black hole'),
#  (273,
#   'particular evolution equation describe mass loss rate charge loss rate get modify'),
#  (274,
#   'observational evidence nature black hole emit electromagnetic radiation hypothetical hawking radiation astrophysicist search black hole must generally rely indirect observation'),
#  (275,
#   'example black hole existence sometimes infer observe gravitational influence surrounding'),
#  (276,
#   'direct interferometry view m87 * black hole polarise light sagittarius a * black hole center milky way event horizon telescope active program directly observe immediate environment black holes event horizon black hole centre milky way'),
#  (277, 'april 2017 eht begin observe black hole centre messier 87'),
#  (278,
#   'eight radio observatory six mountain four continent observe galaxy virgo 10 day april 2017 provide datum yield image april 2019'),
#  (279, 'two year datum processing eht release first direct image black hole'),
#  (280,
#   'specifically supermassive black hole lie centre aforementioned galaxy'),
#  (281, 'visible black hole — show black loss light within dark region'),
#  (282, 'instead gas edge event horizon define black hole'),
#  (283,
#   '12 may 2022 eht release first image sagittarius a * supermassive black hole centre milky way galaxy'),
#  (284,
#   'publish image display ring like structure circular shadow see m87 * black hole image create use technique m87 black hole'),
#  (285,
#   'however imaging process sagittarius a * thousand time small less massive m87 * significantly complex instability surrounding'),
#  (286,
#   'image sagittarius a * also partially blur turbulent plasma way galactic centre effect prevent resolution image long wavelength'),
#  (287,
#   'brightening material bottom half process eht image think cause doppler beaming whereby material approach viewer relativistic speed perceive bright material move away'),
#  (288,
#   'case black hole phenomenon imply visible material rotate relativistic speed speed possible centrifugally balance immense gravitational attraction singularity thereby remain orbit event horizon'),
#  (289,
#   'configuration bright material imply eht observe m87 * perspective catch black hole accretion disc nearly edge whole system rotate clockwise'),
#  (290,
#   'however extreme gravitational lense associate black hole produce illusion perspective see accretion disc'),
#  (291,
#   'reality ring eht image create light emit far side accretion disc bend around black hole gravity well escape mean possible perspective m87 * see entire disc even directly behind shadow'),
#  (292,
#   '2015 eht detect magnetic field outside event horizon sagittarius a * even discern property'),
#  (293, 'field line pass accretion disc complex mixture order tangle'),
#  (294, 'theoretical study black hole predict existence magnetic field'),
#  (295,
#   'april 2023 image shadow messier 87 black hole related high energy jet view together first time present'),
#  (296,
#   'detection gravitational wave merge black hole ligo measurement gravitational wave livingston hanford detector compare theoretical predict value 14 september 2015 ligo gravitational wave observatory make first ever successful direct observation gravitational wave'),
#  (297,
#   'signal consistent theoretical prediction gravitational wave produce merger two black hole one 36 solar masse around 29 solar masse'),
#  (298, 'observation provide concrete evidence existence black hole date'),
#  (299,
#   'instance gravitational wave signal suggest separation two object merger 350xa0 km'),
#  (300,
#   'object must therefore extremely compact leave black hole plausible interpretation'),
#  (301,
#   'importantly signal observe ligo also include start post merger ringdown signal produce newly form compact object settle stationary state'),
#  (302, 'arguably ringdown direct way observe black hole'),
#  (303,
#   'ligo signal possible extract frequency damp time dominant mode ringdown'),
#  (304,
#   'possible infer mass angular momentum final object match independent prediction numerical simulation merger'),
#  (305, 'frequency decay time dominant mode determine geometry photon sphere'),
#  (306, 'hence observation mode confirm presence photon sphere'),
#  (307,
#   'however exclude possible exotic alternative black hole compact enough photon sphere'),
#  (308,
#   'observation also provide first observational evidence existence stellar mass black hole binary'),
#  (309,
#   'furthermore first observational evidence stellar mass black hole weigh 25 solar masse'),
#  (310, 'since many gravitational wave event observe'),
#  (311,
#   'star orbit sagittarius a * main article sagittarius a * cluster stars move around sagittarius a * see 2021 proper motion star near centre milky way provide strong observational evidence star orbit supermassive black hole'),
#  (312,
#   'since 1995 astronomer track motion 90 star orbit invisible object coincident radio source sagittarius a *'),
#  (313,
#   'fit motion keplerian orbit astronomer able infer 1998 2.6 × 10 6 m ☉ object must contain volume radius 0.02 light year cause motion star'),
#  (314, 'since one star — call s2 — complete full orbit'),
#  (315,
#   'orbital datum astronomer able refine calculation mass 4.3 × 10 6 m ☉ radius less 0.002 light year object cause orbital motion star'),
#  (316,
#   'upper limit object size still large test whether small schwarzschild radius'),
#  (317,
#   'nevertheless observation strongly suggest central object supermassive black hole plausible scenario confine much invisible mass small volume'),
#  (318,
#   'additionally observational evidence object might possess event horizon feature unique black hole'),
#  (319,
#   'accretion matter see also accretion disk blurring x ray near black hole due conservation angular momentum gas fall gravitational well create massive object typically form disk like structure around object'),
#  (320,
#   'artists impression accompany representation black hole corona commonly depict black hole flat space body hide part disk behind reality gravitational lense would greatly distort image accretion disk'),
#  (321,
#   'within disk friction would cause angular momentum transport outward allow matter fall far inward thus release potential energy increase temperature gas'),
#  (322,
#   'accrete object neutron star black hole gas inner accretion disk orbit high speed proximity compact object'),
#  (323,
#   'result friction significant heat inner disk temperature emit vast amount electromagnetic radiation'),
#  (324, 'bright x ray source may detect telescope'),
#  (325, 'process accretion one efficient energy produce process know'),
#  (326, '40 % rest mass accrete material emit radiation'),
#  (327,
#   'many case accretion disk accompany relativistic jet emit along pole carry away much energy'),
#  (328,
#   'mechanism creation jet currently well understand part due insufficient datum'),
#  (329,
#   'many universe energetic phenomenon attribute accretion matter black hole'),
#  (330,
#   'particular active galactic nucleus quasar believe accretion disk supermassive black hole'),
#  (331,
#   'similarly x ray binary generally accept binary star system one two star compact object accrete matter companion'),
#  (332,
#   'also suggest ultraluminous x ray source may accretion disk intermediate mass black hole'),
#  (333,
#   'november 2011 first direct observation quasar accretion disk around supermassive black hole report'),
#  (334,
#   'x ray binary see also x ray binary a chandra x ray observatory image cygnus x 1 first strong black hole candidate discover x ray binary binary star system emit majority radiation x ray part spectrum'),
#  (335,
#   'x ray emission generally think result one star accrete matter another star'),
#  (336,
#   'presence ordinary star system provide opportunity study central object determine might black hole'),
#  (337, 'system emit signal directly trace back compact object black hole'),
#  (338,
#   'absence signal however exclude possibility compact object neutron star'),
#  (339,
#   'study companion star often possible obtain orbital parameter system obtain estimate mass compact object'),
#  (340,
#   'much large tolman – oppenheimer – volkoff limit object neutron star generally expect black hole'),
#  (341,
#   'first strong candidate black hole cygnus x 1 discover way charles thomas bolton louise webster paul murdin 1972'),
#  (342,
#   'doubt however remain due uncertainty result companion star much heavy candidate black hole'),
#  (343,
#   'currently well candidate black hole find class x ray binary call soft x ray transient'),
#  (344,
#   'class system companion star relatively low mass allow accurate estimate black hole mass'),
#  (345, 'moreover system actively emit x ray several month every 10–50 year'),
#  (346,
#   'period low x ray emission accretion disk extremely faint allow detailed observation companion star period'),
#  (347, 'one good candidate v404 cygni'),
#  (348,
#   'quasi periodic oscillation main article quasi periodic oscillation x ray emission accretion disk sometimes flicker certain frequency'),
#  (349,
#   'signal call quasi periodic oscillation think cause material move along inner edge accretion disk'),
#  (350, 'frequency link mass compact object'),
#  (351, 'thus use alternative way determine mass candidate black hole'),
#  (352,
#   'galactic nucleus see also active galactic nucleus detection unusually bright x ray flare sagittarius a * black hole centre milky way galaxy 5 january 2015 astronomers use term active galaxy describe galaxy unusual characteristic unusual spectral line emission strong radio emission'),
#  (353,
#   'theoretical observational study show activity active galactic nucleus may explain presence supermassive black hole million time massive stellar one'),
#  (354,
#   'model agn consist central black hole may million billion time massive sun'),
#  (355, 'disk interstellar gas dust call accretion disk'),
#  (356, 'two jet perpendicular accretion disk'),
#  (357,
#   'although supermassive black hole expect find agn galaxies nucleus carefully study attempt identify measure actual masse central supermassive black hole candidate'),
#  (358,
#   'notable galaxy supermassive black hole candidate include andromeda galaxy m32 m87 ngc 3115 ngc 3377 ngc 4258 ngc 4889 ngc 1277 oj 287 apm 08279 + 5255 sombrero galaxy'),
#  (359,
#   'widely accept centre nearly every galaxy active one contain supermassive black hole'),
#  (360,
#   'close observational correlation mass hole velocity dispersion host galaxy bulge know m – sigma relation strongly suggest connection formation black hole galaxy'),
#  (361,
#   'microlensing another way black hole nature object may test observation effect cause strong gravitational field vicinity'),
#  (362,
#   'one effect gravitational lense deformation spacetime around massive object cause light ray deflect light pass optic lens'),
#  (363,
#   'observation make weak gravitational lense light ray deflect arcsecond'),
#  (364, 'microlensing occur source unresolved observer see small brightening'),
#  (365,
#   'january 2022 astronomer report first possible detection microlensing event isolated black hole'),
#  (366,
#   'another possibility observe gravitational lense black hole would observe star orbit black hole'),
#  (367, 'several candidate observation orbit around sagittarius a *'),
#  (368,
#   'alternative see also exotic star evidence stellar black hole strongly rely existence upper limit mass neutron star'),
#  (369, 'size limit heavily depend assumption make property dense matter'),
#  (370, 'new exotic phase matter could push bind'),
#  (371,
#   'phase free quark high density might allow existence dense quark star supersymmetric model predict existence q star'),
#  (372,
#   'extension standard model posit existence preon fundamental building block quark lepton could hypothetically form preon star'),
#  (373,
#   'hypothetical model could potentially explain number observation stellar black hole candidate'),
#  (374, 'however show argument general relativity object maximum mass'),
#  (375,
#   'since average density black hole inside schwarzschild radius inversely proportional square mass supermassive black hole much less dense stellar black hole'),
#  (376,
#   'consequently physics matter form supermassive black hole much well understand possible alternative explanation supermassive black hole observation much mundane'),
#  (377,
#   'example supermassive black hole could model large cluster dark object'),
#  (378,
#   'however alternative typically stable enough explain supermassive black hole candidate'),
#  (379,
#   'evidence existence stellar supermassive black hole imply order black hole form general relativity must fail theory gravity perhaps due onset quantum mechanical correction'),
#  (380,
#   'much anticipate feature theory quantum gravity feature singularity event horizon thus black hole would real artifact'),
#  (381,
#   'example fuzzball model base string theory individual state black hole solution generally event horizon singularity classical / semi classical observer statistical average state appear ordinary black hole deduce general relativity'),
#  (382,
#   'theoretical object conjecture match observation astronomical black hole candidate identically near identically function via different mechanism'),
#  (383, 'include gravastar black star dark energy star'),
#  (384,
#   'open question entropy thermodynamic information black hole thermodynamic bekenstein bind = 1 / 4 c 3 k / għ formula bekenstein – hawk entropy black hole depend area black hole'),
#  (385,
#   'constant speed light boltzmann constant newton constant reduce planck constant'),
#  (386, 'planck unit reduce = a / 4'),
#  (387,
#   '1971 hawking show general condition [ note 5 ] total area event horizon collection classical black hole never decrease even collide merge'),
#  (388,
#   'result know second law black hole mechanic remarkably similar second law thermodynamic state total entropy isolated system never decrease'),
#  (389,
#   'classical object absolute zero temperature assume black hole zero entropy'),
#  (390,
#   'case second law thermodynamic would violate entropy laden matter enter black hole result decrease total entropy universe'),
#  (391,
#   'therefore bekenstein propose black hole entropy proportional horizon area'),
#  (392,
#   'link law thermodynamic far strengthen hawking discovery 1974 quantum field theory predict black hole radiate blackbody radiation constant temperature'),
#  (393,
#   'seemingly cause violation second law black hole mechanic since radiation carry away energy black hole cause shrink'),
#  (394,
#   'radiation however also carry away entropy prove general assumption sum entropy matter surround black hole one quarter area horizon measure planck unit fact always increase'),
#  (395,
#   'allow formulation first law black hole mechanic analogue first law thermodynamic mass acting energy surface gravity temperature area entropy'),
#  (396,
#   'one puzzle feature entropy black hole scale area rather volume since entropy normally extensive quantity scale linearly volume system'),
#  (397,
#   'odd property lead gerard t hooft leonard susskind propose holographic principle suggest anything happen volume spacetime describe datum boundary volume'),
#  (398,
#   'although general relativity use perform semi classical calculation black hole entropy situation theoretically unsatisfying'),
#  (399,
#   'statistical mechanic entropy understand count number microscopic configuration system macroscopic quality'),
#  (400,
#   'without satisfactory theory quantum gravity one perform computation black hole'),
#  (401, 'progress make various approach quantum gravity'),
#  (402,
#   '1995 andrew strominger cumrun vafa show count microstate specific supersymmetric black hole string theory reproduce bekenstein – hawking entropy'),
#  (403,
#   'since similar result report different black hole string theory approach quantum gravity like loop quantum gravity'),
#  (404,
#   'another promising approach constitute treat gravity effective field theory'),
#  (405,
#   'one first compute quantum gravitational correction radius event horizon black hole integrate find quantum gravitational correction entropy give wald formula'),
#  (406,
#   'method apply schwarzschild black hole calmet kuipers successfully generalise charge black hole campos delgado'),
#  (407,
#   'information loss paradox main article black hole information paradox unsolved problem physics physical information lose black hole ? black hole internal parameter information matter go form black hole lose'),
#  (408,
#   'regardless type matter go black hole appear information concern total mass charge angular momentum conserve'),
#  (409,
#   'long black hole think persist forever information loss problematic information think exist inside black hole inaccessible outside represent event horizon accordance holographic principle'),
#  (410, 'however black hole slowly evaporate emit hawk radiation'),
#  (411,
#   'radiation appear carry additional information matter form black hole mean information appear go forever'),
#  (412,
#   'question whether information truly lose black hole divide theoretical physics community'),
#  (413,
#   'quantum mechanic loss information correspond violation property call unitarity argue loss unitarity would also imply violation conservation energy though also dispute'),
#  (414,
#   'recent year evidence build indeed information unitarity preserve full quantum gravitational treatment problem'),
#  (415,
#   'one attempt resolve black hole information paradox know black hole complementarity'),
#  (416,
#   '2012 firewall paradox introduce goal demonstrate black hole complementarity fail solve information paradox'),
#  (417,
#   'accord quantum field theory curve spacetime single emission hawk radiation involve two mutually entangle particle'),
#  (418, 'outgoing particle escape emit quantum hawk radiation'),
#  (419, 'infalle particle swallow black hole'),
#  (420,
#   'assume black hole form finite time past fully evaporate away finite time future'),
#  (421, 'emit finite amount information encode within hawking radiation'),
#  (422,
#   'accord research physicist like don page leonard susskind eventually time outgoing particle must entangle hawking radiation black hole previously emit'),
#  (423,
#   'seemingly create paradox principle call monogamy entanglement require like quantum system outgoing particle fully entangle two system time'),
#  (424,
#   'yet outgoing particle appear entangle infalle particle independently past hawk radiation'),
#  (425,
#   'order resolve contradiction physicist may eventually force give one three time test principle einstein equivalence principle unitarity local quantum field theory'),
#  (426,
#   'one possible solution violate equivalence principle firewall destroy incoming particle event horizon'),
#  (427, 'general — — assumption abandon remain topic debate'),
#  (428,
#   'see also binary black hole black brane black string black hole initiative black hole starship black hole fiction blanet btz black hole charge black hole direct collapse black hole hypothetical black hole kugelblitz list black hole list near black hole outline black hole sonic black hole virtual black hole susskind hawk battle timeline black hole physics white hole planck star dark star schwarzschild radius notes ^ value cj / gm 2 exceed 1 object black hole'),
#  (429,
#   'large value know neutron star ≤ 0.4 commonly use equation state would limit value < 0.7'),
#  (430, '^ event horizon radius scale m + m 2 − 2 − q 2'),
#  (431, 'displaystyle m+sqrt m^2 ^2 q^2'),
#  (432,
#   '^ set possible path accurately future light cone contain possible world line tilt way eddington – finkelstein coordinate coordinate light cone tilt way example schwarzschild coordinate narrow without tilt one approach event horizon kruskal – szekere coordinate light cone change shape orientation'),
#  (433, '^ true four dimensional spacetime'),
#  (434, 'high dimension complicated horizon topology like black ring possible'),
#  (435, '^ particular assume matter satisfy weak energy condition .')]

# %%
lowest_repeating_word(train_sentence)
# Out:
# ('.', 1)

# %%
len(sentence_with_common_words) # => 112
# Out:
# 125

# %%
random.seed(69)

random.choices(sentence_with_common_words,k=20)
# Out:
# ['instead gas edge event horizon define black hole',
#  'michell refer body dark star',
#  'property special visible outside black hole',
#  'hawking theory black hole radiation correct black hole expect shrink evaporate time lose mass emission photon particle',
#  'accord clock appear tick normally cross event horizon finite time without note singular behaviour',
#  'planck unit reduce = a / 4',
#  'system emit signal directly trace back compact object black hole',
#  'several candidate observation orbit around sagittarius a *',
#  'appearance singularity general relativity commonly perceive signal breakdown theory',
#  'disk interstellar gas dust call accretion disk',
#  'growth black hole form continue grow absorb additional matter',
#  'disk interstellar gas dust call accretion disk',
#  'typically process happen rapidly object disappear view within less second',
#  'high energy collision gravitational collapse process could create black hole',
#  'hence light reach outside observer photon sphere must emit object photon sphere event horizon',
#  'appearance singularity general relativity commonly perceive signal breakdown theory',
#  'case charge rotate black hole possible avoid singularity',
#  'appearance singularity general relativity commonly perceive signal breakdown theory',
#  '10 april 2019 first direct image black hole vicinity publish follow observation make event horizon telescope 2017 supermassive black hole messier 87 galactic centre',
#  'analogy complete hawking 1974 show quantum field theory imply black hole radiate like black body temperature proportional surface gravity black hole predict effect know hawk radiation']

# %%
window_size = 5
train_data = []
for sentence in sentence_with_common_words:
    words = sentence.split(" ")
    for i in range(6,len(words)):
        train_data.append((words[-window_size+i:i],words[i]))

# %%
sentence_with_common_words[0:2]
# Out:
# ['black hole region spacetime gravity strong nothing include light electromagnetic wave enough energy escape',
#  'boundary escape call event horizon']

# %%
window_size = 4
train_data_word_around = []
for sentence in sentence_with_common_words:
    words = sentence.split(" ")
    for i in range(0,len(words)):
        collect_index = window_size # 5-0 = 5
        around_words = []
        left = i-window_size

        while collect_index > 0:

            if left < 0 or left == i:
                left += 1
                continue

            if left >= len(words):
                break

            around_words.append(words[left]) 
            collect_index -= 1
            left += 1


        train_data_word_around.append(( around_words ,words[i]))
train_data_word_around
# Out:
# [(['hole', 'region', 'spacetime', 'gravity'], 'black'),
#  (['black', 'region', 'spacetime', 'gravity'], 'hole'),
#  (['black', 'hole', 'spacetime', 'gravity'], 'region'),
#  (['black', 'hole', 'region', 'gravity'], 'spacetime'),
#  (['black', 'hole', 'region', 'spacetime'], 'gravity'),
#  (['hole', 'region', 'spacetime', 'gravity'], 'strong'),
#  (['region', 'spacetime', 'gravity', 'strong'], 'nothing'),
#  (['spacetime', 'gravity', 'strong', 'nothing'], 'include'),
#  (['gravity', 'strong', 'nothing', 'include'], 'light'),
#  (['strong', 'nothing', 'include', 'light'], 'electromagnetic'),
#  (['nothing', 'include', 'light', 'electromagnetic'], 'wave'),
#  (['include', 'light', 'electromagnetic', 'wave'], 'enough'),
#  (['light', 'electromagnetic', 'wave', 'enough'], 'energy'),
#  (['electromagnetic', 'wave', 'enough', 'energy'], 'escape'),
#  (['escape', 'call', 'event', 'horizon'], 'boundary'),
#  (['boundary', 'call', 'event', 'horizon'], 'escape'),
#  (['boundary', 'escape', 'event', 'horizon'], 'call'),
#  (['boundary', 'escape', 'call', 'horizon'], 'event'),
#  (['boundary', 'escape', 'call', 'event'], 'horizon'),
#  (['finkelstein', '1958', 'first', 'publish'], 'david'),
#  (['david', '1958', 'first', 'publish'], 'finkelstein'),
#  (['david', 'finkelstein', 'first', 'publish'], '1958'),
#  (['david', 'finkelstein', '1958', 'publish'], 'first'),
#  (['david', 'finkelstein', '1958', 'first'], 'publish'),
#  (['finkelstein', '1958', 'first', 'publish'], 'interpretation'),
#  (['1958', 'first', 'publish', 'interpretation'], 'black'),
#  (['first', 'publish', 'interpretation', 'black'], 'hole'),
#  (['publish', 'interpretation', 'black', 'hole'], 'region'),
#  (['interpretation', 'black', 'hole', 'region'], 'space'),
#  (['black', 'hole', 'region', 'space'], 'nothing'),
#  (['hole', 'region', 'space', 'nothing'], 'escape'),
#  (['hole', 'long', 'consider', 'mathematical'], 'black'),
#  (['black', 'long', 'consider', 'mathematical'], 'hole'),
#  (['black', 'hole', 'consider', 'mathematical'], 'long'),
#  (['black', 'hole', 'long', 'mathematical'], 'consider'),
#  (['black', 'hole', 'long', 'consider'], 'mathematical'),
#  (['hole', 'long', 'consider', 'mathematical'], 'curiosity'),
#  (['theoretical', 'work', 'show', 'generic'], '1960'),
#  (['1960', 'work', 'show', 'generic'], 'theoretical'),
#  (['1960', 'theoretical', 'show', 'generic'], 'work'),
#  (['1960', 'theoretical', 'work', 'generic'], 'show'),
#  (['1960', 'theoretical', 'work', 'show'], 'generic'),
#  (['theoretical', 'work', 'show', 'generic'], 'prediction'),
#  (['work', 'show', 'generic', 'prediction'], 'general'),
#  (['show', 'generic', 'prediction', 'general'], 'relativity'),
#  (['black', 'hole', 'know', 'cygnus'], 'first'),
#  (['first', 'hole', 'know', 'cygnus'], 'black'),
#  (['first', 'black', 'know', 'cygnus'], 'hole'),
#  (['first', 'black', 'hole', 'cygnus'], 'know'),
#  (['first', 'black', 'hole', 'know'], 'cygnus'),
#  (['black', 'hole', 'know', 'cygnus'], 'x'),
#  (['hole', 'know', 'cygnus', 'x'], '1'),
#  (['know', 'cygnus', 'x', '1'], 'identify'),
#  (['cygnus', 'x', '1', 'identify'], 'several'),
#  (['x', '1', 'identify', 'several'], 'researcher'),
#  (['1', 'identify', 'several', 'researcher'], 'independently'),
#  (['identify', 'several', 'researcher', 'independently'], '1971'),
#  (['hole', 'form', 'grow', 'absorb'], 'black'),
#  (['black', 'form', 'grow', 'absorb'], 'hole'),
#  (['black', 'hole', 'grow', 'absorb'], 'form'),
#  (['black', 'hole', 'form', 'absorb'], 'grow'),
#  (['black', 'hole', 'form', 'grow'], 'absorb'),
#  (['hole', 'form', 'grow', 'absorb'], 'mass'),
#  (['form', 'grow', 'absorb', 'mass'], 'surrounding'),
#  (['black', 'hole', 'million', 'solar'], 'supermassive'),
#  (['supermassive', 'hole', 'million', 'solar'], 'black'),
#  (['supermassive', 'black', 'million', 'solar'], 'hole'),
#  (['supermassive', 'black', 'hole', 'solar'], 'million'),
#  (['supermassive', 'black', 'hole', 'million'], 'solar'),
#  (['black', 'hole', 'million', 'solar'], 'masse'),
#  (['hole', 'million', 'solar', 'masse'], 'may'),
#  (['million', 'solar', 'masse', 'may'], 'form'),
#  (['solar', 'masse', 'may', 'form'], 'absorb'),
#  (['masse', 'may', 'form', 'absorb'], 'star'),
#  (['may', 'form', 'absorb', 'star'], 'merge'),
#  (['form', 'absorb', 'star', 'merge'], 'black'),
#  (['absorb', 'star', 'merge', 'black'], 'hole'),
#  (['star', 'merge', 'black', 'hole'], 'via'),
#  (['merge', 'black', 'hole', 'via'], 'direct'),
#  (['black', 'hole', 'via', 'direct'], 'collapse'),
#  (['hole', 'via', 'direct', 'collapse'], 'gas'),
#  (['via', 'direct', 'collapse', 'gas'], 'cloud'),
#  (['black', 'hole', 'infer', 'interaction'], 'presence'),
#  (['presence', 'hole', 'infer', 'interaction'], 'black'),
#  (['presence', 'black', 'infer', 'interaction'], 'hole'),
#  (['presence', 'black', 'hole', 'interaction'], 'infer'),
#  (['presence', 'black', 'hole', 'infer'], 'interaction'),
#  (['black', 'hole', 'infer', 'interaction'], 'matter'),
#  (['hole', 'infer', 'interaction', 'matter'], 'electromagnetic'),
#  (['infer', 'interaction', 'matter', 'electromagnetic'], 'radiation'),
#  (['interaction', 'matter', 'electromagnetic', 'radiation'], 'visible'),
#  (['matter', 'electromagnetic', 'radiation', 'visible'], 'light'),
#  (['orbit', 'black', 'hole', 'orbit'], 'star'),
#  (['star', 'black', 'hole', 'orbit'], 'orbit'),
#  (['star', 'orbit', 'hole', 'orbit'], 'black'),
#  (['star', 'orbit', 'black', 'orbit'], 'hole'),
#  (['star', 'orbit', 'black', 'hole'], 'orbit'),
#  (['orbit', 'black', 'hole', 'orbit'], 'use'),
#  (['black', 'hole', 'orbit', 'use'], 'determine'),
#  (['hole', 'orbit', 'use', 'determine'], 'black'),
#  (['orbit', 'use', 'determine', 'black'], 'hole'),
#  (['use', 'determine', 'black', 'hole'], 'mass'),
#  (['determine', 'black', 'hole', 'mass'], 'location'),
#  (['use', 'exclude', 'possible', 'alternative'], 'observation'),
#  (['observation', 'exclude', 'possible', 'alternative'], 'use'),
#  (['observation', 'use', 'possible', 'alternative'], 'exclude'),
#  (['observation', 'use', 'exclude', 'alternative'], 'possible'),
#  (['observation', 'use', 'exclude', 'possible'], 'alternative'),
#  (['use', 'exclude', 'possible', 'alternative'], 'neutron'),
#  (['exclude', 'possible', 'alternative', 'neutron'], 'star'),
#  (['refer', 'body', 'dark', 'star'], 'michell'),
#  (['michell', 'body', 'dark', 'star'], 'refer'),
#  (['michell', 'refer', 'dark', 'star'], 'body'),
#  (['michell', 'refer', 'body', 'star'], 'dark'),
#  (['michell', 'refer', 'body', 'dark'], 'star'),
#  (['later', 'karl', 'schwarzschild', 'find'], 'month'),
#  (['month', 'karl', 'schwarzschild', 'find'], 'later'),
#  (['month', 'later', 'schwarzschild', 'find'], 'karl'),
#  (['month', 'later', 'karl', 'find'], 'schwarzschild'),
#  (['month', 'later', 'karl', 'schwarzschild'], 'find'),
#  (['later', 'karl', 'schwarzschild', 'find'], 'solution'),
#  (['karl', 'schwarzschild', 'find', 'solution'], 'einstein'),
#  (['schwarzschild', 'find', 'solution', 'einstein'], 'field'),
#  (['find', 'solution', 'einstein', 'field'], 'equation'),
#  (['solution', 'einstein', 'field', 'equation'], 'describe'),
#  (['einstein', 'field', 'equation', 'describe'], 'gravitational'),
#  (['field', 'equation', 'describe', 'gravitational'], 'field'),
#  (['equation', 'describe', 'gravitational', 'field'], 'point'),
#  (['describe', 'gravitational', 'field', 'point'], 'mass'),
#  (['gravitational', 'field', 'point', 'mass'], 'spherical'),
#  (['field', 'point', 'mass', 'spherical'], 'mass'),
#  (['peculiar', 'behaviour', 'call', 'schwarzschild'], 'solution'),
#  (['solution', 'behaviour', 'call', 'schwarzschild'], 'peculiar'),
#  (['solution', 'peculiar', 'call', 'schwarzschild'], 'behaviour'),
#  (['solution', 'peculiar', 'behaviour', 'schwarzschild'], 'call'),
#  (['solution', 'peculiar', 'behaviour', 'call'], 'schwarzschild'),
#  (['peculiar', 'behaviour', 'call', 'schwarzschild'], 'radius'),
#  (['behaviour', 'call', 'schwarzschild', 'radius'], 'become'),
#  (['call', 'schwarzschild', 'radius', 'become'], 'singular'),
#  (['schwarzschild', 'radius', 'become', 'singular'], 'mean'),
#  (['radius', 'become', 'singular', 'mean'], 'term'),
#  (['become', 'singular', 'mean', 'term'], 'einstein'),
#  (['singular', 'mean', 'term', 'einstein'], 'equation'),
#  (['mean', 'term', 'einstein', 'equation'], 'become'),
#  (['term', 'einstein', 'equation', 'become'], 'infinite'),
#  (['make', 'reference', 'einstein', 'recent'], 'paper'),
#  (['paper', 'reference', 'einstein', 'recent'], 'make'),
#  (['paper', 'make', 'einstein', 'recent'], 'reference'),
#  (['paper', 'make', 'reference', 'recent'], 'einstein'),
#  (['paper', 'make', 'reference', 'einstein'], 'recent'),
#  (['make', 'reference', 'einstein', 'recent'], 'publication'),
#  (['reference', 'einstein', 'recent', 'publication'], 'oppenheimer'),
#  (['einstein', 'recent', 'publication', 'oppenheimer'], 'snyder'),
#  (['recent', 'publication', 'oppenheimer', 'snyder'], 'use'),
#  (['publication', 'oppenheimer', 'snyder', 'use'], 'einstein'),
#  (['oppenheimer', 'snyder', 'use', 'einstein'], 'theory'),
#  (['snyder', 'use', 'einstein', 'theory'], 'general'),
#  (['use', 'einstein', 'theory', 'general'], 'relativity'),
#  (['einstein', 'theory', 'general', 'relativity'], 'show'),
#  (['theory', 'general', 'relativity', 'show'], 'condition'),
#  (['general', 'relativity', 'show', 'condition'], 'black'),
#  (['relativity', 'show', 'condition', 'black'], 'hole'),
#  (['show', 'condition', 'black', 'hole'], 'could'),
#  (['condition', 'black', 'hole', 'could'], 'develop'),
#  (['black', 'hole', 'could', 'develop'], 'first'),
#  (['hole', 'could', 'develop', 'first'], 'time'),
#  (['could', 'develop', 'first', 'time'], 'contemporary'),
#  (['develop', 'first', 'time', 'contemporary'], 'physics'),
#  (['solution', 'extend', 'schwarzschild', 'solution'], 'finkelstein'),
#  (['finkelstein', 'extend', 'schwarzschild', 'solution'], 'solution'),
#  (['finkelstein', 'solution', 'schwarzschild', 'solution'], 'extend'),
#  (['finkelstein', 'solution', 'extend', 'solution'], 'schwarzschild'),
#  (['finkelstein', 'solution', 'extend', 'schwarzschild'], 'solution'),
#  (['solution', 'extend', 'schwarzschild', 'solution'], 'future'),
#  (['extend', 'schwarzschild', 'solution', 'future'], 'observer'),
#  (['schwarzschild', 'solution', 'future', 'observer'], 'fall'),
#  (['solution', 'future', 'observer', 'fall'], 'black'),
#  (['future', 'observer', 'fall', 'black'], 'hole'),
#  (['general', 'black', 'hole', 'solution'], 'period'),
#  (['period', 'black', 'hole', 'solution'], 'general'),
#  (['period', 'general', 'hole', 'solution'], 'black'),
#  (['period', 'general', 'black', 'solution'], 'hole'),
#  (['period', 'general', 'black', 'hole'], 'solution'),
#  (['general', 'black', 'hole', 'solution'], 'find'),
#  (['complete', 'hawking', '1974', 'show'], 'analogy'),
#  (['analogy', 'hawking', '1974', 'show'], 'complete'),
#  (['analogy', 'complete', '1974', 'show'], 'hawking'),
#  (['analogy', 'complete', 'hawking', 'show'], '1974'),
#  (['analogy', 'complete', 'hawking', '1974'], 'show'),
#  (['complete', 'hawking', '1974', 'show'], 'quantum'),
#  (['hawking', '1974', 'show', 'quantum'], 'field'),
#  (['1974', 'show', 'quantum', 'field'], 'theory'),
#  (['show', 'quantum', 'field', 'theory'], 'imply'),
#  (['quantum', 'field', 'theory', 'imply'], 'black'),
#  (['field', 'theory', 'imply', 'black'], 'hole'),
#  (['theory', 'imply', 'black', 'hole'], 'radiate'),
#  (['imply', 'black', 'hole', 'radiate'], 'like'),
#  (['black', 'hole', 'radiate', 'like'], 'black'),
#  (['hole', 'radiate', 'like', 'black'], 'body'),
#  (['radiate', 'like', 'black', 'body'], 'temperature'),
#  (['like', 'black', 'body', 'temperature'], 'proportional'),
#  (['black', 'body', 'temperature', 'proportional'], 'surface'),
#  (['body', 'temperature', 'proportional', 'surface'], 'gravity'),
#  (['temperature', 'proportional', 'surface', 'gravity'], 'black'),
#  (['proportional', 'surface', 'gravity', 'black'], 'hole'),
#  (['surface', 'gravity', 'black', 'hole'], 'predict'),
#  (['gravity', 'black', 'hole', 'predict'], 'effect'),
#  (['black', 'hole', 'predict', 'effect'], 'know'),
#  (['hole', 'predict', 'effect', 'know'], 'hawk'),
#  (['predict', 'effect', 'know', 'hawk'], 'radiation'),
#  (['april', '2019', 'first', 'direct'], '10'),
#  (['10', '2019', 'first', 'direct'], 'april'),
#  (['10', 'april', 'first', 'direct'], '2019'),
#  (['10', 'april', '2019', 'direct'], 'first'),
#  (['10', 'april', '2019', 'first'], 'direct'),
#  (['april', '2019', 'first', 'direct'], 'image'),
#  (['2019', 'first', 'direct', 'image'], 'black'),
#  (['first', 'direct', 'image', 'black'], 'hole'),
#  (['direct', 'image', 'black', 'hole'], 'vicinity'),
#  (['image', 'black', 'hole', 'vicinity'], 'publish'),
#  (['black', 'hole', 'vicinity', 'publish'], 'follow'),
#  (['hole', 'vicinity', 'publish', 'follow'], 'observation'),
#  (['vicinity', 'publish', 'follow', 'observation'], 'make'),
#  (['publish', 'follow', 'observation', 'make'], 'event'),
#  (['follow', 'observation', 'make', 'event'], 'horizon'),
#  (['observation', 'make', 'event', 'horizon'], 'telescope'),
#  (['make', 'event', 'horizon', 'telescope'], '2017'),
#  (['event', 'horizon', 'telescope', '2017'], 'supermassive'),
#  (['horizon', 'telescope', '2017', 'supermassive'], 'black'),
#  (['telescope', '2017', 'supermassive', 'black'], 'hole'),
#  (['2017', 'supermassive', 'black', 'hole'], 'messier'),
#  (['supermassive', 'black', 'hole', 'messier'], '87'),
#  (['black', 'hole', 'messier', '87'], 'galactic'),
#  (['hole', 'messier', '87', 'galactic'], 'centre'),
#  (['would', 'detectable', 'gravitational', 'lensing'], 'therefore'),
#  (['therefore', 'detectable', 'gravitational', 'lensing'], 'would'),
#  (['therefore', 'would', 'gravitational', 'lensing'], 'detectable'),
#  (['therefore', 'would', 'detectable', 'lensing'], 'gravitational'),
#  (['therefore', 'would', 'detectable', 'gravitational'], 'lensing'),
#  (['special', 'visible', 'outside', 'black'], 'property'),
#  (['property', 'visible', 'outside', 'black'], 'special'),
#  (['property', 'special', 'outside', 'black'], 'visible'),
#  (['property', 'special', 'visible', 'black'], 'outside'),
#  (['property', 'special', 'visible', 'outside'], 'black'),
#  (['special', 'visible', 'outside', 'black'], 'hole'),
#  (['hole', 'eventually', 'achieve', 'stable'], 'black'),
#  (['black', 'eventually', 'achieve', 'stable'], 'hole'),
#  (['black', 'hole', 'achieve', 'stable'], 'eventually'),
#  (['black', 'hole', 'eventually', 'stable'], 'achieve'),
#  (['black', 'hole', 'eventually', 'achieve'], 'stable'),
#  (['hole', 'eventually', 'achieve', 'stable'], 'state'),
#  (['eventually', 'achieve', 'stable', 'state'], 'three'),
#  (['achieve', 'stable', 'state', 'three'], 'parameter'),
#  (['stable', 'state', 'three', 'parameter'], 'way'),
#  (['state', 'three', 'parameter', 'way'], 'avoid'),
#  (['three', 'parameter', 'way', 'avoid'], 'lose'),
#  (['parameter', 'way', 'avoid', 'lose'], 'information'),
#  (['way', 'avoid', 'lose', 'information'], 'initial'),
#  (['avoid', 'lose', 'information', 'initial'], 'condition'),
#  (['lose', 'information', 'initial', 'condition'], 'gravitational'),
#  (['information', 'initial', 'condition', 'gravitational'], 'electric'),
#  (['initial', 'condition', 'gravitational', 'electric'], 'field'),
#  (['condition', 'gravitational', 'electric', 'field'], 'black'),
#  (['gravitational', 'electric', 'field', 'black'], 'hole'),
#  (['electric', 'field', 'black', 'hole'], 'give'),
#  (['field', 'black', 'hole', 'give'], 'little'),
#  (['black', 'hole', 'give', 'little'], 'information'),
#  (['hole', 'give', 'little', 'information'], 'go'),
#  (['puzzle', 'call', 'black', 'hole'], 'behavior'),
#  (['behavior', 'call', 'black', 'hole'], 'puzzle'),
#  (['behavior', 'puzzle', 'black', 'hole'], 'call'),
#  (['behavior', 'puzzle', 'call', 'hole'], 'black'),
#  (['behavior', 'puzzle', 'call', 'black'], 'hole'),
#  (['puzzle', 'call', 'black', 'hole'], 'information'),
#  (['call', 'black', 'hole', 'information'], 'loss'),
#  (['black', 'hole', 'information', 'loss'], 'paradox'),
#  (['hole', 'often', 'refer', 'schwarzschild'], 'black'),
#  (['black', 'often', 'refer', 'schwarzschild'], 'hole'),
#  (['black', 'hole', 'refer', 'schwarzschild'], 'often'),
#  (['black', 'hole', 'often', 'schwarzschild'], 'refer'),
#  (['black', 'hole', 'often', 'refer'], 'schwarzschild'),
#  (['hole', 'often', 'refer', 'schwarzschild'], 'black'),
#  (['often', 'refer', 'schwarzschild', 'black'], 'hole'),
#  (['refer', 'schwarzschild', 'black', 'hole'], 'karl'),
#  (['schwarzschild', 'black', 'hole', 'karl'], 'schwarzschild'),
#  (['black', 'hole', 'karl', 'schwarzschild'], 'discover'),
#  (['hole', 'karl', 'schwarzschild', 'discover'], 'solution'),
#  (['karl', 'schwarzschild', 'discover', 'solution'], '1916'),
#  (['describe', 'general', 'black', 'hole'], 'solution'),
#  (['solution', 'general', 'black', 'hole'], 'describe'),
#  (['solution', 'describe', 'black', 'hole'], 'general'),
#  (['solution', 'describe', 'general', 'hole'], 'black'),
#  (['solution', 'describe', 'general', 'black'], 'hole'),
#  (['describe', 'general', 'black', 'hole'], 'also'),
#  (['general', 'black', 'hole', 'also'], 'exist'),
#  (['stationary', 'black', 'hole', 'solution'], 'general'),
#  (['general', 'black', 'hole', 'solution'], 'stationary'),
#  (['general', 'stationary', 'hole', 'solution'], 'black'),
#  (['general', 'stationary', 'black', 'solution'], 'hole'),
#  (['general', 'stationary', 'black', 'hole'], 'solution'),
#  (['stationary', 'black', 'hole', 'solution'], 'know'),
#  (['black', 'hole', 'solution', 'know'], 'kerr'),
#  (['hole', 'solution', 'know', 'kerr'], '–'),
#  (['solution', 'know', 'kerr', '–'], 'newman'),
#  (['know', 'kerr', '–', 'newman'], 'metric'),
#  (['kerr', '–', 'newman', 'metric'], 'describe'),
#  (['–', 'newman', 'metric', 'describe'], 'black'),
#  (['newman', 'metric', 'describe', 'black'], 'hole'),
#  (['metric', 'describe', 'black', 'hole'], 'charge'),
#  (['describe', 'black', 'hole', 'charge'], 'angular'),
#  (['black', 'hole', 'charge', 'angular'], 'momentum'),
#  (['hole', 'minimum', 'possible', 'mass'], 'black'),
#  (['black', 'minimum', 'possible', 'mass'], 'hole'),
#  (['black', 'hole', 'possible', 'mass'], 'minimum'),
#  (['black', 'hole', 'minimum', 'mass'], 'possible'),
#  (['black', 'hole', 'minimum', 'possible'], 'mass'),
#  (['hole', 'minimum', 'possible', 'mass'], 'satisfy'),
#  (['minimum', 'possible', 'mass', 'satisfy'], 'inequality'),
#  (['possible', 'mass', 'satisfy', 'inequality'], 'call'),
#  (['mass', 'satisfy', 'inequality', 'call'], 'extremal'),
#  (['einstein', 'equation', 'violate', 'inequality'], 'solution'),
#  (['solution', 'equation', 'violate', 'inequality'], 'einstein'),
#  (['solution', 'einstein', 'violate', 'inequality'], 'equation'),
#  (['solution', 'einstein', 'equation', 'inequality'], 'violate'),
#  (['solution', 'einstein', 'equation', 'violate'], 'inequality'),
#  (['einstein', 'equation', 'violate', 'inequality'], 'exist'),
#  (['equation', 'violate', 'inequality', 'exist'], 'possess'),
#  (['violate', 'inequality', 'exist', 'possess'], 'event'),
#  (['inequality', 'exist', 'possess', 'event'], 'horizon'),
#  (['approx'], 'mass'),
#  (['mass'], 'approx'),
#  (['black', 'hole', 'spacetime', 'start'], 'close'),
#  (['close', 'hole', 'spacetime', 'start'], 'black'),
#  (['close', 'black', 'spacetime', 'start'], 'hole'),
#  (['close', 'black', 'hole', 'start'], 'spacetime'),
#  (['close', 'black', 'hole', 'spacetime'], 'start'),
#  (['black', 'hole', 'spacetime', 'start'], 'deform'),
#  (['go', 'towards', 'black', 'hole'], 'path'),
#  (['path', 'towards', 'black', 'hole'], 'go'),
#  (['path', 'go', 'black', 'hole'], 'towards'),
#  (['path', 'go', 'towards', 'hole'], 'black'),
#  (['path', 'go', 'towards', 'black'], 'hole'),
#  (['go', 'towards', 'black', 'hole'], 'path'),
#  (['towards', 'black', 'hole', 'path'], 'move'),
#  (['black', 'hole', 'path', 'move'], 'away'),
#  (['possible', 'particle', 'escape'], 'long'),
#  (['long', 'particle', 'escape'], 'possible'),
#  (['long', 'possible', 'escape'], 'particle'),
#  (['long', 'possible', 'particle'], 'escape'),
#  (['feature', 'black', 'hole', 'appearance'], 'define'),
#  (['define', 'black', 'hole', 'appearance'], 'feature'),
#  (['define', 'feature', 'hole', 'appearance'], 'black'),
#  (['define', 'feature', 'black', 'appearance'], 'hole'),
#  (['define', 'feature', 'black', 'hole'], 'appearance'),
#  (['feature', 'black', 'hole', 'appearance'], 'event'),
#  (['black', 'hole', 'appearance', 'event'], 'horizon'),
#  (['hole', 'appearance', 'event', 'horizon'], '—'),
#  (['appearance', 'event', 'horizon', '—'], 'boundary'),
#  (['event', 'horizon', '—', 'boundary'], 'spacetime'),
#  (['horizon', '—', 'boundary', 'spacetime'], 'matter'),
#  (['—', 'boundary', 'spacetime', 'matter'], 'light'),
#  (['boundary', 'spacetime', 'matter', 'light'], 'pass'),
#  (['spacetime', 'matter', 'light', 'pass'], 'inward'),
#  (['matter', 'light', 'pass', 'inward'], 'towards'),
#  (['light', 'pass', 'inward', 'towards'], 'mass'),
#  (['pass', 'inward', 'towards', 'mass'], 'black'),
#  (['inward', 'towards', 'mass', 'black'], 'hole'),
#  (['even', 'light', 'escape', 'inside'], 'nothing'),
#  (['nothing', 'light', 'escape', 'inside'], 'even'),
#  (['nothing', 'even', 'escape', 'inside'], 'light'),
#  (['nothing', 'even', 'light', 'inside'], 'escape'),
#  (['nothing', 'even', 'light', 'escape'], 'inside'),
#  (['even', 'light', 'escape', 'inside'], 'event'),
#  (['light', 'escape', 'inside', 'event'], 'horizon'),
#  (['horizon', 'refer', 'event', 'occur'], 'event'),
#  (['event', 'refer', 'event', 'occur'], 'horizon'),
#  (['event', 'horizon', 'event', 'occur'], 'refer'),
#  (['event', 'horizon', 'refer', 'occur'], 'event'),
#  (['event', 'horizon', 'refer', 'event'], 'occur'),
#  (['horizon', 'refer', 'event', 'occur'], 'within'),
#  (['refer', 'event', 'occur', 'within'], 'boundary'),
#  (['event', 'occur', 'within', 'boundary'], 'information'),
#  (['occur', 'within', 'boundary', 'information'], 'event'),
#  (['within', 'boundary', 'information', 'event'], 'reach'),
#  (['boundary', 'information', 'event', 'reach'], 'outside'),
#  (['information', 'event', 'reach', 'outside'], 'observer'),
#  (['event', 'reach', 'outside', 'observer'], 'make'),
#  (['reach', 'outside', 'observer', 'make'], 'impossible'),
#  (['outside', 'observer', 'make', 'impossible'], 'determine'),
#  (['observer', 'make', 'impossible', 'determine'], 'whether'),
#  (['make', 'impossible', 'determine', 'whether'], 'event'),
#  (['impossible', 'determine', 'whether', 'event'], 'occur'),
#  (['general', 'relativity', 'presence', 'mass'], 'predict'),
#  (['predict', 'relativity', 'presence', 'mass'], 'general'),
#  (['predict', 'general', 'presence', 'mass'], 'relativity'),
#  (['predict', 'general', 'relativity', 'mass'], 'presence'),
#  (['predict', 'general', 'relativity', 'presence'], 'mass'),
#  (['general', 'relativity', 'presence', 'mass'], 'deform'),
#  (['relativity', 'presence', 'mass', 'deform'], 'spacetime'),
#  (['presence', 'mass', 'deform', 'spacetime'], 'way'),
#  (['mass', 'deform', 'spacetime', 'way'], 'path'),
#  (['deform', 'spacetime', 'way', 'path'], 'take'),
#  (['spacetime', 'way', 'path', 'take'], 'particle'),
#  (['way', 'path', 'take', 'particle'], 'bend'),
#  (['path', 'take', 'particle', 'bend'], 'towards'),
#  (['take', 'particle', 'bend', 'towards'], 'mass'),
#  (['horizon', 'black', 'hole', 'deformation'], 'event'),
#  (['event', 'black', 'hole', 'deformation'], 'horizon'),
#  (['event', 'horizon', 'hole', 'deformation'], 'black'),
#  (['event', 'horizon', 'black', 'deformation'], 'hole'),
#  (['event', 'horizon', 'black', 'hole'], 'deformation'),
#  (['horizon', 'black', 'hole', 'deformation'], 'become'),
#  (['black', 'hole', 'deformation', 'become'], 'strong'),
#  (['hole', 'deformation', 'become', 'strong'], 'path'),
#  (['deformation', 'become', 'strong', 'path'], 'lead'),
#  (['become', 'strong', 'path', 'lead'], 'away'),
#  (['strong', 'path', 'lead', 'away'], 'black'),
#  (['path', 'lead', 'away', 'black'], 'hole'),
#  (['observer', 'clock', 'near', 'black'], 'distant'),
#  (['distant', 'clock', 'near', 'black'], 'observer'),
#  (['distant', 'observer', 'near', 'black'], 'clock'),
#  (['distant', 'observer', 'clock', 'black'], 'near'),
#  (['distant', 'observer', 'clock', 'near'], 'black'),
#  (['observer', 'clock', 'near', 'black'], 'hole'),
#  (['clock', 'near', 'black', 'hole'], 'would'),
#  (['near', 'black', 'hole', 'would'], 'appear'),
#  (['black', 'hole', 'would', 'appear'], 'tick'),
#  (['hole', 'would', 'appear', 'tick'], 'slowly'),
#  (['would', 'appear', 'tick', 'slowly'], 'far'),
#  (['appear', 'tick', 'slowly', 'far'], 'away'),
#  (['tick', 'slowly', 'far', 'away'], 'black'),
#  (['slowly', 'far', 'away', 'black'], 'hole'),
#  (['effect', 'know', 'gravitational', 'time'], 'due'),
#  (['due', 'know', 'gravitational', 'time'], 'effect'),
#  (['due', 'effect', 'gravitational', 'time'], 'know'),
#  (['due', 'effect', 'know', 'time'], 'gravitational'),
#  (['due', 'effect', 'know', 'gravitational'], 'time'),
#  (['effect', 'know', 'gravitational', 'time'], 'dilation'),
#  (['know', 'gravitational', 'time', 'dilation'], 'object'),
#  (['gravitational', 'time', 'dilation', 'object'], 'fall'),
#  (['time', 'dilation', 'object', 'fall'], 'black'),
#  (['dilation', 'object', 'fall', 'black'], 'hole'),
#  (['object', 'fall', 'black', 'hole'], 'appear'),
#  (['fall', 'black', 'hole', 'appear'], 'slow'),
#  (['black', 'hole', 'appear', 'slow'], 'approach'),
#  (['hole', 'appear', 'slow', 'approach'], 'event'),
#  (['appear', 'slow', 'approach', 'event'], 'horizon'),
#  (['slow', 'approach', 'event', 'horizon'], 'take'),
#  (['approach', 'event', 'horizon', 'take'], 'infinite'),
#  (['event', 'horizon', 'take', 'infinite'], 'time'),
#  (['horizon', 'take', 'infinite', 'time'], 'reach'),
#  (['fall', 'object', 'fade', 'away'], 'eventually'),
#  (['eventually', 'object', 'fade', 'away'], 'fall'),
#  (['eventually', 'fall', 'fade', 'away'], 'object'),
#  (['eventually', 'fall', 'object', 'away'], 'fade'),
#  (['eventually', 'fall', 'object', 'fade'], 'away'),
#  (['fall', 'object', 'fade', 'away'], 'long'),
#  (['object', 'fade', 'away', 'long'], 'see'),
#  (['process', 'happen', 'rapidly', 'object'], 'typically'),
#  (['typically', 'happen', 'rapidly', 'object'], 'process'),
#  (['typically', 'process', 'rapidly', 'object'], 'happen'),
#  (['typically', 'process', 'happen', 'object'], 'rapidly'),
#  (['typically', 'process', 'happen', 'rapidly'], 'object'),
#  (['process', 'happen', 'rapidly', 'object'], 'disappear'),
#  (['happen', 'rapidly', 'object', 'disappear'], 'view'),
#  (['rapidly', 'object', 'disappear', 'view'], 'within'),
#  (['object', 'disappear', 'view', 'within'], 'less'),
#  (['disappear', 'view', 'within', 'less'], 'second'),
#  (['clock', 'appear', 'tick', 'normally'], 'accord'),
#  (['accord', 'appear', 'tick', 'normally'], 'clock'),
#  (['accord', 'clock', 'tick', 'normally'], 'appear'),
#  (['accord', 'clock', 'appear', 'normally'], 'tick'),
#  (['accord', 'clock', 'appear', 'tick'], 'normally'),
#  (['clock', 'appear', 'tick', 'normally'], 'cross'),
#  (['appear', 'tick', 'normally', 'cross'], 'event'),
#  (['tick', 'normally', 'cross', 'event'], 'horizon'),
#  (['normally', 'cross', 'event', 'horizon'], 'finite'),
#  (['cross', 'event', 'horizon', 'finite'], 'time'),
#  (['event', 'horizon', 'finite', 'time'], 'without'),
#  (['horizon', 'finite', 'time', 'without'], 'note'),
#  (['finite', 'time', 'without', 'note'], 'singular'),
#  (['time', 'without', 'note', 'singular'], 'behaviour'),
#  (['general', 'relativity', 'impossible', 'determine'], 'classical'),
#  (['classical', 'relativity', 'impossible', 'determine'], 'general'),
#  (['classical', 'general', 'impossible', 'determine'], 'relativity'),
#  (['classical', 'general', 'relativity', 'determine'], 'impossible'),
#  (['classical', 'general', 'relativity', 'impossible'], 'determine'),
#  (['general', 'relativity', 'impossible', 'determine'], 'location'),
#  (['relativity', 'impossible', 'determine', 'location'], 'event'),
#  (['impossible', 'determine', 'location', 'event'], 'horizon'),
#  (['determine', 'location', 'event', 'horizon'], 'local'),
#  (['location', 'event', 'horizon', 'local'], 'observation'),
#  (['event', 'horizon', 'local', 'observation'], 'due'),
#  (['horizon', 'local', 'observation', 'due'], 'einstein'),
#  (['local', 'observation', 'due', 'einstein'], 'equivalence'),
#  (['observation', 'due', 'einstein', 'equivalence'], 'principle'),
#  (['main', 'article', 'gravitational', 'singularity'], 'singularity'),
#  (['singularity', 'article', 'gravitational', 'singularity'], 'main'),
#  (['singularity', 'main', 'gravitational', 'singularity'], 'article'),
#  (['singularity', 'main', 'article', 'singularity'], 'gravitational'),
#  (['singularity', 'main', 'article', 'gravitational'], 'singularity'),
#  (['main', 'article', 'gravitational', 'singularity'], 'centre'),
#  (['article', 'gravitational', 'singularity', 'centre'], 'black'),
#  (['gravitational', 'singularity', 'centre', 'black'], 'hole'),
#  (['singularity', 'centre', 'black', 'hole'], 'describe'),
#  (['centre', 'black', 'hole', 'describe'], 'general'),
#  (['black', 'hole', 'describe', 'general'], 'relativity'),
#  (['hole', 'describe', 'general', 'relativity'], 'may'),
#  (['describe', 'general', 'relativity', 'may'], 'lie'),
#  (['general', 'relativity', 'may', 'lie'], 'gravitational'),
#  (['relativity', 'may', 'lie', 'gravitational'], 'singularity'),
#  (['may', 'lie', 'gravitational', 'singularity'], 'region'),
#  (['lie', 'gravitational', 'singularity', 'region'], 'spacetime'),
#  (['gravitational', 'singularity', 'region', 'spacetime'], 'curvature'),
#  (['singularity', 'region', 'spacetime', 'curvature'], 'become'),
#  (['region', 'spacetime', 'curvature', 'become'], 'infinite'),
#  (['rotating', 'black', 'hole', 'region'], 'non'),
#  (['non', 'black', 'hole', 'region'], 'rotating'),
#  (['non', 'rotating', 'hole', 'region'], 'black'),
#  (['non', 'rotating', 'black', 'region'], 'hole'),
#  (['non', 'rotating', 'black', 'hole'], 'region'),
#  (['rotating', 'black', 'hole', 'region'], 'take'),
#  (['black', 'hole', 'region', 'take'], 'shape'),
#  (['hole', 'region', 'take', 'shape'], 'single'),
#  (['region', 'take', 'shape', 'single'], 'point'),
#  (['singular', 'region', 'zero', 'volume'], 'case'),
#  (['case', 'region', 'zero', 'volume'], 'singular'),
#  (['case', 'singular', 'zero', 'volume'], 'region'),
#  (['case', 'singular', 'region', 'volume'], 'zero'),
#  (['case', 'singular', 'region', 'zero'], 'volume'),
#  (['show', 'singular', 'region', 'contain'], 'also'),
#  (['also', 'singular', 'region', 'contain'], 'show'),
#  (['also', 'show', 'region', 'contain'], 'singular'),
#  (['also', 'show', 'singular', 'contain'], 'region'),
#  (['also', 'show', 'singular', 'region'], 'contain'),
#  (['show', 'singular', 'region', 'contain'], 'mass'),
#  (['singular', 'region', 'contain', 'mass'], 'black'),
#  (['region', 'contain', 'mass', 'black'], 'hole'),
#  (['contain', 'mass', 'black', 'hole'], 'solution'),
#  (['region', 'thus', 'think', 'infinite'], 'singular'),
#  (['singular', 'thus', 'think', 'infinite'], 'region'),
#  (['singular', 'region', 'think', 'infinite'], 'thus'),
#  (['singular', 'region', 'thus', 'infinite'], 'think'),
#  (['singular', 'region', 'thus', 'think'], 'infinite'),
#  (['region', 'thus', 'think', 'infinite'], 'density'),
#  (['fall', 'schwarzschild', 'black', 'hole'], 'observer'),
#  (['observer', 'schwarzschild', 'black', 'hole'], 'fall'),
#  (['observer', 'fall', 'black', 'hole'], 'schwarzschild'),
#  (['observer', 'fall', 'schwarzschild', 'hole'], 'black'),
#  (['observer', 'fall', 'schwarzschild', 'black'], 'hole'),
#  (['fall', 'schwarzschild', 'black', 'hole'], 'avoid'),
#  (['schwarzschild', 'black', 'hole', 'avoid'], 'carry'),
#  (['black', 'hole', 'avoid', 'carry'], 'singularity'),
#  (['hole', 'avoid', 'carry', 'singularity'], 'cross'),
#  (['avoid', 'carry', 'singularity', 'cross'], 'event'),
#  (['carry', 'singularity', 'cross', 'event'], 'horizon'),
#  (['charge', 'rotate', 'black', 'hole'], 'case'),
#  (['case', 'rotate', 'black', 'hole'], 'charge'),
#  (['case', 'charge', 'black', 'hole'], 'rotate'),
#  (['case', 'charge', 'rotate', 'hole'], 'black'),
#  (['case', 'charge', 'rotate', 'black'], 'hole'),
#  (['charge', 'rotate', 'black', 'hole'], 'possible'),
#  (['rotate', 'black', 'hole', 'possible'], 'avoid'),
#  (['black', 'hole', 'possible', 'avoid'], 'singularity'),
#  (['travel', 'another', 'universe', 'however'], 'possibility'),
#  (['possibility', 'another', 'universe', 'however'], 'travel'),
#  (['possibility', 'travel', 'universe', 'however'], 'another'),
#  (['possibility', 'travel', 'another', 'however'], 'universe'),
#  (['possibility', 'travel', 'another', 'universe'], 'however'),
#  (['travel', 'another', 'universe', 'however'], 'theoretical'),
#  (['another', 'universe', 'however', 'theoretical'], 'since'),
#  (['universe', 'however', 'theoretical', 'since'], 'perturbation'),
#  (['however', 'theoretical', 'since', 'perturbation'], 'would'),
#  (['theoretical', 'since', 'perturbation', 'would'], 'destroy'),
#  (['since', 'perturbation', 'would', 'destroy'], 'possibility'),
#  (['singularity', 'general', 'relativity', 'commonly'], 'appearance'),
#  (['appearance', 'general', 'relativity', 'commonly'], 'singularity'),
#  (['appearance', 'singularity', 'relativity', 'commonly'], 'general'),
#  (['appearance', 'singularity', 'general', 'commonly'], 'relativity'),
#  (['appearance', 'singularity', 'general', 'relativity'], 'commonly'),
#  (['singularity', 'general', 'relativity', 'commonly'], 'perceive'),
#  (['general', 'relativity', 'commonly', 'perceive'], 'signal'),
#  (['relativity', 'commonly', 'perceive', 'signal'], 'breakdown'),
#  (['commonly', 'perceive', 'signal', 'breakdown'], 'theory'),
#  (['however', 'expect'], 'breakdown'),
#  (['breakdown', 'expect'], 'however'),
#  (['breakdown', 'however'], 'expect'),
#  (['expect', 'theory', 'feature', 'singularity'], 'generally'),
#  (['generally', 'theory', 'feature', 'singularity'], 'expect'),
#  (['generally', 'expect', 'feature', 'singularity'], 'theory'),
#  (['generally', 'expect', 'theory', 'singularity'], 'feature'),
#  (['generally', 'expect', 'theory', 'feature'], 'singularity'),
#  (['rotating', 'black', 'hole', 'photon'], 'non'),
#  (['non', 'black', 'hole', 'photon'], 'rotating'),
#  (['non', 'rotating', 'hole', 'photon'], 'black'),
#  (['non', 'rotating', 'black', 'photon'], 'hole'),
#  (['non', 'rotating', 'black', 'hole'], 'photon'),
#  (['rotating', 'black', 'hole', 'photon'], 'sphere'),
#  (['black', 'hole', 'photon', 'sphere'], 'radius'),
#  (['hole', 'photon', 'sphere', 'radius'], '1.5'),
#  (['photon', 'sphere', 'radius', '1.5'], 'time'),
#  (['sphere', 'radius', '1.5', 'time'], 'schwarzschild'),
#  (['radius', '1.5', 'time', 'schwarzschild'], 'radius'),
#  (['light', 'reach', 'outside', 'observer'], 'hence'),
#  (['hence', 'reach', 'outside', 'observer'], 'light'),
#  (['hence', 'light', 'outside', 'observer'], 'reach'),
#  (['hence', 'light', 'reach', 'observer'], 'outside'),
#  (['hence', 'light', 'reach', 'outside'], 'observer'),
#  (['light', 'reach', 'outside', 'observer'], 'photon'),
#  (['reach', 'outside', 'observer', 'photon'], 'sphere'),
#  (['outside', 'observer', 'photon', 'sphere'], 'must'),
#  (['observer', 'photon', 'sphere', 'must'], 'emit'),
#  (['photon', 'sphere', 'must', 'emit'], 'object'),
#  (['sphere', 'must', 'emit', 'object'], 'photon'),
#  (['must', 'emit', 'object', 'photon'], 'sphere'),
#  (['emit', 'object', 'photon', 'sphere'], 'event'),
#  (['object', 'photon', 'sphere', 'event'], 'horizon'),
#  (['black', 'hole', 'surround', 'region'], 'rotate'),
#  (['rotate', 'hole', 'surround', 'region'], 'black'),
#  (['rotate', 'black', 'surround', 'region'], 'hole'),
#  (['rotate', 'black', 'hole', 'region'], 'surround'),
#  (['rotate', 'black', 'hole', 'surround'], 'region'),
#  (['black', 'hole', 'surround', 'region'], 'spacetime'),
#  (['hole', 'surround', 'region', 'spacetime'], 'impossible'),
#  (['surround', 'region', 'spacetime', 'impossible'], 'stand'),
#  (['region', 'spacetime', 'impossible', 'stand'], 'still'),
#  (['spacetime', 'impossible', 'stand', 'still'], 'call'),
#  (['impossible', 'stand', 'still', 'call'], 'ergosphere'),
#  (['near', 'rotate', 'mass', 'tend'], 'object'),
#  (['object', 'rotate', 'mass', 'tend'], 'near'),
#  (['object', 'near', 'mass', 'tend'], 'rotate'),
#  (['object', 'near', 'rotate', 'tend'], 'mass'),
#  (['object', 'near', 'rotate', 'mass'], 'tend'),
#  (['near', 'rotate', 'mass', 'tend'], 'start'),
#  (['rotate', 'mass', 'tend', 'start'], 'move'),
#  (['mass', 'tend', 'start', 'move'], 'direction'),
#  (['tend', 'start', 'move', 'direction'], 'rotation'),
#  (['radiation', 'escape', 'normally', 'ergosphere'], 'object'),
#  (['object', 'escape', 'normally', 'ergosphere'], 'radiation'),
#  (['object', 'radiation', 'normally', 'ergosphere'], 'escape'),
#  (['object', 'radiation', 'escape', 'ergosphere'], 'normally'),
#  (['object', 'radiation', 'escape', 'normally'], 'ergosphere'),
#  (['process', 'object', 'emerge', 'ergosphere'], 'penrose'),
#  (['penrose', 'object', 'emerge', 'ergosphere'], 'process'),
#  (['penrose', 'process', 'emerge', 'ergosphere'], 'object'),
#  (['penrose', 'process', 'object', 'ergosphere'], 'emerge'),
#  (['penrose', 'process', 'object', 'emerge'], 'ergosphere'),
#  (['process', 'object', 'emerge', 'ergosphere'], 'energy'),
#  (['object', 'emerge', 'ergosphere', 'energy'], 'enter'),
#  (['rotation', 'black', 'hole', 'slow'], 'thereby'),
#  (['thereby', 'black', 'hole', 'slow'], 'rotation'),
#  (['thereby', 'rotation', 'hole', 'slow'], 'black'),
#  (['thereby', 'rotation', 'black', 'slow'], 'hole'),
#  (['thereby', 'rotation', 'black', 'hole'], 'slow'),
#  (['demonstrate', 'event', 'horizon', 'form'], 'penrose'),
#  (['penrose', 'event', 'horizon', 'form'], 'demonstrate'),
#  (['penrose', 'demonstrate', 'horizon', 'form'], 'event'),
#  (['penrose', 'demonstrate', 'event', 'form'], 'horizon'),
#  (['penrose', 'demonstrate', 'event', 'horizon'], 'form'),
#  (['demonstrate', 'event', 'horizon', 'form'], 'general'),
#  (['event', 'horizon', 'form', 'general'], 'relativity'),
#  (['horizon', 'form', 'general', 'relativity'], 'without'),
#  (['form', 'general', 'relativity', 'without'], 'quantum'),
#  (['general', 'relativity', 'without', 'quantum'], 'mechanic'),
#  (['relativity', 'without', 'quantum', 'mechanic'], 'require'),
#  (['without', 'quantum', 'mechanic', 'require'], 'singularity'),
#  (['quantum', 'mechanic', 'require', 'singularity'], 'form'),
#  (['mechanic', 'require', 'singularity', 'form'], 'within'),
#  (['one', 'various', 'type', 'compact'], 'result'),
#  (['result', 'various', 'type', 'compact'], 'one'),
#  (['result', 'one', 'type', 'compact'], 'various'),
#  (['result', 'one', 'various', 'compact'], 'type'),
#  (['result', 'one', 'various', 'type'], 'compact'),
#  (['one', 'various', 'type', 'compact'], 'star'),
#  (['hole', 'could', 'seed', 'supermassive'], 'black'),
#  (['black', 'could', 'seed', 'supermassive'], 'hole'),
#  (['black', 'hole', 'seed', 'supermassive'], 'could'),
#  (['black', 'hole', 'could', 'supermassive'], 'seed'),
#  (['black', 'hole', 'could', 'seed'], 'supermassive'),
#  (['hole', 'could', 'seed', 'supermassive'], 'black'),
#  (['could', 'seed', 'supermassive', 'black'], 'hole'),
#  (['seed', 'supermassive', 'black', 'hole'], 'find'),
#  (['supermassive', 'black', 'hole', 'find'], 'centre'),
#  (['black', 'hole', 'find', 'centre'], 'galaxy'),
#  (['object', 'find', 'observation', 'young'], 'candidate'),
#  (['candidate', 'find', 'observation', 'young'], 'object'),
#  (['candidate', 'object', 'observation', 'young'], 'find'),
#  (['candidate', 'object', 'find', 'young'], 'observation'),
#  (['candidate', 'object', 'find', 'observation'], 'young'),
#  (['object', 'find', 'observation', 'young'], 'universe'),
#  (['release', 'gravitational', 'collapse', 'emit'], 'energy'),
#  (['energy', 'gravitational', 'collapse', 'emit'], 'release'),
#  (['energy', 'release', 'collapse', 'emit'], 'gravitational'),
#  (['energy', 'release', 'gravitational', 'emit'], 'collapse'),
#  (['energy', 'release', 'gravitational', 'collapse'], 'emit'),
#  (['release', 'gravitational', 'collapse', 'emit'], 'quickly'),
#  (['gravitational', 'collapse', 'emit', 'quickly'], 'outside'),
#  (['collapse', 'emit', 'quickly', 'outside'], 'observer'),
#  (['emit', 'quickly', 'outside', 'observer'], 'actually'),
#  (['quickly', 'outside', 'observer', 'actually'], 'see'),
#  (['outside', 'observer', 'actually', 'see'], 'end'),
#  (['observer', 'actually', 'see', 'end'], 'process'),
#  (['external', 'observer', 'never', 'see'], 'thus'),
#  (['thus', 'observer', 'never', 'see'], 'external'),
#  (['thus', 'external', 'never', 'see'], 'observer'),
#  (['thus', 'external', 'observer', 'see'], 'never'),
#  (['thus', 'external', 'observer', 'never'], 'see'),
#  (['external', 'observer', 'never', 'see'], 'formation'),
#  (['observer', 'never', 'see', 'formation'], 'event'),
#  (['never', 'see', 'formation', 'event'], 'horizon'),
#  (['black', 'hole', 'big', 'bang'], 'primordial'),
#  (['primordial', 'hole', 'big', 'bang'], 'black'),
#  (['primordial', 'black', 'big', 'bang'], 'hole'),
#  (['primordial', 'black', 'hole', 'bang'], 'big'),
#  (['primordial', 'black', 'hole', 'big'], 'bang'),
#  (['black', 'hole', 'big', 'bang'], 'gravitational'),
#  (['hole', 'big', 'bang', 'gravitational'], 'collapse'),
#  (['big', 'bang', 'gravitational', 'collapse'], 'require'),
#  (['bang', 'gravitational', 'collapse', 'require'], 'great'),
#  (['gravitational', 'collapse', 'require', 'great'], 'density'),
#  (['energy', 'collision', 'gravitational', 'collapse'], 'high'),
#  (['high', 'collision', 'gravitational', 'collapse'], 'energy'),
#  (['high', 'energy', 'gravitational', 'collapse'], 'collision'),
#  (['high', 'energy', 'collision', 'collapse'], 'gravitational'),
#  (['high', 'energy', 'collision', 'gravitational'], 'collapse'),
#  (['energy', 'collision', 'gravitational', 'collapse'], 'process'),
#  (['collision', 'gravitational', 'collapse', 'process'], 'could'),
#  (['gravitational', 'collapse', 'process', 'could'], 'create'),
#  (['collapse', 'process', 'could', 'create'], 'black'),
#  (['process', 'could', 'create', 'black'], 'hole'),
#  (['must', 'low', 'limit', 'mass'], 'suggest'),
#  (['suggest', 'low', 'limit', 'mass'], 'must'),
#  (['suggest', 'must', 'limit', 'mass'], 'low'),
#  (['suggest', 'must', 'low', 'mass'], 'limit'),
#  (['suggest', 'must', 'low', 'limit'], 'mass'),
#  (['must', 'low', 'limit', 'mass'], 'black'),
#  (['low', 'limit', 'mass', 'black'], 'hole'),
#  (['black', 'hole', 'form', 'continue'], 'growth'),
#  (['growth', 'hole', 'form', 'continue'], 'black'),
#  (['growth', 'black', 'form', 'continue'], 'hole'),
#  (['growth', 'black', 'hole', 'continue'], 'form'),
#  (['growth', 'black', 'hole', 'form'], 'continue'),
#  (['black', 'hole', 'form', 'continue'], 'grow'),
#  (['hole', 'form', 'continue', 'grow'], 'absorb'),
#  (['form', 'continue', 'grow', 'absorb'], 'additional'),
#  (['continue', 'grow', 'absorb', 'additional'], 'matter'),
#  (['process', 'one', 'possible', 'way'], 'growth'),
#  (['growth', 'one', 'possible', 'way'], 'process'),
#  (['growth', 'process', 'possible', 'way'], 'one'),
#  (['growth', 'process', 'one', 'way'], 'possible'),
#  (['growth', 'process', 'one', 'possible'], 'way'),
#  (['process', 'one', 'possible', 'way'], 'supermassive'),
#  (['one', 'possible', 'way', 'supermassive'], 'black'),
#  (['possible', 'way', 'supermassive', 'black'], 'hole'),
#  (['way', 'supermassive', 'black', 'hole'], 'may'),
#  (['supermassive', 'black', 'hole', 'may'], 'form'),
#  (['black', 'hole', 'may', 'form'], 'although'),
#  (['hole', 'may', 'form', 'although'], 'formation'),
#  (['may', 'form', 'although', 'formation'], 'supermassive'),
#  (['form', 'although', 'formation', 'supermassive'], 'black'),
#  (['although', 'formation', 'supermassive', 'black'], 'hole'),
#  (['formation', 'supermassive', 'black', 'hole'], 'still'),
#  (['supermassive', 'black', 'hole', 'still'], 'open'),
#  (['black', 'hole', 'still', 'open'], 'field'),
#  (['hole', 'still', 'open', 'field'], 'research'),
#  (['hole', 'also', 'merge', 'object'], 'black'),
#  (['black', 'also', 'merge', 'object'], 'hole'),
#  (['black', 'hole', 'merge', 'object'], 'also'),
#  (['black', 'hole', 'also', 'object'], 'merge'),
#  (['black', 'hole', 'also', 'merge'], 'object'),
#  (['hole', 'also', 'merge', 'object'], 'star'),
#  (['also', 'merge', 'object', 'star'], 'even'),
#  (['merge', 'object', 'star', 'even'], 'black'),
#  (['object', 'star', 'even', 'black'], 'hole'),
#  (['become', 'know', 'hawk', 'radiation'], 'effect'),
#  (['effect', 'know', 'hawk', 'radiation'], 'become'),
#  (['effect', 'become', 'hawk', 'radiation'], 'know'),
#  (['effect', 'become', 'know', 'radiation'], 'hawk'),
#  (['effect', 'become', 'know', 'hawk'], 'radiation'),
#  (['quantum', 'field', 'theory', 'static'], 'apply'),
#  (['apply', 'field', 'theory', 'static'], 'quantum'),
#  (['apply', 'quantum', 'theory', 'static'], 'field'),
#  (['apply', 'quantum', 'field', 'static'], 'theory'),
#  (['apply', 'quantum', 'field', 'theory'], 'static'),
#  (['quantum', 'field', 'theory', 'static'], 'black'),
#  (['field', 'theory', 'static', 'black'], 'hole'),
#  (['theory', 'static', 'black', 'hole'], 'background'),
#  (['static', 'black', 'hole', 'background'], 'determine'),
#  (['black', 'hole', 'background', 'determine'], 'black'),
#  (['hole', 'background', 'determine', 'black'], 'hole'),
#  (['background', 'determine', 'black', 'hole'], 'emit'),
#  (['determine', 'black', 'hole', 'emit'], 'particle'),
#  (['black', 'hole', 'emit', 'particle'], 'display'),
#  (['hole', 'emit', 'particle', 'display'], 'perfect'),
#  (['emit', 'particle', 'display', 'perfect'], 'black'),
#  (['particle', 'display', 'perfect', 'black'], 'body'),
#  (['display', 'perfect', 'black', 'body'], 'spectrum'),
#  (['theory', 'black', 'hole', 'radiation'], 'hawking'),
#  (['hawking', 'black', 'hole', 'radiation'], 'theory'),
#  (['hawking', 'theory', 'hole', 'radiation'], 'black'),
#  (['hawking', 'theory', 'black', 'radiation'], 'hole'),
#  (['hawking', 'theory', 'black', 'hole'], 'radiation'),
#  (['theory', 'black', 'hole', 'radiation'], 'correct'),
#  (['black', 'hole', 'radiation', 'correct'], 'black'),
#  (['hole', 'radiation', 'correct', 'black'], 'hole'),
#  (['radiation', 'correct', 'black', 'hole'], 'expect'),
#  (['correct', 'black', 'hole', 'expect'], 'shrink'),
#  (['black', 'hole', 'expect', 'shrink'], 'evaporate'),
#  (['hole', 'expect', 'shrink', 'evaporate'], 'time'),
#  (['expect', 'shrink', 'evaporate', 'time'], 'lose'),
#  (['shrink', 'evaporate', 'time', 'lose'], 'mass'),
#  (['evaporate', 'time', 'lose', 'mass'], 'emission'),
#  (['time', 'lose', 'mass', 'emission'], 'photon'),
#  (['lose', 'mass', 'emission', 'photon'], 'particle'),
#  (['thermal', 'spectrum', 'proportional', 'surface'], 'temperature'),
#  (['temperature', 'spectrum', 'proportional', 'surface'], 'thermal'),
#  (['temperature', 'thermal', 'proportional', 'surface'], 'spectrum'),
#  (['temperature', 'thermal', 'spectrum', 'surface'], 'proportional'),
#  (['temperature', 'thermal', 'spectrum', 'proportional'], 'surface'),
#  (['thermal', 'spectrum', 'proportional', 'surface'], 'gravity'),
#  (['spectrum', 'proportional', 'surface', 'gravity'], 'black'),
#  (['proportional', 'surface', 'gravity', 'black'], 'hole'),
#  (['surface', 'gravity', 'black', 'hole'], 'schwarzschild'),
#  (['gravity', 'black', 'hole', 'schwarzschild'], 'black'),
#  (['black', 'hole', 'schwarzschild', 'black'], 'hole'),
#  (['hole', 'schwarzschild', 'black', 'hole'], 'inversely'),
#  (['schwarzschild', 'black', 'hole', 'inversely'], 'proportional'),
#  (['black', 'hole', 'inversely', 'proportional'], 'mass'),
#  (['large', 'black', 'hole', 'emit'], 'hence'),
#  (['hence', 'black', 'hole', 'emit'], 'large'),
#  (['hence', 'large', 'hole', 'emit'], 'black'),
#  (['hence', 'large', 'black', 'emit'], 'hole'),
#  (['hence', 'large', 'black', 'hole'], 'emit'),
#  (['large', 'black', 'hole', 'emit'], 'less'),
#  (['black', 'hole', 'emit', 'less'], 'radiation'),
#  (['hole', 'emit', 'less', 'radiation'], 'small'),
#  (['emit', 'less', 'radiation', 'small'], 'black'),
#  (['less', 'radiation', 'small', 'black'], 'hole'),
#  (['less', '2.7xa0', 'k', 'temperature'], 'far'),
#  (['far', '2.7xa0', 'k', 'temperature'], 'less'),
#  (['far', 'less', 'k', 'temperature'], '2.7xa0'),
#  (['far', 'less', '2.7xa0', 'temperature'], 'k'),
#  (['far', 'less', '2.7xa0', 'k'], 'temperature'),
#  (['less', '2.7xa0', 'k', 'temperature'], 'cosmic'),
#  (['2.7xa0', 'k', 'temperature', 'cosmic'], 'microwave'),
#  (['k', 'temperature', 'cosmic', 'microwave'], 'background'),
#  (['temperature', 'cosmic', 'microwave', 'background'], 'radiation'),
#  (['mass', 'large', 'black', 'hole'], 'stellar'),
#  (['stellar', 'large', 'black', 'hole'], 'mass'),
#  (['stellar', 'mass', 'black', 'hole'], 'large'),
#  (['stellar', 'mass', 'large', 'hole'], 'black'),
#  (['stellar', 'mass', 'large', 'black'], 'hole'),
#  (['mass', 'large', 'black', 'hole'], 'receive'),
#  (['large', 'black', 'hole', 'receive'], 'mass'),
#  (['black', 'hole', 'receive', 'mass'], 'cosmic'),
#  (['hole', 'receive', 'mass', 'cosmic'], 'microwave'),
#  (['receive', 'mass', 'cosmic', 'microwave'], 'background'),
#  (['mass', 'cosmic', 'microwave', 'background'], 'emit'),
#  (['cosmic', 'microwave', 'background', 'emit'], 'hawk'),
#  (['microwave', 'background', 'emit', 'hawk'], 'radiation'),
#  (['background', 'emit', 'hawk', 'radiation'], 'thus'),
#  (['emit', 'hawk', 'radiation', 'thus'], 'grow'),
#  (['hawk', 'radiation', 'thus', 'grow'], 'instead'),
#  (['radiation', 'thus', 'grow', 'instead'], 'shrink'),
#  (['temperature', 'large', '2.7xa0', 'k'], 'hawk'),
#  (['hawk', 'large', '2.7xa0', 'k'], 'temperature'),
#  (['hawk', 'temperature', '2.7xa0', 'k'], 'large'),
#  (['hawk', 'temperature', 'large', 'k'], '2.7xa0'),
#  (['hawk', 'temperature', 'large', '2.7xa0'], 'k'),
#  (['temperature', 'large', '2.7xa0', 'k'], 'black'),
#  (['large', '2.7xa0', 'k', 'black'], 'hole'),
#  (['2.7xa0', 'k', 'black', 'hole'], 'would'),
#  (['k', 'black', 'hole', 'would'], 'need'),
#  (['black', 'hole', 'would', 'need'], 'mass'),
#  (['hole', 'would', 'need', 'mass'], 'less'),
#  (['would', 'need', 'mass', 'less'], 'moon'),
#  (['hole', 'small', 'radiation', 'effect'], 'black'),
#  (['black', 'small', 'radiation', 'effect'], 'hole'),
#  (['black', 'hole', 'radiation', 'effect'], 'small'),
#  (['black', 'hole', 'small', 'effect'], 'radiation'),
#  (['black', 'hole', 'small', 'radiation'], 'effect'),
#  (['hole', 'small', 'radiation', 'effect'], 'expect'),
#  (['small', 'radiation', 'effect', 'expect'], 'become'),
#  (['radiation', 'effect', 'expect', 'become'], 'strong'),
#  (['mass', 'black', 'hole', 'expect'], 'low'),
#  (['low', 'black', 'hole', 'expect'], 'mass'),
#  (['low', 'mass', 'hole', 'expect'], 'black'),
#  (['low', 'mass', 'black', 'expect'], 'hole'),
#  (['low', 'mass', 'black', 'hole'], 'expect'),
#  (['mass', 'black', 'hole', 'expect'], 'evaporate'),
#  (['black', 'hole', 'expect', 'evaporate'], 'even'),
#  (['hole', 'expect', 'evaporate', 'even'], 'fast'),
#  (['black', 'hole', 'existence', 'sometimes'], 'example'),
#  (['example', 'hole', 'existence', 'sometimes'], 'black'),
#  (['example', 'black', 'existence', 'sometimes'], 'hole'),
#  (['example', 'black', 'hole', 'sometimes'], 'existence'),
#  (['example', 'black', 'hole', 'existence'], 'sometimes'),
#  (['black', 'hole', 'existence', 'sometimes'], 'infer'),
#  (['hole', 'existence', 'sometimes', 'infer'], 'observe'),
#  (['existence', 'sometimes', 'infer', 'observe'], 'gravitational'),
#  (['sometimes', 'infer', 'observe', 'gravitational'], 'influence'),
#  (['infer', 'observe', 'gravitational', 'influence'], 'surrounding'),
#  (['black', 'hole', '—', 'show'], 'visible'),
#  (['visible', 'hole', '—', 'show'], 'black'),
#  (['visible', 'black', '—', 'show'], 'hole'),
#  (['visible', 'black', 'hole', 'show'], '—'),
#  (['visible', 'black', 'hole', '—'], 'show'),
#  (['black', 'hole', '—', 'show'], 'black'),
#  (['hole', '—', 'show', 'black'], 'loss'),
#  (['—', 'show', 'black', 'loss'], 'light'),
#  (['show', 'black', 'loss', 'light'], 'within'),
#  (['black', 'loss', 'light', 'within'], 'dark'),
#  (['loss', 'light', 'within', 'dark'], 'region'),
#  (['gas', 'edge', 'event', 'horizon'], 'instead'),
#  (['instead', 'edge', 'event', 'horizon'], 'gas'),
#  (['instead', 'gas', 'event', 'horizon'], 'edge'),
#  (['instead', 'gas', 'edge', 'horizon'], 'event'),
#  (['instead', 'gas', 'edge', 'event'], 'horizon'),
#  (['gas', 'edge', 'event', 'horizon'], 'define'),
#  (['edge', 'event', 'horizon', 'define'], 'black'),
#  (['event', 'horizon', 'define', 'black'], 'hole'),
#  (['image', 'display', 'ring', 'like'], 'publish'),
#  (['publish', 'display', 'ring', 'like'], 'image'),
#  (['publish', 'image', 'ring', 'like'], 'display'),
#  (['publish', 'image', 'display', 'like'], 'ring'),
#  (['publish', 'image', 'display', 'ring'], 'like'),
#  (['image', 'display', 'ring', 'like'], 'structure'),
#  (['display', 'ring', 'like', 'structure'], 'circular'),
#  (['ring', 'like', 'structure', 'circular'], 'shadow'),
#  (['like', 'structure', 'circular', 'shadow'], 'see'),
#  (['structure', 'circular', 'shadow', 'see'], 'm87'),
#  (['circular', 'shadow', 'see', 'm87'], '*'),
#  (['shadow', 'see', 'm87', '*'], 'black'),
#  (['see', 'm87', '*', 'black'], 'hole'),
#  (['m87', '*', 'black', 'hole'], 'image'),
#  (['*', 'black', 'hole', 'image'], 'create'),
#  (['black', 'hole', 'image', 'create'], 'use'),
#  (['hole', 'image', 'create', 'use'], 'technique'),
#  (['image', 'create', 'use', 'technique'], 'm87'),
#  (['create', 'use', 'technique', 'm87'], 'black'),
#  (['use', 'technique', 'm87', 'black'], 'hole'),
#  (['study', 'black', 'hole', 'predict'], 'theoretical'),
#  (['theoretical', 'black', 'hole', 'predict'], 'study'),
#  (['theoretical', 'study', 'hole', 'predict'], 'black'),
#  (['theoretical', 'study', 'black', 'predict'], 'hole'),
#  (['theoretical', 'study', 'black', 'hole'], 'predict'),
#  (['study', 'black', 'hole', 'predict'], 'existence'),
#  (['black', 'hole', 'predict', 'existence'], 'magnetic'),
#  (['hole', 'predict', 'existence', 'magnetic'], 'field'),
#  (['must', 'therefore', 'extremely', 'compact'], 'object'),
#  (['object', 'therefore', 'extremely', 'compact'], 'must'),
#  (['object', 'must', 'extremely', 'compact'], 'therefore'),
#  (['object', 'must', 'therefore', 'compact'], 'extremely'),
#  (['object', 'must', 'therefore', 'extremely'], 'compact'),
#  (['must', 'therefore', 'extremely', 'compact'], 'leave'),
#  (['therefore', 'extremely', 'compact', 'leave'], 'black'),
#  (['extremely', 'compact', 'leave', 'black'], 'hole'),
#  (['compact', 'leave', 'black', 'hole'], 'plausible'),
#  (['leave', 'black', 'hole', 'plausible'], 'interpretation'),
#  (['exclude', 'possible', 'exotic', 'alternative'], 'however'),
#  (['however', 'possible', 'exotic', 'alternative'], 'exclude'),
#  (['however', 'exclude', 'exotic', 'alternative'], 'possible'),
#  (['however', 'exclude', 'possible', 'alternative'], 'exotic'),
#  (['however', 'exclude', 'possible', 'exotic'], 'alternative'),
#  (['exclude', 'possible', 'exotic', 'alternative'], 'black'),
#  (['possible', 'exotic', 'alternative', 'black'], 'hole'),
#  (['exotic', 'alternative', 'black', 'hole'], 'compact'),
#  (['alternative', 'black', 'hole', 'compact'], 'enough'),
#  (['black', 'hole', 'compact', 'enough'], 'photon'),
#  (['hole', 'compact', 'enough', 'photon'], 'sphere'),
#  (['also', 'provide', 'first', 'observational'], 'observation'),
#  (['observation', 'provide', 'first', 'observational'], 'also'),
#  (['observation', 'also', 'first', 'observational'], 'provide'),
#  (['observation', 'also', 'provide', 'observational'], 'first'),
#  (['observation', 'also', 'provide', 'first'], 'observational'),
#  (['also', 'provide', 'first', 'observational'], 'evidence'),
#  (['provide', 'first', 'observational', 'evidence'], 'existence'),
#  (['first', 'observational', 'evidence', 'existence'], 'stellar'),
#  (['observational', 'evidence', 'existence', 'stellar'], 'mass'),
#  (['evidence', 'existence', 'stellar', 'mass'], 'black'),
#  (['existence', 'stellar', 'mass', 'black'], 'hole'),
#  (['stellar', 'mass', 'black', 'hole'], 'binary'),
#  (['many', 'gravitational', 'wave', 'event'], 'since'),
#  (['since', 'gravitational', 'wave', 'event'], 'many'),
#  (['since', 'many', 'wave', 'event'], 'gravitational'),
#  (['since', 'many', 'gravitational', 'event'], 'wave'),
#  (['since', 'many', 'gravitational', 'wave'], 'event'),
#  (['many', 'gravitational', 'wave', 'event'], 'observe'),
#  (['limit', 'object', 'size', 'still'], 'upper'),
#  (['upper', 'object', 'size', 'still'], 'limit'),
#  (['upper', 'limit', 'size', 'still'], 'object'),
#  (['upper', 'limit', 'object', 'still'], 'size'),
#  (['upper', 'limit', 'object', 'size'], 'still'),
#  (['limit', 'object', 'size', 'still'], 'large'),
#  (['object', 'size', 'still', 'large'], 'test'),
#  (['size', 'still', 'large', 'test'], 'whether'),
#  (['still', 'large', 'test', 'whether'], 'small'),
#  (['large', 'test', 'whether', 'small'], 'schwarzschild'),
#  (['test', 'whether', 'small', 'schwarzschild'], 'radius'),
#  (['x', 'ray', 'source', 'may'], 'bright'),
#  ...]

# %%
train_data = train_data_word_around

# %%
train_data[49:55]
# Out:
# [(['first', 'black', 'hole', 'know'], 'cygnus'),
#  (['black', 'hole', 'know', 'cygnus'], 'x'),
#  (['hole', 'know', 'cygnus', 'x'], '1'),
#  (['know', 'cygnus', 'x', '1'], 'identify'),
#  (['cygnus', 'x', '1', 'identify'], 'several'),
#  (['x', '1', 'identify', 'several'], 'researcher')]

# %%
word_to_number = { key : i for i,key in enumerate(list(wordCounter.keys())) }

# %%
number_to_word = { v:k for k,v in word_to_number.items() }

# %%
def list_of_words_to_numbers(words):
    if type(words[0]) == str:
        return [word_to_number[word] for word in words]
    return list_of_words_to_numbers(words[0])

# %%
# Function to map words to numbers using the provided dictionary
#def map_words_to_numbers(data, mapping_dict):
#    return [mapping_dict[word] if isinstance(word, str) else map_words_to_numbers(word, mapping_dict) for word in data]

def map_words_to_numbers(data, mapping_dict):
    result = []
    for line in data:
        print(line)

        new_window = [mapping_dict[w] for w in line[0]]
        new_target = mapping_dict[line[1]]
            
        result.append((new_window, new_target))

    return result

# Apply the function
mapped_data = map_words_to_numbers(train_data, word_to_number)

mapped_data
# Out:
# (['hole', 'region', 'spacetime', 'gravity'], 'black')
# (['black', 'region', 'spacetime', 'gravity'], 'hole')
# (['black', 'hole', 'spacetime', 'gravity'], 'region')
# (['black', 'hole', 'region', 'gravity'], 'spacetime')
# (['black', 'hole', 'region', 'spacetime'], 'gravity')
# (['hole', 'region', 'spacetime', 'gravity'], 'strong')
# (['region', 'spacetime', 'gravity', 'strong'], 'nothing')
# (['spacetime', 'gravity', 'strong', 'nothing'], 'include')
# (['gravity', 'strong', 'nothing', 'include'], 'light')
# (['strong', 'nothing', 'include', 'light'], 'electromagnetic')
# (['nothing', 'include', 'light', 'electromagnetic'], 'wave')
# (['include', 'light', 'electromagnetic', 'wave'], 'enough')
# (['light', 'electromagnetic', 'wave', 'enough'], 'energy')
# (['electromagnetic', 'wave', 'enough', 'energy'], 'escape')
# (['escape', 'call', 'event', 'horizon'], 'boundary')
# (['boundary', 'call', 'event', 'horizon'], 'escape')
# (['boundary', 'escape', 'event', 'horizon'], 'call')
# (['boundary', 'escape', 'call', 'horizon'], 'event')
# (['boundary', 'escape', 'call', 'event'], 'horizon')
# (['finkelstein', '1958', 'first', 'publish'], 'david')
# (['david', '1958', 'first', 'publish'], 'finkelstein')
# (['david', 'finkelstein', 'first', 'publish'], '1958')
# (['david', 'finkelstein', '1958', 'publish'], 'first')
# (['david', 'finkelstein', '1958', 'first'], 'publish')
# (['finkelstein', '1958', 'first', 'publish'], 'interpretation')
# (['1958', 'first', 'publish', 'interpretation'], 'black')
# (['first', 'publish', 'interpretation', 'black'], 'hole')
# (['publish', 'interpretation', 'black', 'hole'], 'region')
# (['interpretation', 'black', 'hole', 'region'], 'space')
# (['black', 'hole', 'region', 'space'], 'nothing')
# (['hole', 'region', 'space', 'nothing'], 'escape')
# (['hole', 'long', 'consider', 'mathematical'], 'black')
# (['black', 'long', 'consider', 'mathematical'], 'hole')
# (['black', 'hole', 'consider', 'mathematical'], 'long')
# (['black', 'hole', 'long', 'mathematical'], 'consider')
# (['black', 'hole', 'long', 'consider'], 'mathematical')
# (['hole', 'long', 'consider', 'mathematical'], 'curiosity')
# (['theoretical', 'work', 'show', 'generic'], '1960')
# (['1960', 'work', 'show', 'generic'], 'theoretical')
# (['1960', 'theoretical', 'show', 'generic'], 'work')
# (['1960', 'theoretical', 'work', 'generic'], 'show')
# (['1960', 'theoretical', 'work', 'show'], 'generic')
# (['theoretical', 'work', 'show', 'generic'], 'prediction')
# (['work', 'show', 'generic', 'prediction'], 'general')
# (['show', 'generic', 'prediction', 'general'], 'relativity')
# (['black', 'hole', 'know', 'cygnus'], 'first')
# (['first', 'hole', 'know', 'cygnus'], 'black')
# (['first', 'black', 'know', 'cygnus'], 'hole')
# (['first', 'black', 'hole', 'cygnus'], 'know')
# (['first', 'black', 'hole', 'know'], 'cygnus')
# (['black', 'hole', 'know', 'cygnus'], 'x')
# (['hole', 'know', 'cygnus', 'x'], '1')
# (['know', 'cygnus', 'x', '1'], 'identify')
# (['cygnus', 'x', '1', 'identify'], 'several')
# (['x', '1', 'identify', 'several'], 'researcher')
# (['1', 'identify', 'several', 'researcher'], 'independently')
# (['identify', 'several', 'researcher', 'independently'], '1971')
# (['hole', 'form', 'grow', 'absorb'], 'black')
# (['black', 'form', 'grow', 'absorb'], 'hole')
# (['black', 'hole', 'grow', 'absorb'], 'form')
# (['black', 'hole', 'form', 'absorb'], 'grow')
# (['black', 'hole', 'form', 'grow'], 'absorb')
# (['hole', 'form', 'grow', 'absorb'], 'mass')
# (['form', 'grow', 'absorb', 'mass'], 'surrounding')
# (['black', 'hole', 'million', 'solar'], 'supermassive')
# (['supermassive', 'hole', 'million', 'solar'], 'black')
# (['supermassive', 'black', 'million', 'solar'], 'hole')
# (['supermassive', 'black', 'hole', 'solar'], 'million')
# (['supermassive', 'black', 'hole', 'million'], 'solar')
# (['black', 'hole', 'million', 'solar'], 'masse')
# (['hole', 'million', 'solar', 'masse'], 'may')
# (['million', 'solar', 'masse', 'may'], 'form')
# (['solar', 'masse', 'may', 'form'], 'absorb')
# (['masse', 'may', 'form', 'absorb'], 'star')
# (['may', 'form', 'absorb', 'star'], 'merge')
# (['form', 'absorb', 'star', 'merge'], 'black')
# (['absorb', 'star', 'merge', 'black'], 'hole')
# (['star', 'merge', 'black', 'hole'], 'via')
# (['merge', 'black', 'hole', 'via'], 'direct')
# (['black', 'hole', 'via', 'direct'], 'collapse')
# (['hole', 'via', 'direct', 'collapse'], 'gas')
# (['via', 'direct', 'collapse', 'gas'], 'cloud')
# (['black', 'hole', 'infer', 'interaction'], 'presence')
# (['presence', 'hole', 'infer', 'interaction'], 'black')
# (['presence', 'black', 'infer', 'interaction'], 'hole')
# (['presence', 'black', 'hole', 'interaction'], 'infer')
# (['presence', 'black', 'hole', 'infer'], 'interaction')
# (['black', 'hole', 'infer', 'interaction'], 'matter')
# (['hole', 'infer', 'interaction', 'matter'], 'electromagnetic')
# (['infer', 'interaction', 'matter', 'electromagnetic'], 'radiation')
# (['interaction', 'matter', 'electromagnetic', 'radiation'], 'visible')
# (['matter', 'electromagnetic', 'radiation', 'visible'], 'light')
# (['orbit', 'black', 'hole', 'orbit'], 'star')
# (['star', 'black', 'hole', 'orbit'], 'orbit')
# (['star', 'orbit', 'hole', 'orbit'], 'black')
# (['star', 'orbit', 'black', 'orbit'], 'hole')
# (['star', 'orbit', 'black', 'hole'], 'orbit')
# (['orbit', 'black', 'hole', 'orbit'], 'use')
# (['black', 'hole', 'orbit', 'use'], 'determine')
# (['hole', 'orbit', 'use', 'determine'], 'black')
# (['orbit', 'use', 'determine', 'black'], 'hole')
# (['use', 'determine', 'black', 'hole'], 'mass')
# (['determine', 'black', 'hole', 'mass'], 'location')
# (['use', 'exclude', 'possible', 'alternative'], 'observation')
# (['observation', 'exclude', 'possible', 'alternative'], 'use')
# (['observation', 'use', 'possible', 'alternative'], 'exclude')
# (['observation', 'use', 'exclude', 'alternative'], 'possible')
# (['observation', 'use', 'exclude', 'possible'], 'alternative')
# (['use', 'exclude', 'possible', 'alternative'], 'neutron')
# (['exclude', 'possible', 'alternative', 'neutron'], 'star')
# (['refer', 'body', 'dark', 'star'], 'michell')
# (['michell', 'body', 'dark', 'star'], 'refer')
# (['michell', 'refer', 'dark', 'star'], 'body')
# (['michell', 'refer', 'body', 'star'], 'dark')
# (['michell', 'refer', 'body', 'dark'], 'star')
# (['later', 'karl', 'schwarzschild', 'find'], 'month')
# (['month', 'karl', 'schwarzschild', 'find'], 'later')
# (['month', 'later', 'schwarzschild', 'find'], 'karl')
# (['month', 'later', 'karl', 'find'], 'schwarzschild')
# (['month', 'later', 'karl', 'schwarzschild'], 'find')
# (['later', 'karl', 'schwarzschild', 'find'], 'solution')
# (['karl', 'schwarzschild', 'find', 'solution'], 'einstein')
# (['schwarzschild', 'find', 'solution', 'einstein'], 'field')
# (['find', 'solution', 'einstein', 'field'], 'equation')
# (['solution', 'einstein', 'field', 'equation'], 'describe')
# (['einstein', 'field', 'equation', 'describe'], 'gravitational')
# (['field', 'equation', 'describe', 'gravitational'], 'field')
# (['equation', 'describe', 'gravitational', 'field'], 'point')
# (['describe', 'gravitational', 'field', 'point'], 'mass')
# (['gravitational', 'field', 'point', 'mass'], 'spherical')
# (['field', 'point', 'mass', 'spherical'], 'mass')
# (['peculiar', 'behaviour', 'call', 'schwarzschild'], 'solution')
# (['solution', 'behaviour', 'call', 'schwarzschild'], 'peculiar')
# (['solution', 'peculiar', 'call', 'schwarzschild'], 'behaviour')
# (['solution', 'peculiar', 'behaviour', 'schwarzschild'], 'call')
# (['solution', 'peculiar', 'behaviour', 'call'], 'schwarzschild')
# (['peculiar', 'behaviour', 'call', 'schwarzschild'], 'radius')
# (['behaviour', 'call', 'schwarzschild', 'radius'], 'become')
# (['call', 'schwarzschild', 'radius', 'become'], 'singular')
# (['schwarzschild', 'radius', 'become', 'singular'], 'mean')
# (['radius', 'become', 'singular', 'mean'], 'term')
# (['become', 'singular', 'mean', 'term'], 'einstein')
# (['singular', 'mean', 'term', 'einstein'], 'equation')
# (['mean', 'term', 'einstein', 'equation'], 'become')
# (['term', 'einstein', 'equation', 'become'], 'infinite')
# (['make', 'reference', 'einstein', 'recent'], 'paper')
# (['paper', 'reference', 'einstein', 'recent'], 'make')
# (['paper', 'make', 'einstein', 'recent'], 'reference')
# (['paper', 'make', 'reference', 'recent'], 'einstein')
# (['paper', 'make', 'reference', 'einstein'], 'recent')
# (['make', 'reference', 'einstein', 'recent'], 'publication')
# (['reference', 'einstein', 'recent', 'publication'], 'oppenheimer')
# (['einstein', 'recent', 'publication', 'oppenheimer'], 'snyder')
# (['recent', 'publication', 'oppenheimer', 'snyder'], 'use')
# (['publication', 'oppenheimer', 'snyder', 'use'], 'einstein')
# (['oppenheimer', 'snyder', 'use', 'einstein'], 'theory')
# (['snyder', 'use', 'einstein', 'theory'], 'general')
# (['use', 'einstein', 'theory', 'general'], 'relativity')
# (['einstein', 'theory', 'general', 'relativity'], 'show')
# (['theory', 'general', 'relativity', 'show'], 'condition')
# (['general', 'relativity', 'show', 'condition'], 'black')
# (['relativity', 'show', 'condition', 'black'], 'hole')
# (['show', 'condition', 'black', 'hole'], 'could')
# (['condition', 'black', 'hole', 'could'], 'develop')
# (['black', 'hole', 'could', 'develop'], 'first')
# (['hole', 'could', 'develop', 'first'], 'time')
# (['could', 'develop', 'first', 'time'], 'contemporary')
# (['develop', 'first', 'time', 'contemporary'], 'physics')
# (['solution', 'extend', 'schwarzschild', 'solution'], 'finkelstein')
# (['finkelstein', 'extend', 'schwarzschild', 'solution'], 'solution')
# (['finkelstein', 'solution', 'schwarzschild', 'solution'], 'extend')
# (['finkelstein', 'solution', 'extend', 'solution'], 'schwarzschild')
# (['finkelstein', 'solution', 'extend', 'schwarzschild'], 'solution')
# (['solution', 'extend', 'schwarzschild', 'solution'], 'future')
# (['extend', 'schwarzschild', 'solution', 'future'], 'observer')
# (['schwarzschild', 'solution', 'future', 'observer'], 'fall')
# (['solution', 'future', 'observer', 'fall'], 'black')
# (['future', 'observer', 'fall', 'black'], 'hole')
# (['general', 'black', 'hole', 'solution'], 'period')
# (['period', 'black', 'hole', 'solution'], 'general')
# (['period', 'general', 'hole', 'solution'], 'black')
# (['period', 'general', 'black', 'solution'], 'hole')
# (['period', 'general', 'black', 'hole'], 'solution')
# (['general', 'black', 'hole', 'solution'], 'find')
# (['complete', 'hawking', '1974', 'show'], 'analogy')
# (['analogy', 'hawking', '1974', 'show'], 'complete')
# (['analogy', 'complete', '1974', 'show'], 'hawking')
# (['analogy', 'complete', 'hawking', 'show'], '1974')
# (['analogy', 'complete', 'hawking', '1974'], 'show')
# (['complete', 'hawking', '1974', 'show'], 'quantum')
# (['hawking', '1974', 'show', 'quantum'], 'field')
# (['1974', 'show', 'quantum', 'field'], 'theory')
# (['show', 'quantum', 'field', 'theory'], 'imply')
# (['quantum', 'field', 'theory', 'imply'], 'black')
# (['field', 'theory', 'imply', 'black'], 'hole')
# (['theory', 'imply', 'black', 'hole'], 'radiate')
# (['imply', 'black', 'hole', 'radiate'], 'like')
# (['black', 'hole', 'radiate', 'like'], 'black')
# (['hole', 'radiate', 'like', 'black'], 'body')
# (['radiate', 'like', 'black', 'body'], 'temperature')
# (['like', 'black', 'body', 'temperature'], 'proportional')
# (['black', 'body', 'temperature', 'proportional'], 'surface')
# (['body', 'temperature', 'proportional', 'surface'], 'gravity')
# (['temperature', 'proportional', 'surface', 'gravity'], 'black')
# (['proportional', 'surface', 'gravity', 'black'], 'hole')
# (['surface', 'gravity', 'black', 'hole'], 'predict')
# (['gravity', 'black', 'hole', 'predict'], 'effect')
# (['black', 'hole', 'predict', 'effect'], 'know')
# (['hole', 'predict', 'effect', 'know'], 'hawk')
# (['predict', 'effect', 'know', 'hawk'], 'radiation')
# (['april', '2019', 'first', 'direct'], '10')
# (['10', '2019', 'first', 'direct'], 'april')
# (['10', 'april', 'first', 'direct'], '2019')
# (['10', 'april', '2019', 'direct'], 'first')
# (['10', 'april', '2019', 'first'], 'direct')
# (['april', '2019', 'first', 'direct'], 'image')
# (['2019', 'first', 'direct', 'image'], 'black')
# (['first', 'direct', 'image', 'black'], 'hole')
# (['direct', 'image', 'black', 'hole'], 'vicinity')
# (['image', 'black', 'hole', 'vicinity'], 'publish')
# (['black', 'hole', 'vicinity', 'publish'], 'follow')
# (['hole', 'vicinity', 'publish', 'follow'], 'observation')
# (['vicinity', 'publish', 'follow', 'observation'], 'make')
# (['publish', 'follow', 'observation', 'make'], 'event')
# (['follow', 'observation', 'make', 'event'], 'horizon')
# (['observation', 'make', 'event', 'horizon'], 'telescope')
# (['make', 'event', 'horizon', 'telescope'], '2017')
# (['event', 'horizon', 'telescope', '2017'], 'supermassive')
# (['horizon', 'telescope', '2017', 'supermassive'], 'black')
# (['telescope', '2017', 'supermassive', 'black'], 'hole')
# (['2017', 'supermassive', 'black', 'hole'], 'messier')
# (['supermassive', 'black', 'hole', 'messier'], '87')
# (['black', 'hole', 'messier', '87'], 'galactic')
# (['hole', 'messier', '87', 'galactic'], 'centre')
# (['would', 'detectable', 'gravitational', 'lensing'], 'therefore')
# (['therefore', 'detectable', 'gravitational', 'lensing'], 'would')
# (['therefore', 'would', 'gravitational', 'lensing'], 'detectable')
# (['therefore', 'would', 'detectable', 'lensing'], 'gravitational')
# (['therefore', 'would', 'detectable', 'gravitational'], 'lensing')
# (['special', 'visible', 'outside', 'black'], 'property')
# (['property', 'visible', 'outside', 'black'], 'special')
# (['property', 'special', 'outside', 'black'], 'visible')
# (['property', 'special', 'visible', 'black'], 'outside')
# (['property', 'special', 'visible', 'outside'], 'black')
# (['special', 'visible', 'outside', 'black'], 'hole')
# (['hole', 'eventually', 'achieve', 'stable'], 'black')
# (['black', 'eventually', 'achieve', 'stable'], 'hole')
# (['black', 'hole', 'achieve', 'stable'], 'eventually')
# (['black', 'hole', 'eventually', 'stable'], 'achieve')
# (['black', 'hole', 'eventually', 'achieve'], 'stable')
# (['hole', 'eventually', 'achieve', 'stable'], 'state')
# (['eventually', 'achieve', 'stable', 'state'], 'three')
# (['achieve', 'stable', 'state', 'three'], 'parameter')
# (['stable', 'state', 'three', 'parameter'], 'way')
# (['state', 'three', 'parameter', 'way'], 'avoid')
# (['three', 'parameter', 'way', 'avoid'], 'lose')
# (['parameter', 'way', 'avoid', 'lose'], 'information')
# (['way', 'avoid', 'lose', 'information'], 'initial')
# (['avoid', 'lose', 'information', 'initial'], 'condition')
# (['lose', 'information', 'initial', 'condition'], 'gravitational')
# (['information', 'initial', 'condition', 'gravitational'], 'electric')
# (['initial', 'condition', 'gravitational', 'electric'], 'field')
# (['condition', 'gravitational', 'electric', 'field'], 'black')
# (['gravitational', 'electric', 'field', 'black'], 'hole')
# (['electric', 'field', 'black', 'hole'], 'give')
# (['field', 'black', 'hole', 'give'], 'little')
# (['black', 'hole', 'give', 'little'], 'information')
# (['hole', 'give', 'little', 'information'], 'go')
# (['puzzle', 'call', 'black', 'hole'], 'behavior')
# (['behavior', 'call', 'black', 'hole'], 'puzzle')
# (['behavior', 'puzzle', 'black', 'hole'], 'call')
# (['behavior', 'puzzle', 'call', 'hole'], 'black')
# (['behavior', 'puzzle', 'call', 'black'], 'hole')
# (['puzzle', 'call', 'black', 'hole'], 'information')
# (['call', 'black', 'hole', 'information'], 'loss')
# (['black', 'hole', 'information', 'loss'], 'paradox')
# (['hole', 'often', 'refer', 'schwarzschild'], 'black')
# (['black', 'often', 'refer', 'schwarzschild'], 'hole')
# (['black', 'hole', 'refer', 'schwarzschild'], 'often')
# (['black', 'hole', 'often', 'schwarzschild'], 'refer')
# (['black', 'hole', 'often', 'refer'], 'schwarzschild')
# (['hole', 'often', 'refer', 'schwarzschild'], 'black')
# (['often', 'refer', 'schwarzschild', 'black'], 'hole')
# (['refer', 'schwarzschild', 'black', 'hole'], 'karl')
# (['schwarzschild', 'black', 'hole', 'karl'], 'schwarzschild')
# (['black', 'hole', 'karl', 'schwarzschild'], 'discover')
# (['hole', 'karl', 'schwarzschild', 'discover'], 'solution')
# (['karl', 'schwarzschild', 'discover', 'solution'], '1916')
# (['describe', 'general', 'black', 'hole'], 'solution')
# (['solution', 'general', 'black', 'hole'], 'describe')
# (['solution', 'describe', 'black', 'hole'], 'general')
# (['solution', 'describe', 'general', 'hole'], 'black')
# (['solution', 'describe', 'general', 'black'], 'hole')
# (['describe', 'general', 'black', 'hole'], 'also')
# (['general', 'black', 'hole', 'also'], 'exist')
# (['stationary', 'black', 'hole', 'solution'], 'general')
# (['general', 'black', 'hole', 'solution'], 'stationary')
# (['general', 'stationary', 'hole', 'solution'], 'black')
# (['general', 'stationary', 'black', 'solution'], 'hole')
# (['general', 'stationary', 'black', 'hole'], 'solution')
# (['stationary', 'black', 'hole', 'solution'], 'know')
# (['black', 'hole', 'solution', 'know'], 'kerr')
# (['hole', 'solution', 'know', 'kerr'], '–')
# (['solution', 'know', 'kerr', '–'], 'newman')
# (['know', 'kerr', '–', 'newman'], 'metric')
# (['kerr', '–', 'newman', 'metric'], 'describe')
# (['–', 'newman', 'metric', 'describe'], 'black')
# (['newman', 'metric', 'describe', 'black'], 'hole')
# (['metric', 'describe', 'black', 'hole'], 'charge')
# (['describe', 'black', 'hole', 'charge'], 'angular')
# (['black', 'hole', 'charge', 'angular'], 'momentum')
# (['hole', 'minimum', 'possible', 'mass'], 'black')
# (['black', 'minimum', 'possible', 'mass'], 'hole')
# (['black', 'hole', 'possible', 'mass'], 'minimum')
# (['black', 'hole', 'minimum', 'mass'], 'possible')
# (['black', 'hole', 'minimum', 'possible'], 'mass')
# (['hole', 'minimum', 'possible', 'mass'], 'satisfy')
# (['minimum', 'possible', 'mass', 'satisfy'], 'inequality')
# (['possible', 'mass', 'satisfy', 'inequality'], 'call')
# (['mass', 'satisfy', 'inequality', 'call'], 'extremal')
# (['einstein', 'equation', 'violate', 'inequality'], 'solution')
# (['solution', 'equation', 'violate', 'inequality'], 'einstein')
# (['solution', 'einstein', 'violate', 'inequality'], 'equation')
# (['solution', 'einstein', 'equation', 'inequality'], 'violate')
# (['solution', 'einstein', 'equation', 'violate'], 'inequality')
# (['einstein', 'equation', 'violate', 'inequality'], 'exist')
# (['equation', 'violate', 'inequality', 'exist'], 'possess')
# (['violate', 'inequality', 'exist', 'possess'], 'event')
# (['inequality', 'exist', 'possess', 'event'], 'horizon')
# (['approx'], 'mass')
# (['mass'], 'approx')
# (['black', 'hole', 'spacetime', 'start'], 'close')
# (['close', 'hole', 'spacetime', 'start'], 'black')
# (['close', 'black', 'spacetime', 'start'], 'hole')
# (['close', 'black', 'hole', 'start'], 'spacetime')
# (['close', 'black', 'hole', 'spacetime'], 'start')
# (['black', 'hole', 'spacetime', 'start'], 'deform')
# (['go', 'towards', 'black', 'hole'], 'path')
# (['path', 'towards', 'black', 'hole'], 'go')
# (['path', 'go', 'black', 'hole'], 'towards')
# (['path', 'go', 'towards', 'hole'], 'black')
# (['path', 'go', 'towards', 'black'], 'hole')
# (['go', 'towards', 'black', 'hole'], 'path')
# (['towards', 'black', 'hole', 'path'], 'move')
# (['black', 'hole', 'path', 'move'], 'away')
# (['possible', 'particle', 'escape'], 'long')
# (['long', 'particle', 'escape'], 'possible')
# (['long', 'possible', 'escape'], 'particle')
# (['long', 'possible', 'particle'], 'escape')
# (['feature', 'black', 'hole', 'appearance'], 'define')
# (['define', 'black', 'hole', 'appearance'], 'feature')
# (['define', 'feature', 'hole', 'appearance'], 'black')
# (['define', 'feature', 'black', 'appearance'], 'hole')
# (['define', 'feature', 'black', 'hole'], 'appearance')
# (['feature', 'black', 'hole', 'appearance'], 'event')
# (['black', 'hole', 'appearance', 'event'], 'horizon')
# (['hole', 'appearance', 'event', 'horizon'], '—')
# (['appearance', 'event', 'horizon', '—'], 'boundary')
# (['event', 'horizon', '—', 'boundary'], 'spacetime')
# (['horizon', '—', 'boundary', 'spacetime'], 'matter')
# (['—', 'boundary', 'spacetime', 'matter'], 'light')
# (['boundary', 'spacetime', 'matter', 'light'], 'pass')
# (['spacetime', 'matter', 'light', 'pass'], 'inward')
# (['matter', 'light', 'pass', 'inward'], 'towards')
# (['light', 'pass', 'inward', 'towards'], 'mass')
# (['pass', 'inward', 'towards', 'mass'], 'black')
# (['inward', 'towards', 'mass', 'black'], 'hole')
# (['even', 'light', 'escape', 'inside'], 'nothing')
# (['nothing', 'light', 'escape', 'inside'], 'even')
# (['nothing', 'even', 'escape', 'inside'], 'light')
# (['nothing', 'even', 'light', 'inside'], 'escape')
# (['nothing', 'even', 'light', 'escape'], 'inside')
# (['even', 'light', 'escape', 'inside'], 'event')
# (['light', 'escape', 'inside', 'event'], 'horizon')
# (['horizon', 'refer', 'event', 'occur'], 'event')
# (['event', 'refer', 'event', 'occur'], 'horizon')
# (['event', 'horizon', 'event', 'occur'], 'refer')
# (['event', 'horizon', 'refer', 'occur'], 'event')
# (['event', 'horizon', 'refer', 'event'], 'occur')
# (['horizon', 'refer', 'event', 'occur'], 'within')
# (['refer', 'event', 'occur', 'within'], 'boundary')
# (['event', 'occur', 'within', 'boundary'], 'information')
# (['occur', 'within', 'boundary', 'information'], 'event')
# (['within', 'boundary', 'information', 'event'], 'reach')
# (['boundary', 'information', 'event', 'reach'], 'outside')
# (['information', 'event', 'reach', 'outside'], 'observer')
# (['event', 'reach', 'outside', 'observer'], 'make')
# (['reach', 'outside', 'observer', 'make'], 'impossible')
# (['outside', 'observer', 'make', 'impossible'], 'determine')
# (['observer', 'make', 'impossible', 'determine'], 'whether')
# (['make', 'impossible', 'determine', 'whether'], 'event')
# (['impossible', 'determine', 'whether', 'event'], 'occur')
# (['general', 'relativity', 'presence', 'mass'], 'predict')
# (['predict', 'relativity', 'presence', 'mass'], 'general')
# (['predict', 'general', 'presence', 'mass'], 'relativity')
# (['predict', 'general', 'relativity', 'mass'], 'presence')
# (['predict', 'general', 'relativity', 'presence'], 'mass')
# (['general', 'relativity', 'presence', 'mass'], 'deform')
# (['relativity', 'presence', 'mass', 'deform'], 'spacetime')
# (['presence', 'mass', 'deform', 'spacetime'], 'way')
# (['mass', 'deform', 'spacetime', 'way'], 'path')
# (['deform', 'spacetime', 'way', 'path'], 'take')
# (['spacetime', 'way', 'path', 'take'], 'particle')
# (['way', 'path', 'take', 'particle'], 'bend')
# (['path', 'take', 'particle', 'bend'], 'towards')
# (['take', 'particle', 'bend', 'towards'], 'mass')
# (['horizon', 'black', 'hole', 'deformation'], 'event')
# (['event', 'black', 'hole', 'deformation'], 'horizon')
# (['event', 'horizon', 'hole', 'deformation'], 'black')
# (['event', 'horizon', 'black', 'deformation'], 'hole')
# (['event', 'horizon', 'black', 'hole'], 'deformation')
# (['horizon', 'black', 'hole', 'deformation'], 'become')
# (['black', 'hole', 'deformation', 'become'], 'strong')
# (['hole', 'deformation', 'become', 'strong'], 'path')
# (['deformation', 'become', 'strong', 'path'], 'lead')
# (['become', 'strong', 'path', 'lead'], 'away')
# (['strong', 'path', 'lead', 'away'], 'black')
# (['path', 'lead', 'away', 'black'], 'hole')
# (['observer', 'clock', 'near', 'black'], 'distant')
# (['distant', 'clock', 'near', 'black'], 'observer')
# (['distant', 'observer', 'near', 'black'], 'clock')
# (['distant', 'observer', 'clock', 'black'], 'near')
# (['distant', 'observer', 'clock', 'near'], 'black')
# (['observer', 'clock', 'near', 'black'], 'hole')
# (['clock', 'near', 'black', 'hole'], 'would')
# (['near', 'black', 'hole', 'would'], 'appear')
# (['black', 'hole', 'would', 'appear'], 'tick')
# (['hole', 'would', 'appear', 'tick'], 'slowly')
# (['would', 'appear', 'tick', 'slowly'], 'far')
# (['appear', 'tick', 'slowly', 'far'], 'away')
# (['tick', 'slowly', 'far', 'away'], 'black')
# (['slowly', 'far', 'away', 'black'], 'hole')
# (['effect', 'know', 'gravitational', 'time'], 'due')
# (['due', 'know', 'gravitational', 'time'], 'effect')
# (['due', 'effect', 'gravitational', 'time'], 'know')
# (['due', 'effect', 'know', 'time'], 'gravitational')
# (['due', 'effect', 'know', 'gravitational'], 'time')
# (['effect', 'know', 'gravitational', 'time'], 'dilation')
# (['know', 'gravitational', 'time', 'dilation'], 'object')
# (['gravitational', 'time', 'dilation', 'object'], 'fall')
# (['time', 'dilation', 'object', 'fall'], 'black')
# (['dilation', 'object', 'fall', 'black'], 'hole')
# (['object', 'fall', 'black', 'hole'], 'appear')
# (['fall', 'black', 'hole', 'appear'], 'slow')
# (['black', 'hole', 'appear', 'slow'], 'approach')
# (['hole', 'appear', 'slow', 'approach'], 'event')
# (['appear', 'slow', 'approach', 'event'], 'horizon')
# (['slow', 'approach', 'event', 'horizon'], 'take')
# (['approach', 'event', 'horizon', 'take'], 'infinite')
# (['event', 'horizon', 'take', 'infinite'], 'time')
# (['horizon', 'take', 'infinite', 'time'], 'reach')
# (['fall', 'object', 'fade', 'away'], 'eventually')
# (['eventually', 'object', 'fade', 'away'], 'fall')
# (['eventually', 'fall', 'fade', 'away'], 'object')
# (['eventually', 'fall', 'object', 'away'], 'fade')
# (['eventually', 'fall', 'object', 'fade'], 'away')
# (['fall', 'object', 'fade', 'away'], 'long')
# (['object', 'fade', 'away', 'long'], 'see')
# (['process', 'happen', 'rapidly', 'object'], 'typically')
# (['typically', 'happen', 'rapidly', 'object'], 'process')
# (['typically', 'process', 'rapidly', 'object'], 'happen')
# (['typically', 'process', 'happen', 'object'], 'rapidly')
# (['typically', 'process', 'happen', 'rapidly'], 'object')
# (['process', 'happen', 'rapidly', 'object'], 'disappear')
# (['happen', 'rapidly', 'object', 'disappear'], 'view')
# (['rapidly', 'object', 'disappear', 'view'], 'within')
# (['object', 'disappear', 'view', 'within'], 'less')
# (['disappear', 'view', 'within', 'less'], 'second')
# (['clock', 'appear', 'tick', 'normally'], 'accord')
# (['accord', 'appear', 'tick', 'normally'], 'clock')
# (['accord', 'clock', 'tick', 'normally'], 'appear')
# (['accord', 'clock', 'appear', 'normally'], 'tick')
# (['accord', 'clock', 'appear', 'tick'], 'normally')
# (['clock', 'appear', 'tick', 'normally'], 'cross')
# (['appear', 'tick', 'normally', 'cross'], 'event')
# (['tick', 'normally', 'cross', 'event'], 'horizon')
# (['normally', 'cross', 'event', 'horizon'], 'finite')
# (['cross', 'event', 'horizon', 'finite'], 'time')
# (['event', 'horizon', 'finite', 'time'], 'without')
# (['horizon', 'finite', 'time', 'without'], 'note')
# (['finite', 'time', 'without', 'note'], 'singular')
# (['time', 'without', 'note', 'singular'], 'behaviour')
# (['general', 'relativity', 'impossible', 'determine'], 'classical')
# (['classical', 'relativity', 'impossible', 'determine'], 'general')
# (['classical', 'general', 'impossible', 'determine'], 'relativity')
# (['classical', 'general', 'relativity', 'determine'], 'impossible')
# (['classical', 'general', 'relativity', 'impossible'], 'determine')
# (['general', 'relativity', 'impossible', 'determine'], 'location')
# (['relativity', 'impossible', 'determine', 'location'], 'event')
# (['impossible', 'determine', 'location', 'event'], 'horizon')
# (['determine', 'location', 'event', 'horizon'], 'local')
# (['location', 'event', 'horizon', 'local'], 'observation')
# (['event', 'horizon', 'local', 'observation'], 'due')
# (['horizon', 'local', 'observation', 'due'], 'einstein')
# (['local', 'observation', 'due', 'einstein'], 'equivalence')
# (['observation', 'due', 'einstein', 'equivalence'], 'principle')
# (['main', 'article', 'gravitational', 'singularity'], 'singularity')
# (['singularity', 'article', 'gravitational', 'singularity'], 'main')
# (['singularity', 'main', 'gravitational', 'singularity'], 'article')
# (['singularity', 'main', 'article', 'singularity'], 'gravitational')
# (['singularity', 'main', 'article', 'gravitational'], 'singularity')
# (['main', 'article', 'gravitational', 'singularity'], 'centre')
# (['article', 'gravitational', 'singularity', 'centre'], 'black')
# (['gravitational', 'singularity', 'centre', 'black'], 'hole')
# (['singularity', 'centre', 'black', 'hole'], 'describe')
# (['centre', 'black', 'hole', 'describe'], 'general')
# (['black', 'hole', 'describe', 'general'], 'relativity')
# (['hole', 'describe', 'general', 'relativity'], 'may')
# (['describe', 'general', 'relativity', 'may'], 'lie')
# (['general', 'relativity', 'may', 'lie'], 'gravitational')
# (['relativity', 'may', 'lie', 'gravitational'], 'singularity')
# (['may', 'lie', 'gravitational', 'singularity'], 'region')
# (['lie', 'gravitational', 'singularity', 'region'], 'spacetime')
# (['gravitational', 'singularity', 'region', 'spacetime'], 'curvature')
# (['singularity', 'region', 'spacetime', 'curvature'], 'become')
# (['region', 'spacetime', 'curvature', 'become'], 'infinite')
# (['rotating', 'black', 'hole', 'region'], 'non')
# (['non', 'black', 'hole', 'region'], 'rotating')
# (['non', 'rotating', 'hole', 'region'], 'black')
# (['non', 'rotating', 'black', 'region'], 'hole')
# (['non', 'rotating', 'black', 'hole'], 'region')
# (['rotating', 'black', 'hole', 'region'], 'take')
# (['black', 'hole', 'region', 'take'], 'shape')
# (['hole', 'region', 'take', 'shape'], 'single')
# (['region', 'take', 'shape', 'single'], 'point')
# (['singular', 'region', 'zero', 'volume'], 'case')
# (['case', 'region', 'zero', 'volume'], 'singular')
# (['case', 'singular', 'zero', 'volume'], 'region')
# (['case', 'singular', 'region', 'volume'], 'zero')
# (['case', 'singular', 'region', 'zero'], 'volume')
# (['show', 'singular', 'region', 'contain'], 'also')
# (['also', 'singular', 'region', 'contain'], 'show')
# (['also', 'show', 'region', 'contain'], 'singular')
# (['also', 'show', 'singular', 'contain'], 'region')
# (['also', 'show', 'singular', 'region'], 'contain')
# (['show', 'singular', 'region', 'contain'], 'mass')
# (['singular', 'region', 'contain', 'mass'], 'black')
# (['region', 'contain', 'mass', 'black'], 'hole')
# (['contain', 'mass', 'black', 'hole'], 'solution')
# (['region', 'thus', 'think', 'infinite'], 'singular')
# (['singular', 'thus', 'think', 'infinite'], 'region')
# (['singular', 'region', 'think', 'infinite'], 'thus')
# (['singular', 'region', 'thus', 'infinite'], 'think')
# (['singular', 'region', 'thus', 'think'], 'infinite')
# (['region', 'thus', 'think', 'infinite'], 'density')
# (['fall', 'schwarzschild', 'black', 'hole'], 'observer')
# (['observer', 'schwarzschild', 'black', 'hole'], 'fall')
# (['observer', 'fall', 'black', 'hole'], 'schwarzschild')
# (['observer', 'fall', 'schwarzschild', 'hole'], 'black')
# (['observer', 'fall', 'schwarzschild', 'black'], 'hole')
# (['fall', 'schwarzschild', 'black', 'hole'], 'avoid')
# (['schwarzschild', 'black', 'hole', 'avoid'], 'carry')
# (['black', 'hole', 'avoid', 'carry'], 'singularity')
# (['hole', 'avoid', 'carry', 'singularity'], 'cross')
# (['avoid', 'carry', 'singularity', 'cross'], 'event')
# (['carry', 'singularity', 'cross', 'event'], 'horizon')
# (['charge', 'rotate', 'black', 'hole'], 'case')
# (['case', 'rotate', 'black', 'hole'], 'charge')
# (['case', 'charge', 'black', 'hole'], 'rotate')
# (['case', 'charge', 'rotate', 'hole'], 'black')
# (['case', 'charge', 'rotate', 'black'], 'hole')
# (['charge', 'rotate', 'black', 'hole'], 'possible')
# (['rotate', 'black', 'hole', 'possible'], 'avoid')
# (['black', 'hole', 'possible', 'avoid'], 'singularity')
# (['travel', 'another', 'universe', 'however'], 'possibility')
# (['possibility', 'another', 'universe', 'however'], 'travel')
# (['possibility', 'travel', 'universe', 'however'], 'another')
# (['possibility', 'travel', 'another', 'however'], 'universe')
# (['possibility', 'travel', 'another', 'universe'], 'however')
# (['travel', 'another', 'universe', 'however'], 'theoretical')
# (['another', 'universe', 'however', 'theoretical'], 'since')
# (['universe', 'however', 'theoretical', 'since'], 'perturbation')
# (['however', 'theoretical', 'since', 'perturbation'], 'would')
# (['theoretical', 'since', 'perturbation', 'would'], 'destroy')
# (['since', 'perturbation', 'would', 'destroy'], 'possibility')
# (['singularity', 'general', 'relativity', 'commonly'], 'appearance')
# (['appearance', 'general', 'relativity', 'commonly'], 'singularity')
# (['appearance', 'singularity', 'relativity', 'commonly'], 'general')
# (['appearance', 'singularity', 'general', 'commonly'], 'relativity')
# (['appearance', 'singularity', 'general', 'relativity'], 'commonly')
# (['singularity', 'general', 'relativity', 'commonly'], 'perceive')
# (['general', 'relativity', 'commonly', 'perceive'], 'signal')
# (['relativity', 'commonly', 'perceive', 'signal'], 'breakdown')
# (['commonly', 'perceive', 'signal', 'breakdown'], 'theory')
# (['however', 'expect'], 'breakdown')
# (['breakdown', 'expect'], 'however')
# (['breakdown', 'however'], 'expect')
# (['expect', 'theory', 'feature', 'singularity'], 'generally')
# (['generally', 'theory', 'feature', 'singularity'], 'expect')
# (['generally', 'expect', 'feature', 'singularity'], 'theory')
# (['generally', 'expect', 'theory', 'singularity'], 'feature')
# (['generally', 'expect', 'theory', 'feature'], 'singularity')
# (['rotating', 'black', 'hole', 'photon'], 'non')
# (['non', 'black', 'hole', 'photon'], 'rotating')
# (['non', 'rotating', 'hole', 'photon'], 'black')
# (['non', 'rotating', 'black', 'photon'], 'hole')
# (['non', 'rotating', 'black', 'hole'], 'photon')
# (['rotating', 'black', 'hole', 'photon'], 'sphere')
# (['black', 'hole', 'photon', 'sphere'], 'radius')
# (['hole', 'photon', 'sphere', 'radius'], '1.5')
# (['photon', 'sphere', 'radius', '1.5'], 'time')
# (['sphere', 'radius', '1.5', 'time'], 'schwarzschild')
# (['radius', '1.5', 'time', 'schwarzschild'], 'radius')
# (['light', 'reach', 'outside', 'observer'], 'hence')
# (['hence', 'reach', 'outside', 'observer'], 'light')
# (['hence', 'light', 'outside', 'observer'], 'reach')
# (['hence', 'light', 'reach', 'observer'], 'outside')
# (['hence', 'light', 'reach', 'outside'], 'observer')
# (['light', 'reach', 'outside', 'observer'], 'photon')
# (['reach', 'outside', 'observer', 'photon'], 'sphere')
# (['outside', 'observer', 'photon', 'sphere'], 'must')
# (['observer', 'photon', 'sphere', 'must'], 'emit')
# (['photon', 'sphere', 'must', 'emit'], 'object')
# (['sphere', 'must', 'emit', 'object'], 'photon')
# (['must', 'emit', 'object', 'photon'], 'sphere')
# (['emit', 'object', 'photon', 'sphere'], 'event')
# (['object', 'photon', 'sphere', 'event'], 'horizon')
# (['black', 'hole', 'surround', 'region'], 'rotate')
# (['rotate', 'hole', 'surround', 'region'], 'black')
# (['rotate', 'black', 'surround', 'region'], 'hole')
# (['rotate', 'black', 'hole', 'region'], 'surround')
# (['rotate', 'black', 'hole', 'surround'], 'region')
# (['black', 'hole', 'surround', 'region'], 'spacetime')
# (['hole', 'surround', 'region', 'spacetime'], 'impossible')
# (['surround', 'region', 'spacetime', 'impossible'], 'stand')
# (['region', 'spacetime', 'impossible', 'stand'], 'still')
# (['spacetime', 'impossible', 'stand', 'still'], 'call')
# (['impossible', 'stand', 'still', 'call'], 'ergosphere')
# (['near', 'rotate', 'mass', 'tend'], 'object')
# (['object', 'rotate', 'mass', 'tend'], 'near')
# (['object', 'near', 'mass', 'tend'], 'rotate')
# (['object', 'near', 'rotate', 'tend'], 'mass')
# (['object', 'near', 'rotate', 'mass'], 'tend')
# (['near', 'rotate', 'mass', 'tend'], 'start')
# (['rotate', 'mass', 'tend', 'start'], 'move')
# (['mass', 'tend', 'start', 'move'], 'direction')
# (['tend', 'start', 'move', 'direction'], 'rotation')
# (['radiation', 'escape', 'normally', 'ergosphere'], 'object')
# (['object', 'escape', 'normally', 'ergosphere'], 'radiation')
# (['object', 'radiation', 'normally', 'ergosphere'], 'escape')
# (['object', 'radiation', 'escape', 'ergosphere'], 'normally')
# (['object', 'radiation', 'escape', 'normally'], 'ergosphere')
# (['process', 'object', 'emerge', 'ergosphere'], 'penrose')
# (['penrose', 'object', 'emerge', 'ergosphere'], 'process')
# (['penrose', 'process', 'emerge', 'ergosphere'], 'object')
# (['penrose', 'process', 'object', 'ergosphere'], 'emerge')
# (['penrose', 'process', 'object', 'emerge'], 'ergosphere')
# (['process', 'object', 'emerge', 'ergosphere'], 'energy')
# (['object', 'emerge', 'ergosphere', 'energy'], 'enter')
# (['rotation', 'black', 'hole', 'slow'], 'thereby')
# (['thereby', 'black', 'hole', 'slow'], 'rotation')
# (['thereby', 'rotation', 'hole', 'slow'], 'black')
# (['thereby', 'rotation', 'black', 'slow'], 'hole')
# (['thereby', 'rotation', 'black', 'hole'], 'slow')
# (['demonstrate', 'event', 'horizon', 'form'], 'penrose')
# (['penrose', 'event', 'horizon', 'form'], 'demonstrate')
# (['penrose', 'demonstrate', 'horizon', 'form'], 'event')
# (['penrose', 'demonstrate', 'event', 'form'], 'horizon')
# (['penrose', 'demonstrate', 'event', 'horizon'], 'form')
# (['demonstrate', 'event', 'horizon', 'form'], 'general')
# (['event', 'horizon', 'form', 'general'], 'relativity')
# (['horizon', 'form', 'general', 'relativity'], 'without')
# (['form', 'general', 'relativity', 'without'], 'quantum')
# (['general', 'relativity', 'without', 'quantum'], 'mechanic')
# (['relativity', 'without', 'quantum', 'mechanic'], 'require')
# (['without', 'quantum', 'mechanic', 'require'], 'singularity')
# (['quantum', 'mechanic', 'require', 'singularity'], 'form')
# (['mechanic', 'require', 'singularity', 'form'], 'within')
# (['one', 'various', 'type', 'compact'], 'result')
# (['result', 'various', 'type', 'compact'], 'one')
# (['result', 'one', 'type', 'compact'], 'various')
# (['result', 'one', 'various', 'compact'], 'type')
# (['result', 'one', 'various', 'type'], 'compact')
# (['one', 'various', 'type', 'compact'], 'star')
# (['hole', 'could', 'seed', 'supermassive'], 'black')
# (['black', 'could', 'seed', 'supermassive'], 'hole')
# (['black', 'hole', 'seed', 'supermassive'], 'could')
# (['black', 'hole', 'could', 'supermassive'], 'seed')
# (['black', 'hole', 'could', 'seed'], 'supermassive')
# (['hole', 'could', 'seed', 'supermassive'], 'black')
# (['could', 'seed', 'supermassive', 'black'], 'hole')
# (['seed', 'supermassive', 'black', 'hole'], 'find')
# (['supermassive', 'black', 'hole', 'find'], 'centre')
# (['black', 'hole', 'find', 'centre'], 'galaxy')
# (['object', 'find', 'observation', 'young'], 'candidate')
# (['candidate', 'find', 'observation', 'young'], 'object')
# (['candidate', 'object', 'observation', 'young'], 'find')
# (['candidate', 'object', 'find', 'young'], 'observation')
# (['candidate', 'object', 'find', 'observation'], 'young')
# (['object', 'find', 'observation', 'young'], 'universe')
# (['release', 'gravitational', 'collapse', 'emit'], 'energy')
# (['energy', 'gravitational', 'collapse', 'emit'], 'release')
# (['energy', 'release', 'collapse', 'emit'], 'gravitational')
# (['energy', 'release', 'gravitational', 'emit'], 'collapse')
# (['energy', 'release', 'gravitational', 'collapse'], 'emit')
# (['release', 'gravitational', 'collapse', 'emit'], 'quickly')
# (['gravitational', 'collapse', 'emit', 'quickly'], 'outside')
# (['collapse', 'emit', 'quickly', 'outside'], 'observer')
# (['emit', 'quickly', 'outside', 'observer'], 'actually')
# (['quickly', 'outside', 'observer', 'actually'], 'see')
# (['outside', 'observer', 'actually', 'see'], 'end')
# (['observer', 'actually', 'see', 'end'], 'process')
# (['external', 'observer', 'never', 'see'], 'thus')
# (['thus', 'observer', 'never', 'see'], 'external')
# (['thus', 'external', 'never', 'see'], 'observer')
# (['thus', 'external', 'observer', 'see'], 'never')
# (['thus', 'external', 'observer', 'never'], 'see')
# (['external', 'observer', 'never', 'see'], 'formation')
# (['observer', 'never', 'see', 'formation'], 'event')
# (['never', 'see', 'formation', 'event'], 'horizon')
# (['black', 'hole', 'big', 'bang'], 'primordial')
# (['primordial', 'hole', 'big', 'bang'], 'black')
# (['primordial', 'black', 'big', 'bang'], 'hole')
# (['primordial', 'black', 'hole', 'bang'], 'big')
# (['primordial', 'black', 'hole', 'big'], 'bang')
# (['black', 'hole', 'big', 'bang'], 'gravitational')
# (['hole', 'big', 'bang', 'gravitational'], 'collapse')
# (['big', 'bang', 'gravitational', 'collapse'], 'require')
# (['bang', 'gravitational', 'collapse', 'require'], 'great')
# (['gravitational', 'collapse', 'require', 'great'], 'density')
# (['energy', 'collision', 'gravitational', 'collapse'], 'high')
# (['high', 'collision', 'gravitational', 'collapse'], 'energy')
# (['high', 'energy', 'gravitational', 'collapse'], 'collision')
# (['high', 'energy', 'collision', 'collapse'], 'gravitational')
# (['high', 'energy', 'collision', 'gravitational'], 'collapse')
# (['energy', 'collision', 'gravitational', 'collapse'], 'process')
# (['collision', 'gravitational', 'collapse', 'process'], 'could')
# (['gravitational', 'collapse', 'process', 'could'], 'create')
# (['collapse', 'process', 'could', 'create'], 'black')
# (['process', 'could', 'create', 'black'], 'hole')
# (['must', 'low', 'limit', 'mass'], 'suggest')
# (['suggest', 'low', 'limit', 'mass'], 'must')
# (['suggest', 'must', 'limit', 'mass'], 'low')
# (['suggest', 'must', 'low', 'mass'], 'limit')
# (['suggest', 'must', 'low', 'limit'], 'mass')
# (['must', 'low', 'limit', 'mass'], 'black')
# (['low', 'limit', 'mass', 'black'], 'hole')
# (['black', 'hole', 'form', 'continue'], 'growth')
# (['growth', 'hole', 'form', 'continue'], 'black')
# (['growth', 'black', 'form', 'continue'], 'hole')
# (['growth', 'black', 'hole', 'continue'], 'form')
# (['growth', 'black', 'hole', 'form'], 'continue')
# (['black', 'hole', 'form', 'continue'], 'grow')
# (['hole', 'form', 'continue', 'grow'], 'absorb')
# (['form', 'continue', 'grow', 'absorb'], 'additional')
# (['continue', 'grow', 'absorb', 'additional'], 'matter')
# (['process', 'one', 'possible', 'way'], 'growth')
# (['growth', 'one', 'possible', 'way'], 'process')
# (['growth', 'process', 'possible', 'way'], 'one')
# (['growth', 'process', 'one', 'way'], 'possible')
# (['growth', 'process', 'one', 'possible'], 'way')
# (['process', 'one', 'possible', 'way'], 'supermassive')
# (['one', 'possible', 'way', 'supermassive'], 'black')
# (['possible', 'way', 'supermassive', 'black'], 'hole')
# (['way', 'supermassive', 'black', 'hole'], 'may')
# (['supermassive', 'black', 'hole', 'may'], 'form')
# (['black', 'hole', 'may', 'form'], 'although')
# (['hole', 'may', 'form', 'although'], 'formation')
# (['may', 'form', 'although', 'formation'], 'supermassive')
# (['form', 'although', 'formation', 'supermassive'], 'black')
# (['although', 'formation', 'supermassive', 'black'], 'hole')
# (['formation', 'supermassive', 'black', 'hole'], 'still')
# (['supermassive', 'black', 'hole', 'still'], 'open')
# (['black', 'hole', 'still', 'open'], 'field')
# (['hole', 'still', 'open', 'field'], 'research')
# (['hole', 'also', 'merge', 'object'], 'black')
# (['black', 'also', 'merge', 'object'], 'hole')
# (['black', 'hole', 'merge', 'object'], 'also')
# (['black', 'hole', 'also', 'object'], 'merge')
# (['black', 'hole', 'also', 'merge'], 'object')
# (['hole', 'also', 'merge', 'object'], 'star')
# (['also', 'merge', 'object', 'star'], 'even')
# (['merge', 'object', 'star', 'even'], 'black')
# (['object', 'star', 'even', 'black'], 'hole')
# (['become', 'know', 'hawk', 'radiation'], 'effect')
# (['effect', 'know', 'hawk', 'radiation'], 'become')
# (['effect', 'become', 'hawk', 'radiation'], 'know')
# (['effect', 'become', 'know', 'radiation'], 'hawk')
# (['effect', 'become', 'know', 'hawk'], 'radiation')
# (['quantum', 'field', 'theory', 'static'], 'apply')
# (['apply', 'field', 'theory', 'static'], 'quantum')
# (['apply', 'quantum', 'theory', 'static'], 'field')
# (['apply', 'quantum', 'field', 'static'], 'theory')
# (['apply', 'quantum', 'field', 'theory'], 'static')
# (['quantum', 'field', 'theory', 'static'], 'black')
# (['field', 'theory', 'static', 'black'], 'hole')
# (['theory', 'static', 'black', 'hole'], 'background')
# (['static', 'black', 'hole', 'background'], 'determine')
# (['black', 'hole', 'background', 'determine'], 'black')
# (['hole', 'background', 'determine', 'black'], 'hole')
# (['background', 'determine', 'black', 'hole'], 'emit')
# (['determine', 'black', 'hole', 'emit'], 'particle')
# (['black', 'hole', 'emit', 'particle'], 'display')
# (['hole', 'emit', 'particle', 'display'], 'perfect')
# (['emit', 'particle', 'display', 'perfect'], 'black')
# (['particle', 'display', 'perfect', 'black'], 'body')
# (['display', 'perfect', 'black', 'body'], 'spectrum')
# (['theory', 'black', 'hole', 'radiation'], 'hawking')
# (['hawking', 'black', 'hole', 'radiation'], 'theory')
# (['hawking', 'theory', 'hole', 'radiation'], 'black')
# (['hawking', 'theory', 'black', 'radiation'], 'hole')
# (['hawking', 'theory', 'black', 'hole'], 'radiation')
# (['theory', 'black', 'hole', 'radiation'], 'correct')
# (['black', 'hole', 'radiation', 'correct'], 'black')
# (['hole', 'radiation', 'correct', 'black'], 'hole')
# (['radiation', 'correct', 'black', 'hole'], 'expect')
# (['correct', 'black', 'hole', 'expect'], 'shrink')
# (['black', 'hole', 'expect', 'shrink'], 'evaporate')
# (['hole', 'expect', 'shrink', 'evaporate'], 'time')
# (['expect', 'shrink', 'evaporate', 'time'], 'lose')
# (['shrink', 'evaporate', 'time', 'lose'], 'mass')
# (['evaporate', 'time', 'lose', 'mass'], 'emission')
# (['time', 'lose', 'mass', 'emission'], 'photon')
# (['lose', 'mass', 'emission', 'photon'], 'particle')
# (['thermal', 'spectrum', 'proportional', 'surface'], 'temperature')
# (['temperature', 'spectrum', 'proportional', 'surface'], 'thermal')
# (['temperature', 'thermal', 'proportional', 'surface'], 'spectrum')
# (['temperature', 'thermal', 'spectrum', 'surface'], 'proportional')
# (['temperature', 'thermal', 'spectrum', 'proportional'], 'surface')
# (['thermal', 'spectrum', 'proportional', 'surface'], 'gravity')
# (['spectrum', 'proportional', 'surface', 'gravity'], 'black')
# (['proportional', 'surface', 'gravity', 'black'], 'hole')
# (['surface', 'gravity', 'black', 'hole'], 'schwarzschild')
# (['gravity', 'black', 'hole', 'schwarzschild'], 'black')
# (['black', 'hole', 'schwarzschild', 'black'], 'hole')
# (['hole', 'schwarzschild', 'black', 'hole'], 'inversely')
# (['schwarzschild', 'black', 'hole', 'inversely'], 'proportional')
# (['black', 'hole', 'inversely', 'proportional'], 'mass')
# (['large', 'black', 'hole', 'emit'], 'hence')
# (['hence', 'black', 'hole', 'emit'], 'large')
# (['hence', 'large', 'hole', 'emit'], 'black')
# (['hence', 'large', 'black', 'emit'], 'hole')
# (['hence', 'large', 'black', 'hole'], 'emit')
# (['large', 'black', 'hole', 'emit'], 'less')
# (['black', 'hole', 'emit', 'less'], 'radiation')
# (['hole', 'emit', 'less', 'radiation'], 'small')
# (['emit', 'less', 'radiation', 'small'], 'black')
# (['less', 'radiation', 'small', 'black'], 'hole')
# (['less', '2.7xa0', 'k', 'temperature'], 'far')
# (['far', '2.7xa0', 'k', 'temperature'], 'less')
# (['far', 'less', 'k', 'temperature'], '2.7xa0')
# (['far', 'less', '2.7xa0', 'temperature'], 'k')
# (['far', 'less', '2.7xa0', 'k'], 'temperature')
# (['less', '2.7xa0', 'k', 'temperature'], 'cosmic')
# (['2.7xa0', 'k', 'temperature', 'cosmic'], 'microwave')
# (['k', 'temperature', 'cosmic', 'microwave'], 'background')
# (['temperature', 'cosmic', 'microwave', 'background'], 'radiation')
# (['mass', 'large', 'black', 'hole'], 'stellar')
# (['stellar', 'large', 'black', 'hole'], 'mass')
# (['stellar', 'mass', 'black', 'hole'], 'large')
# (['stellar', 'mass', 'large', 'hole'], 'black')
# (['stellar', 'mass', 'large', 'black'], 'hole')
# (['mass', 'large', 'black', 'hole'], 'receive')
# (['large', 'black', 'hole', 'receive'], 'mass')
# (['black', 'hole', 'receive', 'mass'], 'cosmic')
# (['hole', 'receive', 'mass', 'cosmic'], 'microwave')
# (['receive', 'mass', 'cosmic', 'microwave'], 'background')
# (['mass', 'cosmic', 'microwave', 'background'], 'emit')
# (['cosmic', 'microwave', 'background', 'emit'], 'hawk')
# (['microwave', 'background', 'emit', 'hawk'], 'radiation')
# (['background', 'emit', 'hawk', 'radiation'], 'thus')
# (['emit', 'hawk', 'radiation', 'thus'], 'grow')
# (['hawk', 'radiation', 'thus', 'grow'], 'instead')
# (['radiation', 'thus', 'grow', 'instead'], 'shrink')
# (['temperature', 'large', '2.7xa0', 'k'], 'hawk')
# (['hawk', 'large', '2.7xa0', 'k'], 'temperature')
# (['hawk', 'temperature', '2.7xa0', 'k'], 'large')
# (['hawk', 'temperature', 'large', 'k'], '2.7xa0')
# (['hawk', 'temperature', 'large', '2.7xa0'], 'k')
# (['temperature', 'large', '2.7xa0', 'k'], 'black')
# (['large', '2.7xa0', 'k', 'black'], 'hole')
# (['2.7xa0', 'k', 'black', 'hole'], 'would')
# (['k', 'black', 'hole', 'would'], 'need')
# (['black', 'hole', 'would', 'need'], 'mass')
# (['hole', 'would', 'need', 'mass'], 'less')
# (['would', 'need', 'mass', 'less'], 'moon')
# (['hole', 'small', 'radiation', 'effect'], 'black')
# (['black', 'small', 'radiation', 'effect'], 'hole')
# (['black', 'hole', 'radiation', 'effect'], 'small')
# (['black', 'hole', 'small', 'effect'], 'radiation')
# (['black', 'hole', 'small', 'radiation'], 'effect')
# (['hole', 'small', 'radiation', 'effect'], 'expect')
# (['small', 'radiation', 'effect', 'expect'], 'become')
# (['radiation', 'effect', 'expect', 'become'], 'strong')
# (['mass', 'black', 'hole', 'expect'], 'low')
# (['low', 'black', 'hole', 'expect'], 'mass')
# (['low', 'mass', 'hole', 'expect'], 'black')
# (['low', 'mass', 'black', 'expect'], 'hole')
# ...
#  ([514, 925, 667, 6], 924),
#  ([924, 925, 667, 6], 514),
#  ([924, 514, 667, 6], 925),
#  ([924, 514, 925, 6], 667),
#  ([924, 514, 925, 667], 6),
#  ([514, 925, 667, 6], 7),
#  ([925, 667, 6, 7], 103),
#  ([667, 6, 7, 103], 601),
#  ([6, 7, 103, 601], 926),
#  ([7, 103, 601, 926], 927),
#  ([103, 601, 926, 927], 476),
#  ([601, 926, 927, 476], 671),
#  ([926, 927, 476, 671], 6),
#  ([927, 476, 671, 6], 7),
#  ([54, 134, 25, 22], 852),
#  ([852, 134, 25, 22], 54),
#  ([852, 54, 25, 22], 134),
#  ([852, 54, 134, 22], 25),
#  ([852, 54, 134, 25], 22),
#  ([54, 134, 25, 22], 308),
#  ([134, 25, 22, 308], 1),
#  ([25, 22, 308, 1], 166),
#  ([22, 308, 1, 166], 6),
#  ([308, 1, 166, 6], 7),
#  ([1, 166, 6, 7], 601),
#  ([166, 6, 7, 601], 264),
#  ([6, 7, 601, 264], 928),
#  ([7, 601, 264, 928], 51),
#  ([601, 264, 928, 51], 52),
#  ([264, 928, 51, 52], 414),
#  ([928, 51, 52, 414], 405),
#  ([51, 52, 414, 405], 22),
#  ([52, 414, 405, 22], 920),
#  ([166, 1, 933, 671], 784),
#  ([784, 1, 933, 671], 166),
#  ([784, 166, 933, 671], 1),
#  ([784, 166, 1, 671], 933),
#  ([784, 166, 1, 933], 671),
#  ([166, 1, 933, 671], 111),
#  ([1, 933, 671, 111], 5),
#  ([561, 935, 565, 1], 934),
#  ([934, 935, 565, 1], 561),
#  ([934, 561, 565, 1], 935),
#  ([934, 561, 935, 1], 565),
#  ([934, 561, 935, 565], 1),
#  ([561, 935, 565, 1], 410),
#  ([935, 565, 1, 410], 247),
#  ([565, 1, 410, 247], 919),
#  ([1, 410, 247, 919], 936),
#  ([410, 247, 919, 936], 937),
#  ([925, 601, 926, 941], 61),
#  ([61, 601, 926, 941], 925),
#  ([61, 925, 926, 941], 601),
#  ([61, 925, 601, 941], 926),
#  ([61, 925, 601, 926], 941),
#  ([925, 601, 926, 941], 57),
#  ([601, 926, 941, 57], 51),
#  ([926, 941, 57, 51], 52),
#  ([941, 57, 51, 52], 942),
#  ([57, 51, 52, 942], 22),
#  ([51, 52, 942, 22], 943),
#  ([52, 942, 22, 943], 234),
#  ([942, 22, 943, 234], 402),
#  ([22, 943, 234, 402], 400),
#  ([42, 43, 86, 183], 944),
#  ([944, 43, 86, 183], 42),
#  ([944, 42, 86, 183], 43),
#  ([944, 42, 43, 183], 86),
#  ([944, 42, 43, 86], 183),
#  ([42, 43, 86, 183], 184),
#  ([43, 86, 183, 184], 51),
#  ([86, 183, 184, 51], 52),
#  ([183, 184, 51, 52], 945),
#  ([184, 51, 52, 945], 185),
#  ([51, 52, 945, 185], 852),
#  ([52, 945, 185, 852], 40),
#  ([945, 185, 852, 40], 294),
#  ([185, 852, 40, 294], 295),
#  ([905, 708, 25, 312], 312),
#  ([312, 708, 25, 312], 905),
#  ([312, 905, 25, 312], 708),
#  ([312, 905, 708, 312], 25),
#  ([312, 905, 708, 25], 312),
#  ([905, 708, 25, 312], 160),
#  ([708, 25, 312, 160], 6),
#  ([25, 312, 160, 6], 7),
#  ([312, 160, 6, 7], 388),
#  ([160, 6, 7, 388], 42),
#  ([6, 7, 388, 42], 43),
#  ([7, 388, 42, 43], 153),
#  ([388, 42, 43, 153], 952),
#  ([42, 43, 153, 952], 25),
#  ([43, 153, 952, 25], 312),
#  ([153, 952, 25, 312], 28),
#  ([952, 25, 312, 28], 29),
#  ([25, 312, 28, 29], 446),
#  ([312, 28, 29, 446], 252),
#  ([28, 29, 446, 252], 405),
#  ([452, 6, 7, 28], 235),
#  ([235, 6, 7, 28], 452),
#  ([235, 452, 7, 28], 6),
#  ([235, 452, 6, 28], 7),
#  ([235, 452, 6, 7], 28),
#  ([452, 6, 7, 28], 414),
#  ([6, 7, 28, 414], 762),
#  ([7, 28, 414, 762], 953),
#  ([28, 414, 762, 953], 389),
#  ([402, 28, 958, 959], 957),
#  ([957, 28, 958, 959], 402),
#  ([957, 402, 958, 959], 28),
#  ([957, 402, 28, 959], 958),
#  ([957, 402, 28, 958], 959),
#  ([117, 402, 28, 199], 274),
#  ([274, 402, 28, 199], 117),
#  ([274, 117, 28, 199], 402),
#  ([274, 117, 402, 199], 28),
#  ([274, 117, 402, 28], 199),
#  ([117, 402, 28, 199], 47),
#  ([402, 28, 199, 47], 6),
#  ([28, 199, 47, 6], 7),
#  ([199, 47, 6, 7], 102),
#  ([28, 960, 501, 405], 402),
#  ([402, 960, 501, 405], 28),
#  ([402, 28, 501, 405], 960),
#  ([402, 28, 960, 405], 501),
#  ([402, 28, 960, 501], 405),
#  ([28, 960, 501, 405], 219),
#  ([166, 17, 6, 7], 514),
#  ([514, 17, 6, 7], 166),
#  ([514, 166, 6, 7], 17),
#  ([514, 166, 17, 7], 6),
#  ([514, 166, 17, 6], 7),
#  ([166, 17, 6, 7], 785),
#  ([17, 6, 7, 785], 961),
#  ([6, 7, 785, 961], 312),
#  ([7, 785, 961, 312], 57),
#  ([785, 961, 312, 57], 51),
#  ([961, 312, 57, 51], 52),
#  ([580, 566, 6, 7], 957),
#  ([957, 566, 6, 7], 580),
#  ([957, 580, 6, 7], 566),
#  ([957, 580, 566, 7], 6),
#  ([957, 580, 566, 6], 7),
#  ([580, 566, 6, 7], 131),
#  ([566, 6, 7, 131], 785),
#  ([6, 7, 131, 785], 312),
#  ([271, 475, 175, 419], 421),
#  ([421, 475, 175, 419], 271),
#  ([421, 271, 175, 419], 475),
#  ([421, 271, 475, 419], 175),
#  ([421, 271, 475, 175], 419),
#  ([271, 475, 175, 419], 115),
#  ([475, 175, 419, 115], 978),
#  ([175, 419, 115, 978], 979),
#  ([419, 115, 978, 979], 103),
#  ([115, 978, 979, 103], 980),
#  ([978, 979, 103, 980], 421),
#  ([312, 42, 43, 632], 916),
#  ([916, 42, 43, 632], 312),
#  ([916, 312, 43, 632], 42),
#  ([916, 312, 42, 632], 43),
#  ([916, 312, 42, 43], 632),
#  ([312, 42, 43, 632], 989),
#  ([42, 43, 632, 989], 990),
#  ([43, 632, 989, 990], 991),
#  ([632, 989, 990, 991], 41),
#  ([419, 820], 991),
#  ([991, 820], 419),
#  ([991, 419], 820),
#  ([820, 41, 60, 312], 996),
#  ([996, 41, 60, 312], 820),
#  ([996, 820, 60, 312], 41),
#  ([996, 820, 41, 312], 60),
#  ([996, 820, 41, 60], 312),
#  ([452, 6, 7, 997], 235),
#  ([235, 6, 7, 997], 452),
#  ([235, 452, 7, 997], 6),
#  ([235, 452, 6, 997], 7),
#  ([235, 452, 6, 7], 997),
#  ([452, 6, 7, 997], 752),
#  ([6, 7, 997, 752], 401),
#  ([7, 997, 752, 401], 497),
#  ([997, 752, 401, 497], 22),
#  ([752, 401, 497, 22], 17),
#  ([401, 497, 22, 17], 401),
#  ([34, 920, 448, 514], 842),
#  ([842, 920, 448, 514], 34),
#  ([842, 34, 448, 514], 920),
#  ([842, 34, 920, 514], 448),
#  ([842, 34, 920, 448], 514),
#  ([34, 920, 448, 514], 997),
#  ([920, 448, 514, 997], 752),
#  ([448, 514, 997, 752], 1012),
#  ([514, 997, 752, 1012], 73),
#  ([997, 752, 1012, 73], 1),
#  ([752, 1012, 73, 1], 997),
#  ([1012, 73, 1, 997], 752),
#  ([73, 1, 997, 752], 51),
#  ([1, 997, 752, 51], 52),
#  ([6, 7, 1020, 28], 566),
#  ([566, 7, 1020, 28], 6),
#  ([566, 6, 1020, 28], 7),
#  ([566, 6, 7, 28], 1020),
#  ([566, 6, 7, 1020], 28),
#  ([6, 7, 1020, 28], 29),
#  ([7, 1020, 28, 29], 86),
#  ([1020, 28, 29, 86], 1021),
#  ([28, 29, 86, 1021], 1009),
#  ([29, 86, 1021, 1009], 50),
#  ([86, 1021, 1009, 50], 1017),
#  ([667, 566, 47, 1023], 1),
#  ([1, 566, 47, 1023], 667),
#  ([1, 667, 47, 1023], 566),
#  ([1, 667, 566, 1023], 47),
#  ([1, 667, 566, 47], 1023),
#  ([667, 566, 47, 1023], 911),
#  ([566, 47, 1023, 911], 906),
#  ([47, 1023, 911, 906], 543),
#  ([1023, 911, 906, 543], 858),
#  ([75, 39, 941, 1017], 1),
#  ([1, 39, 941, 1017], 75),
#  ([1, 75, 941, 1017], 39),
#  ([1, 75, 39, 1017], 941),
#  ([1, 75, 39, 941], 1017),
#  ([561, 1, 588, 1017], 371),
#  ([371, 1, 588, 1017], 561),
#  ([371, 561, 588, 1017], 1),
#  ([371, 561, 1, 1017], 588),
#  ([371, 561, 1, 588], 1017),
#  ([561, 1, 588, 1017], 38),
#  ([1, 588, 1017, 38], 700),
#  ([858, 6, 7, 264], 1034),
#  ([1034, 6, 7, 264], 858),
#  ([1034, 858, 7, 264], 6),
#  ([1034, 858, 6, 264], 7),
#  ([1034, 858, 6, 7], 264),
#  ([1079, 51, 52, 49], 371),
#  ([371, 51, 52, 49], 1079),
#  ([371, 1079, 52, 49], 51),
#  ([371, 1079, 51, 49], 52),
#  ([371, 1079, 51, 52], 49),
#  ([1079, 51, 52, 49], 42),
#  ([51, 52, 49, 42], 43),
#  ([52, 49, 42, 43], 943),
#  ([49, 42, 43, 943], 70),
#  ([42, 43, 943, 70], 1080),
#  ([43, 943, 70, 1080], 1081),
#  ([943, 70, 1080, 1081], 312),
#  ([70, 1080, 1081, 312], 49),
#  ([1080, 1081, 312, 49], 919),
#  ([222, 1108, 570, 46], 546),
#  ([546, 1108, 570, 46], 222),
#  ([546, 222, 570, 46], 1108),
#  ([546, 222, 1108, 46], 570),
#  ([546, 222, 1108, 570], 46),
#  ([222, 1108, 570, 46], 122),
#  ([7, 205, 1125, 11], 6),
#  ([6, 205, 1125, 11], 7),
#  ([6, 7, 1125, 11], 205),
#  ([6, 7, 205, 11], 1125),
#  ([6, 7, 205, 1125], 11),
#  ([7, 205, 1125, 11], 6),
#  ([205, 1125, 11, 6], 7),
#  ([1125, 11, 6, 7], 100),
#  ([11, 6, 7, 100], 160),
#  ([6, 7, 100, 160], 18),
#  ([1, 100, 185, 1128], 190),
#  ([190, 100, 185, 1128], 1),
#  ([190, 1, 185, 1128], 100),
#  ([190, 1, 100, 1128], 185),
#  ([190, 1, 100, 185], 1128),
#  ([1, 100, 185, 1128], 175),
#  ([1133, 25, 130, 73], 38),
#  ([38, 25, 130, 73], 1133),
#  ([38, 1133, 130, 73], 25),
#  ([38, 1133, 25, 73], 130),
#  ([38, 1133, 25, 130], 73),
#  ([1133, 25, 130, 73], 728),
#  ([25, 130, 73, 728], 448),
#  ([130, 73, 728, 448], 514),
#  ([73, 728, 448, 514], 1065),
#  ([728, 448, 514, 1065], 5),
#  ([448, 514, 1065, 5], 144),
#  ([514, 1065, 5, 144], 561),
#  ([168, 514, 272, 5], 960),
#  ([960, 514, 272, 5], 168),
#  ([960, 168, 272, 5], 514),
#  ([960, 168, 514, 5], 272),
#  ([960, 168, 514, 272], 5),
#  ([168, 514, 272, 5], 735),
#  ([514, 272, 5, 735], 51),
#  ([272, 5, 735, 51], 52),
#  ([6, 7, 203, 1084], 1140),
#  ([1140, 7, 203, 1084], 6),
#  ([1140, 6, 203, 1084], 7),
#  ([1140, 6, 7, 1084], 203),
#  ([1140, 6, 7, 203], 1084),
#  ([6, 7, 203, 1084], 25),
#  ([7, 203, 1084, 25], 130),
#  ([203, 1084, 25, 130], 1081),
#  ([1084, 25, 130, 1081], 53),
#  ([25, 130, 1081, 53], 219),
#  ([38, 1169, 25, 130], 433),
#  ([433, 1169, 25, 130], 38),
#  ([433, 38, 25, 130], 1169),
#  ([433, 38, 1169, 130], 25),
#  ([433, 38, 1169, 25], 130),
#  ([38, 1169, 25, 130], 561),
#  ([1169, 25, 130, 561], 205),
#  ([25, 130, 561, 205], 848),
#  ([130, 561, 205, 848], 6),
#  ([561, 205, 848, 6], 7),
#  ([1012, 1178, 472, 47], 721),
#  ([721, 1178, 472, 47], 1012),
#  ([721, 1012, 472, 47], 1178),
#  ([721, 1012, 1178, 47], 472),
#  ([721, 1012, 1178, 472], 47),
#  ([1012, 1178, 472, 47], 6),
#  ([1178, 472, 47, 6], 7),
#  ([6, 7, 49, 1074], 1200),
#  ([1200, 7, 49, 1074], 6),
#  ([1200, 6, 49, 1074], 7),
#  ([1200, 6, 7, 1074], 49),
#  ([1200, 6, 7, 49], 1074),
#  ([6, 7, 49, 1074], 147),
#  ([7, 49, 1074, 147], 148),
#  ([49, 1074, 147, 148], 1118),
#  ([1074, 147, 148, 1118], 164),
#  ([561, 222, 131, 63], 1200),
#  ([1200, 222, 131, 63], 561),
#  ([1200, 561, 131, 63], 222),
#  ([1200, 561, 222, 63], 131),
#  ([1200, 561, 222, 131], 63),
#  ([561, 222, 131, 63], 11),
#  ([222, 131, 63, 11], 6),
#  ([131, 63, 11, 6], 7),
#  ([63, 11, 6, 7], 153),
#  ([11, 6, 7, 153], 49),
#  ([6, 7, 153, 49], 413),
#  ([7, 153, 49, 413], 735),
#  ([153, 49, 413, 735], 11),
#  ([49, 413, 735, 11], 6),
#  ([413, 735, 11, 6], 7),
#  ([735, 11, 6, 7], 1009),
#  ([11, 6, 7, 1009], 1203),
#  ([6, 7, 1009, 1203], 71),
#  ([7, 1009, 1203, 71], 560),
#  ([7, 274, 154, 1], 6),
#  ([6, 274, 154, 1], 7),
#  ([6, 7, 154, 1], 274),
#  ([6, 7, 274, 1], 154),
#  ([6, 7, 274, 154], 1),
#  ([7, 274, 154, 1], 122),
#  ([274, 154, 1, 122], 204),
#  ([154, 1, 122, 204], 6),
#  ([1, 122, 204, 6], 7),
#  ([252, 134, 623, 75], 54),
#  ([54, 134, 623, 75], 252),
#  ([54, 252, 623, 75], 134),
#  ([54, 252, 134, 75], 623),
#  ([54, 252, 134, 623], 75),
#  ([70, 71, 41, 801], 1167),
#  ([1167, 71, 41, 801], 70),
#  ([1167, 70, 41, 801], 71),
#  ([1167, 70, 71, 801], 41),
#  ([1167, 70, 71, 41], 801),
#  ([70, 71, 41, 801], 6),
#  ([71, 41, 801, 6], 7),
#  ([41, 801, 6, 7], 1216),
#  ([801, 6, 7, 1216], 183),
#  ([6, 7, 1216, 183], 6),
#  ([7, 1216, 183, 6], 7),
#  ([1216, 183, 6, 7], 73),
#  ([183, 6, 7, 73], 257),
#  ([6, 7, 73, 257], 1217),
#  ([7, 73, 257, 1217], 539),
#  ([73, 257, 1217, 539], 6),
#  ([257, 1217, 539, 6], 67),
#  ([1217, 539, 6, 67], 76),
#  ([41, 6, 7, 75], 74),
#  ([74, 6, 7, 75], 41),
#  ([74, 41, 7, 75], 6),
#  ([74, 41, 6, 75], 7),
#  ([74, 41, 6, 7], 75),
#  ([41, 6, 7, 75], 468),
#  ([6, 7, 75, 468], 6),
#  ([7, 75, 468, 6], 7),
#  ([75, 468, 6, 7], 820),
#  ([468, 6, 7, 820], 1219),
#  ([6, 7, 820, 1219], 1196),
#  ([7, 820, 1219, 1196], 22),
#  ([820, 1219, 1196, 22], 767),
#  ([1219, 1196, 22, 767], 47),
#  ([1196, 22, 767, 47], 678),
#  ([22, 767, 47, 678], 997),
#  ([767, 47, 678, 997], 257),
#  ([1213, 76, 79, 227], 77),
#  ([77, 76, 79, 227], 1213),
#  ([77, 1213, 79, 227], 76),
#  ([77, 1213, 76, 227], 79),
#  ([77, 1213, 76, 79], 227),
#  ([1213, 76, 79, 227], 30),
#  ([76, 79, 227, 30], 6),
#  ([79, 227, 30, 6], 7),
#  ([227, 30, 6, 7], 17),
#  ([30, 6, 7, 17], 6),
#  ([6, 7, 17, 6], 7),
#  ([7, 17, 6, 7], 78),
#  ([17, 6, 7, 78], 79),
#  ([6, 7, 78, 79], 47),
#  ([428, 6, 7, 73], 842),
#  ([842, 6, 7, 73], 428),
#  ([842, 428, 7, 73], 6),
#  ([842, 428, 6, 73], 7),
#  ([842, 428, 6, 7], 73),
#  ([428, 6, 7, 73], 936),
#  ([6, 7, 73, 936], 75),
#  ([7, 73, 936, 75], 903),
#  ([73, 936, 75, 903], 6),
#  ([936, 75, 903, 6], 7),
#  ([936, 1222, 896, 77], 476),
#  ([476, 1222, 896, 77], 936),
#  ([476, 936, 896, 77], 1222),
#  ([476, 936, 1222, 77], 896),
#  ([476, 936, 1222, 896], 77),
#  ([936, 1222, 896, 77], 845),
#  ([1222, 896, 77, 845], 1223),
#  ([896, 77, 845, 1223], 1216),
#  ([77, 845, 1223, 1216], 75),
#  ([47, 428, 6, 7], 83),
#  ([83, 428, 6, 7], 47),
#  ([83, 47, 6, 7], 428),
#  ([83, 47, 428, 7], 6),
#  ([83, 47, 428, 6], 7),
#  ([47, 428, 6, 7], 618),
#  ([428, 6, 7, 618], 47),
#  ([6, 7, 618, 47], 845),
#  ([7, 618, 47, 845], 1223),
#  ([618, 47, 845, 1223], 1216),
#  ([47, 845, 1223, 1216], 73),
#  ([845, 1223, 1216, 73], 623),
#  ([1223, 1216, 73, 623], 75),
#  ([1216, 73, 623, 75], 960),
#  ([73, 623, 75, 960], 147),
#  ([623, 75, 960, 147], 268),
#  ([75, 960, 147, 268], 1219),
#  ([77, 428, 1222, 896], 623),
#  ([623, 428, 1222, 896], 77),
#  ([623, 77, 1222, 896], 428),
#  ([623, 77, 428, 896], 1222),
#  ([623, 77, 428, 1222], 896),
#  ([77, 428, 1222, 896], 6),
#  ([428, 1222, 896, 6], 7),
#  ([1222, 896, 6, 7], 103),
#  ([896, 6, 7, 103], 1088),
#  ([6, 7, 103, 1088], 47),
#  ([7, 103, 1088, 47], 936),
#  ([103, 1088, 47, 936], 889),
#  ([7, 903, 75, 54], 6),
#  ([6, 903, 75, 54], 7),
#  ([6, 7, 75, 54], 903),
#  ([6, 7, 903, 54], 75),
#  ([6, 7, 903, 75], 54),
#  ([7, 903, 75, 54], 820),
#  ([903, 75, 54, 820], 252),
#  ([75, 54, 820, 252], 31),
#  ([47, 6, 7, 820], 1178),
#  ([1178, 6, 7, 820], 47),
#  ([1178, 47, 7, 820], 6),
#  ([1178, 47, 6, 820], 7),
#  ([1178, 47, 6, 7], 820),
#  ([47, 6, 7, 820], 1196),
#  ([6, 7, 820, 1196], 204),
#  ([7, 820, 1196, 204], 1025),
#  ([6, 7, 442, 971], 747),
#  ([747, 7, 442, 971], 6),
#  ([747, 6, 442, 971], 7),
#  ([747, 6, 7, 971], 442),
#  ([747, 6, 7, 442], 971),
#  ([6, 7, 442, 971], 162),
#  ([7, 442, 971, 162], 27),
#  ([442, 971, 162, 27], 25),
#  ([971, 162, 27, 25], 259),
#  ([162, 27, 25, 259], 149),
#  ([6, 7, 776, 117], 165),
#  ([165, 7, 776, 117], 6),
#  ([165, 6, 776, 117], 7),
#  ([165, 6, 7, 117], 776),
#  ([165, 6, 7, 776], 117),
#  ([6, 7, 776, 117], 6),
#  ([7, 776, 117, 6], 796),
#  ([776, 117, 6, 796], 34),
#  ([117, 6, 796, 34], 919),
#  ([6, 796, 34, 919], 232),
#  ([796, 34, 919, 232], 28),
#  ([156, 1289, 51, 52], 268),
#  ([268, 1289, 51, 52], 156),
#  ([268, 156, 51, 52], 1289),
#  ([268, 156, 1289, 52], 51),
#  ([268, 156, 1289, 51], 52),
#  ([156, 1289, 51, 52], 915),
#  ([1289, 51, 52, 915], 6),
#  ([51, 52, 915, 6], 7),
#  ([10, 1217, 955, 65], 108),
#  ([108, 1217, 955, 65], 10),
#  ([108, 10, 955, 65], 1217),
#  ([108, 10, 1217, 65], 955),
#  ([108, 10, 1217, 955], 65),
#  ([10, 1217, 955, 65], 732),
#  ([1217, 955, 65, 732], 1001),
#  ([955, 65, 732, 1001], 1292),
#  ([65, 732, 1001, 1292], 5),
#  ([732, 1001, 1292, 5], 1269),
#  ([1001, 1292, 5, 1269], 197),
#  ([1292, 5, 1269, 197], 6),
#  ([5, 1269, 197, 6], 7),
#  ([1269, 197, 6, 7], 10),
#  ([197, 6, 7, 10], 848),
#  ([6, 7, 10, 848], 4),
#  ([7, 10, 848, 4], 616),
#  ([10, 848, 4, 616], 1269),
#  ([848, 4, 616, 1269], 6),
#  ([4, 616, 1269, 6], 7),
#  ([1324, 6, 7, 44], 115),
#  ([115, 6, 7, 44], 1324),
#  ([115, 1324, 7, 44], 6),
#  ([115, 1324, 6, 44], 7),
#  ([115, 1324, 6, 7], 44),
#  ([1324, 6, 7, 44], 442),
#  ([6, 7, 44, 442], 1036),
#  ([7, 44, 442, 1036], 71),
#  ([1012, 679, 993, 46], 1),
#  ([1, 679, 993, 46], 1012),
#  ([1, 1012, 993, 46], 679),
#  ([1, 1012, 679, 46], 993),
#  ([1, 1012, 679, 993], 46),
#  ([1012, 679, 993, 46], 273),
#  ([679, 993, 46, 273], 6),
#  ([993, 46, 273, 6], 7),
#  ([46, 273, 6, 7], 1341),
#  ([273, 6, 7, 1341], 109),
#  ([186, 131, 1086, 187], 419),
#  ([419, 131, 1086, 187], 186),
#  ([419, 186, 1086, 187], 131),
#  ([419, 186, 131, 187], 1086),
#  ([419, 186, 131, 1086], 187),
#  ([186, 131, 1086, 187], 6),
#  ([131, 1086, 187, 6], 7),
#  ([1086, 187, 6, 7], 46),
#  ([187, 6, 7, 46], 37),
#  ([6, 7, 46, 37], 997),
#  ([7, 46, 37, 997], 752),
#  ([274, 529, 89, 1263], 185),
#  ([185, 529, 89, 1263], 274),
#  ([185, 274, 89, 1263], 529),
#  ([185, 274, 529, 1263], 89),
#  ([185, 274, 529, 89], 1263),
#  ([274, 529, 89, 1263], 1264),
#  ([529, 89, 1263, 1264], 442),
#  ([89, 1263, 1264, 442], 83),
#  ([1263, 1264, 442, 83], 47),
#  ([1264, 442, 83, 47], 6),
#  ([442, 83, 47, 6], 7),
#  ([83, 47, 6, 7], 191),
#  ([62, 25, 36, 51], 978),
#  ([978, 25, 36, 51], 62),
#  ([978, 62, 36, 51], 25),
#  ([978, 62, 25, 51], 36),
#  ([978, 62, 25, 36], 51),
#  ([62, 25, 36, 51], 27),
#  ([472, 1, 893, 1009], 1376),
#  ([1376, 1, 893, 1009], 472),
#  ([1376, 472, 893, 1009], 1),
#  ([1376, 472, 1, 1009], 893),
#  ([1376, 472, 1, 893], 1009),
#  ([472, 1, 893, 1009], 428),
#  ([1, 893, 1009, 428], 1046),
#  ([893, 1009, 428, 1046], 921),
#  ([1009, 428, 1046, 921], 903),
#  ([428, 1046, 921, 903], 17),
#  ([1046, 921, 903, 17], 401),
#  ([136, 262, 194, 153], 174),
#  ...]

# %%
train_data
# Out:
# [(['hole', 'region', 'spacetime', 'gravity'], 'black'),
#  (['black', 'region', 'spacetime', 'gravity'], 'hole'),
#  (['black', 'hole', 'spacetime', 'gravity'], 'region'),
#  (['black', 'hole', 'region', 'gravity'], 'spacetime'),
#  (['black', 'hole', 'region', 'spacetime'], 'gravity'),
#  (['hole', 'region', 'spacetime', 'gravity'], 'strong'),
#  (['region', 'spacetime', 'gravity', 'strong'], 'nothing'),
#  (['spacetime', 'gravity', 'strong', 'nothing'], 'include'),
#  (['gravity', 'strong', 'nothing', 'include'], 'light'),
#  (['strong', 'nothing', 'include', 'light'], 'electromagnetic'),
#  (['nothing', 'include', 'light', 'electromagnetic'], 'wave'),
#  (['include', 'light', 'electromagnetic', 'wave'], 'enough'),
#  (['light', 'electromagnetic', 'wave', 'enough'], 'energy'),
#  (['electromagnetic', 'wave', 'enough', 'energy'], 'escape'),
#  (['escape', 'call', 'event', 'horizon'], 'boundary'),
#  (['boundary', 'call', 'event', 'horizon'], 'escape'),
#  (['boundary', 'escape', 'event', 'horizon'], 'call'),
#  (['boundary', 'escape', 'call', 'horizon'], 'event'),
#  (['boundary', 'escape', 'call', 'event'], 'horizon'),
#  (['finkelstein', '1958', 'first', 'publish'], 'david'),
#  (['david', '1958', 'first', 'publish'], 'finkelstein'),
#  (['david', 'finkelstein', 'first', 'publish'], '1958'),
#  (['david', 'finkelstein', '1958', 'publish'], 'first'),
#  (['david', 'finkelstein', '1958', 'first'], 'publish'),
#  (['finkelstein', '1958', 'first', 'publish'], 'interpretation'),
#  (['1958', 'first', 'publish', 'interpretation'], 'black'),
#  (['first', 'publish', 'interpretation', 'black'], 'hole'),
#  (['publish', 'interpretation', 'black', 'hole'], 'region'),
#  (['interpretation', 'black', 'hole', 'region'], 'space'),
#  (['black', 'hole', 'region', 'space'], 'nothing'),
#  (['hole', 'region', 'space', 'nothing'], 'escape'),
#  (['hole', 'long', 'consider', 'mathematical'], 'black'),
#  (['black', 'long', 'consider', 'mathematical'], 'hole'),
#  (['black', 'hole', 'consider', 'mathematical'], 'long'),
#  (['black', 'hole', 'long', 'mathematical'], 'consider'),
#  (['black', 'hole', 'long', 'consider'], 'mathematical'),
#  (['hole', 'long', 'consider', 'mathematical'], 'curiosity'),
#  (['theoretical', 'work', 'show', 'generic'], '1960'),
#  (['1960', 'work', 'show', 'generic'], 'theoretical'),
#  (['1960', 'theoretical', 'show', 'generic'], 'work'),
#  (['1960', 'theoretical', 'work', 'generic'], 'show'),
#  (['1960', 'theoretical', 'work', 'show'], 'generic'),
#  (['theoretical', 'work', 'show', 'generic'], 'prediction'),
#  (['work', 'show', 'generic', 'prediction'], 'general'),
#  (['show', 'generic', 'prediction', 'general'], 'relativity'),
#  (['black', 'hole', 'know', 'cygnus'], 'first'),
#  (['first', 'hole', 'know', 'cygnus'], 'black'),
#  (['first', 'black', 'know', 'cygnus'], 'hole'),
#  (['first', 'black', 'hole', 'cygnus'], 'know'),
#  (['first', 'black', 'hole', 'know'], 'cygnus'),
#  (['black', 'hole', 'know', 'cygnus'], 'x'),
#  (['hole', 'know', 'cygnus', 'x'], '1'),
#  (['know', 'cygnus', 'x', '1'], 'identify'),
#  (['cygnus', 'x', '1', 'identify'], 'several'),
#  (['x', '1', 'identify', 'several'], 'researcher'),
#  (['1', 'identify', 'several', 'researcher'], 'independently'),
#  (['identify', 'several', 'researcher', 'independently'], '1971'),
#  (['hole', 'form', 'grow', 'absorb'], 'black'),
#  (['black', 'form', 'grow', 'absorb'], 'hole'),
#  (['black', 'hole', 'grow', 'absorb'], 'form'),
#  (['black', 'hole', 'form', 'absorb'], 'grow'),
#  (['black', 'hole', 'form', 'grow'], 'absorb'),
#  (['hole', 'form', 'grow', 'absorb'], 'mass'),
#  (['form', 'grow', 'absorb', 'mass'], 'surrounding'),
#  (['black', 'hole', 'million', 'solar'], 'supermassive'),
#  (['supermassive', 'hole', 'million', 'solar'], 'black'),
#  (['supermassive', 'black', 'million', 'solar'], 'hole'),
#  (['supermassive', 'black', 'hole', 'solar'], 'million'),
#  (['supermassive', 'black', 'hole', 'million'], 'solar'),
#  (['black', 'hole', 'million', 'solar'], 'masse'),
#  (['hole', 'million', 'solar', 'masse'], 'may'),
#  (['million', 'solar', 'masse', 'may'], 'form'),
#  (['solar', 'masse', 'may', 'form'], 'absorb'),
#  (['masse', 'may', 'form', 'absorb'], 'star'),
#  (['may', 'form', 'absorb', 'star'], 'merge'),
#  (['form', 'absorb', 'star', 'merge'], 'black'),
#  (['absorb', 'star', 'merge', 'black'], 'hole'),
#  (['star', 'merge', 'black', 'hole'], 'via'),
#  (['merge', 'black', 'hole', 'via'], 'direct'),
#  (['black', 'hole', 'via', 'direct'], 'collapse'),
#  (['hole', 'via', 'direct', 'collapse'], 'gas'),
#  (['via', 'direct', 'collapse', 'gas'], 'cloud'),
#  (['black', 'hole', 'infer', 'interaction'], 'presence'),
#  (['presence', 'hole', 'infer', 'interaction'], 'black'),
#  (['presence', 'black', 'infer', 'interaction'], 'hole'),
#  (['presence', 'black', 'hole', 'interaction'], 'infer'),
#  (['presence', 'black', 'hole', 'infer'], 'interaction'),
#  (['black', 'hole', 'infer', 'interaction'], 'matter'),
#  (['hole', 'infer', 'interaction', 'matter'], 'electromagnetic'),
#  (['infer', 'interaction', 'matter', 'electromagnetic'], 'radiation'),
#  (['interaction', 'matter', 'electromagnetic', 'radiation'], 'visible'),
#  (['matter', 'electromagnetic', 'radiation', 'visible'], 'light'),
#  (['orbit', 'black', 'hole', 'orbit'], 'star'),
#  (['star', 'black', 'hole', 'orbit'], 'orbit'),
#  (['star', 'orbit', 'hole', 'orbit'], 'black'),
#  (['star', 'orbit', 'black', 'orbit'], 'hole'),
#  (['star', 'orbit', 'black', 'hole'], 'orbit'),
#  (['orbit', 'black', 'hole', 'orbit'], 'use'),
#  (['black', 'hole', 'orbit', 'use'], 'determine'),
#  (['hole', 'orbit', 'use', 'determine'], 'black'),
#  (['orbit', 'use', 'determine', 'black'], 'hole'),
#  (['use', 'determine', 'black', 'hole'], 'mass'),
#  (['determine', 'black', 'hole', 'mass'], 'location'),
#  (['use', 'exclude', 'possible', 'alternative'], 'observation'),
#  (['observation', 'exclude', 'possible', 'alternative'], 'use'),
#  (['observation', 'use', 'possible', 'alternative'], 'exclude'),
#  (['observation', 'use', 'exclude', 'alternative'], 'possible'),
#  (['observation', 'use', 'exclude', 'possible'], 'alternative'),
#  (['use', 'exclude', 'possible', 'alternative'], 'neutron'),
#  (['exclude', 'possible', 'alternative', 'neutron'], 'star'),
#  (['refer', 'body', 'dark', 'star'], 'michell'),
#  (['michell', 'body', 'dark', 'star'], 'refer'),
#  (['michell', 'refer', 'dark', 'star'], 'body'),
#  (['michell', 'refer', 'body', 'star'], 'dark'),
#  (['michell', 'refer', 'body', 'dark'], 'star'),
#  (['later', 'karl', 'schwarzschild', 'find'], 'month'),
#  (['month', 'karl', 'schwarzschild', 'find'], 'later'),
#  (['month', 'later', 'schwarzschild', 'find'], 'karl'),
#  (['month', 'later', 'karl', 'find'], 'schwarzschild'),
#  (['month', 'later', 'karl', 'schwarzschild'], 'find'),
#  (['later', 'karl', 'schwarzschild', 'find'], 'solution'),
#  (['karl', 'schwarzschild', 'find', 'solution'], 'einstein'),
#  (['schwarzschild', 'find', 'solution', 'einstein'], 'field'),
#  (['find', 'solution', 'einstein', 'field'], 'equation'),
#  (['solution', 'einstein', 'field', 'equation'], 'describe'),
#  (['einstein', 'field', 'equation', 'describe'], 'gravitational'),
#  (['field', 'equation', 'describe', 'gravitational'], 'field'),
#  (['equation', 'describe', 'gravitational', 'field'], 'point'),
#  (['describe', 'gravitational', 'field', 'point'], 'mass'),
#  (['gravitational', 'field', 'point', 'mass'], 'spherical'),
#  (['field', 'point', 'mass', 'spherical'], 'mass'),
#  (['peculiar', 'behaviour', 'call', 'schwarzschild'], 'solution'),
#  (['solution', 'behaviour', 'call', 'schwarzschild'], 'peculiar'),
#  (['solution', 'peculiar', 'call', 'schwarzschild'], 'behaviour'),
#  (['solution', 'peculiar', 'behaviour', 'schwarzschild'], 'call'),
#  (['solution', 'peculiar', 'behaviour', 'call'], 'schwarzschild'),
#  (['peculiar', 'behaviour', 'call', 'schwarzschild'], 'radius'),
#  (['behaviour', 'call', 'schwarzschild', 'radius'], 'become'),
#  (['call', 'schwarzschild', 'radius', 'become'], 'singular'),
#  (['schwarzschild', 'radius', 'become', 'singular'], 'mean'),
#  (['radius', 'become', 'singular', 'mean'], 'term'),
#  (['become', 'singular', 'mean', 'term'], 'einstein'),
#  (['singular', 'mean', 'term', 'einstein'], 'equation'),
#  (['mean', 'term', 'einstein', 'equation'], 'become'),
#  (['term', 'einstein', 'equation', 'become'], 'infinite'),
#  (['make', 'reference', 'einstein', 'recent'], 'paper'),
#  (['paper', 'reference', 'einstein', 'recent'], 'make'),
#  (['paper', 'make', 'einstein', 'recent'], 'reference'),
#  (['paper', 'make', 'reference', 'recent'], 'einstein'),
#  (['paper', 'make', 'reference', 'einstein'], 'recent'),
#  (['make', 'reference', 'einstein', 'recent'], 'publication'),
#  (['reference', 'einstein', 'recent', 'publication'], 'oppenheimer'),
#  (['einstein', 'recent', 'publication', 'oppenheimer'], 'snyder'),
#  (['recent', 'publication', 'oppenheimer', 'snyder'], 'use'),
#  (['publication', 'oppenheimer', 'snyder', 'use'], 'einstein'),
#  (['oppenheimer', 'snyder', 'use', 'einstein'], 'theory'),
#  (['snyder', 'use', 'einstein', 'theory'], 'general'),
#  (['use', 'einstein', 'theory', 'general'], 'relativity'),
#  (['einstein', 'theory', 'general', 'relativity'], 'show'),
#  (['theory', 'general', 'relativity', 'show'], 'condition'),
#  (['general', 'relativity', 'show', 'condition'], 'black'),
#  (['relativity', 'show', 'condition', 'black'], 'hole'),
#  (['show', 'condition', 'black', 'hole'], 'could'),
#  (['condition', 'black', 'hole', 'could'], 'develop'),
#  (['black', 'hole', 'could', 'develop'], 'first'),
#  (['hole', 'could', 'develop', 'first'], 'time'),
#  (['could', 'develop', 'first', 'time'], 'contemporary'),
#  (['develop', 'first', 'time', 'contemporary'], 'physics'),
#  (['solution', 'extend', 'schwarzschild', 'solution'], 'finkelstein'),
#  (['finkelstein', 'extend', 'schwarzschild', 'solution'], 'solution'),
#  (['finkelstein', 'solution', 'schwarzschild', 'solution'], 'extend'),
#  (['finkelstein', 'solution', 'extend', 'solution'], 'schwarzschild'),
#  (['finkelstein', 'solution', 'extend', 'schwarzschild'], 'solution'),
#  (['solution', 'extend', 'schwarzschild', 'solution'], 'future'),
#  (['extend', 'schwarzschild', 'solution', 'future'], 'observer'),
#  (['schwarzschild', 'solution', 'future', 'observer'], 'fall'),
#  (['solution', 'future', 'observer', 'fall'], 'black'),
#  (['future', 'observer', 'fall', 'black'], 'hole'),
#  (['general', 'black', 'hole', 'solution'], 'period'),
#  (['period', 'black', 'hole', 'solution'], 'general'),
#  (['period', 'general', 'hole', 'solution'], 'black'),
#  (['period', 'general', 'black', 'solution'], 'hole'),
#  (['period', 'general', 'black', 'hole'], 'solution'),
#  (['general', 'black', 'hole', 'solution'], 'find'),
#  (['complete', 'hawking', '1974', 'show'], 'analogy'),
#  (['analogy', 'hawking', '1974', 'show'], 'complete'),
#  (['analogy', 'complete', '1974', 'show'], 'hawking'),
#  (['analogy', 'complete', 'hawking', 'show'], '1974'),
#  (['analogy', 'complete', 'hawking', '1974'], 'show'),
#  (['complete', 'hawking', '1974', 'show'], 'quantum'),
#  (['hawking', '1974', 'show', 'quantum'], 'field'),
#  (['1974', 'show', 'quantum', 'field'], 'theory'),
#  (['show', 'quantum', 'field', 'theory'], 'imply'),
#  (['quantum', 'field', 'theory', 'imply'], 'black'),
#  (['field', 'theory', 'imply', 'black'], 'hole'),
#  (['theory', 'imply', 'black', 'hole'], 'radiate'),
#  (['imply', 'black', 'hole', 'radiate'], 'like'),
#  (['black', 'hole', 'radiate', 'like'], 'black'),
#  (['hole', 'radiate', 'like', 'black'], 'body'),
#  (['radiate', 'like', 'black', 'body'], 'temperature'),
#  (['like', 'black', 'body', 'temperature'], 'proportional'),
#  (['black', 'body', 'temperature', 'proportional'], 'surface'),
#  (['body', 'temperature', 'proportional', 'surface'], 'gravity'),
#  (['temperature', 'proportional', 'surface', 'gravity'], 'black'),
#  (['proportional', 'surface', 'gravity', 'black'], 'hole'),
#  (['surface', 'gravity', 'black', 'hole'], 'predict'),
#  (['gravity', 'black', 'hole', 'predict'], 'effect'),
#  (['black', 'hole', 'predict', 'effect'], 'know'),
#  (['hole', 'predict', 'effect', 'know'], 'hawk'),
#  (['predict', 'effect', 'know', 'hawk'], 'radiation'),
#  (['april', '2019', 'first', 'direct'], '10'),
#  (['10', '2019', 'first', 'direct'], 'april'),
#  (['10', 'april', 'first', 'direct'], '2019'),
#  (['10', 'april', '2019', 'direct'], 'first'),
#  (['10', 'april', '2019', 'first'], 'direct'),
#  (['april', '2019', 'first', 'direct'], 'image'),
#  (['2019', 'first', 'direct', 'image'], 'black'),
#  (['first', 'direct', 'image', 'black'], 'hole'),
#  (['direct', 'image', 'black', 'hole'], 'vicinity'),
#  (['image', 'black', 'hole', 'vicinity'], 'publish'),
#  (['black', 'hole', 'vicinity', 'publish'], 'follow'),
#  (['hole', 'vicinity', 'publish', 'follow'], 'observation'),
#  (['vicinity', 'publish', 'follow', 'observation'], 'make'),
#  (['publish', 'follow', 'observation', 'make'], 'event'),
#  (['follow', 'observation', 'make', 'event'], 'horizon'),
#  (['observation', 'make', 'event', 'horizon'], 'telescope'),
#  (['make', 'event', 'horizon', 'telescope'], '2017'),
#  (['event', 'horizon', 'telescope', '2017'], 'supermassive'),
#  (['horizon', 'telescope', '2017', 'supermassive'], 'black'),
#  (['telescope', '2017', 'supermassive', 'black'], 'hole'),
#  (['2017', 'supermassive', 'black', 'hole'], 'messier'),
#  (['supermassive', 'black', 'hole', 'messier'], '87'),
#  (['black', 'hole', 'messier', '87'], 'galactic'),
#  (['hole', 'messier', '87', 'galactic'], 'centre'),
#  (['would', 'detectable', 'gravitational', 'lensing'], 'therefore'),
#  (['therefore', 'detectable', 'gravitational', 'lensing'], 'would'),
#  (['therefore', 'would', 'gravitational', 'lensing'], 'detectable'),
#  (['therefore', 'would', 'detectable', 'lensing'], 'gravitational'),
#  (['therefore', 'would', 'detectable', 'gravitational'], 'lensing'),
#  (['special', 'visible', 'outside', 'black'], 'property'),
#  (['property', 'visible', 'outside', 'black'], 'special'),
#  (['property', 'special', 'outside', 'black'], 'visible'),
#  (['property', 'special', 'visible', 'black'], 'outside'),
#  (['property', 'special', 'visible', 'outside'], 'black'),
#  (['special', 'visible', 'outside', 'black'], 'hole'),
#  (['hole', 'eventually', 'achieve', 'stable'], 'black'),
#  (['black', 'eventually', 'achieve', 'stable'], 'hole'),
#  (['black', 'hole', 'achieve', 'stable'], 'eventually'),
#  (['black', 'hole', 'eventually', 'stable'], 'achieve'),
#  (['black', 'hole', 'eventually', 'achieve'], 'stable'),
#  (['hole', 'eventually', 'achieve', 'stable'], 'state'),
#  (['eventually', 'achieve', 'stable', 'state'], 'three'),
#  (['achieve', 'stable', 'state', 'three'], 'parameter'),
#  (['stable', 'state', 'three', 'parameter'], 'way'),
#  (['state', 'three', 'parameter', 'way'], 'avoid'),
#  (['three', 'parameter', 'way', 'avoid'], 'lose'),
#  (['parameter', 'way', 'avoid', 'lose'], 'information'),
#  (['way', 'avoid', 'lose', 'information'], 'initial'),
#  (['avoid', 'lose', 'information', 'initial'], 'condition'),
#  (['lose', 'information', 'initial', 'condition'], 'gravitational'),
#  (['information', 'initial', 'condition', 'gravitational'], 'electric'),
#  (['initial', 'condition', 'gravitational', 'electric'], 'field'),
#  (['condition', 'gravitational', 'electric', 'field'], 'black'),
#  (['gravitational', 'electric', 'field', 'black'], 'hole'),
#  (['electric', 'field', 'black', 'hole'], 'give'),
#  (['field', 'black', 'hole', 'give'], 'little'),
#  (['black', 'hole', 'give', 'little'], 'information'),
#  (['hole', 'give', 'little', 'information'], 'go'),
#  (['puzzle', 'call', 'black', 'hole'], 'behavior'),
#  (['behavior', 'call', 'black', 'hole'], 'puzzle'),
#  (['behavior', 'puzzle', 'black', 'hole'], 'call'),
#  (['behavior', 'puzzle', 'call', 'hole'], 'black'),
#  (['behavior', 'puzzle', 'call', 'black'], 'hole'),
#  (['puzzle', 'call', 'black', 'hole'], 'information'),
#  (['call', 'black', 'hole', 'information'], 'loss'),
#  (['black', 'hole', 'information', 'loss'], 'paradox'),
#  (['hole', 'often', 'refer', 'schwarzschild'], 'black'),
#  (['black', 'often', 'refer', 'schwarzschild'], 'hole'),
#  (['black', 'hole', 'refer', 'schwarzschild'], 'often'),
#  (['black', 'hole', 'often', 'schwarzschild'], 'refer'),
#  (['black', 'hole', 'often', 'refer'], 'schwarzschild'),
#  (['hole', 'often', 'refer', 'schwarzschild'], 'black'),
#  (['often', 'refer', 'schwarzschild', 'black'], 'hole'),
#  (['refer', 'schwarzschild', 'black', 'hole'], 'karl'),
#  (['schwarzschild', 'black', 'hole', 'karl'], 'schwarzschild'),
#  (['black', 'hole', 'karl', 'schwarzschild'], 'discover'),
#  (['hole', 'karl', 'schwarzschild', 'discover'], 'solution'),
#  (['karl', 'schwarzschild', 'discover', 'solution'], '1916'),
#  (['describe', 'general', 'black', 'hole'], 'solution'),
#  (['solution', 'general', 'black', 'hole'], 'describe'),
#  (['solution', 'describe', 'black', 'hole'], 'general'),
#  (['solution', 'describe', 'general', 'hole'], 'black'),
#  (['solution', 'describe', 'general', 'black'], 'hole'),
#  (['describe', 'general', 'black', 'hole'], 'also'),
#  (['general', 'black', 'hole', 'also'], 'exist'),
#  (['stationary', 'black', 'hole', 'solution'], 'general'),
#  (['general', 'black', 'hole', 'solution'], 'stationary'),
#  (['general', 'stationary', 'hole', 'solution'], 'black'),
#  (['general', 'stationary', 'black', 'solution'], 'hole'),
#  (['general', 'stationary', 'black', 'hole'], 'solution'),
#  (['stationary', 'black', 'hole', 'solution'], 'know'),
#  (['black', 'hole', 'solution', 'know'], 'kerr'),
#  (['hole', 'solution', 'know', 'kerr'], '–'),
#  (['solution', 'know', 'kerr', '–'], 'newman'),
#  (['know', 'kerr', '–', 'newman'], 'metric'),
#  (['kerr', '–', 'newman', 'metric'], 'describe'),
#  (['–', 'newman', 'metric', 'describe'], 'black'),
#  (['newman', 'metric', 'describe', 'black'], 'hole'),
#  (['metric', 'describe', 'black', 'hole'], 'charge'),
#  (['describe', 'black', 'hole', 'charge'], 'angular'),
#  (['black', 'hole', 'charge', 'angular'], 'momentum'),
#  (['hole', 'minimum', 'possible', 'mass'], 'black'),
#  (['black', 'minimum', 'possible', 'mass'], 'hole'),
#  (['black', 'hole', 'possible', 'mass'], 'minimum'),
#  (['black', 'hole', 'minimum', 'mass'], 'possible'),
#  (['black', 'hole', 'minimum', 'possible'], 'mass'),
#  (['hole', 'minimum', 'possible', 'mass'], 'satisfy'),
#  (['minimum', 'possible', 'mass', 'satisfy'], 'inequality'),
#  (['possible', 'mass', 'satisfy', 'inequality'], 'call'),
#  (['mass', 'satisfy', 'inequality', 'call'], 'extremal'),
#  (['einstein', 'equation', 'violate', 'inequality'], 'solution'),
#  (['solution', 'equation', 'violate', 'inequality'], 'einstein'),
#  (['solution', 'einstein', 'violate', 'inequality'], 'equation'),
#  (['solution', 'einstein', 'equation', 'inequality'], 'violate'),
#  (['solution', 'einstein', 'equation', 'violate'], 'inequality'),
#  (['einstein', 'equation', 'violate', 'inequality'], 'exist'),
#  (['equation', 'violate', 'inequality', 'exist'], 'possess'),
#  (['violate', 'inequality', 'exist', 'possess'], 'event'),
#  (['inequality', 'exist', 'possess', 'event'], 'horizon'),
#  (['approx'], 'mass'),
#  (['mass'], 'approx'),
#  (['black', 'hole', 'spacetime', 'start'], 'close'),
#  (['close', 'hole', 'spacetime', 'start'], 'black'),
#  (['close', 'black', 'spacetime', 'start'], 'hole'),
#  (['close', 'black', 'hole', 'start'], 'spacetime'),
#  (['close', 'black', 'hole', 'spacetime'], 'start'),
#  (['black', 'hole', 'spacetime', 'start'], 'deform'),
#  (['go', 'towards', 'black', 'hole'], 'path'),
#  (['path', 'towards', 'black', 'hole'], 'go'),
#  (['path', 'go', 'black', 'hole'], 'towards'),
#  (['path', 'go', 'towards', 'hole'], 'black'),
#  (['path', 'go', 'towards', 'black'], 'hole'),
#  (['go', 'towards', 'black', 'hole'], 'path'),
#  (['towards', 'black', 'hole', 'path'], 'move'),
#  (['black', 'hole', 'path', 'move'], 'away'),
#  (['possible', 'particle', 'escape'], 'long'),
#  (['long', 'particle', 'escape'], 'possible'),
#  (['long', 'possible', 'escape'], 'particle'),
#  (['long', 'possible', 'particle'], 'escape'),
#  (['feature', 'black', 'hole', 'appearance'], 'define'),
#  (['define', 'black', 'hole', 'appearance'], 'feature'),
#  (['define', 'feature', 'hole', 'appearance'], 'black'),
#  (['define', 'feature', 'black', 'appearance'], 'hole'),
#  (['define', 'feature', 'black', 'hole'], 'appearance'),
#  (['feature', 'black', 'hole', 'appearance'], 'event'),
#  (['black', 'hole', 'appearance', 'event'], 'horizon'),
#  (['hole', 'appearance', 'event', 'horizon'], '—'),
#  (['appearance', 'event', 'horizon', '—'], 'boundary'),
#  (['event', 'horizon', '—', 'boundary'], 'spacetime'),
#  (['horizon', '—', 'boundary', 'spacetime'], 'matter'),
#  (['—', 'boundary', 'spacetime', 'matter'], 'light'),
#  (['boundary', 'spacetime', 'matter', 'light'], 'pass'),
#  (['spacetime', 'matter', 'light', 'pass'], 'inward'),
#  (['matter', 'light', 'pass', 'inward'], 'towards'),
#  (['light', 'pass', 'inward', 'towards'], 'mass'),
#  (['pass', 'inward', 'towards', 'mass'], 'black'),
#  (['inward', 'towards', 'mass', 'black'], 'hole'),
#  (['even', 'light', 'escape', 'inside'], 'nothing'),
#  (['nothing', 'light', 'escape', 'inside'], 'even'),
#  (['nothing', 'even', 'escape', 'inside'], 'light'),
#  (['nothing', 'even', 'light', 'inside'], 'escape'),
#  (['nothing', 'even', 'light', 'escape'], 'inside'),
#  (['even', 'light', 'escape', 'inside'], 'event'),
#  (['light', 'escape', 'inside', 'event'], 'horizon'),
#  (['horizon', 'refer', 'event', 'occur'], 'event'),
#  (['event', 'refer', 'event', 'occur'], 'horizon'),
#  (['event', 'horizon', 'event', 'occur'], 'refer'),
#  (['event', 'horizon', 'refer', 'occur'], 'event'),
#  (['event', 'horizon', 'refer', 'event'], 'occur'),
#  (['horizon', 'refer', 'event', 'occur'], 'within'),
#  (['refer', 'event', 'occur', 'within'], 'boundary'),
#  (['event', 'occur', 'within', 'boundary'], 'information'),
#  (['occur', 'within', 'boundary', 'information'], 'event'),
#  (['within', 'boundary', 'information', 'event'], 'reach'),
#  (['boundary', 'information', 'event', 'reach'], 'outside'),
#  (['information', 'event', 'reach', 'outside'], 'observer'),
#  (['event', 'reach', 'outside', 'observer'], 'make'),
#  (['reach', 'outside', 'observer', 'make'], 'impossible'),
#  (['outside', 'observer', 'make', 'impossible'], 'determine'),
#  (['observer', 'make', 'impossible', 'determine'], 'whether'),
#  (['make', 'impossible', 'determine', 'whether'], 'event'),
#  (['impossible', 'determine', 'whether', 'event'], 'occur'),
#  (['general', 'relativity', 'presence', 'mass'], 'predict'),
#  (['predict', 'relativity', 'presence', 'mass'], 'general'),
#  (['predict', 'general', 'presence', 'mass'], 'relativity'),
#  (['predict', 'general', 'relativity', 'mass'], 'presence'),
#  (['predict', 'general', 'relativity', 'presence'], 'mass'),
#  (['general', 'relativity', 'presence', 'mass'], 'deform'),
#  (['relativity', 'presence', 'mass', 'deform'], 'spacetime'),
#  (['presence', 'mass', 'deform', 'spacetime'], 'way'),
#  (['mass', 'deform', 'spacetime', 'way'], 'path'),
#  (['deform', 'spacetime', 'way', 'path'], 'take'),
#  (['spacetime', 'way', 'path', 'take'], 'particle'),
#  (['way', 'path', 'take', 'particle'], 'bend'),
#  (['path', 'take', 'particle', 'bend'], 'towards'),
#  (['take', 'particle', 'bend', 'towards'], 'mass'),
#  (['horizon', 'black', 'hole', 'deformation'], 'event'),
#  (['event', 'black', 'hole', 'deformation'], 'horizon'),
#  (['event', 'horizon', 'hole', 'deformation'], 'black'),
#  (['event', 'horizon', 'black', 'deformation'], 'hole'),
#  (['event', 'horizon', 'black', 'hole'], 'deformation'),
#  (['horizon', 'black', 'hole', 'deformation'], 'become'),
#  (['black', 'hole', 'deformation', 'become'], 'strong'),
#  (['hole', 'deformation', 'become', 'strong'], 'path'),
#  (['deformation', 'become', 'strong', 'path'], 'lead'),
#  (['become', 'strong', 'path', 'lead'], 'away'),
#  (['strong', 'path', 'lead', 'away'], 'black'),
#  (['path', 'lead', 'away', 'black'], 'hole'),
#  (['observer', 'clock', 'near', 'black'], 'distant'),
#  (['distant', 'clock', 'near', 'black'], 'observer'),
#  (['distant', 'observer', 'near', 'black'], 'clock'),
#  (['distant', 'observer', 'clock', 'black'], 'near'),
#  (['distant', 'observer', 'clock', 'near'], 'black'),
#  (['observer', 'clock', 'near', 'black'], 'hole'),
#  (['clock', 'near', 'black', 'hole'], 'would'),
#  (['near', 'black', 'hole', 'would'], 'appear'),
#  (['black', 'hole', 'would', 'appear'], 'tick'),
#  (['hole', 'would', 'appear', 'tick'], 'slowly'),
#  (['would', 'appear', 'tick', 'slowly'], 'far'),
#  (['appear', 'tick', 'slowly', 'far'], 'away'),
#  (['tick', 'slowly', 'far', 'away'], 'black'),
#  (['slowly', 'far', 'away', 'black'], 'hole'),
#  (['effect', 'know', 'gravitational', 'time'], 'due'),
#  (['due', 'know', 'gravitational', 'time'], 'effect'),
#  (['due', 'effect', 'gravitational', 'time'], 'know'),
#  (['due', 'effect', 'know', 'time'], 'gravitational'),
#  (['due', 'effect', 'know', 'gravitational'], 'time'),
#  (['effect', 'know', 'gravitational', 'time'], 'dilation'),
#  (['know', 'gravitational', 'time', 'dilation'], 'object'),
#  (['gravitational', 'time', 'dilation', 'object'], 'fall'),
#  (['time', 'dilation', 'object', 'fall'], 'black'),
#  (['dilation', 'object', 'fall', 'black'], 'hole'),
#  (['object', 'fall', 'black', 'hole'], 'appear'),
#  (['fall', 'black', 'hole', 'appear'], 'slow'),
#  (['black', 'hole', 'appear', 'slow'], 'approach'),
#  (['hole', 'appear', 'slow', 'approach'], 'event'),
#  (['appear', 'slow', 'approach', 'event'], 'horizon'),
#  (['slow', 'approach', 'event', 'horizon'], 'take'),
#  (['approach', 'event', 'horizon', 'take'], 'infinite'),
#  (['event', 'horizon', 'take', 'infinite'], 'time'),
#  (['horizon', 'take', 'infinite', 'time'], 'reach'),
#  (['fall', 'object', 'fade', 'away'], 'eventually'),
#  (['eventually', 'object', 'fade', 'away'], 'fall'),
#  (['eventually', 'fall', 'fade', 'away'], 'object'),
#  (['eventually', 'fall', 'object', 'away'], 'fade'),
#  (['eventually', 'fall', 'object', 'fade'], 'away'),
#  (['fall', 'object', 'fade', 'away'], 'long'),
#  (['object', 'fade', 'away', 'long'], 'see'),
#  (['process', 'happen', 'rapidly', 'object'], 'typically'),
#  (['typically', 'happen', 'rapidly', 'object'], 'process'),
#  (['typically', 'process', 'rapidly', 'object'], 'happen'),
#  (['typically', 'process', 'happen', 'object'], 'rapidly'),
#  (['typically', 'process', 'happen', 'rapidly'], 'object'),
#  (['process', 'happen', 'rapidly', 'object'], 'disappear'),
#  (['happen', 'rapidly', 'object', 'disappear'], 'view'),
#  (['rapidly', 'object', 'disappear', 'view'], 'within'),
#  (['object', 'disappear', 'view', 'within'], 'less'),
#  (['disappear', 'view', 'within', 'less'], 'second'),
#  (['clock', 'appear', 'tick', 'normally'], 'accord'),
#  (['accord', 'appear', 'tick', 'normally'], 'clock'),
#  (['accord', 'clock', 'tick', 'normally'], 'appear'),
#  (['accord', 'clock', 'appear', 'normally'], 'tick'),
#  (['accord', 'clock', 'appear', 'tick'], 'normally'),
#  (['clock', 'appear', 'tick', 'normally'], 'cross'),
#  (['appear', 'tick', 'normally', 'cross'], 'event'),
#  (['tick', 'normally', 'cross', 'event'], 'horizon'),
#  (['normally', 'cross', 'event', 'horizon'], 'finite'),
#  (['cross', 'event', 'horizon', 'finite'], 'time'),
#  (['event', 'horizon', 'finite', 'time'], 'without'),
#  (['horizon', 'finite', 'time', 'without'], 'note'),
#  (['finite', 'time', 'without', 'note'], 'singular'),
#  (['time', 'without', 'note', 'singular'], 'behaviour'),
#  (['general', 'relativity', 'impossible', 'determine'], 'classical'),
#  (['classical', 'relativity', 'impossible', 'determine'], 'general'),
#  (['classical', 'general', 'impossible', 'determine'], 'relativity'),
#  (['classical', 'general', 'relativity', 'determine'], 'impossible'),
#  (['classical', 'general', 'relativity', 'impossible'], 'determine'),
#  (['general', 'relativity', 'impossible', 'determine'], 'location'),
#  (['relativity', 'impossible', 'determine', 'location'], 'event'),
#  (['impossible', 'determine', 'location', 'event'], 'horizon'),
#  (['determine', 'location', 'event', 'horizon'], 'local'),
#  (['location', 'event', 'horizon', 'local'], 'observation'),
#  (['event', 'horizon', 'local', 'observation'], 'due'),
#  (['horizon', 'local', 'observation', 'due'], 'einstein'),
#  (['local', 'observation', 'due', 'einstein'], 'equivalence'),
#  (['observation', 'due', 'einstein', 'equivalence'], 'principle'),
#  (['main', 'article', 'gravitational', 'singularity'], 'singularity'),
#  (['singularity', 'article', 'gravitational', 'singularity'], 'main'),
#  (['singularity', 'main', 'gravitational', 'singularity'], 'article'),
#  (['singularity', 'main', 'article', 'singularity'], 'gravitational'),
#  (['singularity', 'main', 'article', 'gravitational'], 'singularity'),
#  (['main', 'article', 'gravitational', 'singularity'], 'centre'),
#  (['article', 'gravitational', 'singularity', 'centre'], 'black'),
#  (['gravitational', 'singularity', 'centre', 'black'], 'hole'),
#  (['singularity', 'centre', 'black', 'hole'], 'describe'),
#  (['centre', 'black', 'hole', 'describe'], 'general'),
#  (['black', 'hole', 'describe', 'general'], 'relativity'),
#  (['hole', 'describe', 'general', 'relativity'], 'may'),
#  (['describe', 'general', 'relativity', 'may'], 'lie'),
#  (['general', 'relativity', 'may', 'lie'], 'gravitational'),
#  (['relativity', 'may', 'lie', 'gravitational'], 'singularity'),
#  (['may', 'lie', 'gravitational', 'singularity'], 'region'),
#  (['lie', 'gravitational', 'singularity', 'region'], 'spacetime'),
#  (['gravitational', 'singularity', 'region', 'spacetime'], 'curvature'),
#  (['singularity', 'region', 'spacetime', 'curvature'], 'become'),
#  (['region', 'spacetime', 'curvature', 'become'], 'infinite'),
#  (['rotating', 'black', 'hole', 'region'], 'non'),
#  (['non', 'black', 'hole', 'region'], 'rotating'),
#  (['non', 'rotating', 'hole', 'region'], 'black'),
#  (['non', 'rotating', 'black', 'region'], 'hole'),
#  (['non', 'rotating', 'black', 'hole'], 'region'),
#  (['rotating', 'black', 'hole', 'region'], 'take'),
#  (['black', 'hole', 'region', 'take'], 'shape'),
#  (['hole', 'region', 'take', 'shape'], 'single'),
#  (['region', 'take', 'shape', 'single'], 'point'),
#  (['singular', 'region', 'zero', 'volume'], 'case'),
#  (['case', 'region', 'zero', 'volume'], 'singular'),
#  (['case', 'singular', 'zero', 'volume'], 'region'),
#  (['case', 'singular', 'region', 'volume'], 'zero'),
#  (['case', 'singular', 'region', 'zero'], 'volume'),
#  (['show', 'singular', 'region', 'contain'], 'also'),
#  (['also', 'singular', 'region', 'contain'], 'show'),
#  (['also', 'show', 'region', 'contain'], 'singular'),
#  (['also', 'show', 'singular', 'contain'], 'region'),
#  (['also', 'show', 'singular', 'region'], 'contain'),
#  (['show', 'singular', 'region', 'contain'], 'mass'),
#  (['singular', 'region', 'contain', 'mass'], 'black'),
#  (['region', 'contain', 'mass', 'black'], 'hole'),
#  (['contain', 'mass', 'black', 'hole'], 'solution'),
#  (['region', 'thus', 'think', 'infinite'], 'singular'),
#  (['singular', 'thus', 'think', 'infinite'], 'region'),
#  (['singular', 'region', 'think', 'infinite'], 'thus'),
#  (['singular', 'region', 'thus', 'infinite'], 'think'),
#  (['singular', 'region', 'thus', 'think'], 'infinite'),
#  (['region', 'thus', 'think', 'infinite'], 'density'),
#  (['fall', 'schwarzschild', 'black', 'hole'], 'observer'),
#  (['observer', 'schwarzschild', 'black', 'hole'], 'fall'),
#  (['observer', 'fall', 'black', 'hole'], 'schwarzschild'),
#  (['observer', 'fall', 'schwarzschild', 'hole'], 'black'),
#  (['observer', 'fall', 'schwarzschild', 'black'], 'hole'),
#  (['fall', 'schwarzschild', 'black', 'hole'], 'avoid'),
#  (['schwarzschild', 'black', 'hole', 'avoid'], 'carry'),
#  (['black', 'hole', 'avoid', 'carry'], 'singularity'),
#  (['hole', 'avoid', 'carry', 'singularity'], 'cross'),
#  (['avoid', 'carry', 'singularity', 'cross'], 'event'),
#  (['carry', 'singularity', 'cross', 'event'], 'horizon'),
#  (['charge', 'rotate', 'black', 'hole'], 'case'),
#  (['case', 'rotate', 'black', 'hole'], 'charge'),
#  (['case', 'charge', 'black', 'hole'], 'rotate'),
#  (['case', 'charge', 'rotate', 'hole'], 'black'),
#  (['case', 'charge', 'rotate', 'black'], 'hole'),
#  (['charge', 'rotate', 'black', 'hole'], 'possible'),
#  (['rotate', 'black', 'hole', 'possible'], 'avoid'),
#  (['black', 'hole', 'possible', 'avoid'], 'singularity'),
#  (['travel', 'another', 'universe', 'however'], 'possibility'),
#  (['possibility', 'another', 'universe', 'however'], 'travel'),
#  (['possibility', 'travel', 'universe', 'however'], 'another'),
#  (['possibility', 'travel', 'another', 'however'], 'universe'),
#  (['possibility', 'travel', 'another', 'universe'], 'however'),
#  (['travel', 'another', 'universe', 'however'], 'theoretical'),
#  (['another', 'universe', 'however', 'theoretical'], 'since'),
#  (['universe', 'however', 'theoretical', 'since'], 'perturbation'),
#  (['however', 'theoretical', 'since', 'perturbation'], 'would'),
#  (['theoretical', 'since', 'perturbation', 'would'], 'destroy'),
#  (['since', 'perturbation', 'would', 'destroy'], 'possibility'),
#  (['singularity', 'general', 'relativity', 'commonly'], 'appearance'),
#  (['appearance', 'general', 'relativity', 'commonly'], 'singularity'),
#  (['appearance', 'singularity', 'relativity', 'commonly'], 'general'),
#  (['appearance', 'singularity', 'general', 'commonly'], 'relativity'),
#  (['appearance', 'singularity', 'general', 'relativity'], 'commonly'),
#  (['singularity', 'general', 'relativity', 'commonly'], 'perceive'),
#  (['general', 'relativity', 'commonly', 'perceive'], 'signal'),
#  (['relativity', 'commonly', 'perceive', 'signal'], 'breakdown'),
#  (['commonly', 'perceive', 'signal', 'breakdown'], 'theory'),
#  (['however', 'expect'], 'breakdown'),
#  (['breakdown', 'expect'], 'however'),
#  (['breakdown', 'however'], 'expect'),
#  (['expect', 'theory', 'feature', 'singularity'], 'generally'),
#  (['generally', 'theory', 'feature', 'singularity'], 'expect'),
#  (['generally', 'expect', 'feature', 'singularity'], 'theory'),
#  (['generally', 'expect', 'theory', 'singularity'], 'feature'),
#  (['generally', 'expect', 'theory', 'feature'], 'singularity'),
#  (['rotating', 'black', 'hole', 'photon'], 'non'),
#  (['non', 'black', 'hole', 'photon'], 'rotating'),
#  (['non', 'rotating', 'hole', 'photon'], 'black'),
#  (['non', 'rotating', 'black', 'photon'], 'hole'),
#  (['non', 'rotating', 'black', 'hole'], 'photon'),
#  (['rotating', 'black', 'hole', 'photon'], 'sphere'),
#  (['black', 'hole', 'photon', 'sphere'], 'radius'),
#  (['hole', 'photon', 'sphere', 'radius'], '1.5'),
#  (['photon', 'sphere', 'radius', '1.5'], 'time'),
#  (['sphere', 'radius', '1.5', 'time'], 'schwarzschild'),
#  (['radius', '1.5', 'time', 'schwarzschild'], 'radius'),
#  (['light', 'reach', 'outside', 'observer'], 'hence'),
#  (['hence', 'reach', 'outside', 'observer'], 'light'),
#  (['hence', 'light', 'outside', 'observer'], 'reach'),
#  (['hence', 'light', 'reach', 'observer'], 'outside'),
#  (['hence', 'light', 'reach', 'outside'], 'observer'),
#  (['light', 'reach', 'outside', 'observer'], 'photon'),
#  (['reach', 'outside', 'observer', 'photon'], 'sphere'),
#  (['outside', 'observer', 'photon', 'sphere'], 'must'),
#  (['observer', 'photon', 'sphere', 'must'], 'emit'),
#  (['photon', 'sphere', 'must', 'emit'], 'object'),
#  (['sphere', 'must', 'emit', 'object'], 'photon'),
#  (['must', 'emit', 'object', 'photon'], 'sphere'),
#  (['emit', 'object', 'photon', 'sphere'], 'event'),
#  (['object', 'photon', 'sphere', 'event'], 'horizon'),
#  (['black', 'hole', 'surround', 'region'], 'rotate'),
#  (['rotate', 'hole', 'surround', 'region'], 'black'),
#  (['rotate', 'black', 'surround', 'region'], 'hole'),
#  (['rotate', 'black', 'hole', 'region'], 'surround'),
#  (['rotate', 'black', 'hole', 'surround'], 'region'),
#  (['black', 'hole', 'surround', 'region'], 'spacetime'),
#  (['hole', 'surround', 'region', 'spacetime'], 'impossible'),
#  (['surround', 'region', 'spacetime', 'impossible'], 'stand'),
#  (['region', 'spacetime', 'impossible', 'stand'], 'still'),
#  (['spacetime', 'impossible', 'stand', 'still'], 'call'),
#  (['impossible', 'stand', 'still', 'call'], 'ergosphere'),
#  (['near', 'rotate', 'mass', 'tend'], 'object'),
#  (['object', 'rotate', 'mass', 'tend'], 'near'),
#  (['object', 'near', 'mass', 'tend'], 'rotate'),
#  (['object', 'near', 'rotate', 'tend'], 'mass'),
#  (['object', 'near', 'rotate', 'mass'], 'tend'),
#  (['near', 'rotate', 'mass', 'tend'], 'start'),
#  (['rotate', 'mass', 'tend', 'start'], 'move'),
#  (['mass', 'tend', 'start', 'move'], 'direction'),
#  (['tend', 'start', 'move', 'direction'], 'rotation'),
#  (['radiation', 'escape', 'normally', 'ergosphere'], 'object'),
#  (['object', 'escape', 'normally', 'ergosphere'], 'radiation'),
#  (['object', 'radiation', 'normally', 'ergosphere'], 'escape'),
#  (['object', 'radiation', 'escape', 'ergosphere'], 'normally'),
#  (['object', 'radiation', 'escape', 'normally'], 'ergosphere'),
#  (['process', 'object', 'emerge', 'ergosphere'], 'penrose'),
#  (['penrose', 'object', 'emerge', 'ergosphere'], 'process'),
#  (['penrose', 'process', 'emerge', 'ergosphere'], 'object'),
#  (['penrose', 'process', 'object', 'ergosphere'], 'emerge'),
#  (['penrose', 'process', 'object', 'emerge'], 'ergosphere'),
#  (['process', 'object', 'emerge', 'ergosphere'], 'energy'),
#  (['object', 'emerge', 'ergosphere', 'energy'], 'enter'),
#  (['rotation', 'black', 'hole', 'slow'], 'thereby'),
#  (['thereby', 'black', 'hole', 'slow'], 'rotation'),
#  (['thereby', 'rotation', 'hole', 'slow'], 'black'),
#  (['thereby', 'rotation', 'black', 'slow'], 'hole'),
#  (['thereby', 'rotation', 'black', 'hole'], 'slow'),
#  (['demonstrate', 'event', 'horizon', 'form'], 'penrose'),
#  (['penrose', 'event', 'horizon', 'form'], 'demonstrate'),
#  (['penrose', 'demonstrate', 'horizon', 'form'], 'event'),
#  (['penrose', 'demonstrate', 'event', 'form'], 'horizon'),
#  (['penrose', 'demonstrate', 'event', 'horizon'], 'form'),
#  (['demonstrate', 'event', 'horizon', 'form'], 'general'),
#  (['event', 'horizon', 'form', 'general'], 'relativity'),
#  (['horizon', 'form', 'general', 'relativity'], 'without'),
#  (['form', 'general', 'relativity', 'without'], 'quantum'),
#  (['general', 'relativity', 'without', 'quantum'], 'mechanic'),
#  (['relativity', 'without', 'quantum', 'mechanic'], 'require'),
#  (['without', 'quantum', 'mechanic', 'require'], 'singularity'),
#  (['quantum', 'mechanic', 'require', 'singularity'], 'form'),
#  (['mechanic', 'require', 'singularity', 'form'], 'within'),
#  (['one', 'various', 'type', 'compact'], 'result'),
#  (['result', 'various', 'type', 'compact'], 'one'),
#  (['result', 'one', 'type', 'compact'], 'various'),
#  (['result', 'one', 'various', 'compact'], 'type'),
#  (['result', 'one', 'various', 'type'], 'compact'),
#  (['one', 'various', 'type', 'compact'], 'star'),
#  (['hole', 'could', 'seed', 'supermassive'], 'black'),
#  (['black', 'could', 'seed', 'supermassive'], 'hole'),
#  (['black', 'hole', 'seed', 'supermassive'], 'could'),
#  (['black', 'hole', 'could', 'supermassive'], 'seed'),
#  (['black', 'hole', 'could', 'seed'], 'supermassive'),
#  (['hole', 'could', 'seed', 'supermassive'], 'black'),
#  (['could', 'seed', 'supermassive', 'black'], 'hole'),
#  (['seed', 'supermassive', 'black', 'hole'], 'find'),
#  (['supermassive', 'black', 'hole', 'find'], 'centre'),
#  (['black', 'hole', 'find', 'centre'], 'galaxy'),
#  (['object', 'find', 'observation', 'young'], 'candidate'),
#  (['candidate', 'find', 'observation', 'young'], 'object'),
#  (['candidate', 'object', 'observation', 'young'], 'find'),
#  (['candidate', 'object', 'find', 'young'], 'observation'),
#  (['candidate', 'object', 'find', 'observation'], 'young'),
#  (['object', 'find', 'observation', 'young'], 'universe'),
#  (['release', 'gravitational', 'collapse', 'emit'], 'energy'),
#  (['energy', 'gravitational', 'collapse', 'emit'], 'release'),
#  (['energy', 'release', 'collapse', 'emit'], 'gravitational'),
#  (['energy', 'release', 'gravitational', 'emit'], 'collapse'),
#  (['energy', 'release', 'gravitational', 'collapse'], 'emit'),
#  (['release', 'gravitational', 'collapse', 'emit'], 'quickly'),
#  (['gravitational', 'collapse', 'emit', 'quickly'], 'outside'),
#  (['collapse', 'emit', 'quickly', 'outside'], 'observer'),
#  (['emit', 'quickly', 'outside', 'observer'], 'actually'),
#  (['quickly', 'outside', 'observer', 'actually'], 'see'),
#  (['outside', 'observer', 'actually', 'see'], 'end'),
#  (['observer', 'actually', 'see', 'end'], 'process'),
#  (['external', 'observer', 'never', 'see'], 'thus'),
#  (['thus', 'observer', 'never', 'see'], 'external'),
#  (['thus', 'external', 'never', 'see'], 'observer'),
#  (['thus', 'external', 'observer', 'see'], 'never'),
#  (['thus', 'external', 'observer', 'never'], 'see'),
#  (['external', 'observer', 'never', 'see'], 'formation'),
#  (['observer', 'never', 'see', 'formation'], 'event'),
#  (['never', 'see', 'formation', 'event'], 'horizon'),
#  (['black', 'hole', 'big', 'bang'], 'primordial'),
#  (['primordial', 'hole', 'big', 'bang'], 'black'),
#  (['primordial', 'black', 'big', 'bang'], 'hole'),
#  (['primordial', 'black', 'hole', 'bang'], 'big'),
#  (['primordial', 'black', 'hole', 'big'], 'bang'),
#  (['black', 'hole', 'big', 'bang'], 'gravitational'),
#  (['hole', 'big', 'bang', 'gravitational'], 'collapse'),
#  (['big', 'bang', 'gravitational', 'collapse'], 'require'),
#  (['bang', 'gravitational', 'collapse', 'require'], 'great'),
#  (['gravitational', 'collapse', 'require', 'great'], 'density'),
#  (['energy', 'collision', 'gravitational', 'collapse'], 'high'),
#  (['high', 'collision', 'gravitational', 'collapse'], 'energy'),
#  (['high', 'energy', 'gravitational', 'collapse'], 'collision'),
#  (['high', 'energy', 'collision', 'collapse'], 'gravitational'),
#  (['high', 'energy', 'collision', 'gravitational'], 'collapse'),
#  (['energy', 'collision', 'gravitational', 'collapse'], 'process'),
#  (['collision', 'gravitational', 'collapse', 'process'], 'could'),
#  (['gravitational', 'collapse', 'process', 'could'], 'create'),
#  (['collapse', 'process', 'could', 'create'], 'black'),
#  (['process', 'could', 'create', 'black'], 'hole'),
#  (['must', 'low', 'limit', 'mass'], 'suggest'),
#  (['suggest', 'low', 'limit', 'mass'], 'must'),
#  (['suggest', 'must', 'limit', 'mass'], 'low'),
#  (['suggest', 'must', 'low', 'mass'], 'limit'),
#  (['suggest', 'must', 'low', 'limit'], 'mass'),
#  (['must', 'low', 'limit', 'mass'], 'black'),
#  (['low', 'limit', 'mass', 'black'], 'hole'),
#  (['black', 'hole', 'form', 'continue'], 'growth'),
#  (['growth', 'hole', 'form', 'continue'], 'black'),
#  (['growth', 'black', 'form', 'continue'], 'hole'),
#  (['growth', 'black', 'hole', 'continue'], 'form'),
#  (['growth', 'black', 'hole', 'form'], 'continue'),
#  (['black', 'hole', 'form', 'continue'], 'grow'),
#  (['hole', 'form', 'continue', 'grow'], 'absorb'),
#  (['form', 'continue', 'grow', 'absorb'], 'additional'),
#  (['continue', 'grow', 'absorb', 'additional'], 'matter'),
#  (['process', 'one', 'possible', 'way'], 'growth'),
#  (['growth', 'one', 'possible', 'way'], 'process'),
#  (['growth', 'process', 'possible', 'way'], 'one'),
#  (['growth', 'process', 'one', 'way'], 'possible'),
#  (['growth', 'process', 'one', 'possible'], 'way'),
#  (['process', 'one', 'possible', 'way'], 'supermassive'),
#  (['one', 'possible', 'way', 'supermassive'], 'black'),
#  (['possible', 'way', 'supermassive', 'black'], 'hole'),
#  (['way', 'supermassive', 'black', 'hole'], 'may'),
#  (['supermassive', 'black', 'hole', 'may'], 'form'),
#  (['black', 'hole', 'may', 'form'], 'although'),
#  (['hole', 'may', 'form', 'although'], 'formation'),
#  (['may', 'form', 'although', 'formation'], 'supermassive'),
#  (['form', 'although', 'formation', 'supermassive'], 'black'),
#  (['although', 'formation', 'supermassive', 'black'], 'hole'),
#  (['formation', 'supermassive', 'black', 'hole'], 'still'),
#  (['supermassive', 'black', 'hole', 'still'], 'open'),
#  (['black', 'hole', 'still', 'open'], 'field'),
#  (['hole', 'still', 'open', 'field'], 'research'),
#  (['hole', 'also', 'merge', 'object'], 'black'),
#  (['black', 'also', 'merge', 'object'], 'hole'),
#  (['black', 'hole', 'merge', 'object'], 'also'),
#  (['black', 'hole', 'also', 'object'], 'merge'),
#  (['black', 'hole', 'also', 'merge'], 'object'),
#  (['hole', 'also', 'merge', 'object'], 'star'),
#  (['also', 'merge', 'object', 'star'], 'even'),
#  (['merge', 'object', 'star', 'even'], 'black'),
#  (['object', 'star', 'even', 'black'], 'hole'),
#  (['become', 'know', 'hawk', 'radiation'], 'effect'),
#  (['effect', 'know', 'hawk', 'radiation'], 'become'),
#  (['effect', 'become', 'hawk', 'radiation'], 'know'),
#  (['effect', 'become', 'know', 'radiation'], 'hawk'),
#  (['effect', 'become', 'know', 'hawk'], 'radiation'),
#  (['quantum', 'field', 'theory', 'static'], 'apply'),
#  (['apply', 'field', 'theory', 'static'], 'quantum'),
#  (['apply', 'quantum', 'theory', 'static'], 'field'),
#  (['apply', 'quantum', 'field', 'static'], 'theory'),
#  (['apply', 'quantum', 'field', 'theory'], 'static'),
#  (['quantum', 'field', 'theory', 'static'], 'black'),
#  (['field', 'theory', 'static', 'black'], 'hole'),
#  (['theory', 'static', 'black', 'hole'], 'background'),
#  (['static', 'black', 'hole', 'background'], 'determine'),
#  (['black', 'hole', 'background', 'determine'], 'black'),
#  (['hole', 'background', 'determine', 'black'], 'hole'),
#  (['background', 'determine', 'black', 'hole'], 'emit'),
#  (['determine', 'black', 'hole', 'emit'], 'particle'),
#  (['black', 'hole', 'emit', 'particle'], 'display'),
#  (['hole', 'emit', 'particle', 'display'], 'perfect'),
#  (['emit', 'particle', 'display', 'perfect'], 'black'),
#  (['particle', 'display', 'perfect', 'black'], 'body'),
#  (['display', 'perfect', 'black', 'body'], 'spectrum'),
#  (['theory', 'black', 'hole', 'radiation'], 'hawking'),
#  (['hawking', 'black', 'hole', 'radiation'], 'theory'),
#  (['hawking', 'theory', 'hole', 'radiation'], 'black'),
#  (['hawking', 'theory', 'black', 'radiation'], 'hole'),
#  (['hawking', 'theory', 'black', 'hole'], 'radiation'),
#  (['theory', 'black', 'hole', 'radiation'], 'correct'),
#  (['black', 'hole', 'radiation', 'correct'], 'black'),
#  (['hole', 'radiation', 'correct', 'black'], 'hole'),
#  (['radiation', 'correct', 'black', 'hole'], 'expect'),
#  (['correct', 'black', 'hole', 'expect'], 'shrink'),
#  (['black', 'hole', 'expect', 'shrink'], 'evaporate'),
#  (['hole', 'expect', 'shrink', 'evaporate'], 'time'),
#  (['expect', 'shrink', 'evaporate', 'time'], 'lose'),
#  (['shrink', 'evaporate', 'time', 'lose'], 'mass'),
#  (['evaporate', 'time', 'lose', 'mass'], 'emission'),
#  (['time', 'lose', 'mass', 'emission'], 'photon'),
#  (['lose', 'mass', 'emission', 'photon'], 'particle'),
#  (['thermal', 'spectrum', 'proportional', 'surface'], 'temperature'),
#  (['temperature', 'spectrum', 'proportional', 'surface'], 'thermal'),
#  (['temperature', 'thermal', 'proportional', 'surface'], 'spectrum'),
#  (['temperature', 'thermal', 'spectrum', 'surface'], 'proportional'),
#  (['temperature', 'thermal', 'spectrum', 'proportional'], 'surface'),
#  (['thermal', 'spectrum', 'proportional', 'surface'], 'gravity'),
#  (['spectrum', 'proportional', 'surface', 'gravity'], 'black'),
#  (['proportional', 'surface', 'gravity', 'black'], 'hole'),
#  (['surface', 'gravity', 'black', 'hole'], 'schwarzschild'),
#  (['gravity', 'black', 'hole', 'schwarzschild'], 'black'),
#  (['black', 'hole', 'schwarzschild', 'black'], 'hole'),
#  (['hole', 'schwarzschild', 'black', 'hole'], 'inversely'),
#  (['schwarzschild', 'black', 'hole', 'inversely'], 'proportional'),
#  (['black', 'hole', 'inversely', 'proportional'], 'mass'),
#  (['large', 'black', 'hole', 'emit'], 'hence'),
#  (['hence', 'black', 'hole', 'emit'], 'large'),
#  (['hence', 'large', 'hole', 'emit'], 'black'),
#  (['hence', 'large', 'black', 'emit'], 'hole'),
#  (['hence', 'large', 'black', 'hole'], 'emit'),
#  (['large', 'black', 'hole', 'emit'], 'less'),
#  (['black', 'hole', 'emit', 'less'], 'radiation'),
#  (['hole', 'emit', 'less', 'radiation'], 'small'),
#  (['emit', 'less', 'radiation', 'small'], 'black'),
#  (['less', 'radiation', 'small', 'black'], 'hole'),
#  (['less', '2.7xa0', 'k', 'temperature'], 'far'),
#  (['far', '2.7xa0', 'k', 'temperature'], 'less'),
#  (['far', 'less', 'k', 'temperature'], '2.7xa0'),
#  (['far', 'less', '2.7xa0', 'temperature'], 'k'),
#  (['far', 'less', '2.7xa0', 'k'], 'temperature'),
#  (['less', '2.7xa0', 'k', 'temperature'], 'cosmic'),
#  (['2.7xa0', 'k', 'temperature', 'cosmic'], 'microwave'),
#  (['k', 'temperature', 'cosmic', 'microwave'], 'background'),
#  (['temperature', 'cosmic', 'microwave', 'background'], 'radiation'),
#  (['mass', 'large', 'black', 'hole'], 'stellar'),
#  (['stellar', 'large', 'black', 'hole'], 'mass'),
#  (['stellar', 'mass', 'black', 'hole'], 'large'),
#  (['stellar', 'mass', 'large', 'hole'], 'black'),
#  (['stellar', 'mass', 'large', 'black'], 'hole'),
#  (['mass', 'large', 'black', 'hole'], 'receive'),
#  (['large', 'black', 'hole', 'receive'], 'mass'),
#  (['black', 'hole', 'receive', 'mass'], 'cosmic'),
#  (['hole', 'receive', 'mass', 'cosmic'], 'microwave'),
#  (['receive', 'mass', 'cosmic', 'microwave'], 'background'),
#  (['mass', 'cosmic', 'microwave', 'background'], 'emit'),
#  (['cosmic', 'microwave', 'background', 'emit'], 'hawk'),
#  (['microwave', 'background', 'emit', 'hawk'], 'radiation'),
#  (['background', 'emit', 'hawk', 'radiation'], 'thus'),
#  (['emit', 'hawk', 'radiation', 'thus'], 'grow'),
#  (['hawk', 'radiation', 'thus', 'grow'], 'instead'),
#  (['radiation', 'thus', 'grow', 'instead'], 'shrink'),
#  (['temperature', 'large', '2.7xa0', 'k'], 'hawk'),
#  (['hawk', 'large', '2.7xa0', 'k'], 'temperature'),
#  (['hawk', 'temperature', '2.7xa0', 'k'], 'large'),
#  (['hawk', 'temperature', 'large', 'k'], '2.7xa0'),
#  (['hawk', 'temperature', 'large', '2.7xa0'], 'k'),
#  (['temperature', 'large', '2.7xa0', 'k'], 'black'),
#  (['large', '2.7xa0', 'k', 'black'], 'hole'),
#  (['2.7xa0', 'k', 'black', 'hole'], 'would'),
#  (['k', 'black', 'hole', 'would'], 'need'),
#  (['black', 'hole', 'would', 'need'], 'mass'),
#  (['hole', 'would', 'need', 'mass'], 'less'),
#  (['would', 'need', 'mass', 'less'], 'moon'),
#  (['hole', 'small', 'radiation', 'effect'], 'black'),
#  (['black', 'small', 'radiation', 'effect'], 'hole'),
#  (['black', 'hole', 'radiation', 'effect'], 'small'),
#  (['black', 'hole', 'small', 'effect'], 'radiation'),
#  (['black', 'hole', 'small', 'radiation'], 'effect'),
#  (['hole', 'small', 'radiation', 'effect'], 'expect'),
#  (['small', 'radiation', 'effect', 'expect'], 'become'),
#  (['radiation', 'effect', 'expect', 'become'], 'strong'),
#  (['mass', 'black', 'hole', 'expect'], 'low'),
#  (['low', 'black', 'hole', 'expect'], 'mass'),
#  (['low', 'mass', 'hole', 'expect'], 'black'),
#  (['low', 'mass', 'black', 'expect'], 'hole'),
#  (['low', 'mass', 'black', 'hole'], 'expect'),
#  (['mass', 'black', 'hole', 'expect'], 'evaporate'),
#  (['black', 'hole', 'expect', 'evaporate'], 'even'),
#  (['hole', 'expect', 'evaporate', 'even'], 'fast'),
#  (['black', 'hole', 'existence', 'sometimes'], 'example'),
#  (['example', 'hole', 'existence', 'sometimes'], 'black'),
#  (['example', 'black', 'existence', 'sometimes'], 'hole'),
#  (['example', 'black', 'hole', 'sometimes'], 'existence'),
#  (['example', 'black', 'hole', 'existence'], 'sometimes'),
#  (['black', 'hole', 'existence', 'sometimes'], 'infer'),
#  (['hole', 'existence', 'sometimes', 'infer'], 'observe'),
#  (['existence', 'sometimes', 'infer', 'observe'], 'gravitational'),
#  (['sometimes', 'infer', 'observe', 'gravitational'], 'influence'),
#  (['infer', 'observe', 'gravitational', 'influence'], 'surrounding'),
#  (['black', 'hole', '—', 'show'], 'visible'),
#  (['visible', 'hole', '—', 'show'], 'black'),
#  (['visible', 'black', '—', 'show'], 'hole'),
#  (['visible', 'black', 'hole', 'show'], '—'),
#  (['visible', 'black', 'hole', '—'], 'show'),
#  (['black', 'hole', '—', 'show'], 'black'),
#  (['hole', '—', 'show', 'black'], 'loss'),
#  (['—', 'show', 'black', 'loss'], 'light'),
#  (['show', 'black', 'loss', 'light'], 'within'),
#  (['black', 'loss', 'light', 'within'], 'dark'),
#  (['loss', 'light', 'within', 'dark'], 'region'),
#  (['gas', 'edge', 'event', 'horizon'], 'instead'),
#  (['instead', 'edge', 'event', 'horizon'], 'gas'),
#  (['instead', 'gas', 'event', 'horizon'], 'edge'),
#  (['instead', 'gas', 'edge', 'horizon'], 'event'),
#  (['instead', 'gas', 'edge', 'event'], 'horizon'),
#  (['gas', 'edge', 'event', 'horizon'], 'define'),
#  (['edge', 'event', 'horizon', 'define'], 'black'),
#  (['event', 'horizon', 'define', 'black'], 'hole'),
#  (['image', 'display', 'ring', 'like'], 'publish'),
#  (['publish', 'display', 'ring', 'like'], 'image'),
#  (['publish', 'image', 'ring', 'like'], 'display'),
#  (['publish', 'image', 'display', 'like'], 'ring'),
#  (['publish', 'image', 'display', 'ring'], 'like'),
#  (['image', 'display', 'ring', 'like'], 'structure'),
#  (['display', 'ring', 'like', 'structure'], 'circular'),
#  (['ring', 'like', 'structure', 'circular'], 'shadow'),
#  (['like', 'structure', 'circular', 'shadow'], 'see'),
#  (['structure', 'circular', 'shadow', 'see'], 'm87'),
#  (['circular', 'shadow', 'see', 'm87'], '*'),
#  (['shadow', 'see', 'm87', '*'], 'black'),
#  (['see', 'm87', '*', 'black'], 'hole'),
#  (['m87', '*', 'black', 'hole'], 'image'),
#  (['*', 'black', 'hole', 'image'], 'create'),
#  (['black', 'hole', 'image', 'create'], 'use'),
#  (['hole', 'image', 'create', 'use'], 'technique'),
#  (['image', 'create', 'use', 'technique'], 'm87'),
#  (['create', 'use', 'technique', 'm87'], 'black'),
#  (['use', 'technique', 'm87', 'black'], 'hole'),
#  (['study', 'black', 'hole', 'predict'], 'theoretical'),
#  (['theoretical', 'black', 'hole', 'predict'], 'study'),
#  (['theoretical', 'study', 'hole', 'predict'], 'black'),
#  (['theoretical', 'study', 'black', 'predict'], 'hole'),
#  (['theoretical', 'study', 'black', 'hole'], 'predict'),
#  (['study', 'black', 'hole', 'predict'], 'existence'),
#  (['black', 'hole', 'predict', 'existence'], 'magnetic'),
#  (['hole', 'predict', 'existence', 'magnetic'], 'field'),
#  (['must', 'therefore', 'extremely', 'compact'], 'object'),
#  (['object', 'therefore', 'extremely', 'compact'], 'must'),
#  (['object', 'must', 'extremely', 'compact'], 'therefore'),
#  (['object', 'must', 'therefore', 'compact'], 'extremely'),
#  (['object', 'must', 'therefore', 'extremely'], 'compact'),
#  (['must', 'therefore', 'extremely', 'compact'], 'leave'),
#  (['therefore', 'extremely', 'compact', 'leave'], 'black'),
#  (['extremely', 'compact', 'leave', 'black'], 'hole'),
#  (['compact', 'leave', 'black', 'hole'], 'plausible'),
#  (['leave', 'black', 'hole', 'plausible'], 'interpretation'),
#  (['exclude', 'possible', 'exotic', 'alternative'], 'however'),
#  (['however', 'possible', 'exotic', 'alternative'], 'exclude'),
#  (['however', 'exclude', 'exotic', 'alternative'], 'possible'),
#  (['however', 'exclude', 'possible', 'alternative'], 'exotic'),
#  (['however', 'exclude', 'possible', 'exotic'], 'alternative'),
#  (['exclude', 'possible', 'exotic', 'alternative'], 'black'),
#  (['possible', 'exotic', 'alternative', 'black'], 'hole'),
#  (['exotic', 'alternative', 'black', 'hole'], 'compact'),
#  (['alternative', 'black', 'hole', 'compact'], 'enough'),
#  (['black', 'hole', 'compact', 'enough'], 'photon'),
#  (['hole', 'compact', 'enough', 'photon'], 'sphere'),
#  (['also', 'provide', 'first', 'observational'], 'observation'),
#  (['observation', 'provide', 'first', 'observational'], 'also'),
#  (['observation', 'also', 'first', 'observational'], 'provide'),
#  (['observation', 'also', 'provide', 'observational'], 'first'),
#  (['observation', 'also', 'provide', 'first'], 'observational'),
#  (['also', 'provide', 'first', 'observational'], 'evidence'),
#  (['provide', 'first', 'observational', 'evidence'], 'existence'),
#  (['first', 'observational', 'evidence', 'existence'], 'stellar'),
#  (['observational', 'evidence', 'existence', 'stellar'], 'mass'),
#  (['evidence', 'existence', 'stellar', 'mass'], 'black'),
#  (['existence', 'stellar', 'mass', 'black'], 'hole'),
#  (['stellar', 'mass', 'black', 'hole'], 'binary'),
#  (['many', 'gravitational', 'wave', 'event'], 'since'),
#  (['since', 'gravitational', 'wave', 'event'], 'many'),
#  (['since', 'many', 'wave', 'event'], 'gravitational'),
#  (['since', 'many', 'gravitational', 'event'], 'wave'),
#  (['since', 'many', 'gravitational', 'wave'], 'event'),
#  (['many', 'gravitational', 'wave', 'event'], 'observe'),
#  (['limit', 'object', 'size', 'still'], 'upper'),
#  (['upper', 'object', 'size', 'still'], 'limit'),
#  (['upper', 'limit', 'size', 'still'], 'object'),
#  (['upper', 'limit', 'object', 'still'], 'size'),
#  (['upper', 'limit', 'object', 'size'], 'still'),
#  (['limit', 'object', 'size', 'still'], 'large'),
#  (['object', 'size', 'still', 'large'], 'test'),
#  (['size', 'still', 'large', 'test'], 'whether'),
#  (['still', 'large', 'test', 'whether'], 'small'),
#  (['large', 'test', 'whether', 'small'], 'schwarzschild'),
#  (['test', 'whether', 'small', 'schwarzschild'], 'radius'),
#  (['x', 'ray', 'source', 'may'], 'bright'),
#  ...]

# %%
mapped_data[20]
# Out:
# ([105, 107, 89, 108], 106)

# %% [markdown]
# # Word2VEc

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter
import numpy as np

# Sample corpus
corpus = [
    'king is a strong man',
    'queen is a wise woman',
    'boy is a young man',
    'girl is a young woman',
    'prince is a young king',
    'princess is a young queen',
    'man is strong',
    'woman is pretty',
    'prince is a boy will be king',
    'princess is a girl will be queen'
]

corpus = sentence_with_common_words

# Tokenize and build vocab
words = [word for sentence in corpus for word in sentence.split()]
vocab = set(words)

# Hyperparameters
embedding_dim = 5
learning_rate = 0.01
epochs = 60
vocab_size = len(vocab)



training_pairs = mapped_data #generate_training_pairs(corpus, word2idx, window_size)
training_pairs_debug = train_data #generate_training_pairs_debug(corpus, word2idx, window_size)


training_pairs
# Out:
# [([7, 28, 29, 30], 6),
#  ([6, 28, 29, 30], 7),
#  ([6, 7, 29, 30], 28),
#  ([6, 7, 28, 30], 29),
#  ([6, 7, 28, 29], 30),
#  ([7, 28, 29, 30], 31),
#  ([28, 29, 30, 31], 32),
#  ([29, 30, 31, 32], 33),
#  ([30, 31, 32, 33], 34),
#  ([31, 32, 33, 34], 35),
#  ([32, 33, 34, 35], 36),
#  ([33, 34, 35, 36], 37),
#  ([34, 35, 36, 37], 38),
#  ([35, 36, 37, 38], 39),
#  ([39, 50, 51, 52], 3),
#  ([3, 50, 51, 52], 39),
#  ([3, 39, 51, 52], 50),
#  ([3, 39, 50, 52], 51),
#  ([3, 39, 50, 51], 52),
#  ([106, 107, 89, 108], 105),
#  ([105, 107, 89, 108], 106),
#  ([105, 106, 89, 108], 107),
#  ([105, 106, 107, 108], 89),
#  ([105, 106, 107, 89], 108),
#  ([106, 107, 89, 108], 109),
#  ([107, 89, 108, 109], 6),
#  ([89, 108, 109, 6], 7),
#  ([108, 109, 6, 7], 28),
#  ([109, 6, 7, 28], 110),
#  ([6, 7, 28, 110], 32),
#  ([7, 28, 110, 32], 39),
#  ([7, 111, 90, 112], 6),
#  ([6, 111, 90, 112], 7),
#  ([6, 7, 90, 112], 111),
#  ([6, 7, 111, 112], 90),
#  ([6, 7, 111, 90], 112),
#  ([7, 111, 90, 112], 113),
#  ([115, 116, 117, 118], 114),
#  ([114, 116, 117, 118], 115),
#  ([114, 115, 117, 118], 116),
#  ([114, 115, 116, 118], 117),
#  ([114, 115, 116, 117], 118),
#  ([115, 116, 117, 118], 119),
#  ([116, 117, 118, 119], 42),
#  ([117, 118, 119, 42], 43),
#  ([6, 7, 134, 135], 89),
#  ([89, 7, 134, 135], 6),
#  ([89, 6, 134, 135], 7),
#  ([89, 6, 7, 135], 134),
#  ([89, 6, 7, 134], 135),
#  ([6, 7, 134, 135], 136),
#  ([7, 134, 135, 136], 137),
#  ([134, 135, 136, 137], 138),
#  ([135, 136, 137, 138], 139),
#  ([136, 137, 138, 139], 140),
#  ([137, 138, 139, 140], 141),
#  ([138, 139, 140, 141], 142),
#  ([7, 49, 147, 148], 6),
#  ([6, 49, 147, 148], 7),
#  ([6, 7, 147, 148], 49),
#  ([6, 7, 49, 148], 147),
#  ([6, 7, 49, 147], 148),
#  ([7, 49, 147, 148], 47),
#  ([49, 147, 148, 47], 149),
#  ([6, 7, 150, 151], 11),
#  ([11, 7, 150, 151], 6),
#  ([11, 6, 150, 151], 7),
#  ([11, 6, 7, 151], 150),
#  ([11, 6, 7, 150], 151),
#  ([6, 7, 150, 151], 152),
#  ([7, 150, 151, 152], 153),
#  ([150, 151, 152, 153], 49),
#  ([151, 152, 153, 49], 148),
#  ([152, 153, 49, 148], 122),
#  ([153, 49, 148, 122], 154),
#  ([49, 148, 122, 154], 6),
#  ([148, 122, 154, 6], 7),
#  ([122, 154, 6, 7], 155),
#  ([154, 6, 7, 155], 8),
#  ([6, 7, 155, 8], 130),
#  ([7, 155, 8, 130], 156),
#  ([155, 8, 130, 156], 157),
#  ([6, 7, 162, 163], 161),
#  ([161, 7, 162, 163], 6),
#  ([161, 6, 162, 163], 7),
#  ([161, 6, 7, 163], 162),
#  ([161, 6, 7, 162], 163),
#  ([6, 7, 162, 163], 164),
#  ([7, 162, 163, 164], 35),
#  ([162, 163, 164, 35], 75),
#  ([163, 164, 35, 75], 165),
#  ([164, 35, 75, 165], 34),
#  ([182, 6, 7, 182], 122),
#  ([122, 6, 7, 182], 182),
#  ([122, 182, 7, 182], 6),
#  ([122, 182, 6, 182], 7),
#  ([122, 182, 6, 7], 182),
#  ([182, 6, 7, 182], 4),
#  ([6, 7, 182, 4], 183),
#  ([7, 182, 4, 183], 6),
#  ([182, 4, 183, 6], 7),
#  ([4, 183, 6, 7], 47),
#  ([183, 6, 7, 47], 184),
#  ([4, 186, 131, 187], 185),
#  ([185, 186, 131, 187], 4),
#  ([185, 4, 131, 187], 186),
#  ([185, 4, 186, 187], 131),
#  ([185, 4, 186, 131], 187),
#  ([4, 186, 131, 187], 121),
#  ([186, 131, 187, 121], 122),
#  ([231, 67, 232, 122], 94),
#  ([94, 67, 232, 122], 231),
#  ([94, 231, 232, 122], 67),
#  ([94, 231, 67, 122], 232),
#  ([94, 231, 67, 232], 122),
#  ([387, 99, 17, 100], 386),
#  ([386, 99, 17, 100], 387),
#  ([386, 387, 17, 100], 99),
#  ([386, 387, 99, 100], 17),
#  ([386, 387, 99, 17], 100),
#  ([387, 99, 17, 100], 102),
#  ([99, 17, 100, 102], 40),
#  ([17, 100, 102, 40], 71),
#  ([100, 102, 40, 71], 321),
#  ([102, 40, 71, 321], 388),
#  ([40, 71, 321, 388], 25),
#  ([71, 321, 388, 25], 71),
#  ([321, 388, 25, 71], 389),
#  ([388, 25, 71, 389], 47),
#  ([25, 71, 389, 47], 390),
#  ([71, 389, 47, 390], 47),
#  ([399, 400, 50, 17], 102),
#  ([102, 400, 50, 17], 399),
#  ([102, 399, 50, 17], 400),
#  ([102, 399, 400, 17], 50),
#  ([102, 399, 400, 50], 17),
#  ([399, 400, 50, 17], 401),
#  ([400, 50, 17, 401], 252),
#  ([50, 17, 401, 252], 402),
#  ([17, 401, 252, 402], 403),
#  ([401, 252, 402, 403], 404),
#  ([252, 402, 403, 404], 40),
#  ([402, 403, 404, 40], 321),
#  ([403, 404, 40, 321], 252),
#  ([404, 40, 321, 252], 405),
#  ([84, 534, 40, 535], 531),
#  ([531, 534, 40, 535], 84),
#  ([531, 84, 40, 535], 534),
#  ([531, 84, 534, 535], 40),
#  ([531, 84, 534, 40], 535),
#  ([84, 534, 40, 535], 521),
#  ([534, 40, 535, 521], 352),
#  ([40, 535, 521, 352], 353),
#  ([535, 521, 352, 353], 4),
#  ([521, 352, 353, 4], 40),
#  ([352, 353, 4, 40], 41),
#  ([353, 4, 40, 41], 42),
#  ([4, 40, 41, 42], 43),
#  ([40, 41, 42, 43], 117),
#  ([41, 42, 43, 117], 536),
#  ([42, 43, 117, 536], 6),
#  ([43, 117, 536, 6], 7),
#  ([117, 536, 6, 7], 205),
#  ([536, 6, 7, 205], 384),
#  ([6, 7, 205, 384], 89),
#  ([7, 205, 384, 89], 22),
#  ([205, 384, 89, 22], 460),
#  ([384, 89, 22, 460], 377),
#  ([102, 547, 17, 102], 106),
#  ([106, 547, 17, 102], 102),
#  ([106, 102, 17, 102], 547),
#  ([106, 102, 547, 102], 17),
#  ([106, 102, 547, 17], 102),
#  ([102, 547, 17, 102], 548),
#  ([547, 17, 102, 548], 514),
#  ([17, 102, 548, 514], 166),
#  ([102, 548, 514, 166], 6),
#  ([548, 514, 166, 6], 7),
#  ([42, 6, 7, 102], 571),
#  ([571, 6, 7, 102], 42),
#  ([571, 42, 7, 102], 6),
#  ([571, 42, 6, 102], 7),
#  ([571, 42, 6, 7], 102),
#  ([42, 6, 7, 102], 100),
#  ([549, 74, 643, 117], 639),
#  ([639, 74, 643, 117], 549),
#  ([639, 549, 643, 117], 74),
#  ([639, 549, 74, 117], 643),
#  ([639, 549, 74, 643], 117),
#  ([549, 74, 643, 117], 70),
#  ([74, 643, 117, 70], 71),
#  ([643, 117, 70, 71], 41),
#  ([117, 70, 71, 41], 644),
#  ([70, 71, 41, 644], 6),
#  ([71, 41, 644, 6], 7),
#  ([41, 644, 6, 7], 645),
#  ([644, 6, 7, 645], 65),
#  ([6, 7, 645, 65], 6),
#  ([7, 645, 65, 6], 67),
#  ([645, 65, 6, 67], 77),
#  ([65, 6, 67, 77], 79),
#  ([6, 67, 77, 79], 227),
#  ([67, 77, 79, 227], 30),
#  ([77, 79, 227, 30], 6),
#  ([79, 227, 30, 6], 7),
#  ([227, 30, 6, 7], 44),
#  ([30, 6, 7, 44], 54),
#  ([6, 7, 44, 54], 134),
#  ([7, 44, 54, 134], 623),
#  ([44, 54, 134, 623], 75),
#  ([657, 658, 89, 8], 656),
#  ([656, 658, 89, 8], 657),
#  ([656, 657, 89, 8], 658),
#  ([656, 657, 658, 8], 89),
#  ([656, 657, 658, 89], 8),
#  ([657, 658, 89, 8], 10),
#  ([658, 89, 8, 10], 6),
#  ([89, 8, 10, 6], 7),
#  ([8, 10, 6, 7], 659),
#  ([10, 6, 7, 659], 108),
#  ([6, 7, 659, 108], 660),
#  ([7, 659, 108, 660], 185),
#  ([659, 108, 660, 185], 84),
#  ([108, 660, 185, 84], 51),
#  ([660, 185, 84, 51], 52),
#  ([185, 84, 51, 52], 661),
#  ([84, 51, 52, 661], 662),
#  ([51, 52, 661, 662], 11),
#  ([52, 661, 662, 11], 6),
#  ([661, 662, 11, 6], 7),
#  ([662, 11, 6, 7], 13),
#  ([11, 6, 7, 13], 14),
#  ([6, 7, 13, 14], 629),
#  ([7, 13, 14, 629], 160),
#  ([103, 59, 25, 26], 679),
#  ([679, 59, 25, 26], 103),
#  ([679, 103, 25, 26], 59),
#  ([679, 103, 59, 26], 25),
#  ([679, 103, 59, 25], 26),
#  ([296, 165, 448, 6], 398),
#  ([398, 165, 448, 6], 296),
#  ([398, 296, 448, 6], 165),
#  ([398, 296, 165, 6], 448),
#  ([398, 296, 165, 448], 6),
#  ([296, 165, 448, 6], 7),
#  ([7, 784, 734, 457], 6),
#  ([6, 784, 734, 457], 7),
#  ([6, 7, 734, 457], 784),
#  ([6, 7, 784, 457], 734),
#  ([6, 7, 784, 734], 457),
#  ([7, 784, 734, 457], 589),
#  ([784, 734, 457, 589], 591),
#  ([734, 457, 589, 591], 592),
#  ([457, 589, 591, 592], 63),
#  ([589, 591, 592, 63], 785),
#  ([591, 592, 63, 785], 767),
#  ([592, 63, 785, 767], 761),
#  ([63, 785, 767, 761], 786),
#  ([785, 767, 761, 786], 536),
#  ([767, 761, 786, 536], 25),
#  ([761, 786, 536, 25], 595),
#  ([786, 536, 25, 595], 71),
#  ([536, 25, 595, 71], 6),
#  ([25, 595, 71, 6], 7),
#  ([595, 71, 6, 7], 395),
#  ([71, 6, 7, 395], 787),
#  ([6, 7, 395, 787], 761),
#  ([7, 395, 787, 761], 788),
#  ([795, 50, 6, 7], 768),
#  ([768, 50, 6, 7], 795),
#  ([768, 795, 6, 7], 50),
#  ([768, 795, 50, 7], 6),
#  ([768, 795, 50, 6], 7),
#  ([795, 50, 6, 7], 761),
#  ([50, 6, 7, 761], 796),
#  ([6, 7, 761, 796], 797),
#  ([7, 803, 231, 17], 6),
#  ([6, 803, 231, 17], 7),
#  ([6, 7, 231, 17], 803),
#  ([6, 7, 803, 17], 231),
#  ([6, 7, 803, 231], 17),
#  ([7, 803, 231, 17], 6),
#  ([803, 231, 17, 6], 7),
#  ([231, 17, 6, 7], 99),
#  ([17, 6, 7, 99], 17),
#  ([6, 7, 99, 17], 630),
#  ([7, 99, 17, 630], 102),
#  ([99, 17, 630, 102], 98),
#  ([388, 42, 6, 7], 102),
#  ([102, 42, 6, 7], 388),
#  ([102, 388, 6, 7], 42),
#  ([102, 388, 42, 7], 6),
#  ([102, 388, 42, 6], 7),
#  ([388, 42, 6, 7], 274),
#  ([42, 6, 7, 274], 159),
#  ([522, 6, 7, 102], 42),
#  ([42, 6, 7, 102], 522),
#  ([42, 522, 7, 102], 6),
#  ([42, 522, 6, 102], 7),
#  ([42, 522, 6, 7], 102),
#  ([522, 6, 7, 102], 134),
#  ([6, 7, 102, 134], 340),
#  ([7, 102, 134, 340], 315),
#  ([102, 134, 340, 315], 341),
#  ([134, 340, 315, 341], 447),
#  ([340, 315, 341, 447], 388),
#  ([315, 341, 447, 388], 6),
#  ([341, 447, 388, 6], 7),
#  ([447, 388, 6, 7], 580),
#  ([388, 6, 7, 580], 593),
#  ([6, 7, 580, 593], 594),
#  ([7, 837, 131, 47], 6),
#  ([6, 837, 131, 47], 7),
#  ([6, 7, 131, 47], 837),
#  ([6, 7, 837, 47], 131),
#  ([6, 7, 837, 131], 47),
#  ([7, 837, 131, 47], 821),
#  ([837, 131, 47, 821], 822),
#  ([131, 47, 821, 822], 50),
#  ([47, 821, 822, 50], 838),
#  ([40, 321, 839, 822], 102),
#  ([102, 321, 839, 822], 40),
#  ([102, 40, 839, 822], 321),
#  ([102, 40, 321, 822], 839),
#  ([102, 40, 321, 839], 822),
#  ([40, 321, 839, 822], 159),
#  ([321, 839, 822, 159], 840),
#  ([839, 822, 159, 840], 51),
#  ([822, 159, 840, 51], 52),
#  ([873], 47),
#  ([47], 873),
#  ([6, 7, 29, 911], 176),
#  ([176, 7, 29, 911], 6),
#  ([176, 6, 29, 911], 7),
#  ([176, 6, 7, 911], 29),
#  ([176, 6, 7, 29], 911),
#  ([6, 7, 29, 911], 48),
#  ([788, 913, 6, 7], 912),
#  ([912, 913, 6, 7], 788),
#  ([912, 788, 6, 7], 913),
#  ([912, 788, 913, 7], 6),
#  ([912, 788, 913, 6], 7),
#  ([788, 913, 6, 7], 912),
#  ([913, 6, 7, 912], 906),
#  ([6, 7, 912, 906], 671),
#  ([131, 257, 39], 111),
#  ([111, 257, 39], 131),
#  ([111, 131, 39], 257),
#  ([111, 131, 257], 39),
#  ([60, 6, 7, 916], 915),
#  ([915, 6, 7, 916], 60),
#  ([915, 60, 7, 916], 6),
#  ([915, 60, 6, 916], 7),
#  ([915, 60, 6, 7], 916),
#  ([60, 6, 7, 916], 51),
#  ([6, 7, 916, 51], 52),
#  ([7, 916, 51, 52], 776),
#  ([916, 51, 52, 776], 3),
#  ([51, 52, 776, 3], 29),
#  ([52, 776, 3, 29], 164),
#  ([776, 3, 29, 164], 34),
#  ([3, 29, 164, 34], 19),
#  ([29, 164, 34, 19], 917),
#  ([164, 34, 19, 917], 913),
#  ([34, 19, 917, 913], 47),
#  ([19, 917, 913, 47], 6),
#  ([917, 913, 47, 6], 7),
#  ([204, 34, 39, 751], 32),
#  ([32, 34, 39, 751], 204),
#  ([32, 204, 39, 751], 34),
#  ([32, 204, 34, 751], 39),
#  ([32, 204, 34, 39], 751),
#  ([204, 34, 39, 751], 51),
#  ([34, 39, 751, 51], 52),
#  ([52, 231, 51, 918], 51),
#  ([51, 231, 51, 918], 52),
#  ([51, 52, 51, 918], 231),
#  ([51, 52, 231, 918], 51),
#  ([51, 52, 231, 51], 918),
#  ([52, 231, 51, 918], 919),
#  ([231, 51, 918, 919], 3),
#  ([51, 918, 919, 3], 761),
#  ([918, 919, 3, 761], 51),
#  ([919, 3, 761, 51], 920),
#  ([3, 761, 51, 920], 448),
#  ([761, 51, 920, 448], 514),
#  ([51, 920, 448, 514], 84),
#  ([920, 448, 514, 84], 86),
#  ([448, 514, 84, 86], 183),
#  ([514, 84, 86, 183], 921),
#  ([84, 86, 183, 921], 51),
#  ([86, 183, 921, 51], 918),
#  ([42, 43, 161, 47], 44),
#  ([44, 43, 161, 47], 42),
#  ([44, 42, 161, 47], 43),
#  ([44, 42, 43, 47], 161),
#  ([44, 42, 43, 161], 47),
#  ([42, 43, 161, 47], 48),
#  ([43, 161, 47, 48], 29),
#  ([161, 47, 48, 29], 63),
#  ([47, 48, 29, 63], 912),
#  ([48, 29, 63, 912], 414),
#  ([29, 63, 912, 414], 257),
#  ([63, 912, 414, 257], 922),
#  ([912, 414, 257, 922], 913),
#  ([414, 257, 922, 913], 47),
#  ([52, 6, 7, 923], 51),
#  ([51, 6, 7, 923], 52),
#  ([51, 52, 7, 923], 6),
#  ([51, 52, 6, 923], 7),
#  ([51, 52, 6, 7], 923),
#  ([52, 6, 7, 923], 252),
#  ([6, 7, 923, 252], 31),
#  ([7, 923, 252, 31], 912),
#  ([923, 252, 31, 912], 637),
#  ([252, 31, 912, 637], 671),
#  ([31, 912, 637, 671], 6),
#  ([912, 637, 671, 6], 7),
#  ([514, 925, 667, 6], 924),
#  ([924, 925, 667, 6], 514),
#  ([924, 514, 667, 6], 925),
#  ([924, 514, 925, 6], 667),
#  ([924, 514, 925, 667], 6),
#  ([514, 925, 667, 6], 7),
#  ([925, 667, 6, 7], 103),
#  ([667, 6, 7, 103], 601),
#  ([6, 7, 103, 601], 926),
#  ([7, 103, 601, 926], 927),
#  ([103, 601, 926, 927], 476),
#  ([601, 926, 927, 476], 671),
#  ([926, 927, 476, 671], 6),
#  ([927, 476, 671, 6], 7),
#  ([54, 134, 25, 22], 852),
#  ([852, 134, 25, 22], 54),
#  ([852, 54, 25, 22], 134),
#  ([852, 54, 134, 22], 25),
#  ([852, 54, 134, 25], 22),
#  ([54, 134, 25, 22], 308),
#  ([134, 25, 22, 308], 1),
#  ([25, 22, 308, 1], 166),
#  ([22, 308, 1, 166], 6),
#  ([308, 1, 166, 6], 7),
#  ([1, 166, 6, 7], 601),
#  ([166, 6, 7, 601], 264),
#  ([6, 7, 601, 264], 928),
#  ([7, 601, 264, 928], 51),
#  ([601, 264, 928, 51], 52),
#  ([264, 928, 51, 52], 414),
#  ([928, 51, 52, 414], 405),
#  ([51, 52, 414, 405], 22),
#  ([52, 414, 405, 22], 920),
#  ([166, 1, 933, 671], 784),
#  ([784, 1, 933, 671], 166),
#  ([784, 166, 933, 671], 1),
#  ([784, 166, 1, 671], 933),
#  ([784, 166, 1, 933], 671),
#  ([166, 1, 933, 671], 111),
#  ([1, 933, 671, 111], 5),
#  ([561, 935, 565, 1], 934),
#  ([934, 935, 565, 1], 561),
#  ([934, 561, 565, 1], 935),
#  ([934, 561, 935, 1], 565),
#  ([934, 561, 935, 565], 1),
#  ([561, 935, 565, 1], 410),
#  ([935, 565, 1, 410], 247),
#  ([565, 1, 410, 247], 919),
#  ([1, 410, 247, 919], 936),
#  ([410, 247, 919, 936], 937),
#  ([925, 601, 926, 941], 61),
#  ([61, 601, 926, 941], 925),
#  ([61, 925, 926, 941], 601),
#  ([61, 925, 601, 941], 926),
#  ([61, 925, 601, 926], 941),
#  ([925, 601, 926, 941], 57),
#  ([601, 926, 941, 57], 51),
#  ([926, 941, 57, 51], 52),
#  ([941, 57, 51, 52], 942),
#  ([57, 51, 52, 942], 22),
#  ([51, 52, 942, 22], 943),
#  ([52, 942, 22, 943], 234),
#  ([942, 22, 943, 234], 402),
#  ([22, 943, 234, 402], 400),
#  ([42, 43, 86, 183], 944),
#  ([944, 43, 86, 183], 42),
#  ([944, 42, 86, 183], 43),
#  ([944, 42, 43, 183], 86),
#  ([944, 42, 43, 86], 183),
#  ([42, 43, 86, 183], 184),
#  ([43, 86, 183, 184], 51),
#  ([86, 183, 184, 51], 52),
#  ([183, 184, 51, 52], 945),
#  ([184, 51, 52, 945], 185),
#  ([51, 52, 945, 185], 852),
#  ([52, 945, 185, 852], 40),
#  ([945, 185, 852, 40], 294),
#  ([185, 852, 40, 294], 295),
#  ([905, 708, 25, 312], 312),
#  ([312, 708, 25, 312], 905),
#  ([312, 905, 25, 312], 708),
#  ([312, 905, 708, 312], 25),
#  ([312, 905, 708, 25], 312),
#  ([905, 708, 25, 312], 160),
#  ([708, 25, 312, 160], 6),
#  ([25, 312, 160, 6], 7),
#  ([312, 160, 6, 7], 388),
#  ([160, 6, 7, 388], 42),
#  ([6, 7, 388, 42], 43),
#  ([7, 388, 42, 43], 153),
#  ([388, 42, 43, 153], 952),
#  ([42, 43, 153, 952], 25),
#  ([43, 153, 952, 25], 312),
#  ([153, 952, 25, 312], 28),
#  ([952, 25, 312, 28], 29),
#  ([25, 312, 28, 29], 446),
#  ([312, 28, 29, 446], 252),
#  ([28, 29, 446, 252], 405),
#  ([452, 6, 7, 28], 235),
#  ([235, 6, 7, 28], 452),
#  ([235, 452, 7, 28], 6),
#  ([235, 452, 6, 28], 7),
#  ([235, 452, 6, 7], 28),
#  ([452, 6, 7, 28], 414),
#  ([6, 7, 28, 414], 762),
#  ([7, 28, 414, 762], 953),
#  ([28, 414, 762, 953], 389),
#  ([402, 28, 958, 959], 957),
#  ([957, 28, 958, 959], 402),
#  ([957, 402, 958, 959], 28),
#  ([957, 402, 28, 959], 958),
#  ([957, 402, 28, 958], 959),
#  ([117, 402, 28, 199], 274),
#  ([274, 402, 28, 199], 117),
#  ([274, 117, 28, 199], 402),
#  ([274, 117, 402, 199], 28),
#  ([274, 117, 402, 28], 199),
#  ([117, 402, 28, 199], 47),
#  ([402, 28, 199, 47], 6),
#  ([28, 199, 47, 6], 7),
#  ([199, 47, 6, 7], 102),
#  ([28, 960, 501, 405], 402),
#  ([402, 960, 501, 405], 28),
#  ([402, 28, 501, 405], 960),
#  ([402, 28, 960, 405], 501),
#  ([402, 28, 960, 501], 405),
#  ([28, 960, 501, 405], 219),
#  ([166, 17, 6, 7], 514),
#  ([514, 17, 6, 7], 166),
#  ([514, 166, 6, 7], 17),
#  ([514, 166, 17, 7], 6),
#  ([514, 166, 17, 6], 7),
#  ([166, 17, 6, 7], 785),
#  ([17, 6, 7, 785], 961),
#  ([6, 7, 785, 961], 312),
#  ([7, 785, 961, 312], 57),
#  ([785, 961, 312, 57], 51),
#  ([961, 312, 57, 51], 52),
#  ([580, 566, 6, 7], 957),
#  ([957, 566, 6, 7], 580),
#  ([957, 580, 6, 7], 566),
#  ([957, 580, 566, 7], 6),
#  ([957, 580, 566, 6], 7),
#  ([580, 566, 6, 7], 131),
#  ([566, 6, 7, 131], 785),
#  ([6, 7, 131, 785], 312),
#  ([271, 475, 175, 419], 421),
#  ([421, 475, 175, 419], 271),
#  ([421, 271, 175, 419], 475),
#  ([421, 271, 475, 419], 175),
#  ([421, 271, 475, 175], 419),
#  ([271, 475, 175, 419], 115),
#  ([475, 175, 419, 115], 978),
#  ([175, 419, 115, 978], 979),
#  ([419, 115, 978, 979], 103),
#  ([115, 978, 979, 103], 980),
#  ([978, 979, 103, 980], 421),
#  ([312, 42, 43, 632], 916),
#  ([916, 42, 43, 632], 312),
#  ([916, 312, 43, 632], 42),
#  ([916, 312, 42, 632], 43),
#  ([916, 312, 42, 43], 632),
#  ([312, 42, 43, 632], 989),
#  ([42, 43, 632, 989], 990),
#  ([43, 632, 989, 990], 991),
#  ([632, 989, 990, 991], 41),
#  ([419, 820], 991),
#  ([991, 820], 419),
#  ([991, 419], 820),
#  ([820, 41, 60, 312], 996),
#  ([996, 41, 60, 312], 820),
#  ([996, 820, 60, 312], 41),
#  ([996, 820, 41, 312], 60),
#  ([996, 820, 41, 60], 312),
#  ([452, 6, 7, 997], 235),
#  ([235, 6, 7, 997], 452),
#  ([235, 452, 7, 997], 6),
#  ([235, 452, 6, 997], 7),
#  ([235, 452, 6, 7], 997),
#  ([452, 6, 7, 997], 752),
#  ([6, 7, 997, 752], 401),
#  ([7, 997, 752, 401], 497),
#  ([997, 752, 401, 497], 22),
#  ([752, 401, 497, 22], 17),
#  ([401, 497, 22, 17], 401),
#  ([34, 920, 448, 514], 842),
#  ([842, 920, 448, 514], 34),
#  ([842, 34, 448, 514], 920),
#  ([842, 34, 920, 514], 448),
#  ([842, 34, 920, 448], 514),
#  ([34, 920, 448, 514], 997),
#  ([920, 448, 514, 997], 752),
#  ([448, 514, 997, 752], 1012),
#  ([514, 997, 752, 1012], 73),
#  ([997, 752, 1012, 73], 1),
#  ([752, 1012, 73, 1], 997),
#  ([1012, 73, 1, 997], 752),
#  ([73, 1, 997, 752], 51),
#  ([1, 997, 752, 51], 52),
#  ([6, 7, 1020, 28], 566),
#  ([566, 7, 1020, 28], 6),
#  ([566, 6, 1020, 28], 7),
#  ([566, 6, 7, 28], 1020),
#  ([566, 6, 7, 1020], 28),
#  ([6, 7, 1020, 28], 29),
#  ([7, 1020, 28, 29], 86),
#  ([1020, 28, 29, 86], 1021),
#  ([28, 29, 86, 1021], 1009),
#  ([29, 86, 1021, 1009], 50),
#  ([86, 1021, 1009, 50], 1017),
#  ([667, 566, 47, 1023], 1),
#  ([1, 566, 47, 1023], 667),
#  ([1, 667, 47, 1023], 566),
#  ([1, 667, 566, 1023], 47),
#  ([1, 667, 566, 47], 1023),
#  ([667, 566, 47, 1023], 911),
#  ([566, 47, 1023, 911], 906),
#  ([47, 1023, 911, 906], 543),
#  ([1023, 911, 906, 543], 858),
#  ([75, 39, 941, 1017], 1),
#  ([1, 39, 941, 1017], 75),
#  ([1, 75, 941, 1017], 39),
#  ([1, 75, 39, 1017], 941),
#  ([1, 75, 39, 941], 1017),
#  ([561, 1, 588, 1017], 371),
#  ([371, 1, 588, 1017], 561),
#  ([371, 561, 588, 1017], 1),
#  ([371, 561, 1, 1017], 588),
#  ([371, 561, 1, 588], 1017),
#  ([561, 1, 588, 1017], 38),
#  ([1, 588, 1017, 38], 700),
#  ([858, 6, 7, 264], 1034),
#  ([1034, 6, 7, 264], 858),
#  ([1034, 858, 7, 264], 6),
#  ([1034, 858, 6, 264], 7),
#  ([1034, 858, 6, 7], 264),
#  ([1079, 51, 52, 49], 371),
#  ([371, 51, 52, 49], 1079),
#  ([371, 1079, 52, 49], 51),
#  ([371, 1079, 51, 49], 52),
#  ([371, 1079, 51, 52], 49),
#  ([1079, 51, 52, 49], 42),
#  ([51, 52, 49, 42], 43),
#  ([52, 49, 42, 43], 943),
#  ([49, 42, 43, 943], 70),
#  ([42, 43, 943, 70], 1080),
#  ([43, 943, 70, 1080], 1081),
#  ([943, 70, 1080, 1081], 312),
#  ([70, 1080, 1081, 312], 49),
#  ([1080, 1081, 312, 49], 919),
#  ([222, 1108, 570, 46], 546),
#  ([546, 1108, 570, 46], 222),
#  ([546, 222, 570, 46], 1108),
#  ([546, 222, 1108, 46], 570),
#  ([546, 222, 1108, 570], 46),
#  ([222, 1108, 570, 46], 122),
#  ([7, 205, 1125, 11], 6),
#  ([6, 205, 1125, 11], 7),
#  ([6, 7, 1125, 11], 205),
#  ([6, 7, 205, 11], 1125),
#  ([6, 7, 205, 1125], 11),
#  ([7, 205, 1125, 11], 6),
#  ([205, 1125, 11, 6], 7),
#  ([1125, 11, 6, 7], 100),
#  ([11, 6, 7, 100], 160),
#  ([6, 7, 100, 160], 18),
#  ([1, 100, 185, 1128], 190),
#  ([190, 100, 185, 1128], 1),
#  ([190, 1, 185, 1128], 100),
#  ([190, 1, 100, 1128], 185),
#  ([190, 1, 100, 185], 1128),
#  ([1, 100, 185, 1128], 175),
#  ([1133, 25, 130, 73], 38),
#  ([38, 25, 130, 73], 1133),
#  ([38, 1133, 130, 73], 25),
#  ([38, 1133, 25, 73], 130),
#  ([38, 1133, 25, 130], 73),
#  ([1133, 25, 130, 73], 728),
#  ([25, 130, 73, 728], 448),
#  ([130, 73, 728, 448], 514),
#  ([73, 728, 448, 514], 1065),
#  ([728, 448, 514, 1065], 5),
#  ([448, 514, 1065, 5], 144),
#  ([514, 1065, 5, 144], 561),
#  ([168, 514, 272, 5], 960),
#  ([960, 514, 272, 5], 168),
#  ([960, 168, 272, 5], 514),
#  ([960, 168, 514, 5], 272),
#  ([960, 168, 514, 272], 5),
#  ([168, 514, 272, 5], 735),
#  ([514, 272, 5, 735], 51),
#  ([272, 5, 735, 51], 52),
#  ([6, 7, 203, 1084], 1140),
#  ([1140, 7, 203, 1084], 6),
#  ([1140, 6, 203, 1084], 7),
#  ([1140, 6, 7, 1084], 203),
#  ([1140, 6, 7, 203], 1084),
#  ([6, 7, 203, 1084], 25),
#  ([7, 203, 1084, 25], 130),
#  ([203, 1084, 25, 130], 1081),
#  ([1084, 25, 130, 1081], 53),
#  ([25, 130, 1081, 53], 219),
#  ([38, 1169, 25, 130], 433),
#  ([433, 1169, 25, 130], 38),
#  ([433, 38, 25, 130], 1169),
#  ([433, 38, 1169, 130], 25),
#  ([433, 38, 1169, 25], 130),
#  ([38, 1169, 25, 130], 561),
#  ([1169, 25, 130, 561], 205),
#  ([25, 130, 561, 205], 848),
#  ([130, 561, 205, 848], 6),
#  ([561, 205, 848, 6], 7),
#  ([1012, 1178, 472, 47], 721),
#  ([721, 1178, 472, 47], 1012),
#  ([721, 1012, 472, 47], 1178),
#  ([721, 1012, 1178, 47], 472),
#  ([721, 1012, 1178, 472], 47),
#  ([1012, 1178, 472, 47], 6),
#  ([1178, 472, 47, 6], 7),
#  ([6, 7, 49, 1074], 1200),
#  ([1200, 7, 49, 1074], 6),
#  ([1200, 6, 49, 1074], 7),
#  ([1200, 6, 7, 1074], 49),
#  ([1200, 6, 7, 49], 1074),
#  ([6, 7, 49, 1074], 147),
#  ([7, 49, 1074, 147], 148),
#  ([49, 1074, 147, 148], 1118),
#  ([1074, 147, 148, 1118], 164),
#  ([561, 222, 131, 63], 1200),
#  ([1200, 222, 131, 63], 561),
#  ([1200, 561, 131, 63], 222),
#  ([1200, 561, 222, 63], 131),
#  ([1200, 561, 222, 131], 63),
#  ([561, 222, 131, 63], 11),
#  ([222, 131, 63, 11], 6),
#  ([131, 63, 11, 6], 7),
#  ([63, 11, 6, 7], 153),
#  ([11, 6, 7, 153], 49),
#  ([6, 7, 153, 49], 413),
#  ([7, 153, 49, 413], 735),
#  ([153, 49, 413, 735], 11),
#  ([49, 413, 735, 11], 6),
#  ([413, 735, 11, 6], 7),
#  ([735, 11, 6, 7], 1009),
#  ([11, 6, 7, 1009], 1203),
#  ([6, 7, 1009, 1203], 71),
#  ([7, 1009, 1203, 71], 560),
#  ([7, 274, 154, 1], 6),
#  ([6, 274, 154, 1], 7),
#  ([6, 7, 154, 1], 274),
#  ([6, 7, 274, 1], 154),
#  ([6, 7, 274, 154], 1),
#  ([7, 274, 154, 1], 122),
#  ([274, 154, 1, 122], 204),
#  ([154, 1, 122, 204], 6),
#  ([1, 122, 204, 6], 7),
#  ([252, 134, 623, 75], 54),
#  ([54, 134, 623, 75], 252),
#  ([54, 252, 623, 75], 134),
#  ([54, 252, 134, 75], 623),
#  ([54, 252, 134, 623], 75),
#  ([70, 71, 41, 801], 1167),
#  ([1167, 71, 41, 801], 70),
#  ([1167, 70, 41, 801], 71),
#  ([1167, 70, 71, 801], 41),
#  ([1167, 70, 71, 41], 801),
#  ([70, 71, 41, 801], 6),
#  ([71, 41, 801, 6], 7),
#  ([41, 801, 6, 7], 1216),
#  ([801, 6, 7, 1216], 183),
#  ([6, 7, 1216, 183], 6),
#  ([7, 1216, 183, 6], 7),
#  ([1216, 183, 6, 7], 73),
#  ([183, 6, 7, 73], 257),
#  ([6, 7, 73, 257], 1217),
#  ([7, 73, 257, 1217], 539),
#  ([73, 257, 1217, 539], 6),
#  ([257, 1217, 539, 6], 67),
#  ([1217, 539, 6, 67], 76),
#  ([41, 6, 7, 75], 74),
#  ([74, 6, 7, 75], 41),
#  ([74, 41, 7, 75], 6),
#  ([74, 41, 6, 75], 7),
#  ([74, 41, 6, 7], 75),
#  ([41, 6, 7, 75], 468),
#  ([6, 7, 75, 468], 6),
#  ([7, 75, 468, 6], 7),
#  ([75, 468, 6, 7], 820),
#  ([468, 6, 7, 820], 1219),
#  ([6, 7, 820, 1219], 1196),
#  ([7, 820, 1219, 1196], 22),
#  ([820, 1219, 1196, 22], 767),
#  ([1219, 1196, 22, 767], 47),
#  ([1196, 22, 767, 47], 678),
#  ([22, 767, 47, 678], 997),
#  ([767, 47, 678, 997], 257),
#  ([1213, 76, 79, 227], 77),
#  ([77, 76, 79, 227], 1213),
#  ([77, 1213, 79, 227], 76),
#  ([77, 1213, 76, 227], 79),
#  ([77, 1213, 76, 79], 227),
#  ([1213, 76, 79, 227], 30),
#  ([76, 79, 227, 30], 6),
#  ([79, 227, 30, 6], 7),
#  ([227, 30, 6, 7], 17),
#  ([30, 6, 7, 17], 6),
#  ([6, 7, 17, 6], 7),
#  ([7, 17, 6, 7], 78),
#  ([17, 6, 7, 78], 79),
#  ([6, 7, 78, 79], 47),
#  ([428, 6, 7, 73], 842),
#  ([842, 6, 7, 73], 428),
#  ([842, 428, 7, 73], 6),
#  ([842, 428, 6, 73], 7),
#  ([842, 428, 6, 7], 73),
#  ([428, 6, 7, 73], 936),
#  ([6, 7, 73, 936], 75),
#  ([7, 73, 936, 75], 903),
#  ([73, 936, 75, 903], 6),
#  ([936, 75, 903, 6], 7),
#  ([936, 1222, 896, 77], 476),
#  ([476, 1222, 896, 77], 936),
#  ([476, 936, 896, 77], 1222),
#  ([476, 936, 1222, 77], 896),
#  ([476, 936, 1222, 896], 77),
#  ([936, 1222, 896, 77], 845),
#  ([1222, 896, 77, 845], 1223),
#  ([896, 77, 845, 1223], 1216),
#  ([77, 845, 1223, 1216], 75),
#  ([47, 428, 6, 7], 83),
#  ([83, 428, 6, 7], 47),
#  ([83, 47, 6, 7], 428),
#  ([83, 47, 428, 7], 6),
#  ([83, 47, 428, 6], 7),
#  ([47, 428, 6, 7], 618),
#  ([428, 6, 7, 618], 47),
#  ([6, 7, 618, 47], 845),
#  ([7, 618, 47, 845], 1223),
#  ([618, 47, 845, 1223], 1216),
#  ([47, 845, 1223, 1216], 73),
#  ([845, 1223, 1216, 73], 623),
#  ([1223, 1216, 73, 623], 75),
#  ([1216, 73, 623, 75], 960),
#  ([73, 623, 75, 960], 147),
#  ([623, 75, 960, 147], 268),
#  ([75, 960, 147, 268], 1219),
#  ([77, 428, 1222, 896], 623),
#  ([623, 428, 1222, 896], 77),
#  ([623, 77, 1222, 896], 428),
#  ([623, 77, 428, 896], 1222),
#  ([623, 77, 428, 1222], 896),
#  ([77, 428, 1222, 896], 6),
#  ([428, 1222, 896, 6], 7),
#  ([1222, 896, 6, 7], 103),
#  ([896, 6, 7, 103], 1088),
#  ([6, 7, 103, 1088], 47),
#  ([7, 103, 1088, 47], 936),
#  ([103, 1088, 47, 936], 889),
#  ([7, 903, 75, 54], 6),
#  ([6, 903, 75, 54], 7),
#  ([6, 7, 75, 54], 903),
#  ([6, 7, 903, 54], 75),
#  ([6, 7, 903, 75], 54),
#  ([7, 903, 75, 54], 820),
#  ([903, 75, 54, 820], 252),
#  ([75, 54, 820, 252], 31),
#  ([47, 6, 7, 820], 1178),
#  ([1178, 6, 7, 820], 47),
#  ([1178, 47, 7, 820], 6),
#  ([1178, 47, 6, 820], 7),
#  ([1178, 47, 6, 7], 820),
#  ([47, 6, 7, 820], 1196),
#  ([6, 7, 820, 1196], 204),
#  ([7, 820, 1196, 204], 1025),
#  ([6, 7, 442, 971], 747),
#  ([747, 7, 442, 971], 6),
#  ([747, 6, 442, 971], 7),
#  ([747, 6, 7, 971], 442),
#  ([747, 6, 7, 442], 971),
#  ([6, 7, 442, 971], 162),
#  ([7, 442, 971, 162], 27),
#  ([442, 971, 162, 27], 25),
#  ([971, 162, 27, 25], 259),
#  ([162, 27, 25, 259], 149),
#  ([6, 7, 776, 117], 165),
#  ([165, 7, 776, 117], 6),
#  ([165, 6, 776, 117], 7),
#  ([165, 6, 7, 117], 776),
#  ([165, 6, 7, 776], 117),
#  ([6, 7, 776, 117], 6),
#  ([7, 776, 117, 6], 796),
#  ([776, 117, 6, 796], 34),
#  ([117, 6, 796, 34], 919),
#  ([6, 796, 34, 919], 232),
#  ([796, 34, 919, 232], 28),
#  ([156, 1289, 51, 52], 268),
#  ([268, 1289, 51, 52], 156),
#  ([268, 156, 51, 52], 1289),
#  ([268, 156, 1289, 52], 51),
#  ([268, 156, 1289, 51], 52),
#  ([156, 1289, 51, 52], 915),
#  ([1289, 51, 52, 915], 6),
#  ([51, 52, 915, 6], 7),
#  ([10, 1217, 955, 65], 108),
#  ([108, 1217, 955, 65], 10),
#  ([108, 10, 955, 65], 1217),
#  ([108, 10, 1217, 65], 955),
#  ([108, 10, 1217, 955], 65),
#  ([10, 1217, 955, 65], 732),
#  ([1217, 955, 65, 732], 1001),
#  ([955, 65, 732, 1001], 1292),
#  ([65, 732, 1001, 1292], 5),
#  ([732, 1001, 1292, 5], 1269),
#  ([1001, 1292, 5, 1269], 197),
#  ([1292, 5, 1269, 197], 6),
#  ([5, 1269, 197, 6], 7),
#  ([1269, 197, 6, 7], 10),
#  ([197, 6, 7, 10], 848),
#  ([6, 7, 10, 848], 4),
#  ([7, 10, 848, 4], 616),
#  ([10, 848, 4, 616], 1269),
#  ([848, 4, 616, 1269], 6),
#  ([4, 616, 1269, 6], 7),
#  ([1324, 6, 7, 44], 115),
#  ([115, 6, 7, 44], 1324),
#  ([115, 1324, 7, 44], 6),
#  ([115, 1324, 6, 44], 7),
#  ([115, 1324, 6, 7], 44),
#  ([1324, 6, 7, 44], 442),
#  ([6, 7, 44, 442], 1036),
#  ([7, 44, 442, 1036], 71),
#  ([1012, 679, 993, 46], 1),
#  ([1, 679, 993, 46], 1012),
#  ([1, 1012, 993, 46], 679),
#  ([1, 1012, 679, 46], 993),
#  ([1, 1012, 679, 993], 46),
#  ([1012, 679, 993, 46], 273),
#  ([679, 993, 46, 273], 6),
#  ([993, 46, 273, 6], 7),
#  ([46, 273, 6, 7], 1341),
#  ([273, 6, 7, 1341], 109),
#  ([186, 131, 1086, 187], 419),
#  ([419, 131, 1086, 187], 186),
#  ([419, 186, 1086, 187], 131),
#  ([419, 186, 131, 187], 1086),
#  ([419, 186, 131, 1086], 187),
#  ([186, 131, 1086, 187], 6),
#  ([131, 1086, 187, 6], 7),
#  ([1086, 187, 6, 7], 46),
#  ([187, 6, 7, 46], 37),
#  ([6, 7, 46, 37], 997),
#  ([7, 46, 37, 997], 752),
#  ([274, 529, 89, 1263], 185),
#  ([185, 529, 89, 1263], 274),
#  ([185, 274, 89, 1263], 529),
#  ([185, 274, 529, 1263], 89),
#  ([185, 274, 529, 89], 1263),
#  ([274, 529, 89, 1263], 1264),
#  ([529, 89, 1263, 1264], 442),
#  ([89, 1263, 1264, 442], 83),
#  ([1263, 1264, 442, 83], 47),
#  ([1264, 442, 83, 47], 6),
#  ([442, 83, 47, 6], 7),
#  ([83, 47, 6, 7], 191),
#  ([62, 25, 36, 51], 978),
#  ([978, 25, 36, 51], 62),
#  ([978, 62, 36, 51], 25),
#  ([978, 62, 25, 51], 36),
#  ([978, 62, 25, 36], 51),
#  ([62, 25, 36, 51], 27),
#  ([472, 1, 893, 1009], 1376),
#  ([1376, 1, 893, 1009], 472),
#  ([1376, 472, 893, 1009], 1),
#  ([1376, 472, 1, 1009], 893),
#  ([1376, 472, 1, 893], 1009),
#  ([472, 1, 893, 1009], 428),
#  ([1, 893, 1009, 428], 1046),
#  ([893, 1009, 428, 1046], 921),
#  ([1009, 428, 1046, 921], 903),
#  ([428, 1046, 921, 903], 17),
#  ([1046, 921, 903, 17], 401),
#  ([136, 262, 194, 153], 174),
#  ...]

# %%
mapped_data
# Out:
# [([7, 28, 29, 30], 6),
#  ([6, 28, 29, 30], 7),
#  ([6, 7, 29, 30], 28),
#  ([6, 7, 28, 30], 29),
#  ([6, 7, 28, 29], 30),
#  ([7, 28, 29, 30], 31),
#  ([28, 29, 30, 31], 32),
#  ([29, 30, 31, 32], 33),
#  ([30, 31, 32, 33], 34),
#  ([31, 32, 33, 34], 35),
#  ([32, 33, 34, 35], 36),
#  ([33, 34, 35, 36], 37),
#  ([34, 35, 36, 37], 38),
#  ([35, 36, 37, 38], 39),
#  ([39, 50, 51, 52], 3),
#  ([3, 50, 51, 52], 39),
#  ([3, 39, 51, 52], 50),
#  ([3, 39, 50, 52], 51),
#  ([3, 39, 50, 51], 52),
#  ([106, 107, 89, 108], 105),
#  ([105, 107, 89, 108], 106),
#  ([105, 106, 89, 108], 107),
#  ([105, 106, 107, 108], 89),
#  ([105, 106, 107, 89], 108),
#  ([106, 107, 89, 108], 109),
#  ([107, 89, 108, 109], 6),
#  ([89, 108, 109, 6], 7),
#  ([108, 109, 6, 7], 28),
#  ([109, 6, 7, 28], 110),
#  ([6, 7, 28, 110], 32),
#  ([7, 28, 110, 32], 39),
#  ([7, 111, 90, 112], 6),
#  ([6, 111, 90, 112], 7),
#  ([6, 7, 90, 112], 111),
#  ([6, 7, 111, 112], 90),
#  ([6, 7, 111, 90], 112),
#  ([7, 111, 90, 112], 113),
#  ([115, 116, 117, 118], 114),
#  ([114, 116, 117, 118], 115),
#  ([114, 115, 117, 118], 116),
#  ([114, 115, 116, 118], 117),
#  ([114, 115, 116, 117], 118),
#  ([115, 116, 117, 118], 119),
#  ([116, 117, 118, 119], 42),
#  ([117, 118, 119, 42], 43),
#  ([6, 7, 134, 135], 89),
#  ([89, 7, 134, 135], 6),
#  ([89, 6, 134, 135], 7),
#  ([89, 6, 7, 135], 134),
#  ([89, 6, 7, 134], 135),
#  ([6, 7, 134, 135], 136),
#  ([7, 134, 135, 136], 137),
#  ([134, 135, 136, 137], 138),
#  ([135, 136, 137, 138], 139),
#  ([136, 137, 138, 139], 140),
#  ([137, 138, 139, 140], 141),
#  ([138, 139, 140, 141], 142),
#  ([7, 49, 147, 148], 6),
#  ([6, 49, 147, 148], 7),
#  ([6, 7, 147, 148], 49),
#  ([6, 7, 49, 148], 147),
#  ([6, 7, 49, 147], 148),
#  ([7, 49, 147, 148], 47),
#  ([49, 147, 148, 47], 149),
#  ([6, 7, 150, 151], 11),
#  ([11, 7, 150, 151], 6),
#  ([11, 6, 150, 151], 7),
#  ([11, 6, 7, 151], 150),
#  ([11, 6, 7, 150], 151),
#  ([6, 7, 150, 151], 152),
#  ([7, 150, 151, 152], 153),
#  ([150, 151, 152, 153], 49),
#  ([151, 152, 153, 49], 148),
#  ([152, 153, 49, 148], 122),
#  ([153, 49, 148, 122], 154),
#  ([49, 148, 122, 154], 6),
#  ([148, 122, 154, 6], 7),
#  ([122, 154, 6, 7], 155),
#  ([154, 6, 7, 155], 8),
#  ([6, 7, 155, 8], 130),
#  ([7, 155, 8, 130], 156),
#  ([155, 8, 130, 156], 157),
#  ([6, 7, 162, 163], 161),
#  ([161, 7, 162, 163], 6),
#  ([161, 6, 162, 163], 7),
#  ([161, 6, 7, 163], 162),
#  ([161, 6, 7, 162], 163),
#  ([6, 7, 162, 163], 164),
#  ([7, 162, 163, 164], 35),
#  ([162, 163, 164, 35], 75),
#  ([163, 164, 35, 75], 165),
#  ([164, 35, 75, 165], 34),
#  ([182, 6, 7, 182], 122),
#  ([122, 6, 7, 182], 182),
#  ([122, 182, 7, 182], 6),
#  ([122, 182, 6, 182], 7),
#  ([122, 182, 6, 7], 182),
#  ([182, 6, 7, 182], 4),
#  ([6, 7, 182, 4], 183),
#  ([7, 182, 4, 183], 6),
#  ([182, 4, 183, 6], 7),
#  ([4, 183, 6, 7], 47),
#  ([183, 6, 7, 47], 184),
#  ([4, 186, 131, 187], 185),
#  ([185, 186, 131, 187], 4),
#  ([185, 4, 131, 187], 186),
#  ([185, 4, 186, 187], 131),
#  ([185, 4, 186, 131], 187),
#  ([4, 186, 131, 187], 121),
#  ([186, 131, 187, 121], 122),
#  ([231, 67, 232, 122], 94),
#  ([94, 67, 232, 122], 231),
#  ([94, 231, 232, 122], 67),
#  ([94, 231, 67, 122], 232),
#  ([94, 231, 67, 232], 122),
#  ([387, 99, 17, 100], 386),
#  ([386, 99, 17, 100], 387),
#  ([386, 387, 17, 100], 99),
#  ([386, 387, 99, 100], 17),
#  ([386, 387, 99, 17], 100),
#  ([387, 99, 17, 100], 102),
#  ([99, 17, 100, 102], 40),
#  ([17, 100, 102, 40], 71),
#  ([100, 102, 40, 71], 321),
#  ([102, 40, 71, 321], 388),
#  ([40, 71, 321, 388], 25),
#  ([71, 321, 388, 25], 71),
#  ([321, 388, 25, 71], 389),
#  ([388, 25, 71, 389], 47),
#  ([25, 71, 389, 47], 390),
#  ([71, 389, 47, 390], 47),
#  ([399, 400, 50, 17], 102),
#  ([102, 400, 50, 17], 399),
#  ([102, 399, 50, 17], 400),
#  ([102, 399, 400, 17], 50),
#  ([102, 399, 400, 50], 17),
#  ([399, 400, 50, 17], 401),
#  ([400, 50, 17, 401], 252),
#  ([50, 17, 401, 252], 402),
#  ([17, 401, 252, 402], 403),
#  ([401, 252, 402, 403], 404),
#  ([252, 402, 403, 404], 40),
#  ([402, 403, 404, 40], 321),
#  ([403, 404, 40, 321], 252),
#  ([404, 40, 321, 252], 405),
#  ([84, 534, 40, 535], 531),
#  ([531, 534, 40, 535], 84),
#  ([531, 84, 40, 535], 534),
#  ([531, 84, 534, 535], 40),
#  ([531, 84, 534, 40], 535),
#  ([84, 534, 40, 535], 521),
#  ([534, 40, 535, 521], 352),
#  ([40, 535, 521, 352], 353),
#  ([535, 521, 352, 353], 4),
#  ([521, 352, 353, 4], 40),
#  ([352, 353, 4, 40], 41),
#  ([353, 4, 40, 41], 42),
#  ([4, 40, 41, 42], 43),
#  ([40, 41, 42, 43], 117),
#  ([41, 42, 43, 117], 536),
#  ([42, 43, 117, 536], 6),
#  ([43, 117, 536, 6], 7),
#  ([117, 536, 6, 7], 205),
#  ([536, 6, 7, 205], 384),
#  ([6, 7, 205, 384], 89),
#  ([7, 205, 384, 89], 22),
#  ([205, 384, 89, 22], 460),
#  ([384, 89, 22, 460], 377),
#  ([102, 547, 17, 102], 106),
#  ([106, 547, 17, 102], 102),
#  ([106, 102, 17, 102], 547),
#  ([106, 102, 547, 102], 17),
#  ([106, 102, 547, 17], 102),
#  ([102, 547, 17, 102], 548),
#  ([547, 17, 102, 548], 514),
#  ([17, 102, 548, 514], 166),
#  ([102, 548, 514, 166], 6),
#  ([548, 514, 166, 6], 7),
#  ([42, 6, 7, 102], 571),
#  ([571, 6, 7, 102], 42),
#  ([571, 42, 7, 102], 6),
#  ([571, 42, 6, 102], 7),
#  ([571, 42, 6, 7], 102),
#  ([42, 6, 7, 102], 100),
#  ([549, 74, 643, 117], 639),
#  ([639, 74, 643, 117], 549),
#  ([639, 549, 643, 117], 74),
#  ([639, 549, 74, 117], 643),
#  ([639, 549, 74, 643], 117),
#  ([549, 74, 643, 117], 70),
#  ([74, 643, 117, 70], 71),
#  ([643, 117, 70, 71], 41),
#  ([117, 70, 71, 41], 644),
#  ([70, 71, 41, 644], 6),
#  ([71, 41, 644, 6], 7),
#  ([41, 644, 6, 7], 645),
#  ([644, 6, 7, 645], 65),
#  ([6, 7, 645, 65], 6),
#  ([7, 645, 65, 6], 67),
#  ([645, 65, 6, 67], 77),
#  ([65, 6, 67, 77], 79),
#  ([6, 67, 77, 79], 227),
#  ([67, 77, 79, 227], 30),
#  ([77, 79, 227, 30], 6),
#  ([79, 227, 30, 6], 7),
#  ([227, 30, 6, 7], 44),
#  ([30, 6, 7, 44], 54),
#  ([6, 7, 44, 54], 134),
#  ([7, 44, 54, 134], 623),
#  ([44, 54, 134, 623], 75),
#  ([657, 658, 89, 8], 656),
#  ([656, 658, 89, 8], 657),
#  ([656, 657, 89, 8], 658),
#  ([656, 657, 658, 8], 89),
#  ([656, 657, 658, 89], 8),
#  ([657, 658, 89, 8], 10),
#  ([658, 89, 8, 10], 6),
#  ([89, 8, 10, 6], 7),
#  ([8, 10, 6, 7], 659),
#  ([10, 6, 7, 659], 108),
#  ([6, 7, 659, 108], 660),
#  ([7, 659, 108, 660], 185),
#  ([659, 108, 660, 185], 84),
#  ([108, 660, 185, 84], 51),
#  ([660, 185, 84, 51], 52),
#  ([185, 84, 51, 52], 661),
#  ([84, 51, 52, 661], 662),
#  ([51, 52, 661, 662], 11),
#  ([52, 661, 662, 11], 6),
#  ([661, 662, 11, 6], 7),
#  ([662, 11, 6, 7], 13),
#  ([11, 6, 7, 13], 14),
#  ([6, 7, 13, 14], 629),
#  ([7, 13, 14, 629], 160),
#  ([103, 59, 25, 26], 679),
#  ([679, 59, 25, 26], 103),
#  ([679, 103, 25, 26], 59),
#  ([679, 103, 59, 26], 25),
#  ([679, 103, 59, 25], 26),
#  ([296, 165, 448, 6], 398),
#  ([398, 165, 448, 6], 296),
#  ([398, 296, 448, 6], 165),
#  ([398, 296, 165, 6], 448),
#  ([398, 296, 165, 448], 6),
#  ([296, 165, 448, 6], 7),
#  ([7, 784, 734, 457], 6),
#  ([6, 784, 734, 457], 7),
#  ([6, 7, 734, 457], 784),
#  ([6, 7, 784, 457], 734),
#  ([6, 7, 784, 734], 457),
#  ([7, 784, 734, 457], 589),
#  ([784, 734, 457, 589], 591),
#  ([734, 457, 589, 591], 592),
#  ([457, 589, 591, 592], 63),
#  ([589, 591, 592, 63], 785),
#  ([591, 592, 63, 785], 767),
#  ([592, 63, 785, 767], 761),
#  ([63, 785, 767, 761], 786),
#  ([785, 767, 761, 786], 536),
#  ([767, 761, 786, 536], 25),
#  ([761, 786, 536, 25], 595),
#  ([786, 536, 25, 595], 71),
#  ([536, 25, 595, 71], 6),
#  ([25, 595, 71, 6], 7),
#  ([595, 71, 6, 7], 395),
#  ([71, 6, 7, 395], 787),
#  ([6, 7, 395, 787], 761),
#  ([7, 395, 787, 761], 788),
#  ([795, 50, 6, 7], 768),
#  ([768, 50, 6, 7], 795),
#  ([768, 795, 6, 7], 50),
#  ([768, 795, 50, 7], 6),
#  ([768, 795, 50, 6], 7),
#  ([795, 50, 6, 7], 761),
#  ([50, 6, 7, 761], 796),
#  ([6, 7, 761, 796], 797),
#  ([7, 803, 231, 17], 6),
#  ([6, 803, 231, 17], 7),
#  ([6, 7, 231, 17], 803),
#  ([6, 7, 803, 17], 231),
#  ([6, 7, 803, 231], 17),
#  ([7, 803, 231, 17], 6),
#  ([803, 231, 17, 6], 7),
#  ([231, 17, 6, 7], 99),
#  ([17, 6, 7, 99], 17),
#  ([6, 7, 99, 17], 630),
#  ([7, 99, 17, 630], 102),
#  ([99, 17, 630, 102], 98),
#  ([388, 42, 6, 7], 102),
#  ([102, 42, 6, 7], 388),
#  ([102, 388, 6, 7], 42),
#  ([102, 388, 42, 7], 6),
#  ([102, 388, 42, 6], 7),
#  ([388, 42, 6, 7], 274),
#  ([42, 6, 7, 274], 159),
#  ([522, 6, 7, 102], 42),
#  ([42, 6, 7, 102], 522),
#  ([42, 522, 7, 102], 6),
#  ([42, 522, 6, 102], 7),
#  ([42, 522, 6, 7], 102),
#  ([522, 6, 7, 102], 134),
#  ([6, 7, 102, 134], 340),
#  ([7, 102, 134, 340], 315),
#  ([102, 134, 340, 315], 341),
#  ([134, 340, 315, 341], 447),
#  ([340, 315, 341, 447], 388),
#  ([315, 341, 447, 388], 6),
#  ([341, 447, 388, 6], 7),
#  ([447, 388, 6, 7], 580),
#  ([388, 6, 7, 580], 593),
#  ([6, 7, 580, 593], 594),
#  ([7, 837, 131, 47], 6),
#  ([6, 837, 131, 47], 7),
#  ([6, 7, 131, 47], 837),
#  ([6, 7, 837, 47], 131),
#  ([6, 7, 837, 131], 47),
#  ([7, 837, 131, 47], 821),
#  ([837, 131, 47, 821], 822),
#  ([131, 47, 821, 822], 50),
#  ([47, 821, 822, 50], 838),
#  ([40, 321, 839, 822], 102),
#  ([102, 321, 839, 822], 40),
#  ([102, 40, 839, 822], 321),
#  ([102, 40, 321, 822], 839),
#  ([102, 40, 321, 839], 822),
#  ([40, 321, 839, 822], 159),
#  ([321, 839, 822, 159], 840),
#  ([839, 822, 159, 840], 51),
#  ([822, 159, 840, 51], 52),
#  ([873], 47),
#  ([47], 873),
#  ([6, 7, 29, 911], 176),
#  ([176, 7, 29, 911], 6),
#  ([176, 6, 29, 911], 7),
#  ([176, 6, 7, 911], 29),
#  ([176, 6, 7, 29], 911),
#  ([6, 7, 29, 911], 48),
#  ([788, 913, 6, 7], 912),
#  ([912, 913, 6, 7], 788),
#  ([912, 788, 6, 7], 913),
#  ([912, 788, 913, 7], 6),
#  ([912, 788, 913, 6], 7),
#  ([788, 913, 6, 7], 912),
#  ([913, 6, 7, 912], 906),
#  ([6, 7, 912, 906], 671),
#  ([131, 257, 39], 111),
#  ([111, 257, 39], 131),
#  ([111, 131, 39], 257),
#  ([111, 131, 257], 39),
#  ([60, 6, 7, 916], 915),
#  ([915, 6, 7, 916], 60),
#  ([915, 60, 7, 916], 6),
#  ([915, 60, 6, 916], 7),
#  ([915, 60, 6, 7], 916),
#  ([60, 6, 7, 916], 51),
#  ([6, 7, 916, 51], 52),
#  ([7, 916, 51, 52], 776),
#  ([916, 51, 52, 776], 3),
#  ([51, 52, 776, 3], 29),
#  ([52, 776, 3, 29], 164),
#  ([776, 3, 29, 164], 34),
#  ([3, 29, 164, 34], 19),
#  ([29, 164, 34, 19], 917),
#  ([164, 34, 19, 917], 913),
#  ([34, 19, 917, 913], 47),
#  ([19, 917, 913, 47], 6),
#  ([917, 913, 47, 6], 7),
#  ([204, 34, 39, 751], 32),
#  ([32, 34, 39, 751], 204),
#  ([32, 204, 39, 751], 34),
#  ([32, 204, 34, 751], 39),
#  ([32, 204, 34, 39], 751),
#  ([204, 34, 39, 751], 51),
#  ([34, 39, 751, 51], 52),
#  ([52, 231, 51, 918], 51),
#  ([51, 231, 51, 918], 52),
#  ([51, 52, 51, 918], 231),
#  ([51, 52, 231, 918], 51),
#  ([51, 52, 231, 51], 918),
#  ([52, 231, 51, 918], 919),
#  ([231, 51, 918, 919], 3),
#  ([51, 918, 919, 3], 761),
#  ([918, 919, 3, 761], 51),
#  ([919, 3, 761, 51], 920),
#  ([3, 761, 51, 920], 448),
#  ([761, 51, 920, 448], 514),
#  ([51, 920, 448, 514], 84),
#  ([920, 448, 514, 84], 86),
#  ([448, 514, 84, 86], 183),
#  ([514, 84, 86, 183], 921),
#  ([84, 86, 183, 921], 51),
#  ([86, 183, 921, 51], 918),
#  ([42, 43, 161, 47], 44),
#  ([44, 43, 161, 47], 42),
#  ([44, 42, 161, 47], 43),
#  ([44, 42, 43, 47], 161),
#  ([44, 42, 43, 161], 47),
#  ([42, 43, 161, 47], 48),
#  ([43, 161, 47, 48], 29),
#  ([161, 47, 48, 29], 63),
#  ([47, 48, 29, 63], 912),
#  ([48, 29, 63, 912], 414),
#  ([29, 63, 912, 414], 257),
#  ([63, 912, 414, 257], 922),
#  ([912, 414, 257, 922], 913),
#  ([414, 257, 922, 913], 47),
#  ([52, 6, 7, 923], 51),
#  ([51, 6, 7, 923], 52),
#  ([51, 52, 7, 923], 6),
#  ([51, 52, 6, 923], 7),
#  ([51, 52, 6, 7], 923),
#  ([52, 6, 7, 923], 252),
#  ([6, 7, 923, 252], 31),
#  ([7, 923, 252, 31], 912),
#  ([923, 252, 31, 912], 637),
#  ([252, 31, 912, 637], 671),
#  ([31, 912, 637, 671], 6),
#  ([912, 637, 671, 6], 7),
#  ([514, 925, 667, 6], 924),
#  ([924, 925, 667, 6], 514),
#  ([924, 514, 667, 6], 925),
#  ([924, 514, 925, 6], 667),
#  ([924, 514, 925, 667], 6),
#  ([514, 925, 667, 6], 7),
#  ([925, 667, 6, 7], 103),
#  ([667, 6, 7, 103], 601),
#  ([6, 7, 103, 601], 926),
#  ([7, 103, 601, 926], 927),
#  ([103, 601, 926, 927], 476),
#  ([601, 926, 927, 476], 671),
#  ([926, 927, 476, 671], 6),
#  ([927, 476, 671, 6], 7),
#  ([54, 134, 25, 22], 852),
#  ([852, 134, 25, 22], 54),
#  ([852, 54, 25, 22], 134),
#  ([852, 54, 134, 22], 25),
#  ([852, 54, 134, 25], 22),
#  ([54, 134, 25, 22], 308),
#  ([134, 25, 22, 308], 1),
#  ([25, 22, 308, 1], 166),
#  ([22, 308, 1, 166], 6),
#  ([308, 1, 166, 6], 7),
#  ([1, 166, 6, 7], 601),
#  ([166, 6, 7, 601], 264),
#  ([6, 7, 601, 264], 928),
#  ([7, 601, 264, 928], 51),
#  ([601, 264, 928, 51], 52),
#  ([264, 928, 51, 52], 414),
#  ([928, 51, 52, 414], 405),
#  ([51, 52, 414, 405], 22),
#  ([52, 414, 405, 22], 920),
#  ([166, 1, 933, 671], 784),
#  ([784, 1, 933, 671], 166),
#  ([784, 166, 933, 671], 1),
#  ([784, 166, 1, 671], 933),
#  ([784, 166, 1, 933], 671),
#  ([166, 1, 933, 671], 111),
#  ([1, 933, 671, 111], 5),
#  ([561, 935, 565, 1], 934),
#  ([934, 935, 565, 1], 561),
#  ([934, 561, 565, 1], 935),
#  ([934, 561, 935, 1], 565),
#  ([934, 561, 935, 565], 1),
#  ([561, 935, 565, 1], 410),
#  ([935, 565, 1, 410], 247),
#  ([565, 1, 410, 247], 919),
#  ([1, 410, 247, 919], 936),
#  ([410, 247, 919, 936], 937),
#  ([925, 601, 926, 941], 61),
#  ([61, 601, 926, 941], 925),
#  ([61, 925, 926, 941], 601),
#  ([61, 925, 601, 941], 926),
#  ([61, 925, 601, 926], 941),
#  ([925, 601, 926, 941], 57),
#  ([601, 926, 941, 57], 51),
#  ([926, 941, 57, 51], 52),
#  ([941, 57, 51, 52], 942),
#  ([57, 51, 52, 942], 22),
#  ([51, 52, 942, 22], 943),
#  ([52, 942, 22, 943], 234),
#  ([942, 22, 943, 234], 402),
#  ([22, 943, 234, 402], 400),
#  ([42, 43, 86, 183], 944),
#  ([944, 43, 86, 183], 42),
#  ([944, 42, 86, 183], 43),
#  ([944, 42, 43, 183], 86),
#  ([944, 42, 43, 86], 183),
#  ([42, 43, 86, 183], 184),
#  ([43, 86, 183, 184], 51),
#  ([86, 183, 184, 51], 52),
#  ([183, 184, 51, 52], 945),
#  ([184, 51, 52, 945], 185),
#  ([51, 52, 945, 185], 852),
#  ([52, 945, 185, 852], 40),
#  ([945, 185, 852, 40], 294),
#  ([185, 852, 40, 294], 295),
#  ([905, 708, 25, 312], 312),
#  ([312, 708, 25, 312], 905),
#  ([312, 905, 25, 312], 708),
#  ([312, 905, 708, 312], 25),
#  ([312, 905, 708, 25], 312),
#  ([905, 708, 25, 312], 160),
#  ([708, 25, 312, 160], 6),
#  ([25, 312, 160, 6], 7),
#  ([312, 160, 6, 7], 388),
#  ([160, 6, 7, 388], 42),
#  ([6, 7, 388, 42], 43),
#  ([7, 388, 42, 43], 153),
#  ([388, 42, 43, 153], 952),
#  ([42, 43, 153, 952], 25),
#  ([43, 153, 952, 25], 312),
#  ([153, 952, 25, 312], 28),
#  ([952, 25, 312, 28], 29),
#  ([25, 312, 28, 29], 446),
#  ([312, 28, 29, 446], 252),
#  ([28, 29, 446, 252], 405),
#  ([452, 6, 7, 28], 235),
#  ([235, 6, 7, 28], 452),
#  ([235, 452, 7, 28], 6),
#  ([235, 452, 6, 28], 7),
#  ([235, 452, 6, 7], 28),
#  ([452, 6, 7, 28], 414),
#  ([6, 7, 28, 414], 762),
#  ([7, 28, 414, 762], 953),
#  ([28, 414, 762, 953], 389),
#  ([402, 28, 958, 959], 957),
#  ([957, 28, 958, 959], 402),
#  ([957, 402, 958, 959], 28),
#  ([957, 402, 28, 959], 958),
#  ([957, 402, 28, 958], 959),
#  ([117, 402, 28, 199], 274),
#  ([274, 402, 28, 199], 117),
#  ([274, 117, 28, 199], 402),
#  ([274, 117, 402, 199], 28),
#  ([274, 117, 402, 28], 199),
#  ([117, 402, 28, 199], 47),
#  ([402, 28, 199, 47], 6),
#  ([28, 199, 47, 6], 7),
#  ([199, 47, 6, 7], 102),
#  ([28, 960, 501, 405], 402),
#  ([402, 960, 501, 405], 28),
#  ([402, 28, 501, 405], 960),
#  ([402, 28, 960, 405], 501),
#  ([402, 28, 960, 501], 405),
#  ([28, 960, 501, 405], 219),
#  ([166, 17, 6, 7], 514),
#  ([514, 17, 6, 7], 166),
#  ([514, 166, 6, 7], 17),
#  ([514, 166, 17, 7], 6),
#  ([514, 166, 17, 6], 7),
#  ([166, 17, 6, 7], 785),
#  ([17, 6, 7, 785], 961),
#  ([6, 7, 785, 961], 312),
#  ([7, 785, 961, 312], 57),
#  ([785, 961, 312, 57], 51),
#  ([961, 312, 57, 51], 52),
#  ([580, 566, 6, 7], 957),
#  ([957, 566, 6, 7], 580),
#  ([957, 580, 6, 7], 566),
#  ([957, 580, 566, 7], 6),
#  ([957, 580, 566, 6], 7),
#  ([580, 566, 6, 7], 131),
#  ([566, 6, 7, 131], 785),
#  ([6, 7, 131, 785], 312),
#  ([271, 475, 175, 419], 421),
#  ([421, 475, 175, 419], 271),
#  ([421, 271, 175, 419], 475),
#  ([421, 271, 475, 419], 175),
#  ([421, 271, 475, 175], 419),
#  ([271, 475, 175, 419], 115),
#  ([475, 175, 419, 115], 978),
#  ([175, 419, 115, 978], 979),
#  ([419, 115, 978, 979], 103),
#  ([115, 978, 979, 103], 980),
#  ([978, 979, 103, 980], 421),
#  ([312, 42, 43, 632], 916),
#  ([916, 42, 43, 632], 312),
#  ([916, 312, 43, 632], 42),
#  ([916, 312, 42, 632], 43),
#  ([916, 312, 42, 43], 632),
#  ([312, 42, 43, 632], 989),
#  ([42, 43, 632, 989], 990),
#  ([43, 632, 989, 990], 991),
#  ([632, 989, 990, 991], 41),
#  ([419, 820], 991),
#  ([991, 820], 419),
#  ([991, 419], 820),
#  ([820, 41, 60, 312], 996),
#  ([996, 41, 60, 312], 820),
#  ([996, 820, 60, 312], 41),
#  ([996, 820, 41, 312], 60),
#  ([996, 820, 41, 60], 312),
#  ([452, 6, 7, 997], 235),
#  ([235, 6, 7, 997], 452),
#  ([235, 452, 7, 997], 6),
#  ([235, 452, 6, 997], 7),
#  ([235, 452, 6, 7], 997),
#  ([452, 6, 7, 997], 752),
#  ([6, 7, 997, 752], 401),
#  ([7, 997, 752, 401], 497),
#  ([997, 752, 401, 497], 22),
#  ([752, 401, 497, 22], 17),
#  ([401, 497, 22, 17], 401),
#  ([34, 920, 448, 514], 842),
#  ([842, 920, 448, 514], 34),
#  ([842, 34, 448, 514], 920),
#  ([842, 34, 920, 514], 448),
#  ([842, 34, 920, 448], 514),
#  ([34, 920, 448, 514], 997),
#  ([920, 448, 514, 997], 752),
#  ([448, 514, 997, 752], 1012),
#  ([514, 997, 752, 1012], 73),
#  ([997, 752, 1012, 73], 1),
#  ([752, 1012, 73, 1], 997),
#  ([1012, 73, 1, 997], 752),
#  ([73, 1, 997, 752], 51),
#  ([1, 997, 752, 51], 52),
#  ([6, 7, 1020, 28], 566),
#  ([566, 7, 1020, 28], 6),
#  ([566, 6, 1020, 28], 7),
#  ([566, 6, 7, 28], 1020),
#  ([566, 6, 7, 1020], 28),
#  ([6, 7, 1020, 28], 29),
#  ([7, 1020, 28, 29], 86),
#  ([1020, 28, 29, 86], 1021),
#  ([28, 29, 86, 1021], 1009),
#  ([29, 86, 1021, 1009], 50),
#  ([86, 1021, 1009, 50], 1017),
#  ([667, 566, 47, 1023], 1),
#  ([1, 566, 47, 1023], 667),
#  ([1, 667, 47, 1023], 566),
#  ([1, 667, 566, 1023], 47),
#  ([1, 667, 566, 47], 1023),
#  ([667, 566, 47, 1023], 911),
#  ([566, 47, 1023, 911], 906),
#  ([47, 1023, 911, 906], 543),
#  ([1023, 911, 906, 543], 858),
#  ([75, 39, 941, 1017], 1),
#  ([1, 39, 941, 1017], 75),
#  ([1, 75, 941, 1017], 39),
#  ([1, 75, 39, 1017], 941),
#  ([1, 75, 39, 941], 1017),
#  ([561, 1, 588, 1017], 371),
#  ([371, 1, 588, 1017], 561),
#  ([371, 561, 588, 1017], 1),
#  ([371, 561, 1, 1017], 588),
#  ([371, 561, 1, 588], 1017),
#  ([561, 1, 588, 1017], 38),
#  ([1, 588, 1017, 38], 700),
#  ([858, 6, 7, 264], 1034),
#  ([1034, 6, 7, 264], 858),
#  ([1034, 858, 7, 264], 6),
#  ([1034, 858, 6, 264], 7),
#  ([1034, 858, 6, 7], 264),
#  ([1079, 51, 52, 49], 371),
#  ([371, 51, 52, 49], 1079),
#  ([371, 1079, 52, 49], 51),
#  ([371, 1079, 51, 49], 52),
#  ([371, 1079, 51, 52], 49),
#  ([1079, 51, 52, 49], 42),
#  ([51, 52, 49, 42], 43),
#  ([52, 49, 42, 43], 943),
#  ([49, 42, 43, 943], 70),
#  ([42, 43, 943, 70], 1080),
#  ([43, 943, 70, 1080], 1081),
#  ([943, 70, 1080, 1081], 312),
#  ([70, 1080, 1081, 312], 49),
#  ([1080, 1081, 312, 49], 919),
#  ([222, 1108, 570, 46], 546),
#  ([546, 1108, 570, 46], 222),
#  ([546, 222, 570, 46], 1108),
#  ([546, 222, 1108, 46], 570),
#  ([546, 222, 1108, 570], 46),
#  ([222, 1108, 570, 46], 122),
#  ([7, 205, 1125, 11], 6),
#  ([6, 205, 1125, 11], 7),
#  ([6, 7, 1125, 11], 205),
#  ([6, 7, 205, 11], 1125),
#  ([6, 7, 205, 1125], 11),
#  ([7, 205, 1125, 11], 6),
#  ([205, 1125, 11, 6], 7),
#  ([1125, 11, 6, 7], 100),
#  ([11, 6, 7, 100], 160),
#  ([6, 7, 100, 160], 18),
#  ([1, 100, 185, 1128], 190),
#  ([190, 100, 185, 1128], 1),
#  ([190, 1, 185, 1128], 100),
#  ([190, 1, 100, 1128], 185),
#  ([190, 1, 100, 185], 1128),
#  ([1, 100, 185, 1128], 175),
#  ([1133, 25, 130, 73], 38),
#  ([38, 25, 130, 73], 1133),
#  ([38, 1133, 130, 73], 25),
#  ([38, 1133, 25, 73], 130),
#  ([38, 1133, 25, 130], 73),
#  ([1133, 25, 130, 73], 728),
#  ([25, 130, 73, 728], 448),
#  ([130, 73, 728, 448], 514),
#  ([73, 728, 448, 514], 1065),
#  ([728, 448, 514, 1065], 5),
#  ([448, 514, 1065, 5], 144),
#  ([514, 1065, 5, 144], 561),
#  ([168, 514, 272, 5], 960),
#  ([960, 514, 272, 5], 168),
#  ([960, 168, 272, 5], 514),
#  ([960, 168, 514, 5], 272),
#  ([960, 168, 514, 272], 5),
#  ([168, 514, 272, 5], 735),
#  ([514, 272, 5, 735], 51),
#  ([272, 5, 735, 51], 52),
#  ([6, 7, 203, 1084], 1140),
#  ([1140, 7, 203, 1084], 6),
#  ([1140, 6, 203, 1084], 7),
#  ([1140, 6, 7, 1084], 203),
#  ([1140, 6, 7, 203], 1084),
#  ([6, 7, 203, 1084], 25),
#  ([7, 203, 1084, 25], 130),
#  ([203, 1084, 25, 130], 1081),
#  ([1084, 25, 130, 1081], 53),
#  ([25, 130, 1081, 53], 219),
#  ([38, 1169, 25, 130], 433),
#  ([433, 1169, 25, 130], 38),
#  ([433, 38, 25, 130], 1169),
#  ([433, 38, 1169, 130], 25),
#  ([433, 38, 1169, 25], 130),
#  ([38, 1169, 25, 130], 561),
#  ([1169, 25, 130, 561], 205),
#  ([25, 130, 561, 205], 848),
#  ([130, 561, 205, 848], 6),
#  ([561, 205, 848, 6], 7),
#  ([1012, 1178, 472, 47], 721),
#  ([721, 1178, 472, 47], 1012),
#  ([721, 1012, 472, 47], 1178),
#  ([721, 1012, 1178, 47], 472),
#  ([721, 1012, 1178, 472], 47),
#  ([1012, 1178, 472, 47], 6),
#  ([1178, 472, 47, 6], 7),
#  ([6, 7, 49, 1074], 1200),
#  ([1200, 7, 49, 1074], 6),
#  ([1200, 6, 49, 1074], 7),
#  ([1200, 6, 7, 1074], 49),
#  ([1200, 6, 7, 49], 1074),
#  ([6, 7, 49, 1074], 147),
#  ([7, 49, 1074, 147], 148),
#  ([49, 1074, 147, 148], 1118),
#  ([1074, 147, 148, 1118], 164),
#  ([561, 222, 131, 63], 1200),
#  ([1200, 222, 131, 63], 561),
#  ([1200, 561, 131, 63], 222),
#  ([1200, 561, 222, 63], 131),
#  ([1200, 561, 222, 131], 63),
#  ([561, 222, 131, 63], 11),
#  ([222, 131, 63, 11], 6),
#  ([131, 63, 11, 6], 7),
#  ([63, 11, 6, 7], 153),
#  ([11, 6, 7, 153], 49),
#  ([6, 7, 153, 49], 413),
#  ([7, 153, 49, 413], 735),
#  ([153, 49, 413, 735], 11),
#  ([49, 413, 735, 11], 6),
#  ([413, 735, 11, 6], 7),
#  ([735, 11, 6, 7], 1009),
#  ([11, 6, 7, 1009], 1203),
#  ([6, 7, 1009, 1203], 71),
#  ([7, 1009, 1203, 71], 560),
#  ([7, 274, 154, 1], 6),
#  ([6, 274, 154, 1], 7),
#  ([6, 7, 154, 1], 274),
#  ([6, 7, 274, 1], 154),
#  ([6, 7, 274, 154], 1),
#  ([7, 274, 154, 1], 122),
#  ([274, 154, 1, 122], 204),
#  ([154, 1, 122, 204], 6),
#  ([1, 122, 204, 6], 7),
#  ([252, 134, 623, 75], 54),
#  ([54, 134, 623, 75], 252),
#  ([54, 252, 623, 75], 134),
#  ([54, 252, 134, 75], 623),
#  ([54, 252, 134, 623], 75),
#  ([70, 71, 41, 801], 1167),
#  ([1167, 71, 41, 801], 70),
#  ([1167, 70, 41, 801], 71),
#  ([1167, 70, 71, 801], 41),
#  ([1167, 70, 71, 41], 801),
#  ([70, 71, 41, 801], 6),
#  ([71, 41, 801, 6], 7),
#  ([41, 801, 6, 7], 1216),
#  ([801, 6, 7, 1216], 183),
#  ([6, 7, 1216, 183], 6),
#  ([7, 1216, 183, 6], 7),
#  ([1216, 183, 6, 7], 73),
#  ([183, 6, 7, 73], 257),
#  ([6, 7, 73, 257], 1217),
#  ([7, 73, 257, 1217], 539),
#  ([73, 257, 1217, 539], 6),
#  ([257, 1217, 539, 6], 67),
#  ([1217, 539, 6, 67], 76),
#  ([41, 6, 7, 75], 74),
#  ([74, 6, 7, 75], 41),
#  ([74, 41, 7, 75], 6),
#  ([74, 41, 6, 75], 7),
#  ([74, 41, 6, 7], 75),
#  ([41, 6, 7, 75], 468),
#  ([6, 7, 75, 468], 6),
#  ([7, 75, 468, 6], 7),
#  ([75, 468, 6, 7], 820),
#  ([468, 6, 7, 820], 1219),
#  ([6, 7, 820, 1219], 1196),
#  ([7, 820, 1219, 1196], 22),
#  ([820, 1219, 1196, 22], 767),
#  ([1219, 1196, 22, 767], 47),
#  ([1196, 22, 767, 47], 678),
#  ([22, 767, 47, 678], 997),
#  ([767, 47, 678, 997], 257),
#  ([1213, 76, 79, 227], 77),
#  ([77, 76, 79, 227], 1213),
#  ([77, 1213, 79, 227], 76),
#  ([77, 1213, 76, 227], 79),
#  ([77, 1213, 76, 79], 227),
#  ([1213, 76, 79, 227], 30),
#  ([76, 79, 227, 30], 6),
#  ([79, 227, 30, 6], 7),
#  ([227, 30, 6, 7], 17),
#  ([30, 6, 7, 17], 6),
#  ([6, 7, 17, 6], 7),
#  ([7, 17, 6, 7], 78),
#  ([17, 6, 7, 78], 79),
#  ([6, 7, 78, 79], 47),
#  ([428, 6, 7, 73], 842),
#  ([842, 6, 7, 73], 428),
#  ([842, 428, 7, 73], 6),
#  ([842, 428, 6, 73], 7),
#  ([842, 428, 6, 7], 73),
#  ([428, 6, 7, 73], 936),
#  ([6, 7, 73, 936], 75),
#  ([7, 73, 936, 75], 903),
#  ([73, 936, 75, 903], 6),
#  ([936, 75, 903, 6], 7),
#  ([936, 1222, 896, 77], 476),
#  ([476, 1222, 896, 77], 936),
#  ([476, 936, 896, 77], 1222),
#  ([476, 936, 1222, 77], 896),
#  ([476, 936, 1222, 896], 77),
#  ([936, 1222, 896, 77], 845),
#  ([1222, 896, 77, 845], 1223),
#  ([896, 77, 845, 1223], 1216),
#  ([77, 845, 1223, 1216], 75),
#  ([47, 428, 6, 7], 83),
#  ([83, 428, 6, 7], 47),
#  ([83, 47, 6, 7], 428),
#  ([83, 47, 428, 7], 6),
#  ([83, 47, 428, 6], 7),
#  ([47, 428, 6, 7], 618),
#  ([428, 6, 7, 618], 47),
#  ([6, 7, 618, 47], 845),
#  ([7, 618, 47, 845], 1223),
#  ([618, 47, 845, 1223], 1216),
#  ([47, 845, 1223, 1216], 73),
#  ([845, 1223, 1216, 73], 623),
#  ([1223, 1216, 73, 623], 75),
#  ([1216, 73, 623, 75], 960),
#  ([73, 623, 75, 960], 147),
#  ([623, 75, 960, 147], 268),
#  ([75, 960, 147, 268], 1219),
#  ([77, 428, 1222, 896], 623),
#  ([623, 428, 1222, 896], 77),
#  ([623, 77, 1222, 896], 428),
#  ([623, 77, 428, 896], 1222),
#  ([623, 77, 428, 1222], 896),
#  ([77, 428, 1222, 896], 6),
#  ([428, 1222, 896, 6], 7),
#  ([1222, 896, 6, 7], 103),
#  ([896, 6, 7, 103], 1088),
#  ([6, 7, 103, 1088], 47),
#  ([7, 103, 1088, 47], 936),
#  ([103, 1088, 47, 936], 889),
#  ([7, 903, 75, 54], 6),
#  ([6, 903, 75, 54], 7),
#  ([6, 7, 75, 54], 903),
#  ([6, 7, 903, 54], 75),
#  ([6, 7, 903, 75], 54),
#  ([7, 903, 75, 54], 820),
#  ([903, 75, 54, 820], 252),
#  ([75, 54, 820, 252], 31),
#  ([47, 6, 7, 820], 1178),
#  ([1178, 6, 7, 820], 47),
#  ([1178, 47, 7, 820], 6),
#  ([1178, 47, 6, 820], 7),
#  ([1178, 47, 6, 7], 820),
#  ([47, 6, 7, 820], 1196),
#  ([6, 7, 820, 1196], 204),
#  ([7, 820, 1196, 204], 1025),
#  ([6, 7, 442, 971], 747),
#  ([747, 7, 442, 971], 6),
#  ([747, 6, 442, 971], 7),
#  ([747, 6, 7, 971], 442),
#  ([747, 6, 7, 442], 971),
#  ([6, 7, 442, 971], 162),
#  ([7, 442, 971, 162], 27),
#  ([442, 971, 162, 27], 25),
#  ([971, 162, 27, 25], 259),
#  ([162, 27, 25, 259], 149),
#  ([6, 7, 776, 117], 165),
#  ([165, 7, 776, 117], 6),
#  ([165, 6, 776, 117], 7),
#  ([165, 6, 7, 117], 776),
#  ([165, 6, 7, 776], 117),
#  ([6, 7, 776, 117], 6),
#  ([7, 776, 117, 6], 796),
#  ([776, 117, 6, 796], 34),
#  ([117, 6, 796, 34], 919),
#  ([6, 796, 34, 919], 232),
#  ([796, 34, 919, 232], 28),
#  ([156, 1289, 51, 52], 268),
#  ([268, 1289, 51, 52], 156),
#  ([268, 156, 51, 52], 1289),
#  ([268, 156, 1289, 52], 51),
#  ([268, 156, 1289, 51], 52),
#  ([156, 1289, 51, 52], 915),
#  ([1289, 51, 52, 915], 6),
#  ([51, 52, 915, 6], 7),
#  ([10, 1217, 955, 65], 108),
#  ([108, 1217, 955, 65], 10),
#  ([108, 10, 955, 65], 1217),
#  ([108, 10, 1217, 65], 955),
#  ([108, 10, 1217, 955], 65),
#  ([10, 1217, 955, 65], 732),
#  ([1217, 955, 65, 732], 1001),
#  ([955, 65, 732, 1001], 1292),
#  ([65, 732, 1001, 1292], 5),
#  ([732, 1001, 1292, 5], 1269),
#  ([1001, 1292, 5, 1269], 197),
#  ([1292, 5, 1269, 197], 6),
#  ([5, 1269, 197, 6], 7),
#  ([1269, 197, 6, 7], 10),
#  ([197, 6, 7, 10], 848),
#  ([6, 7, 10, 848], 4),
#  ([7, 10, 848, 4], 616),
#  ([10, 848, 4, 616], 1269),
#  ([848, 4, 616, 1269], 6),
#  ([4, 616, 1269, 6], 7),
#  ([1324, 6, 7, 44], 115),
#  ([115, 6, 7, 44], 1324),
#  ([115, 1324, 7, 44], 6),
#  ([115, 1324, 6, 44], 7),
#  ([115, 1324, 6, 7], 44),
#  ([1324, 6, 7, 44], 442),
#  ([6, 7, 44, 442], 1036),
#  ([7, 44, 442, 1036], 71),
#  ([1012, 679, 993, 46], 1),
#  ([1, 679, 993, 46], 1012),
#  ([1, 1012, 993, 46], 679),
#  ([1, 1012, 679, 46], 993),
#  ([1, 1012, 679, 993], 46),
#  ([1012, 679, 993, 46], 273),
#  ([679, 993, 46, 273], 6),
#  ([993, 46, 273, 6], 7),
#  ([46, 273, 6, 7], 1341),
#  ([273, 6, 7, 1341], 109),
#  ([186, 131, 1086, 187], 419),
#  ([419, 131, 1086, 187], 186),
#  ([419, 186, 1086, 187], 131),
#  ([419, 186, 131, 187], 1086),
#  ([419, 186, 131, 1086], 187),
#  ([186, 131, 1086, 187], 6),
#  ([131, 1086, 187, 6], 7),
#  ([1086, 187, 6, 7], 46),
#  ([187, 6, 7, 46], 37),
#  ([6, 7, 46, 37], 997),
#  ([7, 46, 37, 997], 752),
#  ([274, 529, 89, 1263], 185),
#  ([185, 529, 89, 1263], 274),
#  ([185, 274, 89, 1263], 529),
#  ([185, 274, 529, 1263], 89),
#  ([185, 274, 529, 89], 1263),
#  ([274, 529, 89, 1263], 1264),
#  ([529, 89, 1263, 1264], 442),
#  ([89, 1263, 1264, 442], 83),
#  ([1263, 1264, 442, 83], 47),
#  ([1264, 442, 83, 47], 6),
#  ([442, 83, 47, 6], 7),
#  ([83, 47, 6, 7], 191),
#  ([62, 25, 36, 51], 978),
#  ([978, 25, 36, 51], 62),
#  ([978, 62, 36, 51], 25),
#  ([978, 62, 25, 51], 36),
#  ([978, 62, 25, 36], 51),
#  ([62, 25, 36, 51], 27),
#  ([472, 1, 893, 1009], 1376),
#  ([1376, 1, 893, 1009], 472),
#  ([1376, 472, 893, 1009], 1),
#  ([1376, 472, 1, 1009], 893),
#  ([1376, 472, 1, 893], 1009),
#  ([472, 1, 893, 1009], 428),
#  ([1, 893, 1009, 428], 1046),
#  ([893, 1009, 428, 1046], 921),
#  ([1009, 428, 1046, 921], 903),
#  ([428, 1046, 921, 903], 17),
#  ([1046, 921, 903, 17], 401),
#  ([136, 262, 194, 153], 174),
#  ...]

# %%
len(word_to_number.keys())
# Out:
# 1650

# %%
len(train_data)
# Out:
# 1357

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Assuming vocab_size and embedding_dim are defined
vocab_size = len(word_to_number.keys())  # Example, set this to your actual vocabulary size
embedding_dim = 5 # differenct from window size


class ContextWindowModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(ContextWindowModel, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear = nn.Linear(embedding_dim, vocab_size)
        
    def forward(self, context_words):
        # Average embeddings of context words
        embedded = self.embeddings(context_words)  # Shape: [window_size, embedding_dim]
        context_embedding = torch.mean(embedded, dim=0, keepdim=True)  # Shape: [1, embedding_dim]
        out = self.linear(context_embedding)
        log_probs = torch.log_softmax(out, dim=1)
        return log_probs

# Prepare your data
training_data = mapped_data

# Model, Loss, Optimizer
model = ContextWindowModel(vocab_size, embedding_dim)
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Training Loop
epochs = 2000
for epoch in range(epochs):
    total_loss = 0
    for context, target in training_data:
        context_var = torch.tensor(context, dtype=torch.long)
        target_var = torch.tensor([target], dtype=torch.long)
        
        # Forward pass
        log_probs = model(context_var)
        
        # Compute loss
        loss = loss_function(log_probs, target_var)
        
        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    if epoch % 10 == 0:
        print(f'Epoch {epoch}, Loss: {total_loss}')

# it is compressing our training data
# words are compressed in higher dim
        
# Epoch 990, Loss: 5049.21834090658
# Epoch 1990, Loss: 507.8418181762157
# Out:
# Epoch 0, Loss: 9271.959381341934
# Epoch 10, Loss: 6200.009282204133
# Epoch 20, Loss: 5218.999495805092
# Epoch 30, Loss: 4657.716524364054
# Epoch 40, Loss: 4259.787784945065
# Epoch 50, Loss: 3943.5724075650996
# Epoch 60, Loss: 3677.9611976471483
# Epoch 70, Loss: 3449.5537035153966
# Epoch 80, Loss: 3251.2221295450922
# Epoch 90, Loss: 3077.313897719
# Epoch 100, Loss: 2922.894351371303
# Epoch 110, Loss: 2784.204255737481
# Epoch 120, Loss: 2658.314438278554
# Epoch 130, Loss: 2543.0063652357617
# Epoch 140, Loss: 2436.846935007279
# Epoch 150, Loss: 2338.9676360570747
# Epoch 160, Loss: 2248.6616724619203
# Epoch 170, Loss: 2165.1591420409704
# Epoch 180, Loss: 2087.646249485818
# Epoch 190, Loss: 2015.4133540281605
# Epoch 200, Loss: 1947.9470347364008
# Epoch 210, Loss: 1884.8668561262393
# Epoch 220, Loss: 1825.8213206576293
# Epoch 230, Loss: 1770.4664099814509
# Epoch 240, Loss: 1718.485721395067
# Epoch 250, Loss: 1669.5840054817431
# Epoch 260, Loss: 1623.4789812293586
# Epoch 270, Loss: 1579.9041814191212
# Epoch 280, Loss: 1538.614021140772
# Epoch 290, Loss: 1499.39322017064
# Epoch 300, Loss: 1462.0670919093006
# Epoch 310, Loss: 1426.5125409430832
# Epoch 320, Loss: 1392.6659149601496
# Epoch 330, Loss: 1360.508825170023
# Epoch 340, Loss: 1330.0297353868764
# Epoch 350, Loss: 1301.1910334639658
# Epoch 360, Loss: 1273.9206978916677
# Epoch 370, Loss: 1248.1233790716094
# Epoch 380, Loss: 1223.6962031411977
# Epoch 390, Loss: 1200.5400240054921
# Epoch 400, Loss: 1178.5643128176323
# Epoch 410, Loss: 1157.6883412913978
# Epoch 420, Loss: 1137.843312461218
# Epoch 430, Loss: 1118.9696335825488
# Epoch 440, Loss: 1101.0177864287289
# Epoch 450, Loss: 1083.9473789587998
# Epoch 460, Loss: 1067.726931433554

# %%
window_size
# Out:
# 5

# %%
# Example: Get embedding for a word index
word_idx = 4  # Example word index
embedding = model.embeddings(torch.tensor([word_idx]))
print(embedding)
# Out:
# tensor([[-1.4146,  4.4726,  8.6023, -2.0976, -7.4251]],
#        grad_fn=<EmbeddingBackward0>)

# %%
training_pairs
# Out:
# [([2, 3, 4, 5, 6], 1),
#  ([1, 3, 4, 5, 6], 2),
#  ([1, 2, 4, 5, 6], 3),
#  ([1, 2, 3, 5, 6], 4),
#  ([1, 2, 3, 4, 6], 5),
#  ([1, 2, 3, 4, 5], 6),
#  ([8, 9, 10, 6, 11], 7),
#  ([7, 9, 10, 6, 11], 8),
#  ([7, 8, 10, 6, 11], 9),
#  ([7, 8, 9, 6, 11], 10),
#  ([7, 8, 9, 10, 11], 6),
#  ([7, 8, 9, 10, 6], 11),
#  ([8, 9, 10, 6, 11], 12),
#  ([9, 10, 6, 11, 12], 13),
#  ([10, 6, 11, 12, 13], 14),
#  ([6, 11, 12, 13, 14], 15),
#  ([11, 12, 13, 14, 15], 16),
#  ([12, 13, 14, 15, 16], 6),
#  ([13, 14, 15, 16, 6], 17),
#  ([14, 15, 16, 6, 17], 18),
#  ([15, 16, 6, 17, 18], 19),
#  ([21, 22, 23, 24, 25], 20),
#  ([20, 22, 23, 24, 25], 21),
#  ([20, 21, 23, 24, 25], 22),
#  ([20, 21, 22, 24, 25], 23),
#  ([20, 21, 22, 23, 25], 24),
#  ([20, 21, 22, 23, 24], 25),
#  ([21, 22, 23, 24, 25], 17),
#  ([22, 23, 24, 25, 17], 26),
#  ([27, 28, 29, 30, 31], 6),
#  ([6, 28, 29, 30, 31], 27),
#  ([6, 27, 29, 30, 31], 28),
#  ([6, 27, 28, 30, 31], 29),
#  ([6, 27, 28, 29, 31], 30),
#  ([6, 27, 28, 29, 30], 31),
#  ([27, 28, 29, 30, 31], 32),
#  ([28, 29, 30, 31, 32], 33),
#  ([29, 30, 31, 32, 33], 34),
#  ([30, 31, 32, 33, 34], 35),
#  ([31, 32, 33, 34, 35], 36),
#  ([32, 33, 34, 35, 36], 37),
#  ([33, 34, 35, 36, 37], 38),
#  ([40, 41, 42, 43, 44], 39),
#  ([39, 41, 42, 43, 44], 40),
#  ([39, 40, 42, 43, 44], 41),
#  ([39, 40, 41, 43, 44], 42),
#  ([39, 40, 41, 42, 44], 43),
#  ([39, 40, 41, 42, 43], 44),
#  ([40, 41, 42, 43, 44], 45),
#  ([41, 42, 43, 44, 45], 46),
#  ([42, 43, 44, 45, 46], 47),
#  ([43, 44, 45, 46, 47], 48),
#  ([44, 45, 46, 47, 48], 28),
#  ([45, 46, 47, 48, 28], 49),
#  ([46, 47, 48, 28, 49], 6),
#  ([38, 50, 51, 52], 3),
#  ([3, 50, 51, 52], 38),
#  ([3, 38, 51, 52], 50),
#  ([3, 38, 50, 52], 51),
#  ([3, 38, 50, 51], 52),
#  ([53, 54, 55, 56, 1], 6),
#  ([6, 54, 55, 56, 1], 53),
#  ([6, 53, 55, 56, 1], 54),
#  ([6, 53, 54, 56, 1], 55),
#  ([6, 53, 54, 55, 1], 56),
#  ([6, 53, 54, 55, 56], 1),
#  ([53, 54, 55, 56, 1], 57),
#  ([54, 55, 56, 1, 57], 58),
#  ([55, 56, 1, 57, 58], 59),
#  ([56, 1, 57, 58, 59], 60),
#  ([1, 57, 58, 59, 60], 61),
#  ([57, 58, 59, 60, 61], 42),
#  ([58, 59, 60, 61, 42], 43),
#  ([63, 6, 64, 65, 66], 62),
#  ([62, 6, 64, 65, 66], 63),
#  ([62, 63, 64, 65, 66], 6),
#  ([62, 63, 6, 65, 66], 64),
#  ([62, 63, 6, 64, 66], 65),
#  ([62, 63, 6, 64, 65], 66),
#  ([63, 6, 64, 65, 66], 67),
#  ([6, 64, 65, 66, 67], 68),
#  ([64, 65, 66, 67, 68], 69),
#  ([65, 66, 67, 68, 69], 33),
#  ([71, 72, 41, 73, 28], 70),
#  ([70, 72, 41, 73, 28], 71),
#  ([70, 71, 41, 73, 28], 72),
#  ([70, 71, 72, 73, 28], 41),
#  ([70, 71, 72, 41, 28], 73),
#  ([70, 71, 72, 41, 73], 28),
#  ([71, 72, 41, 73, 28], 44),
#  ([72, 41, 73, 28, 44], 51),
#  ([41, 73, 28, 44, 51], 52),
#  ([73, 28, 44, 51, 52], 74),
#  ([28, 44, 51, 52, 74], 75),
#  ([44, 51, 52, 74, 75], 76),
#  ([51, 52, 74, 75, 76], 77),
#  ([52, 74, 75, 76, 77], 67),
#  ([74, 75, 76, 77, 67], 68),
#  ([75, 76, 77, 67, 68], 78),
#  ([76, 77, 67, 68, 78], 79),
#  ([77, 67, 68, 78, 79], 80),
#  ([67, 68, 78, 79, 80], 47),
#  ([81, 82, 83, 84, 6], 78),
#  ([78, 82, 83, 84, 6], 81),
#  ([78, 81, 83, 84, 6], 82),
#  ([78, 81, 82, 84, 6], 83),
#  ([78, 81, 82, 83, 6], 84),
#  ([78, 81, 82, 83, 84], 6),
#  ([81, 82, 83, 84, 6], 85),
#  ([82, 83, 84, 6, 85], 86),
#  ([83, 84, 6, 85, 86], 87),
#  ([84, 6, 85, 86, 87], 26),
#  ([6, 85, 86, 87, 26], 88),
#  ([89, 24, 72, 30, 33], 1),
#  ([1, 24, 72, 30, 33], 89),
#  ([1, 89, 72, 30, 33], 24),
#  ([1, 89, 24, 30, 33], 72),
#  ([1, 89, 24, 72, 33], 30),
#  ([1, 89, 24, 72, 30], 33),
#  ([89, 24, 72, 30, 33], 38),
#  ([24, 72, 30, 33, 38], 90),
#  ([72, 30, 33, 38, 90], 91),
#  ([30, 33, 38, 90, 91], 92),
#  ([33, 38, 90, 91, 92], 93),
#  ([38, 90, 91, 92, 93], 94),
#  ([90, 91, 92, 93, 94], 95),
#  ([91, 92, 93, 94, 95], 96),
#  ([92, 93, 94, 95, 96], 97),
#  ([93, 94, 95, 96, 97], 98),
#  ([100, 16, 101, 90, 102], 99),
#  ([99, 16, 101, 90, 102], 100),
#  ([99, 100, 101, 90, 102], 16),
#  ([99, 100, 16, 90, 102], 101),
#  ([99, 100, 16, 101, 102], 90),
#  ([99, 100, 16, 101, 90], 102),
#  ([100, 16, 101, 90, 102], 103),
#  ([16, 101, 90, 102, 103], 42),
#  ([101, 90, 102, 103, 42], 43),
#  ([90, 102, 103, 42, 43], 104),
#  ([102, 103, 42, 43, 104], 105),
#  ([103, 42, 43, 104, 105], 6),
#  ([107, 108, 90, 109, 110], 106),
#  ([106, 108, 90, 109, 110], 107),
#  ([106, 107, 90, 109, 110], 108),
#  ([106, 107, 108, 109, 110], 90),
#  ([106, 107, 108, 90, 110], 109),
#  ([106, 107, 108, 90, 109], 110),
#  ([107, 108, 90, 109, 110], 6),
#  ([108, 90, 109, 110, 6], 27),
#  ([90, 109, 110, 6, 27], 111),
#  ([109, 110, 6, 27, 111], 31),
#  ([110, 6, 27, 111, 31], 38),
#  ([112, 91, 113, 114], 6),
#  ([6, 91, 113, 114], 112),
#  ([6, 112, 113, 114], 91),
#  ([6, 112, 91, 114], 113),
#  ([6, 112, 91, 113], 114),
#  ([116, 117, 118, 119, 120], 115),
#  ([115, 117, 118, 119, 120], 116),
#  ([115, 116, 118, 119, 120], 117),
#  ([115, 116, 117, 119, 120], 118),
#  ([115, 116, 117, 118, 120], 119),
#  ([115, 116, 117, 118, 119], 120),
#  ([116, 117, 118, 119, 120], 42),
#  ([117, 118, 119, 120, 42], 43),
#  ([122, 123, 124, 125, 126], 121),
#  ([121, 123, 124, 125, 126], 122),
#  ([121, 122, 124, 125, 126], 123),
#  ([121, 122, 123, 125, 126], 124),
#  ([121, 122, 123, 124, 126], 125),
#  ([121, 122, 123, 124, 125], 126),
#  ([122, 123, 124, 125, 126], 127),
#  ([123, 124, 125, 126, 127], 128),
#  ([124, 125, 126, 127, 128], 129),
#  ([125, 126, 127, 128, 129], 130),
#  ([126, 127, 128, 129, 130], 131),
#  ([127, 128, 129, 130, 131], 46),
#  ([128, 129, 130, 131, 46], 1),
#  ([129, 130, 131, 46, 1], 132),
#  ([130, 131, 46, 1, 132], 133),
#  ([131, 46, 1, 132, 133], 134),
#  ([6, 135, 136, 137, 138], 90),
#  ([90, 135, 136, 137, 138], 6),
#  ([90, 6, 136, 137, 138], 135),
#  ([90, 6, 135, 137, 138], 136),
#  ([90, 6, 135, 136, 138], 137),
#  ([90, 6, 135, 136, 137], 138),
#  ([6, 135, 136, 137, 138], 139),
#  ([135, 136, 137, 138, 139], 140),
#  ([136, 137, 138, 139, 140], 141),
#  ([137, 138, 139, 140, 141], 142),
#  ([84, 47, 49, 143, 123], 6),
#  ([6, 47, 49, 143, 123], 84),
#  ([6, 84, 49, 143, 123], 47),
#  ([6, 84, 47, 143, 123], 49),
#  ([6, 84, 47, 49, 123], 143),
#  ([6, 84, 47, 49, 143], 123),
#  ([84, 47, 49, 143, 123], 131),
#  ([47, 49, 143, 123, 131], 144),
#  ([49, 143, 123, 131, 144], 145),
#  ([143, 123, 131, 144, 145], 146),
#  ([49, 147, 148, 47, 149], 6),
#  ([6, 147, 148, 47, 149], 49),
#  ([6, 49, 148, 47, 149], 147),
#  ([6, 49, 147, 47, 149], 148),
#  ([6, 49, 147, 148, 149], 47),
#  ([6, 49, 147, 148, 47], 149),
#  ([6, 150, 151, 152, 153], 10),
#  ([10, 150, 151, 152, 153], 6),
#  ([10, 6, 151, 152, 153], 150),
#  ([10, 6, 150, 152, 153], 151),
#  ([10, 6, 150, 151, 153], 152),
#  ([10, 6, 150, 151, 152], 153),
#  ([6, 150, 151, 152, 153], 49),
#  ([150, 151, 152, 153, 49], 148),
#  ([151, 152, 153, 49, 148], 123),
#  ([152, 153, 49, 148, 123], 154),
#  ([153, 49, 148, 123, 154], 6),
#  ([49, 148, 123, 154, 6], 155),
#  ([148, 123, 154, 6, 155], 7),
#  ([123, 154, 6, 155, 7], 131),
#  ([154, 6, 155, 7, 131], 156),
#  ([6, 155, 7, 131, 156], 157),
#  ([10, 6, 159, 160, 17], 158),
#  ([158, 6, 159, 160, 17], 10),
#  ([158, 10, 159, 160, 17], 6),
#  ([158, 10, 6, 160, 17], 159),
#  ([158, 10, 6, 159, 17], 160),
#  ([158, 10, 6, 159, 160], 17),
#  ([6, 162, 163, 164, 34], 161),
#  ([161, 162, 163, 164, 34], 6),
#  ([161, 6, 163, 164, 34], 162),
#  ([161, 6, 162, 164, 34], 163),
#  ([161, 6, 162, 163, 34], 164),
#  ([161, 6, 162, 163, 164], 34),
#  ([6, 162, 163, 164, 34], 76),
#  ([162, 163, 164, 34, 76], 165),
#  ([163, 164, 34, 76, 165], 33),
#  ([166, 167, 6, 49, 168], 164),
#  ([164, 167, 6, 49, 168], 166),
#  ([164, 166, 6, 49, 168], 167),
#  ([164, 166, 167, 49, 168], 6),
#  ([164, 166, 167, 6, 168], 49),
#  ([164, 166, 167, 6, 49], 168),
#  ([166, 167, 6, 49, 168], 169),
#  ([167, 6, 49, 168, 169], 170),
#  ([6, 49, 168, 169, 170], 171),
#  ([49, 168, 169, 170, 171], 172),
#  ([168, 169, 170, 171, 172], 49),
#  ([169, 170, 171, 172, 49], 173),
#  ([170, 171, 172, 49, 173], 174),
#  ([171, 172, 49, 173, 174], 1),
#  ([172, 49, 173, 174, 1], 175),
#  ([18, 176, 10, 6, 177], 123),
#  ([123, 176, 10, 6, 177], 18),
#  ([123, 18, 10, 6, 177], 176),
#  ([123, 18, 176, 6, 177], 10),
#  ([123, 18, 176, 10, 177], 6),
#  ([123, 18, 176, 10, 6], 177),
#  ([18, 176, 10, 6, 177], 178),
#  ([176, 10, 6, 177, 178], 179),
#  ([10, 6, 177, 178, 179], 180),
#  ([6, 177, 178, 179, 180], 181),
#  ([182, 6, 182, 4, 183], 123),
#  ([123, 6, 182, 4, 183], 182),
#  ([123, 182, 182, 4, 183], 6),
#  ([123, 182, 6, 4, 183], 182),
#  ([123, 182, 6, 182, 183], 4),
#  ([123, 182, 6, 182, 4], 183),
#  ([182, 6, 182, 4, 183], 6),
#  ([6, 182, 4, 183, 6], 40),
#  ([182, 4, 183, 6, 40], 47),
#  ([4, 183, 6, 40, 47], 184),
#  ([4, 186, 132, 187, 122], 185),
#  ([185, 186, 132, 187, 122], 4),
#  ([185, 4, 132, 187, 122], 186),
#  ([185, 4, 186, 187, 122], 132),
#  ([185, 4, 186, 132, 122], 187),
#  ([185, 4, 186, 132, 187], 122),
#  ([4, 186, 132, 187, 122], 123),
#  ([188, 138, 189, 84, 6], 63),
#  ([63, 138, 189, 84, 6], 188),
#  ([63, 188, 189, 84, 6], 138),
#  ([63, 188, 138, 84, 6], 189),
#  ([63, 188, 138, 189, 6], 84),
#  ([63, 188, 138, 189, 84], 6),
#  ([188, 138, 189, 84, 6], 190),
#  ([138, 189, 84, 6, 190], 191),
#  ([189, 84, 6, 190, 191], 192),
#  ([84, 6, 190, 191, 192], 193),
#  ([6, 190, 191, 192, 193], 8),
#  ([190, 191, 192, 193, 8], 194),
#  ([191, 192, 193, 8, 194], 135),
#  ([192, 193, 8, 194, 135], 195),
#  ([193, 8, 194, 135, 195], 196),
#  ([8, 194, 135, 195, 196], 197),
#  ([194, 135, 195, 196, 197], 11),
#  ([135, 195, 196, 197, 11], 198),
#  ([195, 196, 197, 11, 198], 63),
#  ([196, 197, 11, 198, 63], 17),
#  ([197, 11, 198, 63, 17], 199),
#  ([11, 198, 63, 17, 199], 10),
#  ([198, 63, 17, 199, 10], 6),
#  ([63, 17, 199, 10, 6], 200),
#  ([17, 199, 10, 6, 200], 151),
#  ([199, 10, 6, 200, 151], 152),
#  ([202, 68, 203, 204, 33], 201),
#  ([201, 68, 203, 204, 33], 202),
#  ([201, 202, 203, 204, 33], 68),
#  ([201, 202, 68, 204, 33], 203),
#  ([201, 202, 68, 203, 33], 204),
#  ([201, 202, 68, 203, 204], 33),
#  ([202, 68, 203, 204, 33], 205),
#  ([68, 203, 204, 33, 205], 38),
#  ([203, 204, 33, 205, 38], 206),
#  ([204, 33, 205, 38, 206], 207),
#  ([33, 205, 38, 206, 207], 208),
#  ([205, 38, 206, 207, 208], 209),
#  ([38, 206, 207, 208, 209], 210),
#  ([206, 207, 208, 209, 210], 211),
#  ([207, 208, 209, 210, 211], 94),
#  ([208, 209, 210, 211, 94], 95),
#  ([209, 210, 211, 94, 95], 212),
#  ([210, 211, 94, 95, 212], 109),
#  ([211, 94, 95, 212, 109], 213),
#  ([94, 95, 212, 109, 213], 214),
#  ([40, 215, 216, 217, 68], 95),
#  ([95, 215, 216, 217, 68], 40),
#  ([95, 40, 216, 217, 68], 215),
#  ([95, 40, 215, 217, 68], 216),
#  ([95, 40, 215, 216, 68], 217),
#  ([95, 40, 215, 216, 217], 68),
#  ([40, 215, 216, 217, 68], 218),
#  ([215, 216, 217, 68, 218], 219),
#  ([216, 217, 68, 218, 219], 220),
#  ([217, 68, 218, 219, 220], 221),
#  ([68, 218, 219, 220, 221], 222),
#  ([218, 219, 220, 221, 222], 104),
#  ([219, 220, 221, 222, 104], 49),
#  ([220, 221, 222, 104, 49], 123),
#  ([221, 222, 104, 49, 123], 40),
#  ([222, 104, 49, 123, 40], 223),
#  ([104, 49, 123, 40, 223], 224),
#  ([49, 123, 40, 223, 224], 220),
#  ([123, 40, 223, 224, 220], 40),
#  ([40, 223, 224, 220, 40], 225),
#  ([223, 224, 220, 40, 225], 226),
#  ([224, 220, 40, 225, 226], 227),
#  ([220, 40, 225, 226, 227], 38),
#  ([40, 225, 226, 227, 38], 228),
#  ([225, 226, 227, 38, 228], 224),
#  ([226, 227, 38, 228, 224], 229),
#  ([227, 38, 228, 224, 229], 230),
#  ([38, 228, 224, 229, 230], 33),
#  ([231, 68, 232, 123], 95),
#  ([95, 68, 232, 123], 231),
#  ([95, 231, 232, 123], 68),
#  ([95, 231, 68, 123], 232),
#  ([95, 231, 68, 232], 123),
#  ([234, 10, 235, 236, 68], 233),
#  ([233, 10, 235, 236, 68], 234),
#  ([233, 234, 235, 236, 68], 10),
#  ([233, 234, 10, 236, 68], 235),
#  ([233, 234, 10, 235, 68], 236),
#  ([233, 234, 10, 235, 236], 68),
#  ([234, 10, 235, 236, 68], 218),
#  ([10, 235, 236, 68, 218], 59),
#  ([235, 236, 68, 218, 59], 24),
#  ([236, 68, 218, 59, 24], 54),
#  ([68, 218, 59, 24, 54], 237),
#  ([218, 59, 24, 54, 237], 165),
#  ([59, 24, 54, 237, 165], 68),
#  ([21, 239, 240, 241, 242], 238),
#  ([238, 239, 240, 241, 242], 21),
#  ([238, 21, 240, 241, 242], 239),
#  ([238, 21, 239, 241, 242], 240),
#  ([238, 21, 239, 240, 242], 241),
#  ([238, 21, 239, 240, 241], 242),
#  ([21, 239, 240, 241, 242], 243),
#  ([239, 240, 241, 242, 243], 232),
#  ([240, 241, 242, 243, 232], 244),
#  ([241, 242, 243, 232, 244], 218),
#  ([242, 243, 232, 244, 218], 245),
#  ([243, 232, 244, 218, 245], 246),
#  ([232, 244, 218, 245, 246], 247),
#  ([244, 218, 245, 246, 247], 248),
#  ([218, 245, 246, 247, 248], 249),
#  ([245, 246, 247, 248, 249], 250),
#  ([246, 247, 248, 249, 250], 251),
#  ([247, 248, 249, 250, 251], 33),
#  ([248, 249, 250, 251, 33], 252),
#  ([249, 250, 251, 33, 252], 253),
#  ([250, 251, 33, 252, 253], 254),
#  ([251, 33, 252, 253, 254], 255),
#  ([33, 252, 253, 254, 255], 93),
#  ([252, 253, 254, 255, 93], 33),
#  ([253, 254, 255, 93, 33], 35),
#  ([254, 255, 93, 33, 35], 256),
#  ([255, 93, 33, 35, 256], 257),
#  ([93, 33, 35, 256, 257], 258),
#  ([33, 35, 256, 257, 258], 259),
#  ([35, 256, 257, 258, 259], 29),
#  ([256, 257, 258, 259, 29], 104),
#  ([257, 258, 259, 29, 104], 38),
#  ([258, 259, 29, 104, 38], 33),
#  ([259, 29, 104, 38, 33], 35),
#  ([41, 29, 42, 43, 260], 102),
#  ([102, 29, 42, 43, 260], 41),
#  ([102, 41, 42, 43, 260], 29),
#  ([102, 41, 29, 43, 260], 42),
#  ([102, 41, 29, 42, 260], 43),
#  ([102, 41, 29, 42, 43], 260),
#  ([41, 29, 42, 43, 260], 95),
#  ([29, 42, 43, 260, 95], 40),
#  ([42, 43, 260, 95, 40], 261),
#  ([43, 260, 95, 40, 261], 33),
#  ([260, 95, 40, 261, 33], 262),
#  ([95, 40, 261, 33, 262], 263),
#  ([40, 261, 33, 262, 263], 88),
#  ([261, 33, 262, 263, 88], 227),
#  ([33, 262, 263, 88, 227], 10),
#  ([262, 263, 88, 227, 10], 123),
#  ([263, 88, 227, 10, 123], 264),
#  ([88, 227, 10, 123, 264], 123),
#  ([227, 10, 123, 264, 123], 40),
#  ([10, 123, 264, 123, 40], 29),
#  ([123, 264, 123, 40, 29], 265),
#  ([264, 123, 40, 29, 265], 266),
#  ([123, 40, 29, 265, 266], 166),
#  ([40, 29, 265, 266, 166], 267),
#  ([29, 265, 266, 166, 267], 123),
#  ([265, 266, 166, 267, 123], 40),
#  ([266, 166, 267, 123, 40], 227),
#  ([28, 269, 270, 33, 271], 268),
#  ([268, 269, 270, 33, 271], 28),
#  ([268, 28, 270, 33, 271], 269),
#  ([268, 28, 269, 33, 271], 270),
#  ([268, 28, 269, 270, 271], 33),
#  ([268, 28, 269, 270, 33], 271),
#  ([28, 269, 270, 33, 271], 272),
#  ([269, 270, 33, 271, 272], 273),
#  ([270, 33, 271, 272, 273], 227),
#  ([33, 271, 272, 273, 227], 123),
#  ([43, 5, 274, 275, 201], 42),
#  ([42, 5, 274, 275, 201], 43),
#  ([42, 43, 274, 275, 201], 5),
#  ([42, 43, 5, 275, 201], 274),
#  ([42, 43, 5, 274, 201], 275),
#  ([42, 43, 5, 274, 275], 201),
#  ([43, 5, 274, 275, 201], 42),
#  ([5, 274, 275, 201, 42], 43),
#  ([274, 275, 201, 42, 43], 42),
#  ([275, 201, 42, 43, 42], 43),
#  ([201, 42, 43, 42, 43], 276),
#  ([42, 43, 42, 43, 276], 277),
#  ([43, 42, 43, 276, 277], 278),
#  ([42, 43, 276, 277, 278], 279),
#  ([43, 276, 277, 278, 279], 280),
#  ([276, 277, 278, 279, 280], 276),
#  ([277, 278, 279, 280, 276], 277),
#  ([278, 279, 280, 276, 277], 278),
#  ([279, 280, 276, 277, 278], 281),
#  ([280, 276, 277, 278, 281], 282),
#  ([276, 277, 278, 281, 282], 277),
#  ([277, 278, 281, 282, 277], 278),
#  ([278, 281, 282, 277, 278], 283),
#  ([281, 282, 277, 278, 283], 284),
#  ([282, 277, 278, 283, 284], 285),
#  ([277, 278, 283, 284, 285], 279),
#  ([278, 283, 284, 285, 279], 286),
#  ([283, 284, 285, 279, 286], 284),
#  ([284, 285, 279, 286, 284], 285),
#  ([285, 279, 286, 284, 285], 281),
#  ([279, 286, 284, 285, 281], 287),
#  ([286, 284, 285, 281, 287], 288),
#  ([284, 285, 281, 287, 288], 285),
#  ([285, 281, 287, 288, 285], 289),
#  ([281, 287, 288, 285, 289], 201),
#  ([287, 288, 285, 289, 201], 290),
#  ([288, 285, 289, 201, 290], 291),
#  ([285, 289, 201, 290, 291], 113),
#  ([289, 201, 290, 291, 113], 292),
#  ([201, 290, 291, 113, 292], 293),
#  ([290, 291, 113, 292, 293], 294),
#  ([291, 113, 292, 293, 294], 295),
#  ([113, 292, 293, 294, 295], 296),
#  ([292, 293, 294, 295, 296], 297),
#  ([293, 294, 295, 296, 297], 43),
#  ([294, 295, 296, 297, 43], 298),
#  ([295, 296, 297, 43, 298], 299),
#  ([296, 297, 43, 298, 299], 300),
#  ([297, 43, 298, 299, 300], 301),
#  ([43, 298, 299, 300, 301], 302),
#  ([298, 299, 300, 301, 302], 303),
#  ([299, 300, 301, 302, 303], 304),
#  ([300, 301, 302, 303, 304], 305),
#  ([301, 302, 303, 304, 305], 24),
#  ([302, 303, 304, 305, 24], 306),
#  ([303, 304, 305, 24, 306], 24),
#  ([304, 305, 24, 306, 24], 307),
#  ([305, 24, 306, 24, 307], 308),
#  ([24, 306, 24, 307, 308], 24),
#  ([306, 24, 307, 308, 24], 21),
#  ([24, 307, 308, 24, 21], 309),
#  ([307, 308, 24, 21, 309], 24),
#  ([308, 24, 21, 309, 24], 35),
#  ([24, 21, 309, 24, 35], 310),
#  ([21, 309, 24, 35, 310], 311),
#  ([309, 24, 35, 310, 311], 312),
#  ([24, 35, 310, 311, 312], 54),
#  ([35, 310, 311, 312, 54], 51),
#  ([310, 311, 312, 54, 51], 52),
#  ([311, 312, 54, 51, 52], 313),
#  ([312, 54, 51, 52, 313], 6),
#  ([54, 51, 52, 313, 6], 28),
#  ([51, 52, 313, 6, 28], 28),
#  ([52, 313, 6, 28, 28], 314),
#  ([313, 6, 28, 28, 314], 315),
#  ([6, 28, 28, 314, 315], 28),
#  ([28, 28, 314, 315, 28], 39),
#  ([28, 314, 315, 28, 39], 316),
#  ([314, 315, 28, 39, 316], 317),
#  ([315, 28, 39, 316, 317], 318),
#  ([28, 39, 316, 317, 318], 319),
#  ([39, 316, 317, 318, 319], 320),
#  ([316, 317, 318, 319, 320], 319),
#  ([317, 318, 319, 320, 319], 321),
#  ([318, 319, 320, 319, 321], 29),
#  ([319, 320, 319, 321, 29], 39),
#  ([320, 319, 321, 29, 39], 72),
#  ([319, 321, 29, 39, 72], 322),
#  ([321, 29, 39, 72, 322], 323),
#  ([29, 39, 72, 322, 323], 324),
#  ([39, 72, 322, 323, 324], 325),
#  ([72, 322, 323, 324, 325], 316),
#  ([322, 323, 324, 325, 316], 326),
#  ([323, 324, 325, 316, 326], 316),
#  ([324, 325, 316, 326, 316], 327),
#  ([325, 316, 326, 316, 327], 328),
#  ([316, 326, 316, 327, 328], 316),
#  ([326, 316, 327, 328, 316], 329),
#  ([316, 327, 328, 316, 329], 316),
#  ([327, 328, 316, 329, 316], 39),
#  ([328, 316, 329, 316, 39], 320),
#  ([316, 329, 316, 39, 320], 330),
#  ([329, 316, 39, 320, 330], 331),
#  ([316, 39, 320, 330, 331], 332),
#  ([39, 320, 330, 331, 332], 333),
#  ([320, 330, 331, 332, 333], 334),
#  ([330, 331, 332, 333, 334], 41),
#  ([331, 332, 333, 334, 41], 335),
#  ([332, 333, 334, 41, 335], 316),
#  ([333, 334, 41, 335, 316], 336),
#  ([334, 41, 335, 316, 336], 41),
#  ([41, 335, 316, 336, 41], 71),
#  ([335, 316, 336, 41, 71], 29),
#  ([316, 336, 41, 71, 29], 337),
#  ([336, 41, 71, 29, 337], 16),
#  ([41, 71, 29, 337, 16], 338),
#  ([71, 29, 337, 16, 338], 316),
#  ([29, 337, 16, 338, 316], 339),
#  ([337, 16, 338, 316, 339], 340),
#  ([16, 338, 316, 339, 340], 341),
#  ([338, 316, 339, 340, 341], 341),
#  ([316, 339, 340, 341, 341], 316),
#  ([339, 340, 341, 341, 316], 342),
#  ([340, 341, 341, 316, 342], 341),
#  ([341, 341, 316, 342, 341], 316),
#  ([341, 316, 342, 341, 316], 342),
#  ([316, 342, 341, 316, 342], 316),
#  ([342, 341, 316, 342, 316], 343),
#  ([341, 316, 342, 316, 343], 344),
#  ([316, 342, 316, 343, 344], 345),
#  ([342, 316, 343, 344, 345], 346),
#  ([316, 343, 344, 345, 346], 316),
#  ([343, 344, 345, 346, 316], 347),
#  ([344, 345, 346, 316, 347], 348),
#  ([345, 346, 316, 347, 348], 316),
#  ([346, 316, 347, 348, 316], 349),
#  ([316, 347, 348, 316, 349], 350),
#  ([347, 348, 316, 349, 350], 351),
#  ([348, 316, 349, 350, 351], 316),
#  ([316, 349, 350, 351, 316], 352),
#  ([349, 350, 351, 316, 352], 353),
#  ([350, 351, 316, 352, 353], 316),
#  ([351, 316, 352, 353, 316], 354),
#  ([316, 352, 353, 316, 354], 355),
#  ([352, 353, 316, 354, 355], 35),
#  ([353, 316, 354, 355, 35], 356),
#  ([316, 354, 355, 35, 356], 357),
#  ([354, 355, 35, 356, 357], 358),
#  ([355, 35, 356, 357, 358], 359),
#  ([35, 356, 357, 358, 359], 360),
#  ([356, 357, 358, 359, 360], 39),
#  ([357, 358, 359, 360, 39], 361),
#  ([358, 359, 360, 39, 361], 362),
#  ([359, 360, 39, 361, 362], 363),
#  ([360, 39, 361, 362, 363], 16),
#  ([39, 361, 362, 363, 16], 343),
#  ([361, 362, 363, 16, 343], 344),
#  ([362, 363, 16, 343, 344], 338),
#  ([363, 16, 343, 344, 338], 339),
#  ([16, 343, 344, 338, 339], 364),
#  ([343, 344, 338, 339, 364], 365),
#  ([344, 338, 339, 364, 365], 366),
#  ([338, 339, 364, 365, 366], 350),
#  ([339, 364, 365, 366, 350], 367),
#  ([364, 365, 366, 350, 367], 346),
#  ([365, 366, 350, 367, 346], 353),
#  ([366, 350, 367, 346, 353], 340),
#  ([350, 367, 346, 353, 340], 368),
#  ([367, 346, 353, 340, 368], 351),
#  ([346, 353, 340, 368, 351], 369),
#  ([353, 340, 368, 351, 369], 352),
#  ([340, 368, 351, 369, 352], 341),
#  ([368, 351, 369, 352, 341], 370),
#  ([351, 369, 352, 341, 370], 371),
#  ([369, 352, 341, 370, 371], 372),
#  ([352, 341, 370, 371, 372], 75),
#  ([341, 370, 371, 372, 75], 373),
#  ([370, 371, 372, 75, 373], 374),
#  ([371, 372, 75, 373, 374], 375),
#  ([372, 75, 373, 374, 375], 356),
#  ([75, 373, 374, 375, 356], 357),
#  ([373, 374, 375, 356, 357], 348),
#  ([374, 375, 356, 357, 348], 342),
#  ([375, 356, 357, 348, 342], 376),
#  ([356, 357, 348, 342, 376], 377),
#  ([357, 348, 342, 376, 377], 378),
#  ([348, 342, 376, 377, 378], 379),
#  ([342, 376, 377, 378, 379], 380),
#  ([376, 377, 378, 379, 380], 381),
#  ([377, 378, 379, 380, 381], 382),
#  ([378, 379, 380, 381, 382], 383),
#  ([379, 380, 381, 382, 383], 384),
#  ([380, 381, 382, 383, 384], 39),
#  ([381, 382, 383, 384, 39], 385),
#  ([382, 383, 384, 39, 385], 41),
#  ([383, 384, 39, 385, 41], 42),
#  ([384, 39, 385, 41, 42], 43),
#  ([39, 385, 41, 42, 43], 254),
#  ([385, 41, 42, 43, 254], 118),
#  ([41, 42, 43, 254, 118], 29),
#  ([42, 43, 254, 118, 29], 259),
#  ([43, 254, 118, 29, 259], 33),
#  ([254, 118, 29, 259, 33], 40),
#  ([118, 29, 259, 33, 40], 386),
#  ([388, 100, 16, 101, 103], 387),
#  ([387, 100, 16, 101, 103], 388),
#  ([387, 388, 16, 101, 103], 100),
#  ([387, 388, 100, 101, 103], 16),
#  ([387, 388, 100, 16, 103], 101),
#  ([387, 388, 100, 16, 101], 103),
#  ([388, 100, 16, 101, 103], 39),
#  ([100, 16, 101, 103, 39], 72),
#  ([16, 101, 103, 39, 72], 322),
#  ([101, 103, 39, 72, 322], 389),
#  ([103, 39, 72, 322, 389], 24),
#  ([39, 72, 322, 389, 24], 72),
#  ([72, 322, 389, 24, 72], 390),
#  ([322, 389, 24, 72, 390], 47),
#  ([389, 24, 72, 390, 47], 391),
#  ([24, 72, 390, 47, 391], 47),
#  ([16, 392, 393, 394, 395], 387),
#  ([387, 392, 393, 394, 395], 16),
#  ([387, 16, 393, 394, 395], 392),
#  ([387, 16, 392, 394, 395], 393),
#  ([387, 16, 392, 393, 395], 394),
#  ([387, 16, 392, 393, 394], 395),
#  ([16, 392, 393, 394, 395], 361),
#  ([392, 393, 394, 395, 361], 141),
#  ([393, 394, 395, 361, 141], 396),
#  ([394, 395, 361, 141, 396], 103),
#  ([395, 361, 141, 396, 103], 390),
#  ([361, 141, 396, 103, 390], 47),
#  ([141, 396, 103, 390, 47], 397),
#  ([396, 103, 390, 47, 397], 398),
#  ([103, 390, 47, 397, 398], 399),
#  ([400, 401, 50, 16, 402], 103),
#  ([103, 401, 50, 16, 402], 400),
#  ([103, 400, 50, 16, 402], 401),
#  ([103, 400, 401, 16, 402], 50),
#  ([103, 400, 401, 50, 402], 16),
#  ([103, 400, 401, 50, 16], 402),
#  ([400, 401, 50, 16, 402], 252),
#  ([401, 50, 16, 402, 252], 403),
#  ([50, 16, 402, 252, 403], 404),
#  ([16, 402, 252, 403, 404], 405),
#  ([402, 252, 403, 404, 405], 39),
#  ([252, 403, 404, 405, 39], 322),
#  ([403, 404, 405, 39, 322], 252),
#  ([404, 405, 39, 322, 252], 406),
#  ([227, 407, 408, 21], 251),
#  ([251, 407, 408, 21], 227),
#  ([251, 227, 408, 21], 407),
#  ([251, 227, 407, 21], 408),
#  ([251, 227, 407, 408], 21),
#  ([410, 365, 118, 313, 411], 409),
#  ([409, 365, 118, 313, 411], 410),
#  ([409, 410, 118, 313, 411], 365),
#  ([409, 410, 365, 313, 411], 118),
#  ([409, 410, 365, 118, 411], 313),
#  ([409, 410, 365, 118, 313], 411),
#  ([410, 365, 118, 313, 411], 412),
#  ([365, 118, 313, 411, 412], 413),
#  ([118, 313, 411, 412, 413], 414),
#  ([313, 411, 412, 413, 414], 415),
#  ([411, 412, 413, 414, 415], 416),
#  ([412, 413, 414, 415, 416], 417),
#  ([413, 414, 415, 416, 417], 346),
#  ([414, 415, 416, 417, 346], 418),
#  ([415, 416, 417, 346, 418], 404),
#  ([416, 417, 346, 418, 404], 313),
#  ([417, 346, 418, 404, 313], 16),
#  ([346, 418, 404, 313, 16], 402),
#  ([418, 404, 313, 16, 402], 235),
#  ([404, 313, 16, 402, 235], 419),
#  ([313, 16, 402, 235, 419], 413),
#  ([16, 402, 235, 419, 413], 313),
#  ([365, 420, 421, 422, 123], 410),
#  ([410, 420, 421, 422, 123], 365),
#  ([410, 365, 421, 422, 123], 420),
#  ([410, 365, 420, 422, 123], 421),
#  ([410, 365, 420, 421, 123], 422),
#  ([410, 365, 420, 421, 422], 123),
#  ([365, 420, 421, 422, 123], 47),
#  ([420, 421, 422, 123, 47], 423),
#  ([421, 422, 123, 47, 423], 16),
#  ([422, 123, 47, 423, 16], 402),
#  ([123, 47, 423, 16, 402], 424),
#  ([47, 423, 16, 402, 424], 425),
#  ([423, 16, 402, 424, 425], 234),
#  ([16, 402, 424, 425, 234], 39),
#  ([402, 424, 425, 234, 39], 40),
#  ([424, 425, 234, 39, 40], 41),
#  ([425, 234, 39, 40, 41], 426),
#  ([234, 39, 40, 41, 426], 427),
#  ([39, 40, 41, 426, 427], 428),
#  ([40, 41, 426, 427, 428], 429),
#  ([41, 426, 427, 428, 429], 219),
#  ([426, 427, 428, 429, 219], 165),
#  ([427, 428, 429, 219, 165], 123),
#  ([428, 429, 219, 165, 123], 65),
#  ([429, 219, 165, 123, 65], 430),
#  ([219, 165, 123, 65, 430], 123),
#  ([165, 123, 65, 430, 123], 431),
#  ([123, 65, 430, 123, 431], 150),
#  ([65, 430, 123, 431, 150], 432),
#  ([430, 123, 431, 150, 432], 402),
#  ([123, 431, 150, 432, 402], 205),
#  ([431, 150, 432, 402, 205], 433),
#  ([150, 432, 402, 205, 433], 434),
#  ([432, 402, 205, 433, 434], 219),
#  ([402, 205, 433, 434, 219], 220),
#  ([436, 437, 104, 53, 33], 435),
#  ([435, 437, 104, 53, 33], 436),
#  ([435, 436, 104, 53, 33], 437),
#  ([435, 436, 437, 53, 33], 104),
#  ([435, 436, 437, 104, 33], 53),
#  ([435, 436, 437, 104, 53], 33),
#  ([436, 437, 104, 53, 33], 104),
#  ([437, 104, 53, 33, 104], 438),
#  ([104, 53, 33, 104, 438], 38),
#  ([53, 33, 104, 438, 38], 262),
#  ([33, 104, 438, 38, 262], 166),
#  ([104, 438, 38, 262, 166], 267),
#  ([438, 38, 262, 166, 267], 123),
#  ([38, 262, 166, 267, 123], 65),
#  ([262, 166, 267, 123, 65], 439),
#  ([166, 267, 123, 65, 439], 440),
#  ([307, 308, 442, 299, 104], 441),
#  ([441, 308, 442, 299, 104], 307),
#  ([441, 307, 442, 299, 104], 308),
#  ([441, 307, 308, 299, 104], 442),
#  ([441, 307, 308, 442, 104], 299),
#  ([441, 307, 308, 442, 299], 104),
#  ([307, 308, 442, 299, 104], 53),
#  ([308, 442, 299, 104, 53], 77),
#  ([442, 299, 104, 53, 77], 104),
#  ([299, 104, 53, 77, 104], 308),
#  ([104, 53, 77, 104, 308], 443),
#  ([47, 104, 445, 446, 447], 444),
#  ([444, 104, 445, 446, 447], 47),
#  ([444, 47, 445, 446, 447], 104),
#  ([444, 47, 104, 446, 447], 445),
#  ([444, 47, 104, 445, 447], 446),
#  ([444, 47, 104, 445, 446], 447),
#  ([47, 104, 445, 446, 447], 28),
#  ([104, 445, 446, 447, 28], 448),
#  ([445, 446, 447, 28, 448], 111),
#  ([446, 447, 28, 448, 111], 104),
#  ([447, 28, 448, 111, 104], 176),
#  ([28, 448, 111, 104, 176], 20),
#  ([448, 111, 104, 176, 20], 123),
#  ([111, 104, 176, 20, 123], 273),
#  ([104, 176, 20, 123, 273], 449),
#  ([451, 370, 452, 4, 297], 450),
#  ([450, 370, 452, 4, 297], 451),
#  ([450, 451, 452, 4, 297], 370),
#  ([450, 451, 370, 4, 297], 452),
#  ([450, 451, 370, 452, 297], 4),
#  ([450, 451, 370, 452, 4], 297),
#  ([451, 370, 452, 4, 297], 43),
#  ([370, 452, 4, 297, 43], 235),
#  ([452, 4, 297, 43, 235], 453),
#  ([4, 297, 43, 235, 453], 68),
#  ([297, 43, 235, 453, 68], 454),
#  ([43, 235, 453, 68, 454], 455),
#  ([235, 453, 68, 454, 455], 164),
#  ([453, 68, 454, 455, 164], 456),
#  ([68, 454, 455, 164, 456], 457),
#  ([454, 455, 164, 456, 457], 47),
#  ([455, 164, 456, 457, 47], 458),
#  ([164, 456, 457, 47, 458], 103),
#  ([460, 62, 461, 65, 365], 459),
#  ([459, 62, 461, 65, 365], 460),
#  ([459, 460, 461, 65, 365], 62),
#  ([459, 460, 62, 65, 365], 461),
#  ([459, 460, 62, 461, 365], 65),
#  ([459, 460, 62, 461, 65], 365),
#  ([460, 62, 461, 65, 365], 462),
#  ([62, 461, 65, 365, 462], 463),
#  ([461, 65, 365, 462, 463], 464),
#  ([65, 365, 462, 463, 464], 465),
#  ([365, 462, 463, 464, 465], 466),
#  ([462, 463, 464, 465, 466], 467),
#  ([463, 464, 465, 466, 467], 104),
#  ([464, 465, 466, 467, 104], 265),
#  ([465, 466, 467, 104, 265], 131),
#  ([469, 275, 470, 471, 472], 468),
#  ([468, 275, 470, 471, 472], 469),
#  ([468, 469, 470, 471, 472], 275),
#  ([468, 469, 275, 471, 472], 470),
#  ([468, 469, 275, 470, 472], 471),
#  ([468, 469, 275, 470, 471], 472),
#  ([469, 275, 470, 471, 472], 143),
#  ([275, 470, 471, 472, 143], 370),
#  ([470, 471, 472, 143, 370], 473),
#  ([471, 472, 143, 370, 473], 131),
#  ([472, 143, 370, 473, 131], 122),
#  ([143, 370, 473, 131, 122], 123),
#  ([370, 473, 131, 122, 123], 458),
#  ([475, 353, 44, 122, 123], 474),
#  ([474, 353, 44, 122, 123], 475),
#  ([474, 475, 44, 122, 123], 353),
#  ([474, 475, 353, 122, 123], 44),
#  ([474, 475, 353, 44, 123], 122),
#  ([474, 475, 353, 44, 122], 123),
#  ([475, 353, 44, 122, 123], 476),
#  ([353, 44, 122, 123, 476], 473),
#  ([44, 122, 123, 476, 473], 104),
#  ([122, 123, 476, 473, 104], 131),
#  ([123, 476, 473, 104, 131], 477),
#  ([476, 473, 104, 131, 477], 478),
#  ([473, 104, 131, 477, 478], 479),
#  ([104, 131, 477, 478, 479], 370),
#  ([131, 477, 478, 479, 370], 221),
#  ([477, 478, 479, 370, 221], 480),
#  ([478, 479, 370, 221, 480], 378),
#  ([479, 370, 221, 480, 378], 481),
#  ([370, 221, 480, 378, 481], 482),
#  ([221, 480, 378, 481, 482], 265),
#  ([480, 378, 481, 482, 265], 483),
#  ([378, 481, 482, 265, 483], 123),
#  ([481, 482, 265, 483, 123], 131),
#  ([482, 265, 483, 123, 131], 6),
#  ([216, 485, 486, 487, 296], 484),
#  ([484, 485, 486, 487, 296], 216),
#  ([484, 216, 486, 487, 296], 485),
#  ([484, 216, 485, 487, 296], 486),
#  ([484, 216, 485, 486, 296], 487),
#  ([484, 216, 485, 486, 487], 296),
#  ([216, 485, 486, 487, 296], 396),
#  ([485, 486, 487, 296, 396], 488),
#  ([486, 487, 296, 396, 488], 489),
#  ([487, 296, 396, 488, 489], 490),
#  ([492, 122, 122, 493, 494], 491),
#  ([491, 122, 122, 493, 494], 492),
#  ([491, 492, 122, 493, 494], 122),
#  ([491, 492, 122, 493, 494], 122),
#  ([491, 492, 122, 122, 494], 493),
#  ([491, 492, 122, 122, 493], 494),
#  ([492, 122, 122, 493, 494], 30),
#  ([122, 122, 493, 494, 30], 436),
#  ([122, 493, 494, 30, 436], 495),
#  ([493, 494, 30, 436, 495], 496),
#  ([494, 30, 436, 495, 496], 497),
#  ([30, 436, 495, 496, 497], 498),
#  ([436, 495, 496, 497, 498], 489),
#  ([495, 496, 497, 498, 489], 490),
#  ([496, 497, 498, 489, 490], 499),
#  ([497, 498, 489, 490, 499], 489),
#  ([498, 489, 490, 499, 489], 490),
#  ([122, 123, 500, 501, 502], 185),
#  ([185, 123, 500, 501, 502], 122),
#  ([185, 122, 500, 501, 502], 123),
#  ([185, 122, 123, 501, 502], 500),
#  ([185, 122, 123, 500, 502], 501),
#  ([185, 122, 123, 500, 501], 502),
#  ([122, 123, 500, 501, 502], 503),
#  ([123, 500, 501, 502, 503], 6),
#  ([500, 501, 502, 503, 6], 504),
#  ([501, 502, 503, 6, 504], 505),
#  ([502, 503, 6, 504, 505], 506),
#  ([503, 6, 504, 505, 506], 507),
#  ([6, 504, 505, 506, 507], 473),
#  ([504, 505, 506, 507, 473], 496),
#  ([505, 506, 507, 473, 496], 508),
#  ([506, 507, 473, 496, 508], 489),
#  ([507, 473, 496, 508, 489], 490),
#  ([509, 510, 511, 313, 3], 353),
#  ([353, 510, 511, 313, 3], 509),
#  ([353, 509, 511, 313, 3], 510),
#  ([353, 509, 510, 313, 3], 511),
#  ([353, 509, 510, 511, 3], 313),
#  ([353, 509, 510, 511, 313], 3),
#  ([509, 510, 511, 313, 3], 16),
#  ([510, 511, 313, 3, 16], 402),
#  ([511, 313, 3, 16, 402], 512),
#  ([313, 3, 16, 402, 512], 3),
#  ([3, 16, 402, 512, 3], 513),
#  ([16, 402, 512, 3, 513], 21),
#  ([402, 512, 3, 513, 21], 265),
#  ([390, 247, 168, 515, 516], 514),
#  ([514, 247, 168, 515, 516], 390),
#  ([514, 390, 168, 515, 516], 247),
#  ([514, 390, 247, 515, 516], 168),
#  ([514, 390, 247, 168, 516], 515),
#  ([514, 390, 247, 168, 515], 516),
#  ([390, 247, 168, 515, 516], 515),
#  ([131, 123, 50, 517, 123], 399),
#  ([399, 123, 50, 517, 123], 131),
#  ([399, 131, 50, 517, 123], 123),
#  ([399, 131, 123, 517, 123], 50),
#  ([399, 131, 123, 50, 123], 517),
#  ([399, 131, 123, 50, 517], 123),
#  ([131, 123, 50, 517, 123], 449),
#  ([123, 50, 517, 123, 449], 515),
#  ([50, 517, 123, 449, 515], 104),
#  ([517, 123, 449, 515, 104], 5),
#  ([123, 449, 515, 104, 5], 227),
#  ([449, 515, 104, 5, 227], 123),
#  ([515, 104, 5, 227, 123], 518),
#  ([104, 5, 227, 123, 518], 21),
#  ([5, 227, 123, 518, 21], 519),
#  ([227, 123, 518, 21, 519], 131),
#  ([123, 518, 21, 519, 131], 415),
#  ([518, 21, 519, 131, 415], 16),
#  ([21, 519, 131, 415, 16], 402),
#  ([474, 39, 104, 520, 521], 274),
#  ([274, 39, 104, 520, 521], 474),
#  ([274, 474, 104, 520, 521], 39),
#  ([274, 474, 39, 520, 521], 104),
#  ([274, 474, 39, 104, 521], 520),
#  ([274, 474, 39, 104, 520], 521),
#  ([474, 39, 104, 520, 521], 6),
#  ([39, 104, 520, 521, 6], 87),
#  ([104, 520, 521, 6, 87], 522),
#  ([520, 521, 6, 87, 522], 523),
#  ([521, 6, 87, 522, 523], 192),
#  ([6, 87, 522, 523, 192], 391),
#  ([87, 522, 523, 192, 391], 524),
#  ([522, 523, 192, 391, 524], 525),
#  ([523, 192, 391, 524, 525], 62),
#  ([192, 391, 524, 525, 62], 526),
#  ([391, 524, 525, 62, 526], 527),
#  ([524, 525, 62, 526, 527], 4),
#  ([525, 62, 526, 527, 4], 41),
#  ([62, 526, 527, 4, 41], 42),
#  ([526, 527, 4, 41, 42], 43),
#  ([527, 4, 41, 42, 43], 528),
#  ([4, 41, 42, 43, 528], 459),
#  ([388, 353, 394, 529, 354], 387),
#  ([387, 353, 394, 529, 354], 388),
#  ([387, 388, 394, 529, 354], 353),
#  ([387, 388, 353, 529, 354], 394),
#  ([387, 388, 353, 394, 354], 529),
#  ([387, 388, 353, 394, 529], 354),
#  ([388, 353, 394, 529, 354], 104),
#  ([353, 394, 529, 354, 104], 530),
#  ([394, 529, 354, 104, 530], 353),
#  ([529, 354, 104, 530, 353], 316),
#  ([354, 104, 530, 353, 316], 354),
#  ([104, 530, 353, 316, 354], 531),
#  ([530, 353, 316, 354, 531], 532),
#  ([353, 316, 354, 531, 532], 533),
#  ([316, 354, 531, 532, 533], 24),
#  ([354, 531, 532, 533, 24], 534),
#  ([531, 532, 533, 24, 534], 44),
#  ([532, 533, 24, 534, 44], 443),
#  ([533, 24, 534, 44, 443], 6),
#  ([85, 535, 39, 40, 536], 532),
#  ([532, 535, 39, 40, 536], 85),
#  ([532, 85, 39, 40, 536], 535),
#  ([532, 85, 535, 40, 536], 39),
#  ([532, 85, 535, 39, 536], 40),
#  ([532, 85, 535, 39, 40], 536),
#  ([85, 535, 39, 40, 536], 522),
#  ([535, 39, 40, 536, 522], 353),
#  ([39, 40, 536, 522, 353], 354),
#  ...]

# %%
# To get embeddings for a word
word_idx = word_to_number['universe']
embedding_king = model.embeddings(torch.tensor([word_idx]))
print(embedding_king)

# To get embeddings for a word
word_idx = word_to_number['gravity']
embedding_boy = model.embeddings(torch.tensor([word_idx]))
print(embedding_boy)

embeding_king_minus_boy = embedding_king - embedding_boy
# Out:
# tensor([[-6.9142,  0.8498, -7.3056, -0.8535,  7.2863]],
#        grad_fn=<EmbeddingBackward0>)
# tensor([[-4.8458,  3.3936,  0.8506, -1.7958,  3.2913]],
#        grad_fn=<EmbeddingBackward0>)

# %%
import torch

def find_closest_word(embedding, embeddings_matrix, idx2word):
    """
    Find the closest word for a given embedding.
    
    Args:
    - embedding (torch.Tensor): The embedding vector.
    - embeddings_matrix (torch.Tensor): Matrix of embeddings from the model.
    - idx2word (dict): Dictionary mapping indices to words.
    
    Returns:
    - str: The closest word to the given embedding.
    """
    # Compute distances between the given embedding and all embeddings in the matrix
    distances = torch.norm(embeddings_matrix - embedding, dim=1)
    # Find the index of the minimum distance
    closest_idx = torch.argmin(distances).item()
    # Return the word corresponding to the closest index
    return idx2word[closest_idx]

# %%
# To get embeddings for a word
# Example usage
word1 = 'star'
word2 = 'heavy'

print(f"word1 = {word1} <> word2 = {word2}")

word_idx = word_to_number[word1]
embedding_one = model.embeddings(torch.tensor([word_idx]))
#print(embedding_one)

# To get embeddings for a word
word_idx = word_to_number[word2]
embedding_two = model.embeddings(torch.tensor([word_idx]))
#print(embedding_two)

embeding_plus = embedding_one + embedding_two
embeding_minus = embedding_one - embedding_two

# Assuming embeddings_matrix is obtained from your model's embedding layer
embeddings_matrix = model.embeddings.weight.detach()
# Find the closest word to the 'king' embedding
closest_word = find_closest_word(embeding_plus, embeddings_matrix, number_to_word)
print(f"The closest word to 'embeding_plus' is: {closest_word}")

closest_word = find_closest_word(embeding_minus, embeddings_matrix, number_to_word)
print(f"The closest word to 'embeding_minus' is: {closest_word}")

def compute_cosine_similarity(model, word1, word2, word2idx):
    # Retrieve the embeddings for the two words
    idx1 = word2idx[word1]
    idx2 = word2idx[word2]
    
    embedding1 = model.embeddings(torch.tensor([idx1]))
    embedding2 = model.embeddings(torch.tensor([idx2]))
    
    # Compute cosine similarity
    similarity = torch.cosine_similarity(embedding1, embedding2)
    return similarity.item()


similarity = compute_cosine_similarity(model, word1, word2, word_to_number)
print(f"Cosine similarity between '{word1}' and '{word2}': {similarity}")
# Out:
# word1 = star <> word2 = heavy
# The closest word to 'embeding_plus' is: classical
# The closest word to 'embeding_minus' is: toward
# Cosine similarity between 'star' and 'heavy': -0.6431677341461182

# %%
{ k:v for k,v in sorted(wordCounter.items(), key=lambda x: x[1], reverse=True) }
# Out:
# {'black_hole': 323,
#  'mass': 78,
#  'star': 77,
#  'object': 65,
#  'horizon': 55,
#  'event': 54,
#  'gravitational': 51,
#  'would': 47,
#  's': 39,
#  'light': 37,
#  'collapse': 37,
#  'form': 34,
#  'time': 32,
#  'general': 32,
#  'm': 32,
#  'supermassive': 31,
#  'theory': 30,
#  'quantum': 30,
#  'radiation': 30,
#  '–': 30,
#  ':': 29,
#  'relativity': 28,
#  'gravity': 27,
#  'schwarzschild': 26,
#  'solution': 26,
#  'matter': 26,
#  'ray': 26,
#  'singularity': 25,
#  'field': 24,
#  'first': 23,
#  'way': 22,
#  'emit': 22,
#  'possible': 22,
#  'observation': 22,
#  'one': 22,
#  'radius': 22,
#  'information': 22,
#  'energy': 21,
#  'accretion': 21,
#  'orbit': 21,
#  'particle': 21,
#  'effect': 20,
#  'also': 20,
#  'process': 20,
#  'charge': 20,
#  '2': 20,
#  'spacetime': 19,
#  '☉': 19,
#  '10': 19,
#  'galaxy': 18,
#  'disk': 18,
#  'could': 18,
#  'however': 18,
#  'observer': 18,
#  'x': 18,
#  'away': 18,
#  'use': 17,
#  'see': 17,
#  'einstein': 17,
#  'temperature': 17,
#  '*': 17,
#  'entropy': 17,
#  'escape': 16,
#  'predict': 16,
#  'hawking': 16,
#  'system': 16,
#  'photon': 16,
#  'like': 15,
#  'stellar': 15,
#  'find': 15,
#  'show': 15,
#  'neutron': 15,
#  'candidate': 15,
#  'density': 15,
#  'hawk': 15,
#  'expect': 15,
#  'image': 14,
#  'around': 14,
#  'observe': 14,
#  'compact': 14,
#  'know': 14,
#  'centre': 14,
#  'a': 14,
#  'far': 14,
#  'result': 14,
#  'rotate': 14,
#  'angular': 14,
#  'momentum': 14,
#  'appear': 14,
#  'sphere': 14,
#  'wave': 13,
#  'call': 13,
#  'body': 13,
#  'universe': 13,
#  'describe': 13,
#  'high': 13,
#  'law': 13,
#  'cause': 13,
#  'strong': 12,
#  'may': 12,
#  'sagittarius': 12,
#  'early': 12,
#  'property': 12,
#  'allow': 12,
#  'existence': 12,
#  'much': 12,
#  'outside': 12,
#  'limit': 12,
#  'small': 12,
#  'since': 12,
#  'direct': 11,
#  'many': 11,
#  'make': 11,
#  'fall': 11,
#  'binary': 11,
#  'even': 11,
#  'surface': 11,
#  'kerr': 11,
#  'take': 11,
#  'think': 11,
#  'model': 11,
#  'year': 11,
#  'near': 11,
#  'article': 11,
#  'formation': 11,
#  'c': 11,
#  'evaporate': 11,
#  'boundary': 10,
#  'region': 10,
#  'feature': 10,
#  'black': 10,
#  'massive': 10,
#  'become': 10,
#  'principle': 10,
#  'large': 10,
#  'stable': 10,
#  'suggest': 10,
#  'main': 10,
#  'less': 10,
#  'material': 10,
#  'long': 9,
#  'theoretical': 9,
#  'gas': 9,
#  'g': 9,
#  'displaystyle': 9,
#  'oppenheimer': 9,
#  'physics': 9,
#  'two': 9,
#  'thermodynamic': 9,
#  'total': 9,
#  'due': 9,
#  'signal': 9,
#  'evidence': 9,
#  'masse': 8,
#  'determine': 8,
#  'milky': 8,
#  'speed': 8,
#  'note': 8,
#  'non': 8,
#  '+': 8,
#  '=': 8,
#  'state': 8,
#  'galactic': 8,
#  '1': 8,
#  'emission': 8,
#  'value': 8,
#  'example': 8,
#  'loss': 8,
#  'paradox': 8,
#  'move': 8,
#  'occur': 8,
#  'case': 8,
#  'volume': 8,
#  'must': 8,
#  'include': 7,
#  'great': 7,
#  'cross': 7,
#  'proportional': 7,
#  'grow': 7,
#  'solar': 7,
#  'exist': 7,
#  'close': 7,
#  'source': 7,
#  'might': 7,
#  'dark': 7,
#  'view': 7,
#  'slow': 7,
#  'stop': 7,
#  'lense': 7,
#  'equation': 7,
#  'motion': 7,
#  'term': 7,
#  'physical': 7,
#  'possibility': 7,
#  'produce': 7,
#  'another': 7,
#  'infalle': 7,
#  'provide': 7,
#  'parameter': 7,
#  'lead': 7,
#  'area': 7,
#  '[': 7,
#  ']': 7,
#  'lose': 7,
#  '—': 7,
#  'eventually': 7,
#  'create': 7,
#  'approach': 7,
#  'second': 7,
#  'thus': 7,
#  'ergosphere': 7,
#  'active': 7,
#  'low': 7,
#  'observational': 7,
#  'm87': 7,
#  'eht': 7,
#  'enough': 6,
#  'accord': 6,
#  'directly': 6,
#  'michell': 6,
#  'space': 6,
#  'presence': 6,
#  'visible': 6,
#  'alternative': 6,
#  'contain': 6,
#  'big': 6,
#  'sun': 6,
#  'leave': 6,
#  'newman': 6,
#  'penrose': 6,
#  'spherical': 6,
#  'give': 6,
#  'infinite': 6,
#  'coordinate': 6,
#  'although': 6,
#  'earth': 6,
#  'merger': 6,
#  'condition': 6,
#  'electric': 6,
#  'frac': 6,
#  'spin': 6,
#  '3': 6,
#  'r': 6,
#  'path': 6,
#  'within': 6,
#  'reach': 6,
#  'classical': 6,
#  'generally': 6,
#  'circular': 6,
#  'depend': 6,
#  'nucleus': 6,
#  'mechanic': 6,
#  'planck': 6,
#  'constant': 6,
#  '/': 6,
#  'radio': 5,
#  'pass': 5,
#  'electromagnetic': 5,
#  'spectrum': 5,
#  'order': 5,
#  'impossible': 5,
#  'publish': 5,
#  'prediction': 5,
#  'surrounding': 5,
#  'million': 5,
#  'friction': 5,
#  'quasar': 5,
#  'bright': 5,
#  'astronomer': 5,
#  'propose': 5,
#  'assume': 5,
#  'exceed': 5,
#  'nature': 5,
#  'never': 5,
#  'line': 5,
#  'problem': 5,
#  'eddington': 5,
#  'point': 5,
#  'singular': 5,
#  'mean': 5,
#  'km': 5,
#  'force': 5,
#  'metric': 5,
#  'rotating': 5,
#  'mechanism': 5,
#  'prove': 5,
#  'direction': 5,
#  'commonly': 5,
#  'bekenstein': 5,
#  'imply': 5,
#  'ligo': 5,
#  'april': 5,
#  'therefore': 5,
#  'inside': 5,
#  'different': 5,
#  'go': 5,
#  'number': 5,
#  'j': 5,
#  '≤': 5,
#  'hence': 5,
#  '6': 5,
#  '5': 5,
#  'size': 5,
#  'whether': 5,
#  'finite': 5,
#  'without': 5,
#  'carry': 5,
#  'perturbation': 5,
#  'either': 5,
#  'still': 5,
#  'jet': 5,
#  'central': 5,
#  'bang': 5,
#  'exotic': 5,
#  'remnant': 5,
#  'amount': 5,
#  'primordial': 5,
#  'creation': 5,
#  'dense': 5,
#  'datum': 5,
#  'disc': 5,
#  'well': 5,
#  'study': 5,
#  'companion': 5,
#  'ngc': 5,
#  '^': 5,
#  'messier': 4,
#  '87': 4,
#  'john': 4,
#  'finkelstein': 4,
#  '1960': 4,
#  'work': 4,
#  'discovery': 4,
#  'cygnus': 4,
#  'x1': 4,
#  'identify': 4,
#  'end': 4,
#  'absorb': 4,
#  'merge': 4,
#  'infer': 4,
#  'external': 4,
#  'calculation': 4,
#  'refer': 4,
#  'influence': 4,
#  'instead': 4,
#  'equivalence': 4,
#  'red': 4,
#  'shift': 4,
#  'frame': 4,
#  'snyder': 4,
#  'wheeler': 4,
#  'chandrasekhar': 4,
#  'month': 4,
#  'understand': 4,
#  'original': 4,
#  'estimate': 4,
#  'attempt': 4,
#  'stationary': 4,
#  'research': 4,
#  'type': 4,
#  'period': 4,
#  'theorem': 4,
#  'three': 4,
#  'situation': 4,
#  'particular': 4,
#  'discover': 4,
#  'detection': 4,
#  'telescope': 4,
#  'physicist': 4,
#  'science': 4,
#  'report': 4,
#  'measure': 4,
#  'along': 4,
#  'q': 4,
#  '4': 4,
#  'cosmic': 4,
#  'rotation': 4,
#  'intermediate': 4,
#  'k': 4,
#  'inward': 4,
#  'lie': 4,
#  'ring': 4,
#  'zero': 4,
#  'hypothetical': 4,
#  'extremely': 4,
#  'remain': 4,
#  'relativistic': 4,
#  'test': 4,
#  'decrease': 4,
#  'continue': 4,
#  'heavy': 4,
#  'various': 4,
#  'release': 4,
#  'scale': 4,
#  'detect': 4,
#  'frequency': 4,
#  'accrete': 4,
#  'string': 4,
#  'unitarity': 4,
#  'entangle': 4,
#  'outgoing': 4,
#  'core': 3,
#  'simulation': 3,
#  'behind': 3,
#  'nothing': 3,
#  'deform': 3,
#  'detectable': 3,
#  'inversely': 3,
#  'consider': 3,
#  'century': 3,
#  'karl': 3,
#  'modern': 3,
#  'david': 3,
#  'generic': 3,
#  '1967': 3,
#  'gravitationally': 3,
#  'astrophysical': 3,
#  'reality': 3,
#  'several': 3,
#  'independently': 3,
#  'via': 3,
#  'cloud': 3,
#  'location': 3,
#  'exclude': 3,
#  'history': 3,
#  'astronomical': 3,
#  'november': 3,
#  'diameter': 3,
#  'invisible': 3,
#  'back': 3,
#  'curve': 3,
#  'μ': 3,
#  'ν': 3,
#  'nu': 3,
#  'formulation': 3,
#  'special': 3,
#  'dilation': 3,
#  'drag': 3,
#  'reissner': 3,
#  'nordström': 3,
#  'lemaître': 3,
#  'dust': 3,
#  'later': 3,
#  'student': 3,
#  'behaviour': 3,
#  'possibly': 3,
#  'certain': 3,
#  'argument': 3,
#  'correct': 3,
#  'base': 3,
#  'shortly': 3,
#  'publication': 3,
#  'membrane': 3,
#  'extend': 3,
#  'future': 3,
#  'complete': 3,
#  'rapidly': 3,
#  'hair': 3,
#  'hold': 3,
#  'receive': 3,
#  'accept': 3,
#  '1974': 3,
#  '11': 3,
#  'follow': 3,
#  '2017': 3,
#  'though': 3,
#  'phenomenon': 3,
#  'enter': 3,
#  'date': 3,
#  'january': 3,
#  'structure': 3,
#  'achieve': 3,
#  'independent': 3,
#  'conjecture': 3,
#  'true': 3,
#  'currently': 3,
#  'shape': 3,
#  'avoid': 3,
#  'every': 3,
#  'distance': 3,
#  'satisfy': 3,
#  'inequality': 3,
#  'violate': 3,
#  'relatively': 3,
#  'nearly': 3,
#  'class': 3,
#  'micro': 3,
#  'set': 3,
#  'start': 3,
#  'towards': 3,
#  'typically': 3,
#  'happen': 3,
#  'normally': 3,
#  'single': 3,
#  'sometimes': 3,
#  'outward': 3,
#  'spiral': 3,
#  'surround': 3,
#  'magnetic': 3,
#  'innermost': 3,
#  'increase': 3,
#  'question': 3,
#  'require': 3,
#  'pressure': 3,
#  'insufficient': 3,
#  'additional': 3,
#  'rate': 3,
#  'apply': 3,
#  'collision': 3,
#  'growth': 3,
#  'similar': 3,
#  'cluster': 3,
#  'background': 3,
#  'shrink': 3,
#  'weak': 3,
#  'search': 3,
#  'observatory': 3,
#  'edge': 3,
#  'shadow': 3,
#  'perspective': 3,
#  '2015': 3,
#  'ringdown': 3,
#  'mode': 3,
#  'orbital': 3,
#  'strongly': 3,
#  'part': 3,
#  'inner': 3,
#  'quasi': 3,
#  'periodic': 3,
#  'oscillation': 3,
#  'explain': 3,
#  'microlensing': 3,
#  'assumption': 3,
#  'quark': 3,
#  'correction': 3,
#  'violation': 3,
#  'susskind': 3,
#  'cone': 3,
#  'tilt': 3,
#  'extreme': 2,
#  'lensing': 2,
#  'act': 2,
#  'moreover': 2,
#  '1916': 2,
#  '1958': 2,
#  'interpretation': 2,
#  'mathematical': 2,
#  'curiosity': 2,
#  'jocelyn': 2,
#  'bell': 2,
#  'burnell': 2,
#  'interest': 2,
#  'researcher': 2,
#  '1971': 2,
#  'life': 2,
#  'interaction': 2,
#  'heat': 2,
#  'swallow': 2,
#  'briefly': 2,
#  'letter': 2,
#  'conclude': 2,
#  'velocity': 2,
#  'stars': 2,
#  'hide': 2,
#  'rather': 2,
#  'notion': 2,
#  'free': 2,
#  'travel': 2,
#  'g_mu': 2,
#  'timeline': 2,
#  'fundamental': 2,
#  'world': 2,
#  'equations': 2,
#  'formalisms': 2,
#  'post': 2,
#  'newtonian': 2,
#  'gödel': 2,
#  'de': 2,
#  'sitter': 2,
#  'tolman': 2,
#  'taub': 2,
#  'milne': 2,
#  'robertson': 2,
#  'walker': 2,
#  'van': 2,
#  'stockum': 2,
#  'lorentz': 2,
#  'bardeen': 2,
#  '1915': 2,
#  'develop': 2,
#  'peculiar': 2,
#  'arthur': 2,
#  'disappear': 2,
#  'change': 2,
#  'rule': 2,
#  'gravitation': 2,
#  'spectral': 2,
#  'curvature': 2,
#  'contemporary': 2,
#  'argue': 2,
#  'yet': 2,
#  'white': 2,
#  'slightly': 2,
#  '1939': 2,
#  'robert': 2,
#  'present': 2,
#  'likely': 2,
#  '0.7': 2,
#  'raise': 2,
#  'approximately': 2,
#  '1.5': 2,
#  'refine': 2,
#  'indicate': 2,
#  'symmetry': 2,
#  'consist': 2,
#  'paper': 2,
#  'reference': 2,
#  'recent': 2,
#  'golden': 2,
#  'age': 2,
#  'perfect': 2,
#  'extension': 2,
#  'already': 2,
#  'kruskal': 2,
#  'beginning': 2,
#  'subject': 2,
#  'pulsar': 2,
#  '1963': 2,
#  'carter': 2,
#  'emerge': 2,
#  'completely': 2,
#  'pathological': 2,
#  'artifact': 2,
#  'technique': 2,
#  'half': 2,
#  '1970': 2,
#  '1964': 2,
#  'analogy': 2,
#  'radiate': 2,
#  'collaboration': 2,
#  'virgo': 2,
#  'represent': 2,
#  '2019': 2,
#  'vicinity': 2,
#  '2023': 2,
#  'hundred': 2,
#  'trace': 2,
#  'reportedly': 2,
#  'compare': 2,
#  'black_holes': 2,
#  'phrase': 2,
#  'quickly': 2,
#  'catch': 2,
#  'real': 2,
#  'unsolved': 2,
#  'similarly': 2,
#  'distribution': 2,
#  'behavior': 2,
#  'microscopic': 2,
#  'initial': 2,
#  'little': 2,
#  'quantity': 2,
#  'conserve': 2,
#  'lepton': 2,
#  'puzzle': 2,
#  'simple': 2,
#  'static': 2,
#  'often': 2,
#  '0': 2,
#  'minimum': 2,
#  'extremal': 2,
#  'possess': 2,
#  'deem': 2,
#  'numerical': 2,
#  'maximum': 2,
#  'approx': 2,
#  '9': 2,
#  'au': 2,
#  '≈': 2,
#  'moon': 2,
#  '2.95': 2,
#  'r_mathrm': 2,
#  'gmc^2': 2,
#  'define': 2,
#  'appearance': 2,
#  'bend': 2,
#  'deformation': 2,
#  'distant': 2,
#  'clock': 2,
#  'tick': 2,
#  'slowly': 2,
#  'dimmer': 2,
#  'redshift': 2,
#  'fade': 2,
#  'local': 2,
#  'topology': 2,
#  'always': 2,
#  'geometry': 2,
#  'apart': 2,
#  'destroy': 2,
#  'survive': 2,
#  'proper': 2,
#  'treatment': 2,
#  'perceive': 2,
#  'breakdown': 2,
#  'instability': 2,
#  'trajectory': 2,
#  'stand': 2,
#  'tend': 2,
#  'fast': 2,
#  'pole': 2,
#  'extra': 2,
#  'thereby': 2,
#  'luminosity': 2,
#  'stably': 2,
#  'evolution': 2,
#  'actually': 2,
#  'community': 2,
#  'majority': 2,
#  'demonstrate': 2,
#  'need': 2,
#  'internal': 2,
#  'prevent': 2,
#  'degeneracy': 2,
#  'seed': 2,
#  'young': 2,
#  '7': 2,
#  'current': 2,
#  'widely': 2,
#  'thousand': 2,
#  'attraction': 2,
#  'inflation': 2,
#  'balance': 2,
#  'theoretically': 2,
#  'put': 2,
#  'development': 2,
#  'scenario': 2,
#  '1xa0tev/': 2,
#  'interstellar': 2,
#  'open': 2,
#  'important': 2,
#  'evaporation': 2,
#  'thermal': 2,
#  'display': 2,
#  '2.7xa0': 2,
#  'microwave': 2,
#  'hypothetically': 2,
#  'gamma': 2,
#  'flash': 2,
#  'perhaps': 2,
#  '14': 2,
#  'rely': 2,
#  'four': 2,
#  '2022': 2,
#  'complex': 2,
#  'brightening': 2,
#  'configuration': 2,
#  'plausible': 2,
#  'dominant': 2,
#  'match': 2,
#  '1995': 2,
#  'able': 2,
#  '×': 2,
#  'full': 2,
#  'upper': 2,
#  'conservation': 2,
#  'accompany': 2,
#  'ordinary': 2,
#  'obtain': 2,
#  'link': 2,
#  'unusual': 2,
#  'agn': 2,
#  'hole': 2,
#  'deflect': 2,
#  'isolated': 2,
#  'phase': 2,
#  'supersymmetric': 2,
#  'preon': 2,
#  'average': 2,
#  'fail': 2,
#  'semi': 2,
#  'statistical': 2,
#  'identically': 2,
#  'formula': 2,
#  'unit': 2,
#  'seemingly': 2,
#  'leonard': 2,
#  'holographic': 2,
#  'perform': 2,
#  'count': 2,
#  'forever': 2,
#  'resolve': 2,
#  'complementarity': 2,
#  'firewall': 2,
#  'past': 2,
#  'fully': 2,
#  'list': 2,
#  '−': 2,
#  '': 1,
#  'return': 1,
#  'animated': 1,
#  'alignment': 1,
#  'sufficiently': 1,
#  'fate': 1,
#  'circumstance': 1,
#  'locally': 1,
#  'ideal': 1,
#  'reflect': 1,
#  'curved': 1,
#  'billionth': 1,
#  'kelvin': 1,
#  'essentially': 1,
#  'whose': 1,
#  '18th': 1,
#  'pierre': 1,
#  'simon': 1,
#  'laplace': 1,
#  'characterize': 1,
#  'spark': 1,
#  'cycle': 1,
#  'consensus': 1,
#  'toward': 1,
#  'shred': 1,
#  'streamer': 1,
#  'shine': 1,
#  'brightly': 1,
#  'numerous': 1,
#  'establish': 1,
#  '4.3xa0million': 1,
#  'idea': 1,
#  'english': 1,
#  'pioneer': 1,
#  'clergyman': 1,
#  '1784': 1,
#  'simplistic': 1,
#  'factor': 1,
#  '500': 1,
#  'usual': 1,
#  'correctly': 1,
#  'radiating': 1,
#  'nearby': 1,
#  'scholar': 1,
#  'initially': 1,
#  'excite': 1,
#  'proposal': 1,
#  'giant': 1,
#  'plain': 1,
#  'enthusiasm': 1,
#  'dampen': 1,
#  'wavelike': 1,
#  'apparent': 1,
#  'nineteenth': 1,
#  'unclear': 1,
#  'discredit': 1,
#  'shoot': 1,
#  'geodesic': 1,
#  'λ': 1,
#  'κ': 1,
#  'lambda': 1,
#  'kappa': 1,
#  't_mu': 1,
#  'introduction': 1,
#  'tests': 1,
#  'concept': 1,
#  'pseudo': 1,
#  'riemannian': 1,
#  'manifold': 1,
#  'phenomena': 1,
#  'kepler': 1,
#  'geodetic': 1,
#  'diagram': 1,
#  'minkowski': 1,
#  'rosen': 1,
#  'bridge': 1,
#  'linearized': 1,
#  'friedmann': 1,
#  'geodesics': 1,
#  'mathisson': 1,
#  'papapetrou': 1,
#  'dixon': 1,
#  'hamilton': 1,
#  'jacobi': 1,
#  'adm': 1,
#  'bssn': 1,
#  'advanced': 1,
#  'kaluza': 1,
#  'klein': 1,
#  'solutions': 1,
#  'kasner': 1,
#  'nut': 1,
#  'pp': 1,
#  'weyl−lewis−papapetrou': 1,
#  'scientists': 1,
#  'hilbert': 1,
#  'poincaré': 1,
#  'weyl': 1,
#  'friedman': 1,
#  'zwicky': 1,
#  'ehlers': 1,
#  'raychaudhuri': 1,
#  'taylor': 1,
#  'hulse': 1,
#  'yau': 1,
#  'thorne': 1,
#  'portal': 1,
#  'category': 1,
#  'v': 1,
#  'e': 1,
#  'albert': 1,
#  'johannes': 1,
#  'droste': 1,
#  'hendrik': 1,
#  'write': 1,
#  'extensively': 1,
#  'quite': 1,
#  '1924': 1,
#  '1933': 1,
#  'georges': 1,
#  'realize': 1,
#  'comment': 1,
#  'compress': 1,
#  '1926': 1,
#  'book': 1,
#  'overly': 1,
#  'betelgeuse': 1,
#  '250': 1,
#  'firstly': 1,
#  'unable': 1,
#  'stone': 1,
#  'secondly': 1,
#  'thirdly': 1,
#  '1931': 1,
#  'subrahmanyan': 1,
#  'calculate': 1,
#  'electron': 1,
#  'degenerate': 1,
#  'limiting': 1,
#  'oppose': 1,
#  'lev': 1,
#  'landau': 1,
#  'unknown': 1,
#  'partly': 1,
#  'dwarf': 1,
#  'reason': 1,
#  'intervene': 1,
#  'least': 1,
#  'pauli': 1,
#  'exclusion': 1,
#  'subsequent': 1,
#  'consideration': 1,
#  'repulsion': 1,
#  'mediate': 1,
#  '3.0': 1,
#  'gw170817': 1,
#  'generate': 1,
#  'afterward': 1,
#  'tov': 1,
#  '~2.17': 1,
#  'co': 1,
#  'author': 1,
#  'interpret': 1,
#  'bubble': 1,
#  'valid': 1,
#  'frozen': 1,
#  'freeze': 1,
#  'instant': 1,
#  'gravitating': 1,
#  'masses': 1,
#  'defend': 1,
#  'hartland': 1,
#  'continued': 1,
#  'contraction': 1,
#  'unidirectional': 1,
#  'causal': 1,
#  'strictly': 1,
#  'contradict': 1,
#  'martin': 1,
#  'urge': 1,
#  'come': 1,
#  'mark': 1,
#  'mainstream': 1,
#  'help': 1,
#  '1969': 1,
#  'regard': 1,
#  'relevance': 1,
#  'spur': 1,
#  'roy': 1,
#  'exact': 1,
#  'ezra': 1,
#  'axisymmetric': 1,
#  'electrically': 1,
#  'werner': 1,
#  'israel': 1,
#  'brandon': 1,
#  'robinson': 1,
#  'suspect': 1,
#  'strange': 1,
#  'impose': 1,
#  'vladimir': 1,
#  'belinsky': 1,
#  ...}

# %%
sorted_dict = {k: v for k, v in sorted(counterToDict.items(), key=lambda item: item[1], reverse=False)}

# %%
train_data[40:70]
# Out:
# [(['1960', 'theoretical', 'work', 'generic'], 'show'),
#  (['1960', 'theoretical', 'work', 'show'], 'generic'),
#  (['theoretical', 'work', 'show', 'generic'], 'prediction'),
#  (['work', 'show', 'generic', 'prediction'], 'general'),
#  (['show', 'generic', 'prediction', 'general'], 'relativity'),
#  (['black', 'hole', 'know', 'cygnus'], 'first'),
#  (['first', 'hole', 'know', 'cygnus'], 'black'),
#  (['first', 'black', 'know', 'cygnus'], 'hole'),
#  (['first', 'black', 'hole', 'cygnus'], 'know'),
#  (['first', 'black', 'hole', 'know'], 'cygnus'),
#  (['black', 'hole', 'know', 'cygnus'], 'x'),
#  (['hole', 'know', 'cygnus', 'x'], '1'),
#  (['know', 'cygnus', 'x', '1'], 'identify'),
#  (['cygnus', 'x', '1', 'identify'], 'several'),
#  (['x', '1', 'identify', 'several'], 'researcher'),
#  (['1', 'identify', 'several', 'researcher'], 'independently'),
#  (['identify', 'several', 'researcher', 'independently'], '1971'),
#  (['hole', 'form', 'grow', 'absorb'], 'black'),
#  (['black', 'form', 'grow', 'absorb'], 'hole'),
#  (['black', 'hole', 'grow', 'absorb'], 'form'),
#  (['black', 'hole', 'form', 'absorb'], 'grow'),
#  (['black', 'hole', 'form', 'grow'], 'absorb'),
#  (['hole', 'form', 'grow', 'absorb'], 'mass'),
#  (['form', 'grow', 'absorb', 'mass'], 'surrounding'),
#  (['black', 'hole', 'million', 'solar'], 'supermassive'),
#  (['supermassive', 'hole', 'million', 'solar'], 'black'),
#  (['supermassive', 'black', 'million', 'solar'], 'hole'),
#  (['supermassive', 'black', 'hole', 'solar'], 'million'),
#  (['supermassive', 'black', 'hole', 'million'], 'solar'),
#  (['black', 'hole', 'million', 'solar'], 'masse')]
